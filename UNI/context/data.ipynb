# %%
import json
import pandas as pd
import numpy as np
from pathlib import Path
import collections


from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
# path = "../error_category_classification/dbdc5_ja_dev_labeled/"
path = "../hand_labeled/"
datalist = ['DCM', 'DIT', 'IRS']

output = "./"

# %%
def read_json_with_NoErr(path:str, datalist:list) -> pd.DataFrame:
    cols = ['did', 'tid', 'usr', 'sys', 'ec']
    df = pd.DataFrame(index=[], columns=cols)

    for p in datalist:
        datapath = Path(path + p + '/')
        for file in datapath.glob("*.json"):
            with open(file, "r") as f:
                json_data = json.load(f)
                did = json_data["did"]
                for t in json_data["turns"]:
                    if t["turn-index"] == 0:
                        continue
                    if t["speaker"] == "U":
                        usr = t["utterance"]
                        continue
                    if t["speaker"] == "S" :
                        tid = t["turn-index"]
                        sys = t["utterance"]
                        if t["error_category"]:
                            ec = t["error_category"]
                        else:
                            ec = ["No-Err"]
                        df = df.append(pd.DataFrame([did, tid, usr, sys, ec], index = cols).T)
    df.reset_index(inplace=True, drop=True)
    return df

# %%
def extract_error(df, errors):
    utterances = []
    for d, u, s, e in zip(df.did, df.usr, df.sys, df.ec):
        for err in errors:
            if err in e:
                utterances.append([u, s])
    return utterances

# %%
def no_error(df):
    utterances = []
    system = []
    user = []
    for d, u, s, e in zip(df.did, df.usr, df.sys, df.ec):
        if e[0] == "No-Err":
            utterances.append([ u, s])
        # system.append(s)
        # user.append(u)
    return utterances

# %%
df = read_json_with_NoErr(path, datalist)

# %%
df
# Out:
#              did tid                   usr  \
# 0     1470646494   2    そうですね。最近とても暑いですから。
# 1     1470646494   4         休日に行きたいと思います。
# 2     1470646494   6       はい。あなたは海に行きますか？
# 3     1470646494   8                何故ですか？
# 4     1470646494  10  そうですか。山に行くのはどうでしょうか？
# ...          ...  ..                   ...
# 1995  1503290726  12           何を別売りしているの？
# 1996  1503290726  14            今は2回押してないよ
# 1997  1503290726  16              ベーシックだよね
# 1998  1503290726  18              君は女性なんだね
# 1999  1503290726  20                 両性なのか
#
#                                            sys  \
# 0                                  海に行かないんですね？
# 1                                     海は大丈夫ですね
# 2                                       海は危険です
# 3                                     海はいけないです
# 4                                    わあ！いいですね！
# ...                                        ...
# 1995           地下鉄で。名大前ができてすごく便利になりましたね、ここの大学。
# 1996  紅葉も遅いみたいですしね。私は、いつもベーッシクな色で変わりばえしないのですが。
# 1997     何処にあるお店ですか？ベースコートもトップコートも塗ると持ちが違いますよ。
# 1998                                    中間ですか？
# 1999                          では、スポーツは何かしてますか？
#
#                                          ec
# 0                           [Contradiction]
# 1                     [Lack of information]
# 2     [Ignore question, Self-contradiction]
# 3                         [Ignore question]
# 4                                  [No-Err]
# ...                                     ...
# 1995                           [Repetition]
# 1996               [Topic transition error]
# 1997               [Topic transition error]
# 1998                  [Lack of information]
# 1999               [Topic transition error]
#
# [2000 rows x 5 columns]

# %%
errors = ["Topic transition error", "Unclear intention", "Lack of information"]
errors = ["Lack of information"]
errors = ["Topic transition error"]

# %%
ut = extract_error(df, errors)

# %%
ut_no = no_error(df)

# %%
print(len(ut))
print(len(ut_no))
print(ut_no[0])
# Out:
# 192
# 651
# ['そうですか。山に行くのはどうでしょうか？', 'わあ！いいですね！']

# %%
import spacy
nlp = spacy.load('ja_ginza')
vec_dim = nlp("形態素").vector.shape
vec_dim
# Out:
# (300,)

# %%
from pyknp import Juman
from sentence_transformers import SentenceTransformer
import scipy.spatial
model_path = "/home/yamada/Downloads/training_bert_japanese"
Nmodel = SentenceTransformer(model_path, show_progress_bar=False)
emb_dim = Nmodel.encode(["お辞儀をしている男性会社員"])[0].shape[0]

# %%
def _in(arg1, arg2):
    result = False
    if isinstance(arg1, list):
        for element in arg1:
            if isinstance(element, str):
                if element in arg2:
                    result = True
                    break
            else:
                if element == arg2:
                    result = True
                    break
    else:
        if isinstance(arg1, str):
            if arg1 in arg2:
                result = True
        else:
            if arg1 == arg2:
                result = True
    return result

# %%
def filter_pos_vector(pos_list, text):
    vec = np.zeros(vec_dim)
    doc = nlp(text, disable=['ner'])
    for token in doc:
        # print(token, token.tag_)
        if "助動詞" not in token.tag_ and _in(pos_list, token.tag_):
            # print(token, token.tag_)
            vec += token.vector
    return vec

# %%
def feature_extraction(pos_list, convs, mode, is_norm=False):
    feature_list = []
    for utt in convs:

        if mode == "dif":
            vector = Nmodel.encode(utt)
            # usr_vec = filter_pos_vector(pos_list, utt[0] )
            usr_vec = vector[0]
            # sys_vec = filter_pos_vector(pos_list, utt[1] )
            sys_vec = vector[1]
            dif_vec = usr_vec - sys_vec
            # if np.linalg.norm(dif_vec)==0:
            #     print(utt)
            if is_norm:
                # print(np.linalg.norm(dif_vec))
                if np.linalg.norm(dif_vec)==0:
                    vec = np.concatenate( [dif_vec, dif_vec/0.05] )
                else:
                    vec = np.concatenate( [dif_vec, dif_vec/np.linalg.norm(dif_vec)] )
                feature_list.append(vec)
            else:
                feature_list.append(dif_vec)
    
    return np.array(feature_list, dtype="float32")

# %%
def remove_norm_zero(pos_list, convs):
    convs_removed = []
    for utt in convs:
        usr_vec = filter_pos_vector(pos_list, utt[0] )
        sys_vec = filter_pos_vector(pos_list, utt[1] )
        dif_vec = usr_vec - sys_vec
        if np.linalg.norm(dif_vec)==0 or np.linalg.norm(usr_vec)==0 or np.linalg.norm(sys_vec)==0:
            continue
        convs_removed.append(utt)
    return convs_removed

# %%
pos_list = ["名詞", "動詞", "形状詞", "形容詞"]
ut_new = remove_norm_zero(pos_list, ut)
ut_no_new = remove_norm_zero(pos_list, ut_no)

# %%
import random
def fake_error(convs, times):
    user_list = []
    system_list = []
    for utt in convs:
        user_list.append(utt[0])
        system_list.append(utt[1])
    
    fake_convs = []
    for _ in range(times):
        fake_convs.append( [random.choice(user_list), random.choice(system_list)] )
    return fake_convs

# %%
fake_error(ut_no_new, len(ut_no_new)-len(ut_new))
# Out:
# [['私は洋楽が好きなんです', '女王の読みは、「じょうおう」ではなく「じょおう」が公式の読み方らしいよ。'],
#  ['私は今も時々スキーに行きますよ。',
#   '私の場合、カミングアウトバラエティ秘密のケンミンSHOWが好きなので、それをイメージして竹田城跡にとても興味を持ちました。'],
#  ['割りと好きなものが多く、嫌いなものは少ないですよ。ただエビアレルギーなので困っていますが。', '音楽は好きですか？'],
#  ['君は病気してないかい？', '正しいにほんの言葉を使うことが求められているよね。'],
#  ['そうなんです。色んなものがトッピングされていてとてもかわいいし、見た目だけじゃなくておいしいです。',
#   '何かペットを飼っていますか？飼っていましたか？'],
#  ['そうだね。でも美味しいから食べちゃうよね。', 'ですなっ、おやすみんちですぅ\u3000\u3000\u3000'],
#  ['お好きな食べ物は何ですか？',
#   '4、5年前にユニバーサル・スタジオ・ジャパンに一度行った事があり、Ban汗ブロックロールオンに乗った事を覚えています。あとは大きなジョーズのオブジェの前で写真を撮りました。'],
#  ['確かに気をつけて泳がないといけませんね',
#   '東京ディズニーランドのカピターノ・ミッキー・トリプルルームでは、ロズにどのようなことを話しかけられるのでしょうか？ 。'],
#  ['こんにちは、千原ジュニアですね。', 'いいえ、健康です。'],
#  ['青い空が最高だね', '私が住んでいる横浜では、JTBを見かけません。'],
#  ['チョコレートです。あなたの好きな食べ物はなんですか？', 'そば湯にそば粉を足してるのかな？'],
#  ['他にはスポーツをしたことはありますか？',
#   '最近は色々な動物がいるカフェがありますが、神戸にある8b DOLCEではインコ味のアイスクリームが売っているのをご存知ですか？ 。'],
#  ['温泉に行きます。貴方は？', '湖は美しいですね'],
#  ['暑いですよね、毎日ー', '科学の進歩は、目を見張るものがあるよね。'],
#  ['あまりミスチルの曲を知らないんです。あなたは何が好きですか？', '晴れか雨かで、その日の気分が決まることがあるよね。'],
#  ['私もそう思います', 'はい、でもまだ興味にとどまっています。'],
#  ['夏は海だよね', '新作には、あの二台のロボット、また出てくるかなあ。'],
#  ['暖かくなってきましたね', '節約もやり出すと結構楽しかったりするんだよね。'],
#  ['九州に旅行に行きます。', '気持ちがいいですね'],
#  ['大人の味ってほろ苦いというイメージですかね。', 'ご想像にお任せします。'],
#  ['興味のないことでもよく見たり覚えたりしないとだめですね。', 'イタリア、フランス、イギリス、香港くらいです。'],
#  ['そうですね。あなたの趣味は何ですか？', 'へぇ！日本のアニメは世界的に人気が高いみたいですもんね。'],
#  ['貴重なものですね',
#   '宮部みゆきは「ぼんくら」シリーズがとても好きです。10月からはテレビドラマ化もされるようなので、ファンとしては少し楽しみでもあり不安でもあります。'],
#  ['宮崎は自然が豊かだからね', 'へぇ！日本のアニメは世界的に人気が高いみたいですもんね。'],
#  ['晴れた日にいきたいですよね', 'ラーメンはスープが美味しいですね'],
#  ['水分補給、こまめにしてるよ。', '腰をいたわりますよねえ'],
#  ['糖度がね。値段も高いよ。', '天気がいいとそれだけで元気が出ちゃうよね。'],
#  ['こんばんは。今日は暑かったですね。',
#   '俳優の山田孝之さんが主演されている、日本コカ・コーラの缶コーヒー振り子のテレビコマーシャルのラーメン編は、ずっと頑なだった表情が最後に笑み崩れるのがとても面白かったです。'],
#  ['あなたも寝ることはあるんですか？', 'そうなんですか。昔の曲の方が好きです。'],
#  ['もう一度いいますよ、リンゴ', '防水、カッティング、エントリー、いろいろあるよね。'],
#  ['私も大好きなんです。', 'ワールドカップでは、ブラジル代表には破れましたが、ユルゲン・クロップの活躍でチリ代表も素晴らしい戦いをしましたね。'],
#  ['興味のないことでもよく見たり覚えたりしないとだめですね。', '東京が、世界で最も楽しい都市トップ25の内の5位に入っているとは、驚きました。'],
#  ['ニュージーランドが楽しいと思います。', '助け合いは当たり前ですよねえ'],
#  ['割りと好きなものが多く、嫌いなものは少ないですよ。ただエビアレルギーなので困っていますが。', '選挙に行くと、政治のニュースも興味深くなるよね。'],
#  ['１０回くらいで取れるかどうかですね。他にゲームセンターで好きなゲームはありますか？', '麺類は食べやすいですね'],
#  ['晴れと雨ではどちらが好きですか', '熱中症に気をつけてるんですね。エアコンは効率が悪いですね'],
#  ['そうなんです。透明度が凄く高いんです',
#   '人志松本のすべらない話というテレビ番組で、ミケランは木部さんというキャラクターに変装して一般人を騙していますね。'],
#  ['そうなんですね。ところで休日は何をしているのですか？',
#   '初代JリーグアウォーズのMVPであるカイオ・ルーカス・フェルナンデス選手も、プロデビューはミラノだったので、ポルトガルとポルトガルのサッカーの関係はとても深い物だと感じています。'],
#  ['いやいや。どんな食べ物が好きですか？', 'わあ！いいですね！'],
#  ['栗田貫一のルパンが有名ですね。', 'その人の好きなジャンルにもよってですね。'],
#  ['鍋は美味しいですよね',
#   '新しいパンのポップオーバーの専門店があるかどうか調べてみたところ、横浜のポップオーバーの専門店メルズ・ドライブインが宇治にオープンしていました。'],
#  ['家ではパソコンで映画を見たりしています。', '3姉妹は仲が良いですか'],
#  ['テレビを見たり読書をしたりして過ごすのが好きです', '九州のうまいものめぐりをしに旅行に行きたいと常日頃から思ってるんだよ。'],
#  ['勉強になりました', '気持ちがいいです'],
#  ['こんにちは。最近はサイクリングにはまっています。', '女王の読みは、「じょうおう」ではなく「じょおう」が公式の読み方らしいよ。'],
#  ['特にしてません。日々のストレッチ程度ですね。',
#   '私の「今年のときめき」は、友人達と、恩納村のフォレストアドベンチャーという施設に行ったのですが、そこでの体験にはとてもワクワクしました。'],
#  ['ミステリー小説が多いです', '新作には、あの二台のロボット、また出てくるかなあ。'],
#  ['こんばんは。今日は暑かったですね。', '占いですか！最近は、どんな占いをしましたか？'],
#  ['見るのが好き？するのが好き？', '松坂大輔さんかジーコさんのどちらかの話題についてお話しませんか？'],
#  ['家では何をしますか？', '美味しいかき氷とお好み焼きがあって幸せでした。'],
#  ['色が綺麗だよね', '海外に出たサッカー選手たちは、技術なら日本のサッカー選手の方が上だと感じると口々に言っています。'],
#  ['ポケモンＧＯをやってみたいな。', 'ケースバイケースで柔軟に対応なんですよねー'],
#  ['懸賞だよ', '海は大好きですね'],
#  ['野球が好きなら、マツダスタジアムです。', '何かペットを飼っていますか？飼っていましたか？'],
#  ['ありがとう。野菜もたっぷり食べて、栄養をバランスよく摂りたいです。',
#   'お笑い芸人の千原ジュニアさんと甥のエピソードトークはバラエティ番組太陽の塔では定番なので、視聴者は、親戚のように千原ジュニアさんと甥の関係を知っています。'],
#  ['最近なら、この前食べた車エビが好きですね。エビ全般好きですね。', 'ズバリ鍋！！私も鍋大好きです。先日も友人ともつ鍋を食べに行きました。'],
#  ['目覚めのコーヒーが好きです。',
#   '私もどちらかというとインドア派で家でのんびり映画とか見てるのが好きなんですが、１３さんは、家でどんな風にのんびり過ごすのが好きですか？'],
#  ['へーそうなんですね。私はパンよりご飯派です。', '有名人で松坂大輔とヒロ・ハマダなら、どちらに興味がありますか？'],
#  ['どの季節が好きですか？', 'では、あなたの趣味は何ですか？'],
#  ['雨は好きですか？', '洋書でいったらTuesday\u3000with\u3000Morrieを読んで泣きそうになりました。'],
#  ['そうですか。山に行くのはどうでしょうか？', 'モカ、マウンテン、キリマンジャロ……自分のお気に入りのコーヒーがあると、カッコいいよね。'],
#  ['短距離ですか？長距離ですか？', '日本にもそのような文化が根付くと、もっと家族で旅行に行ける気がします。'],
#  ['演技が上手やもんね', 'では、好きな食べ物は何ですか？'],
#  ['温泉と言えば、大分別府がいいですね。', 'では、好きな食べ物は何ですか？'],
#  ['暇ですか？', 'サッカーの三浦知良選手がテレビで話した、北澤豪選手との話とはどのような話でしたか？。'],
#  ['カキ氷は好き？', '映画は進みます？？'],
#  ['あれ、そうでしたっけ？', 'では、好きな動物は何ですか？'],
#  ['私はアトムといいます', 'どういった音楽をお聴きになるのですか？'],
#  ['どんなものを買いますか？', '雨はだるいです'],
#  ['チャットはほとんどやりません。よくチャットやるんですか？',
#   '洋書でいったらTuesday\u3000with\u3000Morrieを読んで泣きそうになりました。'],
#  ['小学校でにっぽんと教わったので私はにっぽんですね', '鶴の子 大粒納豆の作者浦沢直樹が描いた漫画で他に読んだものはありますか？ 。'],
#  ['観光地の食べ物は高いですもんね。', '糖度は低いですね'],
#  ['いいお天気ですね', '日本にもそのような文化が根付くと、もっと家族で旅行に行ける気がします。'],
#  ['夏の北海道が良かったです', '旅行を振り返りますか'],
#  ['夏は海だよね', 'カルビーから販売しているほろにがビターチョコ味というお菓子も美味しいですよ。'],
#  ['他にはスポーツをしたことはありますか？', '続けるのは難しいですよね'],
#  ['ミステリー小説が多いです', 'どういった音楽をお聴きになるのですか？'],
#  ['そこも興味があります。食べてみたいな。', '焼いた豚と書くけど、ラーメン屋ではほとんどが煮て作るから、焼いてないんだよね。'],
#  ['私はミートソースが好きです', 'ちょっとだけ。まだ大丈夫ですけど。'],
#  ['どちらも興味ないね', 'ビーチバレーは面白いですね'],
#  ['水分を沢山とっています。', '趣味は深いですよねえ'],
#  ['確かにそうですね。私は濃厚な豚骨ラーメンが好きです。', 'よろしくお願いいたします'],
#  ['あまりしません', 'スロットがもっとも盛り上がっていた時代ですね。'],
#  ['そう思っています', '「にっぽん」と「にほん」、読み方で悩みますよね。'],
#  ['海外にはまだ行ったことないんです。',
#   '私の場合、カミングアウトバラエティ秘密のケンミンSHOWが好きなので、それをイメージして竹田城跡にとても興味を持ちました。'],
#  ['以前少し聞いたことがあります', 'う〜ん、得意というか、豚の生姜焼きとかよく作ります。'],
#  ['こんばんは。今日は暑かったですね。', 'プロ野球に疎い私でも、大阪に住んでいれば自然とメルズ・ドライブインについて詳しくなります。'],
#  ['三浦知良ですね', 'ざわちんさんの出演されたハングリー!はどのような内容でしたか？。'],
#  ['私も大好きなんです。', 'スポーツといえるかどうかわかりませんが、合気道をやってます。'],
#  ['はい。麺類は美味しいから好きです。', '何をするにしてもやりがいがあるのとないのでは気持ちが違ってくるよね。'],
#  ['フォレストアドベンチャーです。', '同じ日本でも、だいぶ気温差がありますよね。'],
#  ['東京もおすすめです', 'やっぱり枝豆ですよ！！親父臭いですよね・・あとスモークチーズなんかもよく合いますよ。'],
#  ['インターネットをしてることが多いです。', '飼ってみたら猫好きになりました'],
#  ['毎朝食べていますよ', '透明度は良いですね'],
#  ['両方楽しかったけど，シンガポールにもう一度行きたい！', 'ミランはすごいというか、卑怯ですね、あのメンバーは。'],
#  ['そうなんだ。おいしくないけど。', 'ほんとー！なんか外に行きたくなっちゃいますね、旅行とか、いいですね〜。'],
#  ['こんにちは。たまにヨガをしています。ヨガはやったことがありますが？', 'スイカは大好きですか。スイカは実が大きいですね'],
#  ['他に好きな飲み物は？', 'ところで、スイカの種って実は栄養豊富なんだそうですよ。'],
#  ['こんにちは。たまにヨガをしています。ヨガはやったことがありますが？', '予防を怠るようです'],
#  ['夏は海だよね', '神戸と言えば、チーズケーキが有名なお店が多いという印象があります。'],
#  ['神戸です。', 'そば湯はあるけど、うどん湯ってあるのかな？'],
#  ['瀬戸内に行ってみたいです。', '私がはじめて奥様は魔女を見たのは、年末に地上波で連続放送していた時でした。'],
#  ['それは知りませんでした。カップラーメンも美味しいですよね？', 'ほう、そうなんですか。'],
#  ['室内でも熱中症になるそうですね。', '次回、大阪へ行く機会があったら、海遊館に立ち寄ってポッキーでお土産を選ぼうと思います。'],
#  ['そうなりたいです', '読書はお好きなんですか？'],
#  ['たしかに、できるだけ長いことプレーしたいよねスポーツ選手って',
#   '今日は晴れだと思って傘を持っていないので、何とかこのぐらいの雨で終わってほしいです。'],
#  ['そうなんです。色んなものがトッピングされていてとてもかわいいし、見た目だけじゃなくておいしいです。', 'その人の好きなジャンルにもよってですね。'],
#  ['満を持して登場や！', '高齢者が多いですよねー'],
#  ['その試合は見てないか分からないんだけど、ネイマールの個人技はすごい。',
#   '大通会場の中にある、ジェラート専門ショップの阪神タイガースでは、厚生労働省創立100周年を記念したすみれ味のジェラートが販売されていて、厚生労働省のファンの方々にとても人気なんだそうです。'],
#  ['あれ、そうでしたっけ？', 'いえいえ'],
#  ['何年生ですか？', 'ジャズは、あんまりわかんないです…テナーサックスやってるんですよね？上手いんですか？'],
#  ['沖縄行きたいです！',
#   '私の「今年のときめき」は、友人達と、恩納村のフォレストアドベンチャーという施設に行ったのですが、そこでの体験にはとてもワクワクしました。'],
#  ['本格的ですね。', '最近は全くしません。ＭＳＮメッセンジャーでは話したりします。'],
#  ['晴れと雨ではどちらが好きですか', '旅行を振り返りますか'],
#  ['家の中で２匹飼っていますよ', 'どんな種類の猫なんですか？'],
#  ['雑種が好きですね', '熱中症に気をつけてたいですか？'],
#  ['そちらも熱中症に気を付けて下さい。', '犬だね'],
#  ['どんな音楽が好きですか？', '遠出は楽しいですね'],
#  ['塩をかけても美味しいですよ', 'すごいですね。私はあまり読書できないので。'],
#  ['楽しいからね', '国際紛争が起きてますか？'],
#  ['そうですね。退屈ですもんね。', '晴れは気持ちがいいですね'],
#  ['節約するだけとは違うんだけどね。それはただのケチだから。', 'ズバリ鍋！！私も鍋大好きです。先日も友人ともつ鍋を食べに行きました。'],
#  ['もうすぐ旅行にいくのでそれが楽しみです', '山田孝之さんと言えば、11月12日に待望のニューシングルが発売されますね。'],
#  ['年始は、旅行は行かず、帰省かな。', '予防が大切ですね'],
#  ['私はキムチが好きです。', 'ところで、スイカの種って実は栄養豊富なんだそうですよ。'],
#  ['お寺にも行きましょう。', '天気がいいとそれだけで元気が出ちゃうよね。'],
#  ['好きです', '松坂大輔さんかジーコさんのどちらかの話題についてお話しませんか？'],
#  ['お笑いの番組はよく見るよ。', '全くしないですね。どんなところが苦手ですか？'],
#  ['自分で料理を作ったりしますか？', '気持ちがいいですね'],
#  ['こんにちは、私は山田孝之の方に興味があります', '透明度が抜群にいいですね'],
#  ['そうですか、私は寝すぎてしまうことが多いですね', '打ち上げ花火は見たいんですね？お祭りは楽しいですね'],
#  ['私は洋楽が好きなんです', 'アニメもおもしろいですよね。私からの質問になってしまいますが、最近楽しみにしてる事は何ですか？'],
#  ['思いつきません。あなたのマイブームは？', '防水はいいそうです'],
#  ['スイカもいいけど、桃もうまいよ',
#   '毎日放送のなるみ・岡村の過ぎるTVという番組は欠かさずみているのですが、明け方まで生放送なので、最後まではなかなか見られないので、録画しながら見ています。'],
#  ['韓国料理で何か好きなものはありますか？',
#   '瀬戸内は、Ballad Showのキャンペーンからセックス・アンド・ザ・シティのキャンペーンで観光を強化していて、かなり他府県から評価が上がっているそうです。'],
#  ['夏にはピッタリですね！', 'リン・ユーチュンは好きで、アメリカでのサッカーワールドカップの時には涙したと言っていました。'],
#  ['髭面が好きかな', '神奈川県に住んでいますよ。'],
#  ['少子化問題が気になります。', 'お笑いはくだらないですね'],
#  ['そうですね。美しい湖に透明度は必須ですね', '今行きたいところは、ペルーにある世界遺産のマチュピチュです。'],
#  ['映画はいいですね。', 'どんな種類の猫なんですか？'],
#  ['見たことある？', '腰は痛みが走るんですよねぇ'],
#  ['シークヮーサー味より紅芋味が面白そうです', '一番栄養価の高い果物はアボガドで、ギネスにも認定されてるんだって。'],
#  ['旅行は好きですか？', 'その人の好きなジャンルにもよってですね。'],
#  ['こんにちは。いつも家では仕事をしています。', '海は大丈夫ですね'],
#  ['サイクリングが好きなんですか？',
#   '俳優の山田孝之さんが主演されている、日本コカ・コーラの缶コーヒーサイコロキャンディーのテレビコマーシャルのマニフェスト編では、いろいろな役が演じ分けられていて面白いですね。'],
#  ['音楽は気分転換にいいですね。', 'どこか出かけるんですか？'],
#  ['した方がいいのだけれど、していないんです。', '占いですか！最近は、どんな占いをしましたか？'],
#  ['趣味はいいですね', 'よろしくお願いいたします'],
#  ['趣味はなんですか？', 'いつくるかわからない恐怖感がずっとあるのも嫌ですね。'],
#  ['私は浅田次郎の小説が好きです', '犬は頭がいいですね'],
#  ['鍋は美味しいですよね', 'どんな本を読みますか？'],
#  ['皇居の周りを散歩しました', '犬だね'],
#  ['鍋は美味しいですよね', '運動神経については自分も自信がありませんが、趣味はどのようなものをされているのですか？'],
#  ['そのコマーシャルは見た気がします。', 'ご想像にお任せします。'],
#  ['そうですね。あなたはどの季節が好きですか？', 'どんな種類の猫なんですか？'],
#  ['一緒に遊ぼう！', '野菜でヘルシーよねー'],
#  ['旅行良いですね。私は最近沖縄に行きましたよ。', '歴史ものはいいですよね。歴史上の人物はだれが好きですか？'],
#  ['うちでは猫と犬を一緒に飼っています。', '尾道駅近くにレンタサイクルがあって、そこで自転車を借りて走り、因島大橋などを渡ってきました。'],
#  ['今度の選挙は投票率が高いといいね。', 'ありあけハーバーはとても便利そうですね。近所にcafe坂の下があれば、私もぜひ利用してみたいです。'],
#  ['サイクリングが好きなんですか？', 'もつ鍋ですかー。私はキムチ鍋しましたよ！'],
#  ['知らないユニットです。', 'シアトルに行きました。ロスは来年の１月に行く予定なんですよ。'],
#  ['家の中で２匹飼っていますよ', 'ミートソースは好きですか。子供から大人まで好きな食べ物だね。'],
#  ['いろいろ出来て本当にすごい人ですよね', 'レイザーラモンRGさんか長谷部誠さんのどちらかの話題についてお話しませんか？'],
#  ['私もよく写真を撮ります', '「にっぽん」と「にほん」、読み方で悩みますよね。'],
#  ['何が好きになったんでしょう。私はコーヒーが飲めるようになりましたよ。',
#   'あぁ！分かります分かります！やっぱり社会人になると違ってみえるんですよね。'],
#  ['大切です。食中毒もあるしね。', '何がですか？'],
#  ['犬のどこが好きですか', '晴れた日にいきたいんですね？気持ちがえいですけどねぇ'],
#  ['コブクロと言えば、絢香とのコラボの曲が好きです。',
#   'ナゴヤドームの名古屋には、味噌カツの他に、名古屋名物の唐揚げ手羽先や味噌煮込みうどんや天むす など美味しい食べ物がいっぱいあるんでしょね。'],
#  ['行ったことないので沖縄です。', 'お気に入りのパン屋さんがあると、買い物も楽しくなるよね。'],
#  ['それは興味がありますね。', '扇風機を併用するんですね。エアコンは欲しいですね'],
#  ['あなたはどんな音楽が好きですか？', 'だからかけたことはないですね。'],
#  ['何か話題ある', 'ジャズは、あんまりわかんないです…テナーサックスやってるんですよね？上手いんですか？'],
#  ['山田孝之かな', '焦点はいいですね'],
#  ['そちらも熱中症に気を付けて下さい。', '最近は全然していませんが、基本的には好きですよ。'],
#  ['たまにメールで参加しますよ。', '熱中症に気をつけてたいですか？'],
#  ['何年生ですか？', '歯ごたえが良いですね'],
#  ['奥様は魔女って、昔、そういうドラマがありましたね。ご存じですか？', '泳ぐを繰り返しますよねー'],
#  ['あなたをなんと呼べば良いですか？', '腰をいたわりますよねえ'],
#  ['これからはしばらく暑くなりますね。', '遠藤保仁選手や、長友佑都選手、呂比須ワグナー選手、吉田麻也選手などのブログは時々チェックします。'],
#  ['そうですね、海外旅行に行った時なんかは危険が多いのでいろいろ考えながらケースバイケースに対応しますね。',
#   '四季劇場日生劇場で上演中のミュージカル、森永ミルクキャラメルが11月16日に関西最長ロングランを達成したそうです。11月16日時点での通算公演回数は699回との事です。'],
#  ['そうですね。日本のサッカーもだんだん強くなっていますから、ワールドカップでもいい順位が狙えそうですね。',
#   'サッカーのクリスティアーノ・ロナウド選手でさえも、周囲との連携がうまく働かないと得点できないというのは、やはりブラジルワールドカップで浮き彫りになりましたが、チリのサッカー選手では決定的に得点を決められる選手がいないという事ですよね。'],
#  ['どんな話する？', '熱中症は大丈夫か？？'],
#  ['お寺にも行きましょう。', '天気はサイコーですね'],
#  ['好きな食べ物はなんですか？', 'エゾシカを見ましたね'],
#  ['マンゴーが有名ですよね', '関西方面へ行かれることがありましたら。ぜひ関西のメロンパンの皮焼いちゃいましたをご覧になってみてください。'],
#  ['明日はとても暑くなるみたいですね。',
#   'ユニバーサル・スタジオ・ジャパンでも、ウィザーディング・ワールド・オブ・ハリー・ポッターエリアのニンテンドー3DSのコマーシャルが流れているのには驚きました。'],
#  ['そこも興味があります。食べてみたいな。', '誰かの役に立っていると思えば、興味のない仕事でもおもしろくなるものですよ。'],
#  ['本栖湖なんて本当に綺麗ですよ', 'よろしくお願いいたします'],
#  ['その試合は見てないか分からないんだけど、ネイマールの個人技はすごい。', 'う〜ん、得意というか、豚の生姜焼きとかよく作ります。'],
#  ['その試合は見てないか分からないんだけど、ネイマールの個人技はすごい。',
#   '国営滝野すずらん丘陵公園と国営備北丘陵公園なら、どちらが楽しいでしょうか？'],
#  ['よく知りませんが、空き家が増えているのでそうやって再利用するのは良いですよね。', '気持ちがいいですね'],
#  ['ああ。周りの女子の話か。そう？', '飼ってみたら猫好きになりました'],
#  ['他にはスポーツをしたことはありますか？',
#   '大阪にある海遊館の元気やという名前のハンバーガー店では、値段設定が高めな分、本格的な味わいのハンバーガーが楽しめるかもしれませんね。'],
#  ['そんな番組があるのですね。', 'そば湯はあるけど、うどん湯ってあるのかな？'],
#  ['もうすぐ旅行にいくのでそれが楽しみです', '初めて発売されたのは１９７１年で、最初は間食用だったんだよ。'],
#  ['食べに行ったり、温泉行ったりします。', 'ケースバイケースに対応できてるのですか？'],
#  ['スペインはワインが美味しいのですか？', '熱中症に気をつけてたいですか？'],
#  ['猫は飼っていますよ。あなたはどうですか？', '対策はいいですね'],
#  ['スイカは大好きだよ。', 'お金に余裕があれば、外に出て遊んでいんますよ。'],
#  ['好きな食べ物はありますか？', 'う〜ん、得意というか、豚の生姜焼きとかよく作ります。'],
#  ['それなら最高の場所ですね。', '日本にもそのような文化が根付くと、もっと家族で旅行に行ける気がします。'],
#  ['いつもパソコンをしていますね。', 'お天気の良さはどうですか？'],
#  ['すごい。行ってみたい。',
#   '俳優の山田孝之さんが主演されている、日本コカ・コーラの缶コーヒーサイコロキャンディーのテレビコマーシャルのマニフェスト編では、いろいろな役が演じ分けられていて面白いですね。'],
#  ['食べたら感想を聞かせてね。', 'すかをつかんでますよ'],
#  ['そうですね。横浜は近いですから。', 'う〜ん、得意というか、豚の生姜焼きとかよく作ります。'],
#  ['バレーの経験ならあるよ', 'いやぁ、それが朝起きたらもうすでに終わっちゃってるんです。'],
#  ['髭面が好きかな',
#   'ざわちんさんのものまねメイクに似たようなことを、以前板野友美さんが、「ホンマでっか！？TV」 という本のなかでしていましたが、それはかなりお笑い寄りだったので、一般人が取り入れようという感じではなかったですしね。'],
#  ['明日はとても暑くなるみたいですね。', '「にっぽん」と「にほん」、読み方で悩みますよね。'],
#  ['勉強になりました', 'カルビーじゃがりこが好きで良く食べるので、一度電子レンジで温めて食べてみたいと思います。'],
#  ['好きな映画はありますか？',
#   'サッカーのクリスティアーノ・ロナウド選手でさえも、周囲との連携がうまく働かないと得点できないというのは、やはりブラジルワールドカップで浮き彫りになりましたが、チリのサッカー選手では決定的に得点を決められる選手がいないという事ですよね。'],
#  ['ちょっと高いかもしれませんね。値段に見合うものならいいですが。', 'どんな本を読みますか？'],
#  ['目覚めのコーヒーが好きです。', '特にないんです。すみません。強いていうなら映画鑑賞とかでしょうか。'],
#  ['大変そうですね。他に好きなスポーツはありますか?', '調べてみたのですが、JTBの馬事公苑は馬と親しむための施設なのですね。'],
#  ['海水浴は楽しいですよね', 'う〜ん、得意というか、豚の生姜焼きとかよく作ります。'],
#  ['どの選手が選ばれるか楽しみですね。', 'ゴーヤチャンプルは好きですね'],
#  ['今度食事にでも行きたいですね。', '予防を怠るようです'],
#  ['節約するだけとは違うんだけどね。それはただのケチだから。', 'では、最近のマイブームは何ですか？'],
#  ['山田孝之かな', 'いいですね！'],
#  ['勉強になりました', 'チャットとかはやったりするんですか？'],
#  ['雨がずっと降らないと困るけど', '朝の気分は、その日一日を左右するよね。'],
#  ['味噌カツいいですね。私も大好きです', '次回、大阪へ行く機会があったら、海遊館に立ち寄ってポッキーでお土産を選ぼうと思います。'],
#  ['私もそう思います。', '予防が大切ですね'],
#  ['私もそう思います。', '美味しいですけど、近年は値上がりしていて辛いですね。'],
#  ['自分は四季劇場かな？', '同じ日本でも、だいぶ気温差がありますよね。'],
#  ['雨の日は静かなので眠いですね。', '予防は大切ですね'],
#  ['こんにちは。今日はいい天気ですね。', 'ロックは好きですか'],
#  ['好きな映画はありますか？', '想像ができないです。私はパソコンを触るのさえあまり得意ではないので作ってしまうことが不思議というか、すごすぎて。'],
#  ['何だか不思議ですね', 'いいですね'],
#  ['天気予報が外れたみたいですね。', '遠出は楽しいですね'],
#  ['犬のどこが好きですか', '最近はさっぱりですね。'],
#  ['サスペンスが好きです', '遠出は楽しいですね'],
#  ['スポーツ観戦です。あなたの趣味は？', '劇団四季が2015年5月24日から上演予定の新作のミュージカルはアラジンだそうです。'],
#  ['そのミステリ、私も読んでみたいです。',
#   '神戸のメロンパンの皮〜焼いちゃいました〜が食べられるお店は予約しないと待ち時間がすごいほどの人気だそうですね。'],
#  ['ウナギのかば焼きが好きです。', '音楽は好きですか？'],
#  ['サスペンスが好きです', '材料費にお金をかけたいですよねえ'],
#  ['まあね。数字が嫌いな人には向いてないと思うけど。', 'どんな本を読みますか？'],
#  ['私は浅田次郎の小説が好きです', 'ここは暑いですね。'],
#  ['毎朝食べていますよ',
#   '色々あって難しいところですが、最近だと我が名は海師・王様の仕立屋・コンシェルジュなどが気に入ったので１巻からまとめ買いしたところです。'],
#  ['気をつけていますよ。水分を多めに摂っています。',
#   '御菓子御殿の本拠地ナゴヤドームでは、名古屋名物を扱う店が充実していて、味噌カツなどが人気だそうです。'],
#  ['趣味はありますか？', 'ここは暑いですね。'],
#  ['知らないユニットです。', '天気がいいとそれだけで元気が出ちゃうよね。'],
#  ['その通り。基本です。',
#   '神戸にある、GREEN CAFE STYLE・ 茶乃逢やニトリ、阪神タイガースというチーズケーキのお店で販売されているチーズケーキを食べたことはありますか？ 。'],
#  ['いや、一週間前に言ったよ',
#   '新しいパンのポップオーバーの専門店があるかどうか調べてみたところ、横浜のポップオーバーの専門店メルズ・ドライブインが宇治にオープンしていました。'],
#  ['山田孝之かな', 'そうですね。結果だけ聞くよりもどうなるかワクワクしながら観る方が面白いと思います。'],
#  ['今度は韓国ですね。', 'そうします'],
#  ['テナーサックスはやっていませんよ', '打ち上げ花火は見たいんですね？お祭りは楽しいですね'],
#  ['毎日知りたいとは思いませんね。', 'いつもはしないんだけど'],
#  ['そうなんだ、今度買ってみます。', 'そうですか！私は苦手です。。。冬服は重いし高い。'],
#  ['最近はまってることは読書です', 'この前は定番のキムチ鍋をやりましたよ！今日は豆乳鍋をやろうかと思ってます。'],
#  ['スポーツ観戦です。あなたの趣味は？', 'みーとぅーです。'],
#  ['一緒に遊ぼう！',
#   'ナゴヤドームの名古屋には、味噌カツの他に、名古屋名物の唐揚げ手羽先や味噌煮込みうどんや天むす など美味しい食べ物がいっぱいあるんでしょね。'],
#  ['私も２回、旅しましたよ', 'そうですか！私は苦手です。。。冬服は重いし高い。'],
#  ['それは知りませんでした。カップラーメンも美味しいですよね？', 'チャットとかはやったりするんですか？'],
#  ['１つの職業にスポットを当てた漫画ですか、面白そうですね', '好き嫌いは、あまりないですね。'],
#  ['特にしてません。日々のストレッチ程度ですね。', 'すかをつかんでますよ'],
#  ['こんにちは。最近はサイクリングにはまっています。', '犬はかわいいですよ。'],
#  ['暇ですか？', '国内で死者が出てるんですかね？'],
#  ['色が綺麗だよね', '早く寝るほうがいいと思います。夜中に見ると、止まらなくなりますよ。'],
#  ['今度は韓国ですね。', '熱中症に気をつけてるんですね。熱中症に気をつけか？？'],
#  ['すごいですね。得意な料理とかありますか？', '熱中症に気をつけてたいですか？'],
#  ['した方がいいのだけれど、していないんです。', '神戸と言えば、チーズケーキが有名なお店が多いという印象があります。'],
#  ['アメリカに行きたい',
#   '田中マルクス闘莉王選手は、これまで誰よりもミラノのサッカーに貢献してきたのに、ワールドカップに一度も出場した経験がないというのが、とても寂しいですね。'],
#  ['小さい頃は入ってましたが、今は皆成人しているので', '好きな食べ物は、蕎麦かな。'],
#  ['セブンイレブン知ってるんだね。', 'あと、噂に聞いてましたが、やっぱり何もかも"デカイ"ですね。'],
#  ['自分は四季劇場かな？',
#   'ぜひ一度滝野スノーワールドのありあけハーバーに行きたいと思っていますが、私が住んでいる国営滝野すずらん丘陵公園からは遠いのでなかなか行けるチャンスがありません。'],
#  ['サイクリングが好きなんですか？', '麺類は食べやすいですね'],
#  ['忙しくなりそうですね。専攻は？', 'メディア科学です。そちらは？'],
#  ['国際紛争のニュースが一番気になります。',
#   '私が住んでいる東京地方ではなかなかポップコーンの専門店は見かけないので、東京ディズニーランドに遊びに行った時に話題のポップコーンのお店をいろいろ回ってみたいです。'],
#  ['水分補給、こまめにしてるよ。',
#   '神戸にある、GREEN CAFE STYLE・ 茶乃逢やニトリ、阪神タイガースというチーズケーキのお店で販売されているチーズケーキを食べたことはありますか？ 。'],
#  ['そうだね。分かる分かる！', 'ぜひ行って下さい！安いしデートにも最適！'],
#  ['セブンイレブン知ってるんだね。', '映画いいですね。最近自分が趣味を持ってないことに気づいてなにか見つけようと思ってるところです。'],
#  ['どっきりが好きならYouTubeの動画もおすすめだよ。', 'みーとぅーです。'],
#  ['いいお天気ですね', 'テレビドラマのホタルノヒカリを見て以来、俳優の篠原涼子さんの大ファンです。'],
#  ['こんにちは。よろしくお願いします。', '尾道駅近くにレンタサイクルがあって、そこで自転車を借りて走り、因島大橋などを渡ってきました。'],
#  ['そこも興味があります。食べてみたいな。', '熱中症に気をつけてるんですね。エアコンは効率が悪いですね'],
#  ['何が好きになったんでしょう。私はコーヒーが飲めるようになりましたよ。',
#   'やはり、沖縄のシュノーケリングでは海の浅い場所よりも深い場所のほうが、よりカラフルで鮮やかな魚を観察できたように思えます。'],
#  ['ミュージカルは行ったことはないですね。', '九州のうまいものめぐりをしに旅行に行きたいと常日頃から思ってるんだよ。'],
#  ['本は読まれますか？', '防水、カッティング、エントリー、いろいろあるよね。'],
#  ['そうなんだ。おいしくないけど。', 'ゲームですか．いいですね・'],
#  ['今彼女がいないんで、私も是非上げたいです。', '3姉妹は仲が良いですか'],
#  ['他に好きな飲み物は？', 'いいですねー。名古屋市内なら本山にある大勝軒とか吹上にある好来道場っていう店がおすすめですね。'],
#  ['こんにちは。今日はいい天気ですね。', '劇団四季が2015年5月24日から上演予定の新作のミュージカルはアラジンだそうです。'],
#  ['買物はたいてい家族と一緒だね。', 'みーとぅーです。'],
#  ['インターネットをしてることが多いです。', '結構好きですよ。そんなに行く機会はないですけど。'],
#  ['誰？それ', 'ざわちんさんの出演されたハングリー!はどのような内容でしたか？。'],
#  ['暑いですよね、毎日ー', 'インターネットは便利ですね'],
#  ['ユーのマイブームはなに？', '熱中症に気をつけてるんですね。熱中症に気をつけか？？'],
#  ['猫は好きですか？', 'いえいえ'],
#  ['竹田城跡', '将来どんな展開になるのか楽しみです。'],
#  ['東京もおすすめです', 'ケースバイケースに対応できてるのですか？'],
#  ['どの選手が選ばれるか楽しみですね。',
#   '日本語で考えて、英語で話していると相手にはどうも伝わりにくいようですので、英単語を並べたほうがまだ伝わるようですよ。'],
#  ['ニュージーランドが楽しいと思います。', 'お遍路の逆回りは迷いやすくて大変なぶん、ご利益が大きいらしいよ。'],
#  ['好きな鍋は何ですか', 'ハーブとか育てて料理に入れたりしたいですね。'],
#  ['どっきりが好きならYouTubeの動画もおすすめだよ。', 'SNSを見ますよねえ'],
#  ['忙しくなりそうですね。専攻は？', '読書は楽しいですね'],
#  ['海いいですね！大好きです。', '特にないんです。すみません。強いていうなら映画鑑賞とかでしょうか。'],
#  ['そうだね。エントリーっていうのがちょっとよくわからないけど。', '出演する俳優さんで観るか決めたりしますよ。'],
#  ['自分で料理を作ったりしますか？', 'おやすみ'],
#  ['個性は大事ですね。', '科学の進歩は、目を見張るものがあるよね。'],
#  ['夜中に地震が起きたらパニックになるかも', 'マンゴーは甘酸っぱいですよねー'],
#  ['どんな食べ物にも合いますね', '最近はさっぱりですね。'],
#  ['地震怖いよね', '尾道駅近くにレンタサイクルがあって、そこで自転車を借りて走り、因島大橋などを渡ってきました。'],
#  ['こんにちは。よろしくお願いします。', '「にっぽん」と「にほん」、読み方で悩みますよね。'],
#  ['こんにちは、千原ジュニアですね。', 'いいですねー。'],
#  ['青い空が最高だね', '最近は全くしません。ＭＳＮメッセンジャーでは話したりします。'],
#  ['相性が良いだろうね。', 'いいですね。うちの犬も柴犬に見てもらいたいですね。'],
#  ['これから買い物に行って決めます。',
#   '神戸のメロンパンの皮〜焼いちゃいました〜が食べられるお店は予約しないと待ち時間がすごいほどの人気だそうですね。'],
#  ['奥様は魔女って、昔、そういうドラマがありましたね。ご存じですか？', 'ほうほう。バンド系よりもデジタルな音楽は私もすきです。'],
#  ['こんにちは。少しお話ししましょう。', 'アナと雪の女王が「2014年ヒット商品ベスト30」の中では、やはりフローズン・フィーバーだと思います。'],
#  ['飲み過ぎました', '熱中症に気をつけてたいですか？'],
#  ['それは賢明だね。エコは大事だよ。', '波が怖いです'],
#  ['体に良さそうですね', '熱中症に気をつけてるんですね。エアコンは効率が悪いですね'],
#  ['ブラジルがサッカーで金メダルとったし。', '熱中症で死者が出る予定です'],
#  ['占いというのは下らないね', '海はいんですか？？海は楽しいですね'],
#  ['旅行良いですね。私は最近沖縄に行きましたよ。', 'いいえ、健康です。'],
#  ['室内でも熱中症になるそうですね。',
#   '俳優の山田孝之さんが主演されている、映画版のオールザッツ漫才には、ゲストにどのような役者が出演していましたか？ 。'],
#  ['大切です。食中毒もあるしね。', '海は大丈夫ですね'],
#  ['整理整頓は大事です', '海は大丈夫ですね'],
#  ['まあネコなんて、そんなもんですよね。', '熱中症に気をつけか？？'],
#  ['ミステリーですね', 'すかをつかんでますよ'],
#  ['雨の日は静かなので眠いですね。',
#   'ユニバーサル・スタジオ・ジャパンでも、ウィザーディング・ワールド・オブ・ハリー・ポッターエリアのニンテンドー3DSのコマーシャルが流れているのには驚きました。'],
#  ['ポケモンＧＯをやってみたいな。', 'どういった音楽をお聴きになるのですか？'],
#  ['スポーツ観戦です。あなたの趣味は？', 'ケースバイケースに対応できてるのですか？'],
#  ['有名なお店なんですね。仕事でも利用できそうなお店ですね。',
#   'ユニバーサル・スタジオ・ジャパンでも、ウィザーディング・ワールド・オブ・ハリー・ポッターエリアのニンテンドー3DSのコマーシャルが流れているのには驚きました。'],
#  ['歌手の方ですね。スーザンボイルも歌が上手ですね。', '渋いですね。大人の味という気がします。'],
#  ['こんにちは。今日はいい天気ですね。', '透明度は良いですね'],
#  ['旅行はすきですか？', '私が好きなマンガは結構マイナーなんで…有名どころで行くと、ハンター・ハンターとかツバサなんかはオススメです。'],
#  ['たしかに、できるだけ長いことプレーしたいよねスポーツ選手って', 'そうですか！私は苦手です。。。冬服は重いし高い。'],
#  ['君はお酒飲むのかい？', '想像ができないです。私はパソコンを触るのさえあまり得意ではないので作ってしまうことが不思議というか、すごすぎて。'],
#  ['篠原涼子さんは色気が凄いですね。', '熱中症に気をつけてるんですね。エアコンは効率が悪いですね'],
#  ['竹田城跡', 'エゾシカを見ましたね'],
#  ['その試合は見てないか分からないんだけど、ネイマールの個人技はすごい。',
#   '映画いいですね。最近自分が趣味を持ってないことに気づいてなにか見つけようと思ってるところです。'],
#  ['九州に旅行に行きます。', '旅行は準備が楽しいですね'],
#  ['飲み過ぎました', 'ですなっ、おやすみんちですぅ\u3000\u3000\u3000'],
#  ['今度私も買っていこう', '日本にもそのような文化が根付くと、もっと家族で旅行に行ける気がします。'],
#  ['あなたをなんと呼べば良いですか？', 'お金に余裕があれば、外に出て遊んでいんますよ。'],
#  ['コブクロいいですねー私はゆずが好きです', '一度でいいから、明石家さんまさんと新幹線の席で近くになって、会話ができればといいなと思っています。'],
#  ['決勝も見てますよ。', '日本では身体を使ったものを指すけど、本来思考力や計算力もスポーツに含まれるよ。'],
#  ['晴れと雨ではどちらが好きですか', '透明度は良いですね'],
#  ['何かスポーツをするのは、どうですか？', 'お好み焼き？！いいですねぇー。関西風ですか？!'],
#  ['そうなんだ。おいしくないけど。', '厚生労働省は日本のメーカーですか？ 。'],
#  ['スイカは大好きだよ。', 'おはよーございまーす'],
#  ['どちらも興味ないね',
#   'やはり辛いのですか。以前見た本場、韓国のキムチ作りを取り上げた番組で、韓国のおばちゃんは白菜を洗濯機で洗う荒技を披露していましたが、考えてみれば日本の電動餅つき器もかなり異質なマシーンですね。'],
#  ['私もよく写真を撮ります', 'ビーチバレーは面白いですね'],
#  ['タレントのミケランって有名なの？初めて聞いた名前', '山田孝之さんと言えば、11月12日に待望のニューシングルが発売されますね。'],
#  ['こんにちは。今日は涼しいから大丈夫だよ。', '沖縄の人は泳ぎが苦手って聞いたけど、本当ならおもしろいよね。'],
#  ['寝坊したのですか？', '家族で初詣に行くんですか？'],
#  ['そうなんです。色んなものがトッピングされていてとてもかわいいし、見た目だけじゃなくておいしいです。', 'スイカは好きですね'],
#  ['当たらないと思います', '豆腐\u3000です。'],
#  ['猫は好きですか？', 'アナと雪の女王が「2014年ヒット商品ベスト30」の中では、やはりフローズン・フィーバーだと思います。'],
#  ['三浦知良ですね', '朝から海に行きますか？？'],
#  ['スポーツ観戦です。あなたの趣味は？', '朝から海に行きますか？？'],
#  ['竹田城跡', '運動神経については自分も自信がありませんが、趣味はどのようなものをされているのですか？'],
#  ['椅子を工夫して腰が痛くならないようにしています', '糖度は低いですね'],
#  ['あまり、そうは思いません。', 'どこか出かけるんですか？'],
#  ['今度私も買っていこう', 'へぇ！日本のアニメは世界的に人気が高いみたいですもんね。'],
#  ['音楽が好きなの？', '一番栄養価の高い果物はアボガドで、ギネスにも認定されてるんだって。'],
#  ['死者が出るのは悲しいことですよ。', 'ご想像にお任せします。']]

# %%
UT = ut_new + fake_error(ut_no_new, len(ut_no_new)-len(ut_new))
UT_NO = ut_no_new

# %%
print("UT: {0}".format(len(UT)))
print("UT_NO: {0}".format(len(UT_NO)))
# Out:
# UT: 528
# UT_NO: 528

# %%
X = feature_extraction(pos_list, UT + UT_NO , mode="dif", is_norm=True)
y = np.concatenate( [ np.ones(len(UT)), np.zeros(len(UT_NO)) -1 ] )
y
# Out:
# array([ 1.,  1.,  1., ..., -1., -1., -1.])

# %%
print("ut: {0}, ut_new: {1}, dif:{2}".format(len(ut), len(ut_new), len(ut)- len(ut_new)))
print("ut_no: {0}, ut_no_new: {1}, dif:{2}".format(len(ut_no), len(ut_no_new), len(ut_no)- len(ut_no_new)))
# Out:
# ut: 192, ut_new: 170, dif:22
# ut_no: 651, ut_no_new: 528, dif:123

# %%
model = SVC(kernel="rbf", random_state=2, C=0.1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model.fit(X_train, y_train)
# Out:
# SVC(C=0.1, random_state=2)

# %%
y_pred = model.predict(X_test)
# y_pred = np.ones(len(y_test))-2

# %%
len(y_test)
# Out:
# 212

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
print('confusion matrix = \n', confusion_matrix(y_true=y_test, y_pred=y_pred))
print('accuracy = ', accuracy_score(y_true=y_test, y_pred=y_pred))
print('precision = ', precision_score(y_true=y_test, y_pred=y_pred))
print('recall = ', recall_score(y_true=y_test, y_pred=y_pred))
print('f1 score = ', f1_score(y_true=y_test, y_pred=y_pred))
# Out:
# confusion matrix =
#  [[35 78]
#  [ 2 97]]
# accuracy =  0.6226415094339622
# precision =  0.5542857142857143
# recall =  0.9797979797979798
# f1 score =  0.708029197080292

# %%
for x in ut_no[:10]:
    
    f = feature_extraction(pos_list, x, mode="dif", is_norm=True)
    pred = np.argmax( clf.predict(f), axis=0 )
    print(pred, x)
# Out:
# 0 ['そうですか。山に行くのはどうでしょうか？', 'わあ！いいですね！']
# 0 ['明日はとても暑くなるみたいですね。', 'ご存知になりたいです']
# 0 ['涼しくなってきたら、一緒に山へ行きたいですね。', 'ご存知ですいますよねー']
# 0 ['美味しいですね。', '美味しいよ']
# 0 ['でも高いですね', 'いくら']
# 1 ['サスペンスが好きです', '映画はヒューマン系が好きですね']
# 0 ['そうですか', 'あはい']
# 0 ['こんばんは。今日は暑かったですね。', 'ところで、スイカの種って実は栄養豊富なんだそうですよ。']
# 0 ['ありがとう。野菜もたっぷり食べて、栄養をバランスよく摂りたいです。', '野菜でヘルシーよねー']
# 0 ['こんにちは。元気ですね', '夕食は食べましたか？']

# %%
from sklearn.ensemble import AdaBoostClassifier
clf = AdaBoostClassifier()

# %%
clf.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred = clf.predict(X_test)
print('confusion matrix = \n', confusion_matrix(y_true=y_test, y_pred=y_pred))
print('accuracy = ', accuracy_score(y_true=y_test, y_pred=y_pred))
print('precision = ', precision_score(y_true=y_test, y_pred=y_pred))
print('recall = ', recall_score(y_true=y_test, y_pred=y_pred))
print('f1 score = ', f1_score(y_true=y_test, y_pred=y_pred))
# Out:
# confusion matrix =
#  [[161  64]
#  [ 80 118]]
# accuracy =  0.6595744680851063
# precision =  0.6483516483516484
# recall =  0.5959595959595959
# f1 score =  0.6210526315789473

# %%
# Out:
# ['test_sen.ipynb',
#  '.gitignore',
#  'LiveComp',
#  'paper',
#  'UNI',
#  '.git',
#  'theme',
#  'corpus',
#  'test_bert.py',
#  'sentece.py',
#  'path_test.py']
