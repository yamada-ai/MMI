# %%
import json
import pandas as pd
import numpy as np
from pathlib import Path
import collections


from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
# path = "../error_category_classification/dbdc5_ja_dev_labeled/"
path = "../hand_labeled/"
datalist = ['DCM', 'DIT', 'IRS']

output = "./"

# %%
def read_json_with_NoErr(path:str, datalist:list) -> pd.DataFrame:
    cols = ['did', 'tid', 'usr', 'sys', 'ec']
    df = pd.DataFrame(index=[], columns=cols)

    for p in datalist:
        datapath = Path(path + p + '/')
        for file in datapath.glob("*.json"):
            with open(file, "r") as f:
                json_data = json.load(f)
                did = json_data["did"]
                for t in json_data["turns"]:
                    if t["turn-index"] == 0:
                        continue
                    if t["speaker"] == "U":
                        usr = t["utterance"]
                        continue
                    if t["speaker"] == "S" :
                        tid = t["turn-index"]
                        sys = t["utterance"]
                        if t["error_category"]:
                            ec = t["error_category"]
                        else:
                            ec = ["No-Err"]
                        df = df.append(pd.DataFrame([did, tid, usr, sys, ec], index = cols).T)
    df.reset_index(inplace=True, drop=True)
    return df

# %%
def extract_error(df, errors):
    utterances = []
    for d, u, s, e in zip(df.did, df.usr, df.sys, df.ec):
        for err in errors:
            if err in e:
                utterances.append([u, s])
    return utterances

# %%
def no_error(df):
    utterances = []
    system = []
    user = []
    for d, u, s, e in zip(df.did, df.usr, df.sys, df.ec):
        if e[0] == "No-Err":
            utterances.append([ u, s])
        # system.append(s)
        # user.append(u)
    return utterances

# %%
df = read_json_with_NoErr(path, datalist)

# %%
df
# Out:
#              did tid                   usr  \
# 0     1470646494   2    そうですね。最近とても暑いですから。
# 1     1470646494   4         休日に行きたいと思います。
# 2     1470646494   6       はい。あなたは海に行きますか？
# 3     1470646494   8                何故ですか？
# 4     1470646494  10  そうですか。山に行くのはどうでしょうか？
# ...          ...  ..                   ...
# 1995  1503290726  12           何を別売りしているの？
# 1996  1503290726  14            今は2回押してないよ
# 1997  1503290726  16              ベーシックだよね
# 1998  1503290726  18              君は女性なんだね
# 1999  1503290726  20                 両性なのか
#
#                                            sys  \
# 0                                  海に行かないんですね？
# 1                                     海は大丈夫ですね
# 2                                       海は危険です
# 3                                     海はいけないです
# 4                                    わあ！いいですね！
# ...                                        ...
# 1995           地下鉄で。名大前ができてすごく便利になりましたね、ここの大学。
# 1996  紅葉も遅いみたいですしね。私は、いつもベーッシクな色で変わりばえしないのですが。
# 1997     何処にあるお店ですか？ベースコートもトップコートも塗ると持ちが違いますよ。
# 1998                                    中間ですか？
# 1999                          では、スポーツは何かしてますか？
#
#                                          ec
# 0                           [Contradiction]
# 1                     [Lack of information]
# 2     [Ignore question, Self-contradiction]
# 3                         [Ignore question]
# 4                                  [No-Err]
# ...                                     ...
# 1995                           [Repetition]
# 1996               [Topic transition error]
# 1997               [Topic transition error]
# 1998                  [Lack of information]
# 1999               [Topic transition error]
#
# [2000 rows x 5 columns]

# %%
errors = ["Topic transition error", "Unclear intention", "Lack of information"]
errors = ["Lack of information"]
errors = ["Topic transition error"]

# %%
ut = extract_error(df, errors)

# %%
ut_no = no_error(df)

# %%
print(len(ut))
print(len(ut_no))
print(ut_no[0])
# Out:
# 192
# 651
# ['そうですか。山に行くのはどうでしょうか？', 'わあ！いいですね！']

# %%
import spacy
nlp = spacy.load('ja_ginza')
vec_dim = nlp("形態素").vector.shape
vec_dim
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:80: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# (300,)

# %%
def _in(arg1, arg2):
    result = False
    if isinstance(arg1, list):
        for element in arg1:
            if isinstance(element, str):
                if element in arg2:
                    result = True
                    break
            else:
                if element == arg2:
                    result = True
                    break
    else:
        if isinstance(arg1, str):
            if arg1 in arg2:
                result = True
        else:
            if arg1 == arg2:
                result = True
    return result

# %%
def filter_pos_vector(pos_list, text):
    vec = np.zeros(vec_dim)
    doc = nlp(text, disable=['ner'])
    for token in doc:
        # print(token, token.tag_)
        if "助動詞" not in token.tag_ and _in(pos_list, token.tag_):
            # print(token, token.tag_)
            vec += token.vector
    return vec

# %%
def feature_extraction(pos_list, convs, mode, is_norm=False):
    feature_list = []
    for utt in convs:

        if mode == "dif":
            usr_vec = filter_pos_vector(pos_list, utt[0] )
            sys_vec = filter_pos_vector(pos_list, utt[1] )
            dif_vec = usr_vec - sys_vec
            # if np.linalg.norm(dif_vec)==0:
            #     print(utt)
            if is_norm:
                # print(np.linalg.norm(dif_vec))
                if np.linalg.norm(dif_vec)==0:
                    vec = np.concatenate( [dif_vec, dif_vec/0.05] )
                else:
                    vec = np.concatenate( [dif_vec, dif_vec/np.linalg.norm(dif_vec)] )
                feature_list.append(vec)
            else:
                feature_list.append(dif_vec)
    
    return np.array(feature_list, dtype="float32")

# %%
def remove_norm_zero(pos_list, convs):
    convs_removed = []
    for utt in convs:
        usr_vec = filter_pos_vector(pos_list, utt[0] )
        sys_vec = filter_pos_vector(pos_list, utt[1] )
        dif_vec = usr_vec - sys_vec
        if np.linalg.norm(dif_vec)==0 or np.linalg.norm(usr_vec)==0 or np.linalg.norm(sys_vec)==0:
            continue
        convs_removed.append(utt)
    return convs_removed

# %%
pos_list = ["名詞", "動詞", "形状詞", "形容詞"]
ut_new = remove_norm_zero(pos_list, ut)
ut_no_new = remove_norm_zero(pos_list, ut_no)

# %%
import random
def fake_error(convs, times):
    user_list = []
    system_list = []
    for utt in convs:
        user_list.append(utt[0])
        system_list.append(utt[1])
    
    fake_convs = []
    for _ in range(times):
        fake_convs.append( [random.choice(user_list), random.choice(system_list)] )
    return fake_convs

# %%
fake_error(ut_no_new, len(ut_no_new)-len(ut_new))
# Out:
# [['観光地の食べ物は高いですもんね。', '読書は楽しいですね'],
#  ['大人に見えることがよくありますね', '何をするにしてもやりがいがあるのとないのでは気持ちが違ってくるよね。'],
#  ['お寺にも行きましょう。', 'ケースバイケースに対応できます'],
#  ['テナーサックスはやっていませんよ', 'だからかけたことはないですね。'],
#  ['竹田城跡', '予防を怠るようです'],
#  ['こんにちは。怖いですよね熱中症。毎日蒸し暑いですからね。', '同じ日本でも、だいぶ気温差がありますよね。'],
#  ['社会人です', 'パパイヤは味が強いですね'],
#  ['嫌いなものは最初に食べます。', '私はお気に入りに入れてますよ！なかなか人気あるみたいだし、使いやすいです。'],
#  ['凍らせると糖度は上がるっていうよね', '家族で初詣に行くんですか？'],
#  ['行きましたよ', '今日は晴れだと思って傘を持っていないので、何とかこのぐらいの雨で終わってほしいです。'],
#  ['いい天気ですね', 'しりとりでもしましょうか'],
#  ['ミスチルは昔のイノセントワールドなんか好きですよ。', '朝の気分は、その日一日を左右するよね。'],
#  ['そうなんだ。運動神経良さそうだね。', '北海道は懐かしいですね'],
#  ['家では何をしますか？', '大阪にあるユニバーサル・スタジオ・ジャパンでは待ち時間も多そうなので、食べ歩きができる食べ物は便利ですね。'],
#  ['すごい。行ってみたい。', '気持ちがいいですね'],
#  ['耳は冷たいよね', 'どんな本を読みますか？'],
#  ['何で行くの？電車？車？', '川でバーベキューとか素敵だと思います。'],
#  ['野球が好きなら、マツダスタジアムです。', 'プロ野球に疎い私でも、海遊館に住んでいれば自然と峯嵐堂について詳しくなります。'],
#  ['おはようございます。', 'しりとりでもしましょうか'],
#  ['そうですね。あなたは犬と猫ではどちらが好きですか？', '最近だと旅行にはまりだしたので、旅代で消えてしまいますね。'],
#  ['私も行きたいです', 'ラーメンはスープが美味しいですね'],
#  ['新鮮な気持ちになりたいですよね',
#   '初代JリーグアウォーズのMVPであるカイオ・ルーカス・フェルナンデス選手も、プロデビューはミラノだったので、ポルトガルとポルトガルのサッカーの関係はとても深い物だと感じています。'],
#  ['グラッドじゃないよ', '海は好きですね'],
#  ['漫画を読むのが好きなので浦沢直樹さんの話をしましょう',
#   '私もどちらかというとインドア派で家でのんびり映画とか見てるのが好きなんですが、１３さんは、家でどんな風にのんびり過ごすのが好きですか？'],
#  ['嫌いなものは最初に食べます。', '渋いですね。大人の味という気がします。'],
#  ['何か話題ある', 'そうですか。漫画は、手軽に一人で楽しめるのでとてもいいですよね。'],
#  ['練習すればきっと上手になりますよ', '血液型占いって、本当に当たるのかな。'],
#  ['私もそう思います',
#   '初代JリーグアウォーズのMVPであるカイオ・ルーカス・フェルナンデス選手も、プロデビューはミラノだったので、ポルトガルとポルトガルのサッカーの関係はとても深い物だと感じています。'],
#  ['こんにちは。たまにヨガをしています。ヨガはやったことがありますが？', 'ご想像にお任せします。'],
#  ['音楽です。', '水が綺麗ですね'],
#  ['？ん？', '死者がでなかったでしたっけ？'],
#  ['占いというのは下らないね', '海は好きですね'],
#  ['こんにちは。今日は涼しいから大丈夫だよ。', 'おっ、私もなんですよ。場所はどこですか？'],
#  ['趣味はなんですか？', 'パパイヤは味が強いですね'],
#  ['晴れと雨ではどちらが好きですか', '御菓子御殿の本拠地ナゴヤドームでは、名古屋名物を扱う店が充実していて、味噌カツなどが人気だそうです。'],
#  ['思いつきません。あなたのマイブームは？', 'この前は定番のキムチ鍋をやりましたよ！今日は豆乳鍋をやろうかと思ってます。'],
#  ['沢田研二は好きですか', 'ラーメンはスープが美味しいですね'],
#  ['青い空が最高だね', 'いやぁ、それが朝起きたらもうすでに終わっちゃってるんです。'],
#  ['馬はかっこいいんで好きなんです。', 'ありあけハーバーはとても便利そうですね。近所にcafe坂の下があれば、私もぜひ利用してみたいです。'],
#  ['行きましたよ', 'プロ野球に疎い私でも、大阪に住んでいれば自然とメルズ・ドライブインについて詳しくなります。'],
#  ['夏は海だよね', '果物は安いそうです'],
#  ['仲良しな感じがするね。', 'ロックは好きですか'],
#  ['そうですか、私は寝すぎてしまうことが多いですね', 'パパイヤは味が強いですね'],
#  ['瀬戸内に行ってみたいです。', 'スロットがもっとも盛り上がっていた時代ですね。'],
#  ['こんにちは。私は犬が好きです。', 'はい。何度かあります。近いし、安いし、食べ物はうまいし本当に良いところですよ。'],
#  ['そうなんですね。ところで休日は何をしているのですか？', '好きな食べ物は、蕎麦かな。'],
#  ['どんな食べ物にも合いますね', 'ほんとに．失言が多いもんね．'],
#  ['今日はとてもいい天気ですね。', '今まで京都は行ったことありますか？'],
#  ['毎日知りたいとは思いませんね。', '熱中症に気をつけてたいですか？'],
#  ['音楽は気分転換にいいですね。',
#   '私もどちらかというとインドア派で家でのんびり映画とか見てるのが好きなんですが、１３さんは、家でどんな風にのんびり過ごすのが好きですか？'],
#  ['スペインの魅力を教えてください', '紅玉が良いですね'],
#  ['手洗いは基本だよ。', 'そうします'],
#  ['占いというのは下らないね', '結構作ってますよ。前までは全然作れなかったんですが、やっぱり一人暮らしだと自然に覚えていきました。'],
#  ['ボードゲームです', 'みんな長編だから、読むときは気合いが必要だね。'],
#  ['こんにちは、私は山田孝之の方に興味があります', '海は最高ですか。海は好きですね'],
#  ['海水浴は楽しいですよね', '大きい買い物だから悩みますよね。'],
#  ['こんにちは、私は山田孝之の方に興味があります',
#   '瀬戸内は、Ballad Showのキャンペーンからセックス・アンド・ザ・シティのキャンペーンで観光を強化していて、かなり他府県から評価が上がっているそうです。'],
#  ['雨が降ってきましたね', '一年目って言っても、学部時代に４年過ごしてるから、あんまり新鮮味はないかも。'],
#  ['演技が上手やもんね', 'マイブームかぁ・・・。旅行です。'],
#  ['スポーツ観戦です。あなたの趣味は？', '気持ちがいいです'],
#  ['国営滝野すずらん丘陵公園です。', '次回、大阪へ行く機会があったら、海遊館に立ち寄ってポッキーでお土産を選ぼうと思います。'],
#  ['色が綺麗だよね', 'いいですねぇ'],
#  ['味噌カツいいですね。私も大好きです',
#   'スナック菓子であるカルビーのじゃがりこをポテトサラダ風にアレンジした際には、母親に「こんなバカな事して!」と怒られた記憶があります。'],
#  ['ざわちんですね。',
#   '四季劇場日生劇場で上演中のミュージカル、森永ミルクキャラメルが11月16日に関西最長ロングランを達成したそうです。11月16日時点での通算公演回数は699回との事です。'],
#  ['私はスターウォーズが好きです。', 'そうですか！私は苦手です。。。冬服は重いし高い。'],
#  ['篠原涼子さんは色気が凄いですね。', 'お遍路さんに優しいそうです'],
#  ['チョコレートです。あなたの好きな食べ物はなんですか？', 'スロットがもっとも盛り上がっていた時代ですね。'],
#  ['瀬戸内に行ってみたいです。', 'ほうほう。バンド系よりもデジタルな音楽は私もすきです。'],
#  ['沢山の魚がいるからね', 'お気に入りのパン屋さんがあると、買い物も楽しくなるよね。'],
#  ['スポーツは何もしていないなあ。',
#   '4、5年前にユニバーサル・スタジオ・ジャパンに一度行った事があり、Ban汗ブロックロールオンに乗った事を覚えています。あとは大きなジョーズのオブジェの前で写真を撮りました。'],
#  ['そうなんです。透明度が凄く高いんです', '本格的にやる人は、キューとかケースとかも全部自分で購入してやってますよ。'],
#  ['好きなんですか？', '沖縄の人は泳ぎが苦手って聞いたけど、本当ならおもしろいよね。'],
#  ['地震怖いよね', '今は３年生です。そろそろ就活と卒論に怯える日々が近づいてます…。'],
#  ['手洗いは基本だよ。', '何がですか？'],
#  ['SMAPは解散らしいけどGLAYは解散しなさそうだよね', '新作には、あの二台のロボット、また出てくるかなあ。'],
#  ['そういえば、しばらくお好み焼きを食べていないかもしれません。',
#   'その気持ちよくわかります。あの土産屋さんがならんでいるところで、八つ橋の試食をしまくりながらただでお茶を飲んだり。'],
#  ['もうすぐ旅行にいくのでそれが楽しみです', '今行きたいところは、ペルーにある世界遺産のマチュピチュです。'],
#  ['そう思っています', '国営滝野すずらん丘陵公園と国営備北丘陵公園なら、どちらが楽しいでしょうか？'],
#  ['いいお天気ですね', 'ゴーヤチャンプルは美味しいですよねー'],
#  ['一度は富士山に登ってみたいですね。', '熱中症に気をつけてたいですか？'],
#  ['コブクロいいですねー私はゆずが好きです', 'おやすみ'],
#  ['私は浅田次郎の小説が好きです', 'ご想像にお任せします。'],
#  ['沢山の魚がいるからね', '続けるのは難しいですよね'],
#  ['自分の意識を変えると仕事にやりがいが持てますよね。', 'SNSを見ますよねえ'],
#  ['SMAPは解散らしいけどGLAYは解散しなさそうだよね', '朝から海に行きますか？？'],
#  ['私は特に打ち上げ花火が見たいです。', 'メディア科学です。そちらは？'],
#  ['今日は何時に起きました？', 'ロックは好きですか'],
#  ['夏は海だよね', '好きな食べ物は、蕎麦かな。'],
#  ['どんな芸でしょう？', 'え、マラソンかな'],
#  ['一緒に遊ぼう！', '越前海岸の温泉とか'],
#  ['ボーっとするのが好きなので、嫌いではないですよ', 'やっぱり地元なんでドラゴンズが好きですね。'],
#  ['特にしてません。日々のストレッチ程度ですね。', 'いつもはしないんだけど'],
#  ['マッサージ屋行きたい', '新作には、あの二台のロボット、また出てくるかなあ。'],
#  ['クライミングです', '日本にいて見られるかどうかがポイントなのですね。'],
#  ['食べるのが好きなんですね。', 'イタリアはとても面白いそうですね。'],
#  ['家の猫は物静かで、よくゆうことを聞く良い子たちです。', '三毛猫でチビって名前ですが、太って大きいです。'],
#  ['そうですか、食べてみたいです。', '雨はだるいです'],
#  ['まあね。数字が嫌いな人には向いてないと思うけど。', 'ほんとー！なんか外に行きたくなっちゃいますね、旅行とか、いいですね〜。'],
#  ['塩をかけても美味しいですよ', 'お気に入りのパン屋さんがあると、買い物も楽しくなるよね。'],
#  ['主演は誰なの？', 'みんな長編だから、読むときは気合いが必要だね。'],
#  ['何ですかそれは、それを聞いて、食べる気が失せました。', 'ラジオにはまりますか？'],
#  ['こんにちは、私は山田孝之の方に興味があります', 'はい。何度かあります。近いし、安いし、食べ物はうまいし本当に良いところですよ。'],
#  ['瀬戸内に行ってみたいです。', '映画いいですね。最近自分が趣味を持ってないことに気づいてなにか見つけようと思ってるところです。'],
#  ['焼きそばも好きです', '天気は冴えないです'],
#  ['インドア派だから外出はあまりしませんね', '防水、カッティング、エントリー、いろいろあるよね。'],
#  ['四国の食べ物と言えば、なにが好きですか？',
#   'ところで、気になるニュースがあったのですが、7月29日から公開された映画「シン・ゴジラ」の観客数が1日までに71万人に達し、1954年に第1作が公開された「ゴジラ」シリーズの累計観客数が1億人突破し、実写映画では初めてだそうですよ。'],
#  ['フォレストアドベンチャーです。', '日本人の８割が人生の間で腰痛に悩むらしいよ。'],
#  ['うちでは猫と犬を一緒に飼っています。',
#   '4、5年前にユニバーサル・スタジオ・ジャパンに一度行った事があり、Ban汗ブロックロールオンに乗った事を覚えています。あとは大きなジョーズのオブジェの前で写真を撮りました。'],
#  ['食べに行ったり、温泉行ったりします。', 'いやぁ、それが朝起きたらもうすでに終わっちゃってるんです。'],
#  ['誰？それ', '私もどちらかというとｊ−POPですね'],
#  ['熱中症になったことがないのでよくわかりません。', '将来どんな展開になるのか楽しみです。'],
#  ['青い空が最高だね', 'なんだかこうゆうのって初めてでちょっと緊張しませんか？'],
#  ['色が綺麗だよね', 'その際のお写真に添えるかもしれない'],
#  ['私は本を読むのが好きです。', 'ざわちんさんの出演されたハングリー!はどのような内容でしたか？。'],
#  ['じゃあ私からいきますよ、リンゴ。', '機嫌をよくします'],
#  ['ジャンプの漫画は昔も今もよい作品が多い', 'そうですね、ちょっと古いですがマリオカートが好きです。'],
#  ['へ〜。セブンイレブンのコーヒーは飲んだことある？', '朝から海に行きますか？？'],
#  ['私は洋楽が好きなんです', '洋書でいったらTuesday\u3000with\u3000Morrieを読んで泣きそうになりました。'],
#  ['何で行くの？電車？車？', 'サッカーの三浦知良選手がテレビで話した、北澤豪選手との話とはどのような話でしたか？。'],
#  ['温泉が好きなんですね？', 'スイカはいんですか？？桃がいいですね'],
#  ['焦点は合うけど疲れたら頭がボーっとするね', 'そうですか！私は苦手です。。。冬服は重いし高い。'],
#  ['旅はいいですね。', 'やはり女子に期待ですか？'],
#  ['両方楽しかったけど，シンガポールにもう一度行きたい！', '神奈川県に住んでいますよ。'],
#  ['沖縄行きたいです！', 'へぇ！日本のアニメは世界的に人気が高いみたいですもんね。'],
#  ['何で行くの？電車？車？', '早く寝るほうがいいと思います。夜中に見ると、止まらなくなりますよ。'],
#  ['食べに行ったり、温泉行ったりします。', '好きな食べ物は、蕎麦かな。'],
#  ['糖度がね。値段も高いよ。', '日泰寺とかですか？違うかな'],
#  ['よく知りませんが、空き家が増えているのでそうやって再利用するのは良いですよね。', 'マイブームかぁ・・・。旅行です。'],
#  ['国営滝野すずらん丘陵公園です。', 'ご家族は何人ですか？'],
#  ['沢山の魚がいるからね', '美味しいかき氷とお好み焼きがあって幸せでした。'],
#  ['私も行きたいです', '風見鶏という歌が好きです。まぁ、１番というのは非常に決めがたいですが…。'],
#  ['節約するだけとは違うんだけどね。それはただのケチだから。', 'お天気の良さはどうですか？'],
#  ['スポーツは何もしていないなあ。', '誰かの役に立っていると思えば、興味のない仕事でもおもしろくなるものですよ。'],
#  ['私も大好きなんです。',
#   'ナゴヤドームの名古屋には、味噌カツの他に、名古屋名物の唐揚げ手羽先や味噌煮込みうどんや天むす など美味しい食べ物がいっぱいあるんでしょね。'],
#  ['味噌カツいいですね。私も大好きです', '沖縄の海の深さによって生息する魚が違うのでしょうね。'],
#  ['最近なら、この前食べた車エビが好きですね。エビ全般好きですね。', '熱中症に気をつけてるんですね。熱中症に気をつけか？？'],
#  ['その試合は見てないか分からないんだけど、ネイマールの個人技はすごい。', '扇風機を併用するんですね。エアコンは欲しいですね'],
#  ['四国の食べ物と言えば、なにが好きですか？', '熱中症に気をつけなければなりませんがね'],
#  ['今日は天気いいですね', 'お金に余裕があれば、外に出て遊んでいんますよ。'],
#  ['歩きにくいですものね', '大きい買い物だから悩みますよね。'],
#  ['どの選手が選ばれるか楽しみですね。', 'お天気の良さはどうですか？'],
#  ['おたがいに助け合いですね。',
#   '神戸にあるグランフロント大阪のアイスクリームの中身は、鳥達のえさを人間が食べやすいようにアレンジしてあるのですが、トッピングに特徴があって、インコの背中の匂いを味にした粉をアイスクリームにかけて食べるそうです。'],
#  ['チャットはほとんどやりません。よくチャットやるんですか？', '気持ちがいいですね'],
#  ['宮部みゆきなんてどう？',
#   'ぴあでテレビ放送されているゲゲゲの女房という旅番組では、旅をしながら現地の人と会話をするのですが、実際の撮影班の音声が芸能人のナレーションに差し替えられて、まるでナレーターをしている芸能人が実際に旅をしているような映像が作られています。'],
#  ['それは楽しみですね！USJも賑わいそうですね！', '全くしないですね。どんなところが苦手ですか？'],
#  ['そうですね、自分でいじって作るみたいです。', 'ほう、そうなんですか。'],
#  ['どの選手が選ばれるか楽しみですね。', 'アナと雪の女王が「2014年ヒット商品ベスト30」の中では、やはりフローズン・フィーバーだと思います。'],
#  ['海水浴は楽しいですよね', 'すごいですね。私はあまり読書できないので。'],
#  ['夜は寝苦しい', 'だからかけたことはないですね。'],
#  ['家の中で２匹飼っていますよ', '今日は晴れだと思って傘を持っていないので、何とかこのぐらいの雨で終わってほしいです。'],
#  ['どの季節が好きですか？', 'そうですか！私は苦手です。。。冬服は重いし高い。'],
#  ['水分を沢山とっています。', '晴れか雨かで、その日の気分が決まることがあるよね。'],
#  ['ワクワク感がいいよね。', 'イタリアはとても面白いそうですね。'],
#  ['年始は、旅行は行かず、帰省かな。', '海は好きですね'],
#  ['いいですね~私はセロリが嫌いです。',
#   'ハビエル・アギーレ監督もサッカー日本代表のホンジュラス戦とオーストラリア戦は勝ちに行くと言っていたので、選手起用も含め楽しみですね。'],
#  ['もう一度いいますよ、リンゴ', '自分的にもあれが原点ですね＞古谷金田一'],
#  ['サイクリングが好きなんですか？', 'ゲームですか．いいですね・'],
#  ['はい。麺類は美味しいから好きです。', '熱中症に気をつけてたいですか？'],
#  ['あなたは嫌いな食べ物はありますか。', 'リン・ユーチュンは好きで、アメリカでのサッカーワールドカップの時には涙したと言っていました。'],
#  ['カラオケとかよく行くんですか？', 'そうですね、秋晴れですね。'],
#  ['沖縄といえばゴーヤチャンプルですね。', '美味しいですけど、近年は値上がりしていて辛いですね。'],
#  ['そうなんです。透明度が凄く高いんです',
#   'ぴあでテレビ放送されているゲゲゲの女房という旅番組では、旅をしながら現地の人と会話をするのですが、実際の撮影班の音声が芸能人のナレーションに差し替えられて、まるでナレーターをしている芸能人が実際に旅をしているような映像が作られています。'],
#  ['興味のないことでもよく見たり覚えたりしないとだめですね。',
#   'カルビーは11月1日に、ごろっとグラノーラの新製品である、カールとクリアアサヒを発売するそうです。'],
#  ['忙しくなりそうですね。専攻は？', '腰をいたわりますよねえ'],
#  ['いえ、知りませんでした。', 'すごいですね。私はあまり読書できないので。'],
#  ['まだ今年は海へ行ってませんね。', 'ワールドカップのブラジル代表とチリ代表の試合をリアルタイムで観ていて、とても興奮しました。'],
#  ['ミュージカルは行ったことはないですね。', '私は練乳がかかってるのが一番好きなんだ。'],
#  ['ウォーキングです。', '金メダルは無理です'],
#  ['スポーツ観戦です。あなたの趣味は？', 'ゴーヤチャンプルは美味しいですよねー'],
#  ['東京もおすすめです', '晴れか雨かで、その日の気分が決まることがあるよね。'],
#  ['ウィザーディング・ワールド・オブ・ハリー・ポッターエリアに関心があります。', '真夏日はいいですね'],
#  ['これからはしばらく暑くなりますね。', '天気がいいとそれだけで元気が出ちゃうよね。'],
#  ['迫力があって楽しそうですね！',
#   'セブンイレブンのチョコケーキマウンテンというスイーツは、濃厚なチョコレートの味わいが楽しめるケーキで、チョコレート味の生クリームが高く盛られていて、チョコケーキマウンテンという名前の通り、山のような形になっています。'],
#  ['塩辛なんかも塩加減が色々あって、好みの味は甘口ですよ。', 'ご家族は何人ですか？'],
#  ['特にしてません。日々のストレッチ程度ですね。', '海はいんですか？？海は楽しいですね'],
#  ['思いつきません。あなたのマイブームは？', '北海道は懐かしいですね'],
#  ['それは楽しみですね！USJも賑わいそうですね！', 'ラジオは聞くのがいいですね'],
#  ['そちらも熱中症に気を付けて下さい。', '家族を大切にする人って、すごく大人に見えるよね。'],
#  ['私大好物です。', 'へぇー！\u3000ところで、お仕事、残業とかありますか？？'],
#  ['自由だと思うよ。', 'いいえ、健康です。'],
#  ['アウトレットではどのような物を買ったのですか？', '犬はかわいいですよ。'],
#  ['こんにちは。よろしくお願いします。', 'みーとぅーです。'],
#  ['とても面白い本を読みます', '紅玉が良いですね'],
#  ['そうですね、自分でいじって作るみたいです。', '今、ボードゲームにはまってますね。'],
#  ['インターネットをしてることが多いです。', 'メディア科学です。そちらは？'],
#  ['三浦知良ですね', '天気は冴えないです'],
#  ['毎日放送ってことはMBSだね。', 'もつ鍋ですかー。私はキムチ鍋しましたよ！'],
#  ['今まで旅行した所で、一番良かったのは何処ですか？', 'ワールドカップのブラジル代表とチリ代表の試合をリアルタイムで観ていて、とても興奮しました。'],
#  ['毎日知りたいとは思いませんね。', '高齢者が多いですよねー'],
#  ['自分は四季劇場かな？', 'エコは大事ですか。エコは大切ですね'],
#  ['京都も好きです', '私がはじめて奥様は魔女を見たのは、年末に地上波で連続放送していた時でした。'],
#  ['君はお酒飲むのかい？', 'お遍路の逆回りは迷いやすくて大変なぶん、ご利益が大きいらしいよ。'],
#  ['社会人です', '短距離でした。４００ｍ走ってました。'],
#  ['韓国料理で何か好きなものはありますか？', '紅玉が良いですね'],
#  ['奥様は魔女って、昔、そういうドラマがありましたね。ご存じですか？', '越前海岸の温泉とか'],
#  ['見たことある？', 'その気持ちよくわかります。あの土産屋さんがならんでいるところで、八つ橋の試食をしまくりながらただでお茶を飲んだり。'],
#  ['私もいつか海遊館に旅行に行ってみたいです。',
#   '御菓子御殿の本拠地ナゴヤドームでは、名古屋名物を扱う店が充実していて、味噌カツなどが人気だそうです。'],
#  ['晴れと雨ではどちらが好きですか', '最近は全くしません。ＭＳＮメッセンジャーでは話したりします。'],
#  ['君は病気してないかい？', '御菓子御殿の本拠地ナゴヤドームでは、名古屋名物を扱う店が充実していて、味噌カツなどが人気だそうです。'],
#  ['こんにちは。今日は涼しいから大丈夫だよ。', 'スイカはいんですか？？桃がいいですね'],
#  ['短距離ですか？長距離ですか？', '焼きそばは好きですか。麺が美味しいですね'],
#  ['勉強になりました', 'そうですか！私は苦手です。。。冬服は重いし高い。'],
#  ['人柄がでそうだね', '占いですか！最近は、どんな占いをしましたか？'],
#  ['私も行きたいです', 'お祭りに行きたいんですね？お祭りは夜が楽しいですよねえ'],
#  ['好きな鍋は何ですか', '沖縄は新幹線等で来る事が出来ないので、あまりコンサートが開かれないと思います。'],
#  ['あなたの好きな食べ物は何ですか？', 'そば湯はあるけど、うどん湯ってあるのかな？'],
#  ['焼きそばも好きです', '日泰寺とかですか？違うかな'],
#  ['あなたも寝ることはあるんですか？', 'そうですね。結果だけ聞くよりもどうなるかワクワクしながら観る方が面白いと思います。'],
#  ['何か話題ある', 'そうします'],
#  ['私もよく写真を撮ります', 'パパイヤは味が強いですね'],
#  ['アボガドはおいしいね。ハンバーガーに入っているのとか好き',
#   '劇団四季が2015年5月24日から上演予定の新作のミュージカルはアラジンだそうです。'],
#  ['マッサージ屋行きたい', '海はいんですか？？海は楽しいですね'],
#  ['有名なお店なんですね。仕事でも利用できそうなお店ですね。',
#   'サッカーチームFCバルセロナの久保健英選手は、スペインやマドリッド、イングランドなどの各国の厳しいリーグを渡り歩いてきたので、セレッソ大阪との温度差に戸惑ってしまったのでしょうね。'],
#  ['いいお天気ですね', 'では、好きな動物は何ですか？'],
#  ['ユーのマイブームはなに？', 'では、最近のマイブームは何ですか？'],
#  ['チャットは苦手であまりやらないです。', '風情は欲しいですね'],
#  ['あなたは嫌いな食べ物はありますか。',
#   '大阪にある海遊館の元気やという名前のハンバーガー店では、値段設定が高めな分、本格的な味わいのハンバーガーが楽しめるかもしれませんね。'],
#  ['練習すればきっと上手になりますよ', 'どんな種類の猫なんですか？'],
#  ['そうですか、私は寝すぎてしまうことが多いですね', '今まで京都は行ったことありますか？'],
#  ['ジーコってブラジルの元サッカー選手だよね？', 'おやすみ'],
#  ['うん、楽しいね。芸人さんの深夜ラジオもよく聴くし。', '今日は、８時起床です。何時ですか？'],
#  ['奥様は魔女って、昔、そういうドラマがありましたね。ご存じですか？', '予防が重要ですね'],
#  ['じゃがアリゴっていう料理が流行ってるらしいね。', 'いいですね！'],
#  ['ミスチルは昔のイノセントワールドなんか好きですよ。', '防水はいいそうです'],
#  ['うちでは猫と犬を一緒に飼っています。', '雨はうざいです'],
#  ['沢山の魚がいるからね',
#   '私もどちらかというとインドア派で家でのんびり映画とか見てるのが好きなんですが、１３さんは、家でどんな風にのんびり過ごすのが好きですか？'],
#  ['沖縄行きたいです！', 'ご想像にお任せします。'],
#  ['普段から水分をしっかりとる様に心がけてます。', 'そうします'],
#  ['そうなりたいです', 'ケースバイケースに対応できてるのですか？'],
#  ['主演は誰なの？', '劇団四季が2015年5月24日から上演予定の新作のミュージカルはベストジーニスト2014だそうです。'],
#  ['本栖湖なんて本当に綺麗ですよ', '男性はバニラ系好きな方あまりみかけないです。'],
#  ['私は名古屋の方が関心ありますね', '私もラーメンは好きです。先日、誘われて、天一のラーメンを食べに行ってきました。'],
#  ['国際紛争のニュースが一番気になります。',
#   'クラゲが大好きなので海遊館で、期間限定にて、不老不死の「スパイダーマン」と超巨大「ぐりこ・やKitchen」の展示を行っているのにとても興味があります。'],
#  ['本は読まれますか？', '三毛猫でチビって名前ですが、太って大きいです。'],
#  ['グラッドじゃないよ', '一番栄養価の高い果物はアボガドで、ギネスにも認定されてるんだって。'],
#  ['いえ、知りませんでした。',
#   '以前、俳優の山田孝之さんが出演したテレビ番組で、演技に関するインタビューに答えていたのですが、それがとても興味深い内容でした。'],
#  ['観光地の食べ物は高いですもんね。', 'う〜ん、得意というか、豚の生姜焼きとかよく作ります。'],
#  ['他にもシュウマイ等色々名物がありますよ。', '音楽は好きですか？'],
#  ['した方がいいのだけれど、していないんです。', '未来とかどろろの主題歌とかですかねえ'],
#  ['体に良さそうですね', '好き嫌いは、あまりないですね。'],
#  ['同じ姿勢を続けるのはよくないらしいよ', 'ところで、老後は海したいと話をしていましたよね？海は恐ろしいです'],
#  ['私も蕎麦が大好きですよ。', '熱中症に気をつけか？？'],
#  ['何をですか', '政治家になりたいです．'],
#  ['大人の味ってほろ苦いというイメージですかね。',
#   '結構作ってますよ。前までは全然作れなかったんですが、やっぱり一人暮らしだと自然に覚えていきました。'],
#  ['読書好きですか？自分はよく図書館を利用します', 'ご想像にお任せします。'],
#  ['寝坊したのですか？', 'ラジオにはまりますか？'],
#  ['他のアトラクションを教えてください', '腰をいたわりますよねえ'],
#  ['？ん？', '結構好きですよ。そんなに行く機会はないですけど。'],
#  ['他にはスポーツをしたことはありますか？',
#   'あまり拘らないもので基本的に気に入ったら何でも読むのですが（バトル物から萌え系？と言われるような物まで）、最近は先ほどあげたように、一つの職業にスポットを当てた漫画を多く読んでいる気がします。'],
#  ['ワクワク感がいいよね。',
#   'テレビドラマごちそうさんに出演される栗原はるみさんは、設備の充実ぶりに感動し、すっかりネットカフェの虜になったそうです。'],
#  ['私も２回、旅しましたよ', '今日は晴れだと思って傘を持っていないので、何とかこのぐらいの雨で終わってほしいです。'],
#  ['好きな食べ物はありますか？', '美味しいですけど、近年は値上がりしていて辛いですね。'],
#  ['運転が疲れた時は車を止めて少し休みましょう。', '竹田城跡には行ったことがありますか？ 。'],
#  ['私大好物です。', '大分別府はいんですか？？大分別府まで九州横断特急に乗りますよねー'],
#  ['馬はかっこいいんで好きなんです。', 'BrainWarsを観戦するために観光客がたくさん訪れると、日本の景気が少しだけ良くなるような気がします。'],
#  ['そちらも行ってみたいです。', 'お笑いはくだらないですね'],
#  ['栗田貫一のルパンが有名ですね。', 'サッカーの三浦知良選手がテレビで話した、北澤豪選手との話とはどのような話でしたか？。'],
#  ['産地偽装はダメです。', '神奈川県に住んでいますよ。'],
#  ['ちょっと高いかもしれませんね。値段に見合うものならいいですが。',
#   'サッカーの三浦知良選手がテレビで話した、北澤豪選手との話とはどのような話でしたか？。'],
#  ['おはようございます。', '家族で食事に行きますか？'],
#  ['海はいいですよね。', 'じゃがりこはもともと、じゃがいものお菓子なので、たらこバターと合いそうですね。'],
#  ['沢田研二は好きですか', 'しりとりでもしましょうか'],
#  ['私は見たことがない番組なので、よく知らないんですよ。',
#   'サッカーのクリスティアーノ・ロナウド選手でさえも、周囲との連携がうまく働かないと得点できないというのは、やはりブラジルワールドカップで浮き彫りになりましたが、チリのサッカー選手では決定的に得点を決められる選手がいないという事ですよね。'],
#  ['どんな食べ物にも合いますね', '予防が重要ですね'],
#  ['もう寝るんですか？', '晴れた日にいきたいんですね？気持ちがえいですけどねぇ'],
#  ['好きな食べ物は何ですか？',
#   '海外組のサッカー選手たちと三浦知良選手とで催された食事会はカズ会といって、何度か開催され、たしか幹事は北澤豪選手だったと思います。'],
#  ['劇団四季の舞台を一度観てみたいな', '一日のほとんどをベットで過ごしています。'],
#  ['そういえば、しばらくお好み焼きを食べていないかもしれません。',
#   '海遊館にはイルカはいませんが、大水槽で泳ぐジンベイザメが有名で、しかし残念ながら海遊館のジンベイザメは最近亡くなってしまったそうです。'],
#  ['雑種が好きですね', '映画は進みます？？'],
#  ['よく知りませんが、空き家が増えているのでそうやって再利用するのは良いですよね。', 'はい、でもまだ興味にとどまっています。'],
#  ['そうですね、海外旅行に行った時なんかは危険が多いのでいろいろ考えながらケースバイケースに対応しますね。',
#   'やっぱり地元なんでドラゴンズが好きですね。'],
#  ['好きな食べ物は何ですか？', '透明度は良いですね'],
#  ['娯楽小説と料理本を読みます。どんな本読みますか？',
#   '尾道駅近くにレンタサイクルがあって、そこで自転車を借りて走り、因島大橋などを渡ってきました。'],
#  ['韓国料理で何か好きなものはありますか？', '国内で死者が出てるんですかね？'],
#  ['海のどこが好きですか?',
#   'やはり、沖縄のシュノーケリングでは海の浅い場所よりも深い場所のほうが、よりカラフルで鮮やかな魚を観察できたように思えます。'],
#  ['旅はいいですね。', '北海道は懐かしいですね'],
#  ['味噌カツいいですね。私も大好きです',
#   'お笑い芸人の千原ジュニアさんと甥のエピソードトークはバラエティ番組太陽の塔では定番なので、視聴者は、親戚のように千原ジュニアさんと甥の関係を知っています。'],
#  ['ジャンプの漫画は昔も今もよい作品が多い', '北海道は懐かしいですね'],
#  ['ポケモンＧＯをやってみたいな。', 'スーパージャンプ、ウルトラジャンプ、ビジネスジャンプ、ジャンプスクエア、赤丸ジャンプ、当たりがありますね。'],
#  ['らんま知ってますよ！高橋留美子先生の作品は好きです。', 'マツダスタジアムの球場グルメの泣ける！広島県は、すぐに売り切れるほど人気だそうです。'],
#  ['晴れと雨ではどちらが好きですか', '天気がいいとそれだけで元気が出ちゃうよね。'],
#  ['スイカなんかもいいですよね。',
#   '俳優の山田孝之さんが主演されている、日本コカ・コーラの缶コーヒー振り子のテレビコマーシャルのラーメン編は、ずっと頑なだった表情が最後に笑み崩れるのがとても面白かったです。'],
#  ['そうですね、自分でいじって作るみたいです。', 'おはよーございまーす'],
#  ['こんにちは！私も退屈してました。', 'おはよーございまーす'],
#  ['旅行良いですね。私は最近沖縄に行きましたよ。', 'ざわちんさんの出演されたハングリー!はどのような内容でしたか？。'],
#  ['食べに行ったり、温泉行ったりします。', 'パパイヤは味が強いですね'],
#  ['色が綺麗だよね', '食べ物は和食が好きですね'],
#  ['毎朝食べていますよ', 'じゃがりこはもともと、じゃがいものお菓子なので、たらこバターと合いそうですね。'],
#  ['じゃあ、用意して待ってます。', '海は最高ですか。海は好きですね'],
#  ['そうなんだ。運動神経良さそうだね。', '風見鶏という歌が好きです。まぁ、１番というのは非常に決めがたいですが…。'],
#  ['他にもシュウマイ等色々名物がありますよ。', '竹田城跡には行ったことがありますか？ 。'],
#  ['あなたは嫌いな食べ物はありますか。', '面白いですよね。よく小説とか読まれたりします？'],
#  ['ああ。周りの女子の話か。そう？', '日本にもそのような文化が根付くと、もっと家族で旅行に行ける気がします。'],
#  ['他にはスポーツをしたことはありますか？',
#   'あなたの住む街でぴあの街歩きテレビ番組ゲゲゲの女房の地方ロケが行われるとしたら、大泉洋さんに歩いて欲しい場所はありますか？ 。'],
#  ['蔵王ハートランドの夏は楽しいですか', 'リン・ユーチュンは好きで、アメリカでのサッカーワールドカップの時には涙したと言っていました。'],
#  ['どちらも興味ないね', '挑戦したんですか！！すげ〜！！じゃあ今年は一個いけるようにがんばってください!'],
#  ['１０回くらいで取れるかどうかですね。他にゲームセンターで好きなゲームはありますか？',
#   '神戸のメロンパンの皮〜焼いちゃいました〜が食べられるお店は予約しないと待ち時間がすごいほどの人気だそうですね。'],
#  ['私も体験したいです。', 'もつ鍋ですかー。私はキムチ鍋しましたよ！'],
#  ['扇風機も併用するのさ。塩分を補給するのも良いらしいよ？', '海にはものすごい量があるのに、取り出すのは案外手間がいるんだよね。'],
#  ['海はいいですよね。', 'ご存知ですいますよねー'],
#  ['死者が出るのは悲しいことですよ。', 'いいですねぇ'],
#  ['あなたは嫌いな食べ物はありますか。', 'ミートソースは好きですか。子供から大人まで好きな食べ物だね。'],
#  ['それなら最高の場所ですね。', 'いやぁ、それが朝起きたらもうすでに終わっちゃってるんです。'],
#  ['スイカなんかもいいですよね。', '女性ファッション誌とか地元情報誌とかです。'],
#  ['割りと好きなものが多く、嫌いなものは少ないですよ。ただエビアレルギーなので困っていますが。', 'おっ、私もなんですよ。場所はどこですか？'],
#  ['最近なら、この前食べた車エビが好きですね。エビ全般好きですね。', '歴史ものはいいですよね。歴史上の人物はだれが好きですか？'],
#  ['バレーの経験ならあるよ', 'おやすみ'],
#  ['好きな食べ物はなんですか？', '助け合いは当たり前ですよねえ'],
#  ['ニュージーランドが楽しいと思います。', '正しいにほんの言葉を使うことが求められているよね。'],
#  ['インターネットをしてることが多いです。', '好きな食べ物はなんですか？'],
#  ['焼きそばも好きです', '一年目って言っても、学部時代に４年過ごしてるから、あんまり新鮮味はないかも。'],
#  ['スカイプはゲームをする時に良く使います', 'なるほど、インターネットは便利ですよね。'],
#  ['それも見てませんけど、山田孝之さんの事をよく知っているんですね',
#   '挑戦したんですか！！すげ〜！！じゃあ今年は一個いけるようにがんばってください!'],
#  ['音楽が好きなの？', '雨はだるいです'],
#  ['カキ氷は好き？', '鎌倉では、ダ・ヴィンチの他に、カレーも有名です。'],
#  ['そうなんだ、今度買ってみます。', '退屈なときが、実は一番幸せな時なんだって。'],
#  ['インターネットをしてることが多いです。', '昨日は見られませんでしたけど、カナダ戦は見ました。'],
#  ['こんにちは。少しお話ししましょう。', '最新の洋楽って、最近の人はあまり聞かないのかなあ。'],
#  ['カラオケとかよく行くんですか？', 'ご想像にお任せします。'],
#  ['そうなんです。色んなものがトッピングされていてとてもかわいいし、見た目だけじゃなくておいしいです。', 'イタリアはとても面白いそうですね。'],
#  ['知らないユニットです。', '雨は欲しいですね'],
#  ['晴れた日にいきたいですよね', 'ズバリ鍋！！私も鍋大好きです。先日も友人ともつ鍋を食べに行きました。'],
#  ['それは初耳です。', '洋書でいったらTuesday\u3000with\u3000Morrieを読んで泣きそうになりました。'],
#  ['好きな食べ物はなんですか？', 'BrainWarsを観戦するために観光客がたくさん訪れると、日本の景気が少しだけ良くなるような気がします。'],
#  ['私は知りませんが、探せばあるのではないですか。',
#   '色々あって難しいところですが、最近だと我が名は海師・王様の仕立屋・コンシェルジュなどが気に入ったので１巻からまとめ買いしたところです。'],
#  ['家の猫は仲良くしてますよ。', '3姉妹は仲が良いですか'],
#  ['最近はもう長距離泳げなくなりましたが頑張ります。あなたはスポーツは何かしていますか？',
#   'そうですか。漫画は、手軽に一人で楽しめるのでとてもいいですよね。'],
#  ['勉強になりました', '確かに。。'],
#  ['ボードですか、楽しそうですね', '私が好きなマンガは結構マイナーなんで…有名どころで行くと、ハンター・ハンターとかツバサなんかはオススメです。'],
#  ['あなたは嫌いな食べ物はありますか。', '予防が重要ですね'],
#  ['大阪といえば、道頓堀が有名ですよね。', '今日は自分で夕ご飯を作る予定だけど、暇なら手伝ってよ。'],
#  ['コブクロいいですねー私はゆずが好きです', '家族で食事に行きますか？'],
#  ['私も行きたい', '食べ物は和食が好きですね'],
#  ['初めて聞きました。今度調べてみます。まだまだ暑い日が続きますね。', '国内で死者が出てるんですかね？'],
#  ['政治家の失言は多いですね', 'そうですね、散歩がてら買い物にでも出ます'],
#  ['そのミステリ、私も読んでみたいです。', '確かに。。'],
#  ['ラーメンも美味しいですよね', '一番栄養価の高い果物はアボガドで、ギネスにも認定されてるんだって。'],
#  ['それなら最高の場所ですね。', 'ゴーヤチャンプルは好きですね'],
#  ['当たらないと思います', '焼肉もしながらとかできるのかな？'],
#  ['あなたも寝ることはあるんですか？', '海にはものすごい量があるのに、取り出すのは案外手間がいるんだよね。'],
#  ['私はうどんです。', '大分別府はいんですか？？大分別府まで九州横断特急に乗りますよねー'],
#  ['シークヮーサー味より紅芋味が面白そうです', '最近は全然していませんが、基本的には好きですよ。'],
#  ['そうですね、海外旅行に行った時なんかは危険が多いのでいろいろ考えながらケースバイケースに対応しますね。', '熱中症に気をつけてたいですか？'],
#  ['お好きな食べ物は何ですか？', 'そば湯はあるけど、うどん湯ってあるのかな？'],
#  ['私も蕎麦が大好きですよ。', '水が綺麗ですね'],
#  ['眠いのですか？',
#   '神戸にあるグランフロント大阪のアイスクリームの中身は、鳥達のえさを人間が食べやすいようにアレンジしてあるのですが、トッピングに特徴があって、インコの背中の匂いを味にした粉をアイスクリームにかけて食べるそうです。'],
#  ['ジーコってブラジルの元サッカー選手だよね？', 'ほんとー！なんか外に行きたくなっちゃいますね、旅行とか、いいですね〜。'],
#  ['宮崎は自然が豊かだからね', 'お天気の良さはどうですか？'],
#  ['こちらこそよろしくお願いします', 'ご想像にお任せします。'],
#  ['はい。麺類は美味しいから好きです。', '材料費にお金をかけたいですよねえ'],
#  ['へー。最近のお気に入りは煮干系ラーメンです。',
#   'あなたの住む街でぴあの街歩きテレビ番組ゲゲゲの女房の地方ロケが行われるとしたら、大泉洋さんに歩いて欲しい場所はありますか？ 。'],
#  ['宮崎は自然が豊かだからね', '鶴の子 大粒納豆の作者浦沢直樹が描いた漫画で他に読んだものはありますか？ 。'],
#  ['私も行きたいです', 'パパイヤは味が強いですね'],
#  ['気持ちいいよね',
#   'タレントの千原ジュニアが劇団四季の新作のミュージカル、アラジンの中で宮川大輔役なる可能性もあるらしく、もし実現したら面白そうなので私は見てみたいです。'],
#  ['大人の味ってほろ苦いというイメージですかね。', '映画は面白いですね'],
#  ['好きな食べ物はありますか？', 'ですなっ、おやすみんちですぅ\u3000\u3000\u3000'],
#  ['あなたも寝ることはあるんですか？', '瀬戸内とオランダなら、どちらに興味がありますか？'],
#  ['夏は海だよね', '日本にいて見られるかどうかがポイントなのですね。']]

# %%
UT = ut_new + fake_error(ut_no_new, len(ut_no_new)-len(ut_new))
UT_NO = ut_no_new

# %%
print("UT: {0}".format(len(UT)))
print("UT_NO: {0}".format(len(UT_NO)))
# Out:
# UT: 1056
# UT_NO: 1056

# %%
X = feature_extraction(pos_list, UT + UT_NO , mode="dif", is_norm=True)
y = np.concatenate( [ np.ones(len(UT)), np.zeros(len(UT_NO)) -1 ] )
y
# Out:
# array([ 1.,  1.,  1., ..., -1., -1., -1.])

# %%
print("ut: {0}, ut_new: {1}, dif:{2}".format(len(ut), len(ut_new), len(ut)- len(ut_new)))
print("ut_no: {0}, ut_no_new: {1}, dif:{2}".format(len(ut_no), len(ut_no_new), len(ut_no)- len(ut_no_new)))
# Out:
# ut: 192, ut_new: 170, dif:22
# ut_no: 651, ut_no_new: 528, dif:123

# %%
model = SVC(kernel="rbf", random_state=2, C=0.1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model.fit(X_train, y_train)
# Out:
# SVC(C=0.1, random_state=2)

# %%
y_pred = model.predict(X_test)
# y_pred = np.ones(len(y_test))-2

# %%
len(y_test)
# Out:
# 423

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
print('confusion matrix = \n', confusion_matrix(y_true=y_test, y_pred=y_pred))
print('accuracy = ', accuracy_score(y_true=y_test, y_pred=y_pred))
print('precision = ', precision_score(y_true=y_test, y_pred=y_pred))
print('recall = ', recall_score(y_true=y_test, y_pred=y_pred))
print('f1 score = ', f1_score(y_true=y_test, y_pred=y_pred))
# Out:
# confusion matrix =
#  [[180  45]
#  [120  78]]
# accuracy =  0.6099290780141844
# precision =  0.6341463414634146
# recall =  0.3939393939393939
# f1 score =  0.48598130841121495

# %%
for x in ut_no[:10]:
    
    f = feature_extraction(pos_list, x, mode="dif", is_norm=True)
    pred = np.argmax( clf.predict(f), axis=0 )
    print(pred, x)
# Out:
# 0 ['そうですか。山に行くのはどうでしょうか？', 'わあ！いいですね！']
# 0 ['明日はとても暑くなるみたいですね。', 'ご存知になりたいです']
# 0 ['涼しくなってきたら、一緒に山へ行きたいですね。', 'ご存知ですいますよねー']
# 0 ['美味しいですね。', '美味しいよ']
# 0 ['でも高いですね', 'いくら']
# 1 ['サスペンスが好きです', '映画はヒューマン系が好きですね']
# 0 ['そうですか', 'あはい']
# 0 ['こんばんは。今日は暑かったですね。', 'ところで、スイカの種って実は栄養豊富なんだそうですよ。']
# 0 ['ありがとう。野菜もたっぷり食べて、栄養をバランスよく摂りたいです。', '野菜でヘルシーよねー']
# 0 ['こんにちは。元気ですね', '夕食は食べましたか？']

# %%
from sklearn.ensemble import AdaBoostClassifier
clf = AdaBoostClassifier()

# %%
clf.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred = clf.predict(X_test)
print('confusion matrix = \n', confusion_matrix(y_true=y_test, y_pred=y_pred))
print('accuracy = ', accuracy_score(y_true=y_test, y_pred=y_pred))
print('precision = ', precision_score(y_true=y_test, y_pred=y_pred))
print('recall = ', recall_score(y_true=y_test, y_pred=y_pred))
print('f1 score = ', f1_score(y_true=y_test, y_pred=y_pred))
# Out:
# confusion matrix =
#  [[161  64]
#  [ 80 118]]
# accuracy =  0.6595744680851063
# precision =  0.6483516483516484
# recall =  0.5959595959595959
# f1 score =  0.6210526315789473

# %%
# Out:
# ['test_sen.ipynb',
#  '.gitignore',
#  'LiveComp',
#  'paper',
#  'UNI',
#  '.git',
#  'theme',
#  'corpus',
#  'test_bert.py',
#  'sentece.py',
#  'path_test.py']
