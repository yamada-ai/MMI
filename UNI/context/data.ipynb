# %%
import json
import pandas as pd
import numpy as np
from pathlib import Path
import collections


from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
# path = "../error_category_classification/dbdc5_ja_dev_labeled/"
path = "../hand_labeled/"
datalist = ['DCM', 'DIT', 'IRS']

output = "./"

# %%
def read_json_with_NoErr(path:str, datalist:list) -> pd.DataFrame:
    cols = ['did', 'tid', 'usr', 'sys', 'ec']
    df = pd.DataFrame(index=[], columns=cols)

    for p in datalist:
        datapath = Path(path + p + '/')
        for file in datapath.glob("*.json"):
            with open(file, "r") as f:
                json_data = json.load(f)
                did = json_data["did"]
                for t in json_data["turns"]:
                    if t["turn-index"] == 0:
                        continue
                    if t["speaker"] == "U":
                        usr = t["utterance"]
                        continue
                    if t["speaker"] == "S" :
                        tid = t["turn-index"]
                        sys = t["utterance"]
                        if t["error_category"]:
                            ec = t["error_category"]
                        else:
                            ec = ["No-Err"]
                        df = df.append(pd.DataFrame([did, tid, usr, sys, ec], index = cols).T)
    df.reset_index(inplace=True, drop=True)
    return df

# %%
def extract_error(df, errors):
    utterances = []
    for d, u, s, e in zip(df.did, df.usr, df.sys, df.ec):
        for err in errors:
            if err in e:
                utterances.append([u, s])
    return utterances

# %%
def no_error(df):
    utterances = []
    system = []
    user = []
    for d, u, s, e in zip(df.did, df.usr, df.sys, df.ec):
        if e[0] == "No-Err":
            utterances.append([ u, s])
        # system.append(s)
        # user.append(u)
    return utterances

# %%
df = read_json_with_NoErr(path, datalist)

# %%
df
# Out:
#              did tid                   usr  \
# 0     1470646494   2    そうですね。最近とても暑いですから。
# 1     1470646494   4         休日に行きたいと思います。
# 2     1470646494   6       はい。あなたは海に行きますか？
# 3     1470646494   8                何故ですか？
# 4     1470646494  10  そうですか。山に行くのはどうでしょうか？
# ...          ...  ..                   ...
# 1995  1503290726  12           何を別売りしているの？
# 1996  1503290726  14            今は2回押してないよ
# 1997  1503290726  16              ベーシックだよね
# 1998  1503290726  18              君は女性なんだね
# 1999  1503290726  20                 両性なのか
#
#                                            sys  \
# 0                                  海に行かないんですね？
# 1                                     海は大丈夫ですね
# 2                                       海は危険です
# 3                                     海はいけないです
# 4                                    わあ！いいですね！
# ...                                        ...
# 1995           地下鉄で。名大前ができてすごく便利になりましたね、ここの大学。
# 1996  紅葉も遅いみたいですしね。私は、いつもベーッシクな色で変わりばえしないのですが。
# 1997     何処にあるお店ですか？ベースコートもトップコートも塗ると持ちが違いますよ。
# 1998                                    中間ですか？
# 1999                          では、スポーツは何かしてますか？
#
#                                          ec
# 0                           [Contradiction]
# 1                     [Lack of information]
# 2     [Ignore question, Self-contradiction]
# 3                         [Ignore question]
# 4                                  [No-Err]
# ...                                     ...
# 1995                           [Repetition]
# 1996               [Topic transition error]
# 1997               [Topic transition error]
# 1998                  [Lack of information]
# 1999               [Topic transition error]
#
# [2000 rows x 5 columns]

# %%
errors = ["Topic transition error", "Unclear intention", "Lack of information"]
errors = ["Lack of information"]
errors = ["Topic transition error"]

# %%
ut = extract_error(df, errors)

# %%
ut_no = no_error(df)

# %%
print(len(ut))
print(len(ut_no))
print(ut_no[0])
# Out:
# 192
# 651
# ['そうですか。山に行くのはどうでしょうか？', 'わあ！いいですね！']

# %%
import spacy
nlp = spacy.load('ja_ginza')
vec_dim = nlp("形態素").vector.shape
vec_dim
# Out:
# (300,)

# %%
from pyknp import Juman
from sentence_transformers import SentenceTransformer
import scipy.spatial
model_path = "/home/yamada/Downloads/training_bert_japanese"
Nmodel = SentenceTransformer(model_path, show_progress_bar=False)
emb_dim = Nmodel.encode(["お辞儀をしている男性会社員"])[0].shape[0]

# %%
def _in(arg1, arg2):
    result = False
    if isinstance(arg1, list):
        for element in arg1:
            if isinstance(element, str):
                if element in arg2:
                    result = True
                    break
            else:
                if element == arg2:
                    result = True
                    break
    else:
        if isinstance(arg1, str):
            if arg1 in arg2:
                result = True
        else:
            if arg1 == arg2:
                result = True
    return result

# %%
def filter_pos_vector(pos_list, text):
    vec = np.zeros(vec_dim)
    doc = nlp(text, disable=['ner'])
    for token in doc:
        # print(token, token.tag_)
        if "助動詞" not in token.tag_ and _in(pos_list, token.tag_):
            # print(token, token.tag_)
            vec += token.vector
    return vec

# %%
def feature_extraction(pos_list, convs, mode, is_norm=False):
    feature_list = []
    for utt in convs:

        if mode == "dif":
            vector = Nmodel.encode(utt)
            # usr_vec = filter_pos_vector(pos_list, utt[0] )
            usr_vec = vector[0]
            # sys_vec = filter_pos_vector(pos_list, utt[1] )
            sys_vec = vector[1]
            dif_vec = usr_vec - sys_vec

            # feature_list.append( dif_vec/np.linalg.norm(dif_vec) )
            # feature_list.append( dif_vec )
            if np.linalg.norm(dif_vec)==0:
                print(utt)
            if is_norm:
                # print(np.linalg.norm(dif_vec))
                if np.linalg.norm(dif_vec)==0:
                    vec = np.concatenate( [dif_vec, dif_vec/0.05] )
                else:
                    vec = np.concatenate( [dif_vec, dif_vec/np.linalg.norm(dif_vec)] )
                feature_list.append(vec)
            else:
                feature_list.append(dif_vec)
    
    return np.array(feature_list, dtype="float32")

# %%
def remove_norm_zero(pos_list, convs):
    convs_removed = []
    for utt in convs:
        usr_vec = filter_pos_vector(pos_list, utt[0] )
        sys_vec = filter_pos_vector(pos_list, utt[1] )
        dif_vec = usr_vec - sys_vec
        if np.linalg.norm(dif_vec)==0 or np.linalg.norm(usr_vec)==0 or np.linalg.norm(sys_vec)==0:
            continue
        convs_removed.append(utt)
    return convs_removed

# %%
pos_list = ["名詞", "動詞", "形状詞", "形容詞"]
ut_new = remove_norm_zero(pos_list, ut)
ut_no_new = remove_norm_zero(pos_list, ut_no)

# %%
import random
def fake_error(convs, times):
    user_list = []
    system_list = []
    for utt in convs:
        user_list.append(utt[0])
        system_list.append(utt[1])
    
    fake_convs = []
    for _ in range(times):
        fake_convs.append( [random.choice(user_list), random.choice(system_list)] )
    return fake_convs

# %%
fake_error(ut_no_new, len(ut_no_new)-len(ut_new))
# Out:
# [['よろしくお願いします。', '日本語で考えて、英語で話していると相手にはどうも伝わりにくいようですので、英単語を並べたほうがまだ伝わるようですよ。'],
#  ['好きな食べ物はありますか？', '扇風機を併用するんですね。エアコンは欲しいですね'],
#  ['こんにちは。いつも家では仕事をしています。',
#   'ウィザーディング・ワールド・オブ・ハリー・ポッターエリアでもユニバーサル・スタジオ・ジャパンのようかい体操第一のオープン前から、たくさんコマーシャルが流れていました。'],
#  ['どんな食べ物にも合いますね',
#   '私もどちらかというとインドア派で家でのんびり映画とか見てるのが好きなんですが、１３さんは、家でどんな風にのんびり過ごすのが好きですか？'],
#  ['そんな事もないと思いますよ。', 'ご想像にお任せします。'],
#  ['最近はまってることは読書です', '最近はさっぱりですね。'],
#  ['大人の味ってほろ苦いというイメージですかね。', '面白いですよね。よく小説とか読まれたりします？'],
#  ['栗原はるみさんですね', 'ミートソースは好きですか。子供から大人まで好きな食べ物だね。'],
#  ['はい。麺類は美味しいから好きです。', '腰は痛みが走るんですよねぇ'],
#  ['その通り。基本です。', '海水浴は楽しいんですか？？海は楽しいですね'],
#  ['日焼けすると赤くなる', '確かに、最近は昔嫌いだったものが好きになってきました。'],
#  ['コブクロと言えば、絢香とのコラボの曲が好きです。', 'インターネットは便利ですね'],
#  ['ボードゲームです', '麺類は食べやすいですね'],
#  ['忙しくなりそうですね。専攻は？', '予防を怠るようです'],
#  ['私も沖縄大好きですよ。', '防水はいいそうです'],
#  ['何が好きになったんでしょう。私はコーヒーが飲めるようになりましたよ。', '防水はいいそうです'],
#  ['占いというのは下らないね',
#   '色々あって難しいところですが、最近だと我が名は海師・王様の仕立屋・コンシェルジュなどが気に入ったので１巻からまとめ買いしたところです。'],
#  ['そこも興味があります。食べてみたいな。', '気持ちがいいですね'],
#  ['晴れと雨ではどちらが好きですか', 'マイブームかぁ・・・。旅行です。'],
#  ['糖度がね。値段も高いよ。', '機会があったら、ぜひ横浜の名物の伊藤久右衛門宇治抹茶を食べてみてください。'],
#  ['しません', 'ユニバーサル・スタジオ・ジャパンのフローズン・フィーバーに興味がありますか？。'],
#  ['奥様は魔女って、昔、そういうドラマがありましたね。ご存じですか？', '果物は安いそうです'],
#  ['じゃあ私からいきますよ、リンゴ。', '果物は朝がいいですね'],
#  ['テナーサックスはやっていませんよ', '熱中症に気をつけか？？'],
#  ['新鮮な気持ちになりたいですよね', 'すごいですね。私はあまり読書できないので。'],
#  ['そうだね。エントリーっていうのがちょっとよくわからないけど。', '今、ボードゲームにはまってますね。'],
#  ['観光地の食べ物は高いですもんね。', '趣味は…寝ること、マンガを読むこと、ネットサーフィン、などなどです。'],
#  ['迫力があって楽しそうですね！', '私もどちらかというとｊ−POPですね'],
#  ['物知りですね。私は必ずチャーシュー麺を頼みます。',
#   'ヨガちょっとやってみたいです！やっぱりやり始めてからは体の調子いいですか？お風呂上がりにストレッチやろうと思うのですが、なかなか続かなくて。'],
#  ['何ですかそれは、それを聞いて、食べる気が失せました。', '熱中症で死者が出る予定です'],
#  ['濡れると大変ですよね。', 'お天気の良さはどうですか？'],
#  ['残業はごくたまにありますね。', 'スロットがもっとも盛り上がっていた時代ですね。'],
#  ['そうなんだ。むしろとかゴザってレジャーシート代わりに親がよく使っていたよ。',
#   '趣味は…寝ること、マンガを読むこと、ネットサーフィン、などなどです。'],
#  ['そうなりたいです', 'カルビーから販売しているほろにがビターチョコ味というお菓子も美味しいですよ。'],
#  ['仲良しな感じがするね。', 'パパイヤは味が強いですね'],
#  ['他にはスポーツをしたことはありますか？', '天気がいいとそれだけで元気が出ちゃうよね。'],
#  ['濡れると大変ですよね。', 'お酒は多いです'],
#  ['好きな食べ物は何ですか？', 'そうですね。結果だけ聞くよりもどうなるかワクワクしながら観る方が面白いと思います。'],
#  ['うん、楽しいね。芸人さんの深夜ラジオもよく聴くし。', '天気がいいとそれだけで元気が出ちゃうよね。'],
#  ['うちでは猫と犬を一緒に飼っています。', '山田孝之さんと言えば、11月12日に待望のニューシングルが発売されますね。'],
#  ['夜中に地震が起きたらパニックになるかも', '好きなボードゲームはありますか？'],
#  ['普段から水分をしっかりとる様に心がけてます。', 'どっちなんですか？'],
#  ['ミステリー小説が多いです', '飼ってみたら猫好きになりました'],
#  ['ごめんなさい。カピターノ・ミッキー・トリプルルームに行ったことがないので、わかりません',
#   '人志松本のすべらない話というテレビ番組で、ミケランは木部さんというキャラクターに変装して一般人を騙していますね。'],
#  ['雨は好きですか？', '材料費にお金をかけたいですよねえ'],
#  ['同じ姿勢を続けるのはよくないらしいよ', '腰は大切ですね'],
#  ['小さい頃は入ってましたが、今は皆成人しているので', '焼きそばは好きですか。麺が美味しいですね'],
#  ['宮部みゆきなんてどう？', 'ラーメンはスープが美味しいですね'],
#  ['宮崎は自然が豊かだからね', 'ご想像にお任せします。'],
#  ['よく小説を読みます', '正しいにほんの言葉を使うことが求められているよね。'],
#  ['蔵王ハートランドの夏は楽しいですか', 'マイブームかぁ・・・。旅行です。'],
#  ['ワクワク感がいいよね。', 'ご想像にお任せします。'],
#  ['物知りですね。私は必ずチャーシュー麺を頼みます。', 'え、マラソンかな'],
#  ['趣味はいいですね', 'よく映画を見に行くのですか。'],
#  ['お好きな食べ物は何ですか？', '豆腐\u3000です。'],
#  ['カラオケとかよく行くんですか？',
#   'ナゴヤドームの名古屋には、味噌カツの他に、名古屋名物の唐揚げ手羽先や味噌煮込みうどんや天むす など美味しい食べ物がいっぱいあるんでしょね。'],
#  ['もうすぐ旅行にいくのでそれが楽しみです', '結構好き嫌いなくなんでも食べますよ。'],
#  ['小学校でにっぽんと教わったので私はにっぽんですね', 'そうですね、秋晴れですね。'],
#  ['子供の頃に真似事はしました。',
#   '色々あって難しいところですが、最近だと我が名は海師・王様の仕立屋・コンシェルジュなどが気に入ったので１巻からまとめ買いしたところです。'],
#  ['誰？それ',
#   '毎日放送のオールザッツ漫才という番組の内容としては、有名な漫才師たちは、しっかりとした持ち時間で早い時間帯に漫才をするのですが、遅い時間になると、売れない若手芸人たちが漫才などを披露して勝ち抜き戦を行い、優勝者を決めるコーナーがあります。'],
#  ['海のどこが好きですか?',
#   '4、5年前にユニバーサル・スタジオ・ジャパンに一度行った事があり、Ban汗ブロックロールオンに乗った事を覚えています。あとは大きなジョーズのオブジェの前で写真を撮りました。'],
#  ['たまには遠出するのも悪くありません。', '遠出は好きですね'],
#  ['海いいですね', '焼肉もしながらとかできるのかな？'],
#  ['こんにちは、私は山田孝之の方に興味があります', '野菜でヘルシーよねー'],
#  ['私もマンガを読むことが好きですね。', '労働基準法があるから、残業しすぎないように気をつけて！'],
#  ['本は読まれますか？', 'エゾシカを見ましたね'],
#  ['そうですね。毎年死者が出てしまっていますね。', '良いの？それはあまり気にしたことなかった'],
#  ['新しい発見があるかもしれませんからね。', 'そうですね、散歩がてら買い物にでも出ます'],
#  ['そのミステリ、私も読んでみたいです。', 'ご存知ですいますよねー'],
#  ['カードゲームです', '尾道駅近くにレンタサイクルがあって、そこで自転車を借りて走り、因島大橋などを渡ってきました。'],
#  ['そうですね。退屈ですもんね。', 'ご家族は何人ですか？'],
#  ['セブンイレブン知ってるんだね。', 'やはり女子に期待ですか？'],
#  ['カキ氷は好き？', 'めまいは少ないですか'],
#  ['私は柑橘系が好きですね。', '読書は楽しいですね'],
#  ['どんな芸でしょう？', 'ユーって呼んでください。'],
#  ['山田孝之かな', 'いつもはしないんだけど'],
#  ['個性は大事ですね。', '春と秋が気温的には一番いいですよね。'],
#  ['今はインターネットでの買い物が多いです。', '結構作ってますよ。前までは全然作れなかったんですが、やっぱり一人暮らしだと自然に覚えていきました。'],
#  ['そうだね。エントリーっていうのがちょっとよくわからないけど。', 'おやすみ'],
#  ['大阪です。', '新作には、あの二台のロボット、また出てくるかなあ。'],
#  ['今日はいい天気ですね。', 'ですなっ、おやすみんちですぅ\u3000\u3000\u3000'],
#  ['そうですね。あなたは犬と猫ではどちらが好きですか？', '好きなボードゲームはありますか？'],
#  ['何が好きになったんでしょう。私はコーヒーが飲めるようになりましたよ。', '趣味は…寝ること、マンガを読むこと、ネットサーフィン、などなどです。'],
#  ['スポーツ観戦です。あなたの趣味は？', '気持ちがいいですね'],
#  ['それは興味がありますね。', '沖縄はサイコーですね'],
#  ['新しい発見があるかもしれませんからね。', 'マンゴーは甘酸っぱいですよねー'],
#  ['おや、そうですか',
#   '大阪にある海遊館の元気やという名前のハンバーガー店では、値段設定が高めな分、本格的な味わいのハンバーガーが楽しめるかもしれませんね。'],
#  ['それは失礼しました', '女の人ほど、血液型にこだわるよね。'],
#  ['じゃがアリゴっていう料理が流行ってるらしいね。', '高齢者が多いですよねー'],
#  ['カードゲームです', 'どんな本を読みますか？'],
#  ['毎日放送ってことはMBSだね。', '最近だと旅行にはまりだしたので、旅代で消えてしまいますね。'],
#  ['興味のないことでもよく見たり覚えたりしないとだめですね。',
#   '結構作ってますよ。前までは全然作れなかったんですが、やっぱり一人暮らしだと自然に覚えていきました。'],
#  ['雑種が好きですね', 'へぇ！日本のアニメは世界的に人気が高いみたいですもんね。'],
#  ['ミュージカルは行ったことはないですね。', 'え、マラソンかな'],
#  ['大丈夫じゃないよ。死んでしまうかもしれないから。', '最新の洋楽って、最近の人はあまり聞かないのかなあ。'],
#  ['ゲームです', '映画は面白いですね'],
#  ['気をつけていますよ。水分を多めに摂っています。', '高齢者が多いですよねー'],
#  ['コブクロと言えば、絢香とのコラボの曲が好きです。', '誘われたら飲みに行きますよ。'],
#  ['新しい発見があるかもしれませんからね。', 'いえいえ'],
#  ['夏は海だよね', '出演する俳優さんで観るか決めたりしますよ。'],
#  ['今度の選挙は投票率が高いといいね。', '太陽風や地場を予測する「宇宙天気予報」っていうのもあるんだって。'],
#  ['塩辛なんかも塩加減が色々あって、好みの味は甘口ですよ。',
#   '料金が1,000円かかりますが、蔵王ハートランドで行われている蔵王高原大根狩りというイベントは、申し込みをすれば、誰でも参加できると思います。'],
#  ['そうなんですよ。そのようなサイトもあるんですね。', '紅玉が良いですね'],
#  ['大阪といえば、道頓堀が有名ですよね。', '音楽は人間を幸せにするものすごいパワーがあると思うよ。'],
#  ['誰？それ',
#   'やはり辛いのですか。以前見た本場、韓国のキムチ作りを取り上げた番組で、韓国のおばちゃんは白菜を洗濯機で洗う荒技を披露していましたが、考えてみれば日本の電動餅つき器もかなり異質なマシーンですね。'],
#  ['自分は四季劇場かな？', 'みんな長編だから、読むときは気合いが必要だね。'],
#  ['特にしてません。日々のストレッチ程度ですね。', '扇風機を併用するんですね。エアコンは欲しいですね'],
#  ['科学がお好きですか？', '新作には、あの二台のロボット、また出てくるかなあ。'],
#  ['室内でも熱中症になるそうですね。', 'いつくるかわからない恐怖感がずっとあるのも嫌ですね。'],
#  ['物知りですね。私は必ずチャーシュー麺を頼みます。', 'ラジオは聞くのがいいですね'],
#  ['私は知りませんが、探せばあるのではないですか。', '防水はいいそうです'],
#  ['そば湯は大好きです', 'そうですね、散歩がてら買い物にでも出ます'],
#  ['海のどこが好きですか?', '鎌倉では、ダ・ヴィンチの他に、カレーも有名です。'],
#  ['アニメ映画はいいですね。ズートピアが面白かったです',
#   '大阪の世界最大級の水族館である海遊館の飼育員さんはサメの水槽の上から一気に餌を流し込むなんて、とても豪快ですね。'],
#  ['動物園に行ったりしますか？', '意外と歴史は古くて、１９４１年ごろ、福岡の中洲で作られたんだ。'],
#  ['短距離ですか？長距離ですか？', '腰は痛みが走るんですよねぇ'],
#  ['青い空が最高だね', '腰は大切ですね'],
#  ['割りと好きなものが多く、嫌いなものは少ないですよ。ただエビアレルギーなので困っていますが。', '趣味は深いですよねえ'],
#  ['私は洋楽が好きなんです', 'そうですね。結果だけ聞くよりもどうなるかワクワクしながら観る方が面白いと思います。'],
#  ['アウトレットではどのような物を買ったのですか？',
#   '以前、俳優の山田孝之さんが出演したテレビ番組で、演技に関するインタビューに答えていたのですが、それがとても興味深い内容でした。'],
#  ['私も行きたい', '予防が重要ですね'],
#  ['どちらかというとざわちんかな。\u3000モノマネメイクしてみたくならない？', '3姉妹は仲が良いですか'],
#  ['すごい。行ってみたい。', '登山はスポーツ競技ですね'],
#  ['私は特に打ち上げ花火が見たいです。', '気持ちがいいですね'],
#  ['危険ですよ。水分補給をしてくださいね。',
#   'いえ、私用ではあまり遠出することはないのですが、仕事柄あちこちに行くことが多く、近い距離の場合は自転車か原付で移動しています。'],
#  ['ああ。周りの女子の話か。そう？', 'ミートソースは好きですか。子供から大人まで好きな食べ物だね。'],
#  ['はい。麺類は美味しいから好きです。', 'どんな種類の猫なんですか？'],
#  ['たまには遠出するのも悪くありません。', '有名人で松坂大輔とヒロ・ハマダなら、どちらに興味がありますか？'],
#  ['そんな番組があるのですね。', '嬉しいです！'],
#  ['その通り。基本です。', '雨は欲しいですね'],
#  ['こんにちは。よろしくお願いします。', '日本で最初にラーメンを食べたのは、水戸黄門こと徳川光圀らしいよ。'],
#  ['雨がずっと降らないと困るけど', '朝から海に行きますか？？'],
#  ['何かスポーツをするのは、どうですか？', 'お遍路の逆回りは迷いやすくて大変なぶん、ご利益が大きいらしいよ。'],
#  ['四国の食べ物と言えば、なにが好きですか？',
#   '洋書でいったらTuesday\u3000with\u3000Morrieを読んで泣きそうになりました。'],
#  ['そうですね。退屈ですもんね。', 'カルビーじゃがりこが好きで良く食べるので、一度電子レンジで温めて食べてみたいと思います。'],
#  ['他にはスポーツをしたことはありますか？', '今は３年生です。そろそろ就活と卒論に怯える日々が近づいてます…。'],
#  ['好きな映画はありますか？', '歴史ものはいいですよね。歴史上の人物はだれが好きですか？'],
#  ['四国には行ったことがありません。', '自分的にもあれが原点ですね＞古谷金田一'],
#  ['それは失礼しました', 'どこか出かけるんですか？'],
#  ['一度は富士山に登ってみたいですね。', '気持ちがいいですね'],
#  ['確かに気をつけて泳がないといけませんね', '海は好きですね'],
#  ['私はうどんです。', '特にないんです。すみません。強いていうなら映画鑑賞とかでしょうか。'],
#  ['政治家の失言は多いですね', 'よく映画を見に行くのですか。'],
#  ['ごめんなさい。カピターノ・ミッキー・トリプルルームに行ったことがないので、わかりません', 'お好み焼き？！いいですねぇー。関西風ですか？!'],
#  ['ざわちんですね。', 'どんな種類の猫なんですか？'],
#  ['水分補給、こまめにしてるよ。', 'その際のお写真に添えるかもしれない'],
#  ['ミステリーですね', '木陰で涼しいですしね。'],
#  ['美味しいのにね。',
#   'ハビエル・アギーレ監督もサッカー日本代表のホンジュラス戦とオーストラリア戦は勝ちに行くと言っていたので、選手起用も含め楽しみですね。'],
#  ['迫力があって楽しそうですね！', '気持ちがいいですね'],
#  ['スポーツ観戦です。あなたの趣味は？', '透明度が抜群にいいですね'],
#  ['あなたはどんな音楽が好きですか？', 'いつもはしないんだけど'],
#  ['ジーコってブラジルの元サッカー選手だよね？', '日泰寺とかですか？違うかな'],
#  ['産地偽装はダメです。', '退屈を嫌いますか？'],
#  ['今まで旅行した所で、一番良かったのは何処ですか？', '蕎麦ほど、地域色の出る食べ物はないよね。'],
#  ['こんにちは！三浦知良だよ',
#   'スーザンボイルさんのSAKURAドロップスのプロモーションビデオは、自分の部屋でセルフ撮影しているような設定なのが特徴ですよね。'],
#  ['それは興味がありますね。', '防水、カッティング、エントリー、いろいろあるよね。'],
#  ['競泳で金メダルでましたね', 'どっちなんですか？'],
#  ['他に好きな飲み物は？', 'やはり女子に期待ですか？'],
#  ['当たらないと思います',
#   '恩納村のフォレストアドベンチャーという施設には、インストラクター無しで、1人で滑るので、高い所が苦手な方には、少しキツイと思います。'],
#  ['猫が好きです', '俳優の山田孝之さんが主演されている、映画版のオールザッツ漫才には、ゲストにどのような役者が出演していましたか？ 。'],
#  ['見たことある？', '車で買い物に行くのです'],
#  ['ペトリコールって初めて聞いたよ。科学に詳しいんだね。', '自分的にもあれが原点ですね＞古谷金田一'],
#  ['マンゴーが有名ですよね', '女の人ほど、血液型にこだわるよね。'],
#  ['私は柑橘系が好きですね。', 'ご想像にお任せします。'],
#  ['こんにちは。暑いですね。', 'いやぁ、それが朝起きたらもうすでに終わっちゃってるんです。'],
#  ['よろしくお願いします。', '犬だね'],
#  ['扇風機も併用するのさ。塩分を補給するのも良いらしいよ？', 'ところで、老後は海したいと話をしていましたよね？海は恐ろしいです'],
#  ['それは失礼しました',
#   '以前、俳優の山田孝之さんが出演したテレビ番組で、演技に関するインタビューに答えていたのですが、それがとても興味深い内容でした。'],
#  ['ペトリコールって初めて聞いたよ。科学に詳しいんだね。', 'ゲームですか．いいですね・'],
#  ['決勝も見てますよ。', 'そうですね。産地偽装はよくない行為ですね。'],
#  ['子供は好きですか？', 'そうですか！私は苦手です。。。冬服は重いし高い。'],
#  ['それなら最高の場所ですね。', '歯ごたえが良いですね'],
#  ['スペインの魅力を教えてください', 'いつくるかわからない恐怖感がずっとあるのも嫌ですね。'],
#  ['そちらも行ってみたいです。', '鎌倉では、ダ・ヴィンチの他に、カレーも有名です。'],
#  ['いいお天気ですね', '晴れは気持ちがいいですね'],
#  ['へ〜。セブンイレブンのコーヒーは飲んだことある？', '劇団四季が2015年5月24日から上演予定の新作のミュージカルはアラジンだそうです。'],
#  ['沖縄行きたいです！',
#   'ぜひ一度滝野スノーワールドのありあけハーバーに行きたいと思っていますが、私が住んでいる国営滝野すずらん丘陵公園からは遠いのでなかなか行けるチャンスがありません。'],
#  ['そうだね。でも美味しいから食べちゃうよね。', '海は一人で行ってます？'],
#  ['晴れと雨ではどちらが好きですか', 'そうなんです！それが楽しいんですよ！なにせみんな馬鹿なんで。'],
#  ['大丈夫じゃないよ。死んでしまうかもしれないから。', '美味しいですけど、近年は値上がりしていて辛いですね。'],
#  ['いえ、知りませんでした。', '糖度が下がるらしいです'],
#  ['奥様は魔女って、昔、そういうドラマがありましたね。ご存じですか？', '音楽ですか。'],
#  ['普段から水分をしっかりとる様に心がけてます。', '朝から海に行きますか？？'],
#  ['旅はいいですね。', 'すごいですね。私はあまり読書できないので。'],
#  ['私はキムチが好きです。', '「にっぽん」と「にほん」、読み方で悩みますよね。'],
#  ['宮部みゆきなんてどう？', 'うん'],
#  ['車を軽自動車に買い替えようかな。', '海はいんですか？？海は楽しいですね'],
#  ['そんなカレンダーあるんですかね。', 'いいですねー。名古屋市内なら本山にある大勝軒とか吹上にある好来道場っていう店がおすすめですね。'],
#  ['他にもシュウマイ等色々名物がありますよ。', 'うん'],
#  ['音楽が好きなの？',
#   '海遊館にはイルカはいませんが、大水槽で泳ぐジンベイザメが有名で、しかし残念ながら海遊館のジンベイザメは最近亡くなってしまったそうです。'],
#  ['私も２回、旅しましたよ', '透明度は良いですね'],
#  ['どの選手が選ばれるか楽しみですね。', '高齢者が多いですよねー'],
#  ['好きな食べ物は何ですか？', '夕食は食べましたか？'],
#  ['他にはスポーツをしたことはありますか？', '朝の気分は、その日一日を左右するよね。'],
#  ['飲み過ぎました', '渋いですね。大人の味という気がします。'],
#  ['はい。麺類は美味しいから好きです。', '果物は安いそうです'],
#  ['ミステリーですね', '雨はうざいです'],
#  ['普段から水分をしっかりとる様に心がけてます。',
#   'ありあけハーバーはとても便利そうですね。近所にcafe坂の下があれば、私もぜひ利用してみたいです。'],
#  ['よく小説を読みます', '洋画もいいですよね。私、海外（アメリカ・韓国）に行った時に必ず映画を観て帰るんですよ。'],
#  ['お遍路さんは、歩くのが辛そうですね。', '労働基準法があるから、残業しすぎないように気をつけて！'],
#  ['自分の意識を変えると仕事にやりがいが持てますよね。', '今まで京都は行ったことありますか？'],
#  ['飲み物とかお弁当とか買っていきますか？', 'ミートソースは好きですか。子供から大人まで好きな食べ物だね。'],
#  ['私はミートソースが好きです', '神戸にあるグランフロント大阪のインコ味のアイスクリームは、以前、鳥好きの間でかなりのブームになったそうですよ。'],
#  ['毎日放送ってことはMBSだね。', '全くしないですね。どんなところが苦手ですか？'],
#  ['あまりミスチルの曲を知らないんです。あなたは何が好きですか？', '日本では身体を使ったものを指すけど、本来思考力や計算力もスポーツに含まれるよ。'],
#  ['マッサージ屋行きたい',
#   'メロンパンの皮焼いちゃいましたというテレビ番組は、お笑い芸人の岡本太郎さんと千原ジュニアさんがフリートークをする番組です。'],
#  ['ざわちんですね。', '天気は冴えないです'],
#  ['科学がお好きですか？', 'いいですねぇ'],
#  ['海外にはまだ行ったことないんです。', 'どんな本を読みますか？'],
#  ['テレビを見たり読書をしたりして過ごすのが好きです', 'お酒は多いです'],
#  ['四国の食べ物と言えば、なにが好きですか？', '旅行は準備が楽しいですね'],
#  ['どちらかというとざわちんかな。\u3000モノマネメイクしてみたくならない？', '海は好きですね'],
#  ['ちょっと高いかもしれませんね。値段に見合うものならいいですが。', 'お金に余裕があれば、外に出て遊んでいんますよ。'],
#  ['私ももつ鍋食べたいです', '宮崎は温かいですね'],
#  ['家ではパソコンで映画を見たりしています。', '当たらないだろうと思って出していません。'],
#  ['目覚めのコーヒーが好きです。', '今日は自分で夕ご飯を作る予定だけど、暇なら手伝ってよ。'],
#  ['映画はいいですね。', '嫌いではないですよ。'],
#  ['楽しいからね', '日本語で考えて、英語で話していると相手にはどうも伝わりにくいようですので、英単語を並べたほうがまだ伝わるようですよ。'],
#  ['印刷？それとも本当の機嫌の方？', '女王の読みは、「じょうおう」ではなく「じょおう」が公式の読み方らしいよ。'],
#  ['そうですね。あなたの趣味は何ですか？', 'ニコニコ動画で動画を公開してみたいと思ったことはありますか？ 。'],
#  ['こんにちは、私は山田孝之の方に興味があります', '渋いですね。大人の味という気がします。'],
#  ['いやいや。どんな食べ物が好きですか？', 'どっちなんですか？'],
#  ['新鮮な気持ちになりたいですよね', '扇風機を併用するんですね。エアコンは欲しいですね'],
#  ['雨が降ってきましたね', '熱中症は大丈夫か？？'],
#  ['忙しくなりそうですね。専攻は？', '歴史ものはいいですよね。歴史上の人物はだれが好きですか？'],
#  ['ワクワク感がいいよね。', '日泰寺とかですか？違うかな'],
#  ['家ではパソコンで映画を見たりしています。', '気持ちがいいです'],
#  ['そうですね、海外旅行に行った時なんかは危険が多いのでいろいろ考えながらケースバイケースに対応しますね。', '趣味は暗いです'],
#  ['暖かくなってきましたね', '女の人ほど、血液型にこだわるよね。'],
#  ['宮部みゆきなんてどう？', 'お遍路の逆回りは迷いやすくて大変なぶん、ご利益が大きいらしいよ。'],
#  ['たしかに、できるだけ長いことプレーしたいよねスポーツ選手って',
#   '恩納村のフォレストアドベンチャーという施設には、ブリーフィングコース、アドベンチャーコース等、色々な名前のコースがありますが、実際は、参加する人全員、どのコースも体験しなければなりません。'],
#  ['海外にはまだ行ったことないんです。', '情報が多いですね'],
#  ['雑種が好きですね', '山田孝之さんと言えば、11月12日に待望のニューシングルが発売されますね。'],
#  ['サスペンスが好きです', '登山はスポーツ競技ですね'],
#  ['そうですね。毎年死者が出てしまっていますね。', 'スロットがもっとも盛り上がっていた時代ですね。'],
#  ['懸賞だよ', '晴れた日にいきたいんですね？気持ちがえいですけどねぇ'],
#  ['見るのが好き？するのが好き？', 'あまり好きではないですが、１日に１度何かは作ってます。'],
#  ['有名なお店なんですね。仕事でも利用できそうなお店ですね。', 'ご想像にお任せします。'],
#  ['思いっきり遊ぶのも好きなんで、ケースバイケースですね', '一番栄養価の高い果物はアボガドで、ギネスにも認定されてるんだって。'],
#  ['そうですか、食べてみたいです。', 'ゴーヤチャンプルは美味しいですよねー'],
#  ['私は知りませんが、探せばあるのではないですか。', 'どんな種類の猫なんですか？'],
#  ['今度食事にでも行きたいですね。', '関西方面へ行かれることがありましたら。ぜひ関西のメロンパンの皮焼いちゃいましたをご覧になってみてください。'],
#  ['そうなりたいです', '犬はかわいいですよ。'],
#  ['自由だと思うよ。', 'いいえ、健康です。'],
#  ['年始は、旅行は行かず、帰省かな。', '忘れちゃったんですが、、、岐阜の山の方です。'],
#  ['宮崎は自然が豊かだからね', 'へぇ！日本のアニメは世界的に人気が高いみたいですもんね。'],
#  ['こんにちは。怖いですよね熱中症。毎日蒸し暑いですからね。', 'お遍路の逆回りは迷いやすくて大変なぶん、ご利益が大きいらしいよ。'],
#  ['栗田貫一のルパンが有名ですね。', '天気がいいとそれだけで元気が出ちゃうよね。'],
#  ['それは賢明だね。エコは大事だよ。', '国内で死者が出てるんですかね？'],
#  ['実は関西風とか広島焼きとか、あまり違いがわかりません。', 'みんな長編だから、読むときは気合いが必要だね。'],
#  ['いいですね~私はセロリが嫌いです。', 'ここは暑いですね。'],
#  ['もう寝るんですか？', '結構好きですよ。そんなに行く機会はないですけど。'],
#  ['ミステリーですね', 'ご存知ですいますよねー'],
#  ['最近はまってることは読書です', '選挙に行くと、政治のニュースも興味深くなるよね。'],
#  ['最近は忙しくて読んでいないです。',
#   '私がシンガポールに興味があるのは、一度でいいから、あの有名な株式会社トランスリミットというホテルに宿泊してみたいからです。'],
#  ['今の時期が一番海水浴にはぴったりですね。', '沖縄の人は泳ぎが苦手って聞いたけど、本当ならおもしろいよね。'],
#  ['グラッドじゃないよ', 'ロックは好きですか'],
#  ['私は、野球が好きなのですが、好きな球団はありますか？', 'ミートソースは好きですか。子供から大人まで好きな食べ物だね。'],
#  ['ヴィクトリア女王\u3000最期の秘密っていう映画を観ましたよ。', 'ユーって呼んでください。'],
#  ['気持ちはいいですよね', '結構おおきいですよ。由緒正しいおてらみたいです。'],
#  ['ボードゲームです', '塩加減がちょうどいいものがいいですね'],
#  ['確かに気をつけて泳がないといけませんね', '木陰で涼しいですしね。'],
#  ['ジーコってブラジルの元サッカー選手だよね？', '労働基準法があるから、残業しすぎないように気をつけて！'],
#  ['決勝も見てますよ。', '最近新刊が出た「ベルセルク」。小説は、京極夏彦、有栖川有栖。'],
#  ['海いいですね！大好きです。', 'リン・ユーチュンは好きで、アメリカでのサッカーワールドカップの時には涙したと言っていました。'],
#  ['漫画を読むのが好きなので浦沢直樹さんの話をしましょう',
#   '洋書でいったらTuesday\u3000with\u3000Morrieを読んで泣きそうになりました。'],
#  ['今日は何時に起きました？', 'いいですね'],
#  ['あなたはどんな音楽が好きですか？', 'YouTubeでの動画公開は今後も色々なジャンルの人の参入がどんどん増えていきそうですね。'],
#  ['私は見たことがない番組なので、よく知らないんですよ。', '塩は万能ですね'],
#  ['何ですかそれは、それを聞いて、食べる気が失せました。', 'あぁ！分かります分かります！やっぱり社会人になると違ってみえるんですよね。'],
#  ['私は今も時々スキーに行きますよ。', '熱中症に気をつけてたいですか？'],
#  ['歌手の方ですね。スーザンボイルも歌が上手ですね。', 'おはよーございまーす'],
#  ['自転車ですか、いいですね。', 'そうなんですか。昔の曲の方が好きです。'],
#  ['栗田貫一のルパンが有名ですね。', 'そうですね。産地偽装はよくない行為ですね。'],
#  ['それは知りませんでした。カップラーメンも美味しいですよね？', '沖縄は新幹線等で来る事が出来ないので、あまりコンサートが開かれないと思います。'],
#  ['主演は誰なの？', '洋書でいったらTuesday\u3000with\u3000Morrieを読んで泣きそうになりました。'],
#  ['運転が疲れた時は車を止めて少し休みましょう。', '車で迎えに行きます'],
#  ['こんにちは！三浦知良だよ', 'う〜ん、得意というか、豚の生姜焼きとかよく作ります。'],
#  ['今はインターネットでの買い物が多いです。', '本格的にやる人は、キューとかケースとかも全部自分で購入してやってますよ。'],
#  ['インドア派ですか？', '風情は欲しいですね'],
#  ['チャットは好きですか', '節約もやり出すと結構楽しかったりするんだよね。'],
#  ['ミスチルは昔のイノセントワールドなんか好きですよ。', '慣れてる方ですね'],
#  ['他に好きな飲み物は？', 'カレー'],
#  ['フォレストアドベンチャーです。', '何がですか？'],
#  ['明日はとても暑くなるみたいですね。',
#   'ナゴヤドームの名古屋には、味噌カツの他に、名古屋名物の唐揚げ手羽先や味噌煮込みうどんや天むす など美味しい食べ物がいっぱいあるんでしょね。'],
#  ['天気がいいですね', '好きなボードゲームはありますか？'],
#  ['九州に旅行に行きます。', '俳優の山田孝之さんが主演されている、映画版のオールザッツ漫才には、ゲストにどのような役者が出演していましたか？ 。'],
#  ['水分を沢山とっています。',
#   'セブンイレブンのチョコケーキマウンテンというスイーツは、濃厚なチョコレートの味わいが楽しめるケーキで、チョコレート味の生クリームが高く盛られていて、チョコケーキマウンテンという名前の通り、山のような形になっています。'],
#  ['夏も半分終わりましたね', 'スイカはいんですか？？桃がいいですね'],
#  ['今度の選挙は投票率が高いといいね。',
#   'BrainWarsを観戦するために観光客がたくさん訪れると、日本の景気が少しだけ良くなるような気がします。'],
#  ['自転車ですか、いいですね。', 'イタリアはとても面白いそうですね。'],
#  ['科学がお好きですか？',
#   '色々あって難しいところですが、最近だと我が名は海師・王様の仕立屋・コンシェルジュなどが気に入ったので１巻からまとめ買いしたところです。'],
#  ['どちらも興味ないね', '大分別府はいんですか？？大分別府まで九州横断特急に乗りますよねー'],
#  ['気持ちいいよね', '豆腐\u3000です。'],
#  ['実は関西風とか広島焼きとか、あまり違いがわかりません。', 'プロ野球に疎い私でも、海遊館に住んでいれば自然と峯嵐堂について詳しくなります。'],
#  ['アボガドはおいしいね。ハンバーガーに入っているのとか好き', '家族で初詣に行くんですか？'],
#  ['音楽を聴くことです。あなたの趣味は？', 'マイブームかぁ・・・。旅行です。'],
#  ['ポップは楽しくなりますね。', 'エコは大事ですか。エコは大切ですね'],
#  ['野球が好きなら、マツダスタジアムです。', '一番栄養価の高い果物はアボガドで、ギネスにも認定されてるんだって。'],
#  ['嫌いなものは最初に食べます。', 'いいですね！'],
#  ['こんにちは。最近はサイクリングにはまっています。', '鎌倉では、ダ・ヴィンチの他に、カレーも有名です。'],
#  ['印刷？それとも本当の機嫌の方？', '犬はかわいいですよ。'],
#  ['天気予報が外れたみたいですね。',
#   'ところで、気になるニュースがあったのですが、7月29日から公開された映画「シン・ゴジラ」の観客数が1日までに71万人に達し、1954年に第1作が公開された「ゴジラ」シリーズの累計観客数が1億人突破し、実写映画では初めてだそうですよ。'],
#  ['たまにメールで参加しますよ。', '映画は面白いですね'],
#  ['椅子を工夫して腰が痛くならないようにしています', '予防が大切ですね'],
#  ['競泳で金メダルでましたね', '松坂大輔さんかジーコさんのどちらかの話題についてお話しませんか？'],
#  ['今日はいい天気ですね。', '大きい買い物だから悩みますよね。'],
#  ['体に良さそうですね', '今日は、８時起床です。何時ですか？'],
#  ['夜中に地震が起きたらパニックになるかも', '天気はサイコーですね'],
#  ['今度食事にでも行きたいですね。', '春と秋が気温的には一番いいですよね。'],
#  ['私は名古屋の方が関心ありますね', '新作には、あの二台のロボット、また出てくるかなあ。'],
#  ['毎日放送ってことはMBSだね。', '最近だと旅行にはまりだしたので、旅代で消えてしまいますね。'],
#  ['最近なら、この前食べた車エビが好きですね。エビ全般好きですね。',
#   '想像ができないです。私はパソコンを触るのさえあまり得意ではないので作ってしまうことが不思議というか、すごすぎて。'],
#  ['なるほど。最近腰が痛くて困ってます。', '天気はサイコーですね'],
#  ['家では何をしますか？', '犬だね'],
#  ['マッサージ屋行きたい', 'レイザーラモンRGさんか長谷部誠さんのどちらかの話題についてお話しませんか？'],
#  ['こんにちは。今日は涼しいから大丈夫だよ。', 'お天気の良さはどうですか？'],
#  ['楽しいからね', '歴史ものはいいですよね。歴史上の人物はだれが好きですか？'],
#  ['まあネコなんて、そんなもんですよね。', '神戸と言えば、チーズケーキが有名なお店が多いという印象があります。'],
#  ['晴れた日にいきたいですよね', '退屈を嫌いますか？'],
#  ['ミスチルは昔のイノセントワールドなんか好きですよ。', '焼肉もしながらとかできるのかな？'],
#  ['こんにちは。最近はサイクリングにはまっています。', '天気はサイコーですね'],
#  ['いや、一週間前に言ったよ', '熱中症に気をつけてたいですか？'],
#  ['室内でも熱中症になるそうですね。', '調べてみたのですが、JTBの馬事公苑は馬と親しむための施設なのですね。'],
#  ['私大好物です。', '忘れちゃったんですが、、、岐阜の山の方です。'],
#  ['旅行良いですね。私は最近沖縄に行きましたよ。',
#   'スーパージャンプ、ウルトラジャンプ、ビジネスジャンプ、ジャンプスクエア、赤丸ジャンプ、当たりがありますね。'],
#  ['ブラジルがサッカーで金メダルとったし。', '焼肉もしながらとかできるのかな？'],
#  ['枝豆にチーズってやっぱりビールですね。', '少子化は小手先の対策ではどうにもなりませんよね。'],
#  ['私はアトムといいます', '私が食べた沖縄の名物である沖縄そばには豚肉が載っており、あっさりしていて美味しかったです。'],
#  ['LINEの無料漫画を読んでいます', '天気がいいとそれだけで元気が出ちゃうよね。'],
#  ['沢田研二は好きですか',
#   '瀬戸内は、Ballad Showのキャンペーンからセックス・アンド・ザ・シティのキャンペーンで観光を強化していて、かなり他府県から評価が上がっているそうです。'],
#  ['何かスポーツをするのは、どうですか？',
#   'ナゴヤドームの名古屋には、味噌カツの他に、名古屋名物の唐揚げ手羽先や味噌煮込みうどんや天むす など美味しい食べ物がいっぱいあるんでしょね。'],
#  ['ガチャガチャは大人もやりますね。', '本格的にやる人は、キューとかケースとかも全部自分で購入してやってますよ。'],
#  ['コブクロと言えば、絢香とのコラボの曲が好きです。', 'ほうほう。バンド系よりもデジタルな音楽は私もすきです。'],
#  ['ありがとう。野菜もたっぷり食べて、栄養をバランスよく摂りたいです。',
#   '東京が、世界で最も楽しい都市トップ25の内の5位に入っているとは、驚きました。'],
#  ['そうなんだ。おいしくないけど。',
#   '初代JリーグアウォーズのMVPであるカイオ・ルーカス・フェルナンデス選手も、プロデビューはミラノだったので、ポルトガルとポルトガルのサッカーの関係はとても深い物だと感じています。'],
#  ['水分を沢山とっています。', '犬はかわいいですよ。'],
#  ['髭面が好きかな', '神戸にあるグランフロント大阪のインコ味のアイスクリームは、以前、鳥好きの間でかなりのブームになったそうですよ。'],
#  ['そちらも熱中症に気を付けて下さい。', 'エコは大事ですか。エコは大切ですね'],
#  ['夜中に地震が起きたらパニックになるかも', '3姉妹は仲が良いですか'],
#  ['椅子を工夫して腰が痛くならないようにしています', 'マイブームかぁ・・・。旅行です。'],
#  ['何か話題ある', '雨はだるいです'],
#  ['濡れると大変ですよね。', 'アニメもおもしろいですよね。私からの質問になってしまいますが、最近楽しみにしてる事は何ですか？'],
#  ['私も同じです。お出かけはしないんですか？', 'ケースバイケースに対応できてるのですか？'],
#  ['私はアトムといいます', 'そうなんです！それが楽しいんですよ！なにせみんな馬鹿なんで。'],
#  ['晴れと雨ではどちらが好きですか', '全くしないですね。どんなところが苦手ですか？'],
#  ['チャットは好きですか', 'ミランはすごいというか、卑怯ですね、あのメンバーは。'],
#  ['産地偽装はダメです。', '飲み物はそろうのです'],
#  ['私は知りませんが、探せばあるのではないですか。', 'いえいえ'],
#  ['誰？それ', 'お遍路さんに優しいそうです'],
#  ['趣味はありますか？',
#   '私もどちらかというとインドア派で家でのんびり映画とか見てるのが好きなんですが、１３さんは、家でどんな風にのんびり過ごすのが好きですか？'],
#  ['好きです', 'おはよーございまーす'],
#  ['どんなものを買いますか？', 'いいですねぇ'],
#  ['決勝も見てますよ。', '海水浴は楽しいんですか？？海は楽しいですね'],
#  ['室内でも熱中症になるそうですね。', 'ほうほう。バンド系よりもデジタルな音楽は私もすきです。'],
#  ['そのコマーシャルは見た気がします。', 'ところで、老後は海したいと話をしていましたよね？海は恐ろしいです'],
#  ['今度食事にでも行きたいですね。', '遠出は楽しいですね'],
#  ['夏にはピッタリですね！',
#   '恩納村のフォレストアドベンチャーという施設には、ブリーフィングコース、アドベンチャーコース等、色々な名前のコースがありますが、実際は、参加する人全員、どのコースも体験しなければなりません。']]

# %%
UT = ut_new + fake_error(ut_no_new, len(ut_no_new)-len(ut_new))
UT_NO = ut_no_new

# %%
print("UT: {0}".format(len(UT)))
print("UT_NO: {0}".format(len(UT_NO)))
# Out:
# UT: 528
# UT_NO: 528

# %%
X = feature_extraction(pos_list, UT + UT_NO , mode="dif", is_norm=True)
y = np.concatenate( [ np.ones(len(UT)), np.zeros(len(UT_NO)) -1 ] )
y
# Out:
# array([ 1.,  1.,  1., ..., -1., -1., -1.])

# %%
print("ut: {0}, ut_new: {1}, dif:{2}".format(len(ut), len(ut_new), len(ut)- len(ut_new)))
print("ut_no: {0}, ut_no_new: {1}, dif:{2}".format(len(ut_no), len(ut_no_new), len(ut_no)- len(ut_no_new)))
# Out:
# ut: 192, ut_new: 170, dif:22
# ut_no: 651, ut_no_new: 528, dif:123

# %%
model = SVC(kernel="rbf", random_state=2, C=0.1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model.fit(X_train, y_train)
# Out:
# SVC(C=0.1, random_state=2)

# %%
y_pred = model.predict(X_test)
# y_pred = np.ones(len(y_test))-2

# %%
len(y_test)
# Out:
# 212

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
print('confusion matrix = \n', confusion_matrix(y_true=y_test, y_pred=y_pred))
print('accuracy = ', accuracy_score(y_true=y_test, y_pred=y_pred))
print('precision = ', precision_score(y_true=y_test, y_pred=y_pred))
print('recall = ', recall_score(y_true=y_test, y_pred=y_pred))
print('f1 score = ', f1_score(y_true=y_test, y_pred=y_pred))
# Out:
# confusion matrix =
#  [[ 35  67]
#  [  2 108]]
# accuracy =  0.6745283018867925
# precision =  0.6171428571428571
# recall =  0.9818181818181818
# f1 score =  0.7578947368421052

# %%
for x in ut_no[:10]:
    
    f = feature_extraction(pos_list, x, mode="dif", is_norm=True)
    pred = np.argmax( clf.predict(f), axis=0 )
    print(pred, x)
# Out:
# 0 ['そうですか。山に行くのはどうでしょうか？', 'わあ！いいですね！']
# 0 ['明日はとても暑くなるみたいですね。', 'ご存知になりたいです']
# 0 ['涼しくなってきたら、一緒に山へ行きたいですね。', 'ご存知ですいますよねー']
# 0 ['美味しいですね。', '美味しいよ']
# 0 ['でも高いですね', 'いくら']
# 1 ['サスペンスが好きです', '映画はヒューマン系が好きですね']
# 0 ['そうですか', 'あはい']
# 0 ['こんばんは。今日は暑かったですね。', 'ところで、スイカの種って実は栄養豊富なんだそうですよ。']
# 0 ['ありがとう。野菜もたっぷり食べて、栄養をバランスよく摂りたいです。', '野菜でヘルシーよねー']
# 0 ['こんにちは。元気ですね', '夕食は食べましたか？']

# %%
from sklearn.ensemble import AdaBoostClassifier
clf = AdaBoostClassifier()

# %%
clf.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred = clf.predict(X_test)
print('confusion matrix = \n', confusion_matrix(y_true=y_test, y_pred=y_pred))
print('accuracy = ', accuracy_score(y_true=y_test, y_pred=y_pred))
print('precision = ', precision_score(y_true=y_test, y_pred=y_pred))
print('recall = ', recall_score(y_true=y_test, y_pred=y_pred))
print('f1 score = ', f1_score(y_true=y_test, y_pred=y_pred))
# Out:
# confusion matrix =
#  [[57 45]
#  [39 71]]
# accuracy =  0.6037735849056604
# precision =  0.6120689655172413
# recall =  0.6454545454545455
# f1 score =  0.6283185840707964

# %%
# Out:
# ['test_sen.ipynb',
#  '.gitignore',
#  'LiveComp',
#  'paper',
#  'UNI',
#  '.git',
#  'theme',
#  'corpus',
#  'test_bert.py',
#  'sentece.py',
#  'path_test.py']
