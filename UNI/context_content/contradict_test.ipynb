# %%
import json
import os
import pandas as pd
import numpy as np
from pathlib import Path
import collections
from sklearn.model_selection import train_test_split
from sklearn import metrics

import sys
sys.path.append("../")
from datatools.analyzer import *
from utterance.error_tools import *

from datatools.maneger import DataManager
from datatools.preproc import Preprocessor

# %%
from sentence_transformers import SentenceTransformer
from sentence_transformers import models
bert_path = "../../corpus/pretrained/sbert_snli"
sbert = SentenceTransformer(bert_path)
# Out:
# [5560] 2022-01-16 14:17:14,628 Info sentence_transformers.SentenceTransformer :Load pretrained SentenceTransformer: ../../corpus/pretrained/sbert_snli
# [5560] 2022-01-16 14:17:15,786 Info sentence_transformers.SentenceTransformer :Use pytorch device: cuda

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.modules import loss
import torch.optim as optim
import torch.nn.utils.rnn as rnn

# %%
def text2vec(text):
    sentences = []
    if isinstance(text, str):
        sentences = [text]
    elif isinstance(text, list):
        sentences = text
    
    return sbert.encode(sentences)

def text2feature(text):
    vector = text2vec(text)
    diff = np.abs( vector[0] - vector[1] )
    return np.concatenate([vector.flatten(), diff])


def vec2feature(vector):
    diff = np.abs( vector[0] - vector[1] )
    return np.concatenate([vector.flatten(), diff])

# %%
class SNLIModel(nn.Module):
    def __init__(self, embedding_dim, tagset_size):
        # 親クラスのコンストラクタ。決まり文句
        super(SNLIModel, self).__init__()    
        self.embedding_dim = embedding_dim
        self.hid1= embedding_dim*2
        self.hid2 = embedding_dim//2
        self.fc1 = nn.Linear(self.embedding_dim, self.hid1)
        self.fc2 = nn.Linear(self.hid1, self.hid2)
        # LSTMの出力を受け取って全結合してsoftmaxに食わせるための１層のネットワーク
        # self.hidden2tag = nn.Linear(self.hid2+self.fb_dim, tagset_size)
        self.hidden2tag = nn.Linear(self.hid2, tagset_size)
    
    def forward(self, x):
        # fb = x[:, :self.fb_dim]
        y = F.relu(self.fc1(x))
        # y = F.relu(self.fc1(x[]))
        y = F.relu(self.fc2(y))
        y = self.hidden2tag( y )
        y = F.log_softmax(y, dim=1)
        return y

# %%
model_path = "../models/context/"
model_name = "sbert_snli_dnn.pickle"
modelM = DataManager(model_path)
model = modelM.load_data(model_name)
# Out:
# success load : ../models/context/sbert_snli_dnn.pickle

# %%
symbol = {"unk_token": "[UNK]", "sep_token": "[SEP]", "pad_token": "[PAD]", "cls_token": "[CLS]", "mask_token": "[MASK]"}

# %%
# path = "../../corpus/eval_labeled/"
path = "../eval_labeled/"

datalist = ['DCM', 'DIT', 'IRS']
convs = read_conv(path, datalist)

# %%
def add_prev_utt(dialogue:list):
    base = ""
    added = []
    for utt in dialogue:
        if base=="":
            added.append(utt)
        else:
            added.append(base+symbol["sep_token"]+utt)
            # added.append(base+utt)
        base = utt
    # 巻き戻す
    added[-1] = dialogue[-1]
    return added

def make_Xy(convs, N=7):
    errors = ["Contradiction", "Self-contradiction"]
    print(errors)
    X = []
    y = []
    for conv in convs:
        dialogue = [""]*N
        for i, ut in enumerate( conv ) :
            # ユーザ発話駆動
            dialogue.append(clean_text( ut.utt) )
            if ut.is_system() and ut.is_exist_error():
                # X.append( add_prev_utt( dialogue[-N:] ))
                X.append(dialogue[-N:])
                if ut.is_error_included(errors) :
                    y.append(1)
                else:
                    y.append(0)
    
    return X, y

# %%
N=4
X_str, y = make_Xy(convs, N=N)
# Out:
# ['Contradiction', 'Self-contradiction']

# %%
X_str_all = sum(X_str, [])

# %%
len( X_str_all )
# Out:
# 5544

# %%
X_all = text2vec(X_str_all)
# Out:
# Batches:   0%|          | 0/174 [00:00<?, ?it/s]

# %%
X_vec =  X_all.reshape(len(X_str), N, -1)

# %%
X_vec.shape
# Out:
# (1386, 4, 768)

# %%
# 推定の時間だ
y_pred = []
for X in tqdm( X_vec):
    hypo = X[-1]
    is_contradict = False
    features = []
    for prev in X[:-1]:
        feature = vec2feature( np.array([prev, hypo]) )
        features.append(feature)
    features = np.array(features)
    with torch.no_grad():
        features = torch.from_numpy(features).cuda()
        y_pred_ = np.array(model(features).cpu()).argmax(axis=1)
    if 2 in y_pred_:
        y_pred.append(1)
    else:
        y_pred.append(0)
# Out:
# 100%|██████████| 1386/1386 [00:01<00:00, 771.50it/s]

# %%
score(y, y_pred)
# Out:
# confusion matrix =
#  [[1211  153]
#  [  16    6]]
# accuracy =  0.8780663780663781
# precision =  0.03773584905660377
# recall =  0.2727272727272727
# f1 score =  0.06629834254143646

# %%
data_path = "../X_y_data/context_content/"
data_name = "contradict.pickle"
dataM = DataManager(data_path)
dataM.save_data(data_name, [y, y_pred])
# Out:
# success save : ../X_y_data/context_content/contradict.pickle

# %% [markdown]
# - N=7 eval
#
#         confusion matrix =
#         [[1166  198]
#         [  16    6]]
#         accuracy =  0.8455988455988456
#         precision =  0.029411764705882353
#         recall =  0.2727272727272727
#         f1 score =  0.05309734513274336
#
#     - 6件だけの検出
#     - 結構ミスが多いので，もっとNを減らして効果を見る
#
# - N=6 eval
#
#         confusion matrix =
#         [[1173  191]
#         [  16    6]]
#         accuracy =  0.8506493506493507
#         precision =  0.030456852791878174
#         recall =  0.2727272727272727
#         f1 score =  0.05479452054794521
#
#     - おそらく最もここが精度が高い，が...
#
# - N=4 eval
#
#         confusion matrix =
#         [[1208  156]
#         [  17    5]]
#         accuracy =  0.8751803751803752
#         precision =  0.031055900621118012
#         recall =  0.22727272727272727
#         f1 score =  0.054644808743169404
#
# ## 発話加算スタイル
# - ### 各前提に，直前の発話を加算
# - N=6 added
#
#         confusion matrix =
#         [[1256  108]
#         [  18    4]]
#         accuracy =  0.9090909090909091
#         precision =  0.03571428571428571
#         recall =  0.18181818181818182
#         f1 score =  0.05970149253731343
#
#    - 結構誤検出が減る
#
# - N=4 added
#
#         confusion matrix =
#         [[1283   81]
#         [  18    4]]
#         accuracy =  0.9285714285714286
#         precision =  0.047058823529411764
#         recall =  0.18181818181818182
#         f1 score =  0.07476635514018691
#
#     - 減ったけどなぁ
#
# - N=3 added
#
#     confusion matrix =
#     [[1311   53]
#     [  21    1]]
#     accuracy =  0.9466089466089466
#     precision =  0.018518518518518517
#     recall =  0.045454545454545456
#     f1 score =  0.02631578947368421
#
#     - N=3, N=4で大きな違いはありそう
#     - しかし，未検出の18を拾いたい

# %%
# 検出出来ているものはなんだ
i = 0
for i, x in enumerate(X_str):
    if y[i]==0 and y_pred[i]==1:
        print(x)
# Out:
# ['', 'こんにちは!熱中症に気をつけて。', 'こんにちは。暑いから気をつけないといけませんね', '熱中症に気をつけか??']
# ['水をたくさん飲んでいますよ', '熱中症はいいですね', '良くないですよ', 'いつ']
# ['', 'こんにちは。海へ行きたいね。', '海はいいですね。泳ぎは得意ですか。', '泳ぎはいいですね']
# ['ありがとう。クロールが得意なんです。', 'クロールは得意ですね', 'そう、スイミングで習ってるんです。', '朝からスイミングで泳ぎます??']
# ['こんにちは。調子はどうですか?', '何か普段の生活で気をつけていることはありますか。', '健康には特に気を付けています。', '和食、洋食、中華どれが食べたいですか?']
# ['センスが良くないから、同じような服ばかり選んでしまうよ。', 'センスはいいですね', '残念だけど、あまり良くないと思うんだ。', '昨日は何を食べましたか?']
# ['所で今日は、何をしてあそんでいますか。', '掛け声をあげるかもしれない', 'わたしはバーベキューをしました。バーベキューは好きですか。', '大声で上げるかもしれない']
# ['わたしはバーベキューをしました。バーベキューは好きですか。', '大声で上げるかもしれない', '大声をあげたら、迷惑になりますよ。雨は好きですか。', '女性が大声を上げるのです']
# ['海に行って何をしたら楽しいですか?', '海は大好きですね', '私も好きです。', 'ありがとう']
# ['洋食ではどんなメニューが好きですか?', '外食はたまにがいいですね', 'そうですね。', 'うむ']
# ['今何をしていますか?', '御覧の通りです。', '一緒にお茶でもどうですか', '独身で0人暮らしですね。']
# ['暇なの?', 'うん', 'じゃあ遊ぼうか', '普段はどんな服を着てますか?']
# ['何か見るのですか?', '池は寒いです', '夏の時期は気持ちが良いかもしれません。', '池に住むのです']
# ['気をつかってくれてありがとうございます。', '熱中症に気をつけてたいですか?', 'なるべく元気でいたいと思っています。', '熱中症が心配されます??']
# ['今からですか?', 'うん', '今日は予定があるので行けません。', '海に行ってないなあ']
# ['今日は予定があるので行けません。', '海に行ってないなあ', '私も今年はまだ行ってないですね。', '海まで散歩に行くのです']
# ['', 'こんにちは。気軽に声かけてね。', 'こんにちは、今日の天気はどう?', '今は答えられないんです。']
# ['こんにちは、今日の天気はどう?', '今は答えられないんです。', 'どうして?外が見えない場所にいるとか?', '天気がいいとそれだけで元気が出ちゃうよね。']
# ['どういう意味?', '困らせていますか?コミュニケーション取れるように頑張るので、お付き合いください。お気に入りの音楽って何ですか?', 'クラシックがいいですね', '英語でコミュニケーションがとれるらしいです']
# ['水分の補給が大事。', '補給は少ないですね', 'しっかり補給しないと。', 'コンビニで取りますよねー']
# ['自動販売機は便利です。', '自動販売機はほしいですね', '欲しくはないですけどね。', '自動販売機は何気ないですね']
# ['話は変わりますけど、旅行には良く行きますか?', '料理が出来上がるのです', '料理はまだですが、テレビですきな番組がありますか?', '朝からテレビをつけるかもしれない']
# ['', 'こんにちは!夏といえばスイカだね。', 'こんにちは、スイカ好きなんだね', 'スイカで有名か??']
# ['自炊してますか?', '自炊は安上がりです', '安上がりですけど面倒ですよね?', '自炊はお金がかからないんですよねぇ']
# ['カレーライスを食べました。', '夕食は無しか??', '食べました。', '食べてない']
# ['まだなんですね。', '晩御飯を食べるかもしれない', '何が食べたいですか?', '御飯を食べに行きますよねえ']
# ['何が食べたいですか?', '御飯を食べに行きますよねえ', 'じゃあどんな食べ物が好きですか?', '炊き立てがおいしいですね']
# ['', 'こんにちは!ちょうど退屈してたんだ。', '今日も暑いですね', '夕食は食べましたか?']
# ['どうんなゲームが好きですか?', 'どうだと思いますか??', 'パズルゲームが好きそうですが違いますか?', '寝られなくなるから夜はやめた方がいいよ。']
# ['涼しい感じでしょうか。', '見た目はかっこいいらしいですよ', 'またまた。', 'たまたま']
# ['私もかけようか迷っていた所です', '体は丈夫ですか?', '少し痛いですね', '今日のお昼は何を食べました?']
# ['いい言葉ですね。', '健康美は手に入れられるらしいです', 'なにか運動されているんですか?', '健康美を目指しますねぇ']
# ['私は料理を勉強中です。', '料理にはまってますか?', 'はい、母親に教えてもらっています。', '料理はそろいますか?']
# ['', 'こんにちはー。夏といえばスイカだね。', 'そうですね。昨日ちょうど食べました。', 'スイカで有名か??']
# ['こんにちは。朝御飯は何を食べた?', '朝御飯が楽しみです', '君の好きな食べ物は?', '朝御飯は一人で食べるのです']
# ['私は家族で食べるよ。', '御握りがいいですね', '自分で料理はする?', '料理は必要です']
# ['料理するのは楽しいよね。', '料理は大切です', '昨日は何を食べた?', '料理に欠かせてないかも']
# ['はい', 'やあ', 'よう!', 'おはよー']
# ['よう!', 'おはよー', 'おはようございます', 'メリークリスマス']
# ['傘を持って行った方がいいですか', '0月0日は梅雨入りになることが多いから、「傘の日」なんだって。', '知りませんでした', '梅雨入りはいいですね']
# ['', 'こんにちは。熱中症に気をつけて。', 'こんにちは。あなたも気をつけてください。', '熱中症に気をつけないんですか?']
# ['こんにちは。あなたも気をつけてください。', '熱中症に気をつけないんですか?', '塩分を取るようにしています。', '塩分は気にしません??']
# ['', 'こんにちはー。夏といえばスイカだね。', 'こんにちは!そうですねー、欠き氷もいいですよね', 'スイカで有名か??']
# ['泳ぐのも好きですか?', '泳ぐを覚えるのです', '暑い時、どうしてますか?', '泳ぐを繰り返すのです']
# ['そうなんですね、山は好きですか?', '泳ぐを覚えたりとかします', '泳ぎ覚えるの大変ですか?', '泳ぐを覚えないんです']
# ['泳ぎ覚えるの大変ですか?', '泳ぐを覚えないんです', '最近、雨ばっかりですねー', '泳ぐを繰り返してるのですか?']
# ['', 'こんにちはー。熱中症に気をつけて。', '今日も暑いですもんね', '熱中症に気をつけか??']
# ['寝不足にも注意が必要ですね。', '寝不足の時は、頭の天辺を軽く押すといいんだって。', '頭の天辺ですか。一人でやっていると、何かのギャグみたいですが。', '寝不足の時は、頭の天辺を軽く押すといいんだって。']
# ['頭の天辺ですか。一人でやっていると、何かのギャグみたいですが。', '寝不足の時は、頭の天辺を軽く押すといいんだって。', '私は、こめかみを押すと良いと聞きました。', '寝不足の時は、頭の天辺を軽く押すといいんだって。']
# ['今度、試してみますね。', '寝不足で頭が重いですか', '今は大丈夫です。', '寝不足で頭が痛いですか']
# ['こんばんは。最近の調子はどうですか?', 'お仕事何かしてますか?', 'していますよ。', 'IDおしえてー']
# ['やっはろー', 'おはようございます', '性別は何?', '逆子で性別がわかってないかもです']
# ['性別は何?', '逆子で性別がわかってないかもです', '恋人はいるの?', '恋人を求めるかもしれない']
# ['なぜそう思うのですか?', 'そういえば、あなたは美味しい物を食べるのが好きでしたよね?メロンにトマトを見せます', 'ありがとうございます', 'どどういたしまして']
# ['', 'こんにちは。夏といえばスイカだね。', 'そうですね。でもスイカはあまり好きではないです。', 'スイカで有名か??']
# ['違います。', 'ご家族と一緒にお住まいですか?', 'いいえ。独り暮らしです。', 'ペットを飼うのです']
# ['踊りと言えば、最近中学校ではダンスが必修科目になったらしいですね。', '午後から中学校に行くそうです', '何をしに行かれるんですか?', '中学校は生徒が少ないです']
# ['', 'こんにちは!鎌倉とイギリスなら、どちらに行ってみたいですか?', '鎌倉に行ってみたいです。お寺巡りとかすきなので。', '鎌倉の全国ラーメン党では名物のカフェメニューはありますか?。']
# ['しっかり応援しないといけませんね', '来年にプロ野球球団福岡ソフトバンクホークス入りがささやかれている稲葉篤紀投手のように、プロ野球1年目から活躍できるのは一握りなのではないかと思います。', '高校野球も盛り上がりましたもんね', '福岡マラソンでマラソン用に饂飩を提供するのは、福岡市を中心に店舗展開するボストン・レッドソックスで、ボストン・レッドソックスは全国にPRする目的で、今回マラソンでの饂飩提供に参加するそうです。']
# ['遠藤憲一さんが監督とは面白そう。', 'たった一度の世界ナゼそこに?日本人知られざる波瀾万丈伝の問題でマクドナルドを利用しなくなるというのは少し勿体ない気もします。', 'マクドナルドはいろいろありましたね。', 'マクドナルドでリングを食べるのも1苦労ですね。']
# ['', 'こんにちは!東京ディズニーシーと四季劇場なら、どちらに行ってみたいですか?', '東京ディズニーシーですね', '東京ディズニーランドや東京ディズニーシーには、たまに遊びに行く程度ですが、天下一品は好きです。']
# ['ぜひ買ってみます', 'まだ、ヨークベニマルで販売されている辛口グリーンカレーライスを食べたことがありません。', '自分も食べたことはないです', 'ヨークベニマルでは、電子マネーのハイチュウも使用できて、ポイントもたまるのでよく利用しています。']
# ['自分も食べたことはないです', 'ヨークベニマルでは、電子マネーのハイチュウも使用できて、ポイントもたまるのでよく利用しています。', '電子マネーのハイチュウって何ですか', 'コンビニエンスストアの商品の値段は高いですが、最近はヨークベニマルのキリン・フレビア・レモン&ホップのように、プライベートブランド商品をスーパーマーケットとコンビニエンスストアで同じ金額で提供している会社もありますね。']
# ['面白いのですか?', 'NHKでテレビ放送されている紙の月という旅番組をチェックしてみます。', '旅に行くことが多いの?', 'NHKのいないいないばあっ!でセアカゴケグモの特集番組をみました。']
# ['鈴木明子です。あなたは?', 'セブンイレブンのマルチコピー機の性能が良いので、自宅のプリンターを使用する機会がなくなりました。', '便利になりましたよね。コンビニにはよく行くのですか?', '先日セブンイレブンで、契りパンというスイーツを購入し、食べました。']
# ['食べたことないなあ', '一時、静岡の水曜どうでしょうなどのタレント発掘オーディション番組で、多くのスターが誕生し、ブームになりましたね。', '知らなかったよ', 'チョコレート菓子である静岡・宇治土産のあまおうのハイチュウや、関東土産の宇多田ヒカルの歌-0組の音楽家による0の解釈について-の宇多田ヒカルの歌-0組の音楽家による0の解釈について-、イギリス土産のストロベリーチーズケーキ味の宇多田ヒカルの歌-0組の音楽家による0の解釈について-などは一度食べてみたいです。']
# ['沖縄ですかね', '昔私が沖縄でスキューバダイビングした時は、魚達のカラフルさに圧倒されました。', '誰と沖縄に行ったのですか?', '沖縄に観光に来た際には、もちろん沖縄そばの御店は外せませんね。']
# ['誰と沖縄に行ったのですか?', '沖縄に観光に来た際には、もちろん沖縄そばの御店は外せませんね。', 'よく旅行には行くんですか', '沖縄のカミングアウトバラエティー秘密の県民SHOWの詳しい大きさはわかりませんが、離れていても肉眼で確認できる位には大きいです。']
# ['かばの欠伸とか生で見てみたい物です。', '海豹を間近に見ることができるというのは、旭山動物園の妖怪ウォッチは魅力的ですね。', 'やはりテレビで見るのとは一味違うのでしょうね。', '旭川市の旭山動物園には、0回しか行ったことがありません。']
# ['BANDAI ホビー センターに興味があります。', 'あなたが、あなたのご家族と東海キオスクのBANDAI ホビー センターへ行かれたらぜひ感想を教えてください。', 'はい、もし行くことがあったらお教えします。', 'BANDAI ホビー センターにある、読売テレビの静岡県静岡市ですね。']
# ['', 'こんにちは!有名人でヒロ・ハマダと吉田麻也なら、どちらに興味がありますか?', 'どちらも知りません。', 'ゴッホさんかくまもんさんのどちらかの話題についてお話しませんか?']
# ['今度買ってみます。', '→PIA-NO-JAC←のYouTubeは、いろいろな団体がダンスをしている動画を蜂蜜0%のキャンデーにアップロードしていますね。', 'そうですか。', 'ヒカキンさんのパラパラ漫画は絶対に御勧めなので、騙されたと思って一度蜂蜜0%のキャンデーで見てみてください。']
# ['それはよく知りませんでした', '衆議院のソレデモシタイはフィリピン南部発祥のマッサマンカレーをキャプテン翼にアレンジした物で、ハーブの香りを利かせたレッドカレーやグリーンカレーとは一味違う、ココナッツミルクとドライスパイスを使用した、ほど良い辛さと濃厚な旨み、甘みが特徴だそうです。', 'よくわからないカレーですね', 'スパイスの効いたカレーは好きですし、フィリピンカレーが好きなので、衆議院のバラード SHOWを早く食べてみたいです。']
# ['わかります。普通の人には考えられませよね。', 'チーズやピザ自体が好きなこともあり、アサヒビールのスナック菓子であるラジウム卵にトッピングされているチーズに魅力を感じています。', 'ラジウム王子とは何ですか?', 'あなたが自宅でアサヒビールの山葵抜き!?輪さビーフなどの発泡酒を楽しむ時には、お摘みなどは何か食べていますか?。']
# ['岡崎慎司さん格好良いですよね', '岡崎慎司選手がルームウェアで、清武弘嗣選手の部屋でくつろぐ画像は見たことがありますね。', 'サッカーで好きなチームはありますか?', '岡崎慎司選手のオフィシャルサイトはあるみたいですが、公式ブログはないみたいです。']
# ['専業主婦とは羨ましい。旦那さん稼いでいるんですね。', 'うらやましいのかなぁ?でも、いつでも昼寝ができていいですね。', '子供はいないんですか?', '例えば何かありますか?']
# ['毎晩ジョギングしています', 'スポーツが好きなんですね。', '汗を掻くと気持ちいいですからね', 'もちろんスポーツクラブだけじゃなくて']
# ['スノーボードできるんですか!すごいです。', '天気がよく、暖かい日は、0km位走ることもありますね。', '一人で走るんですか?', 'そうですね!一人でドライブする時は自分の好きな曲を流しながら走っています。']
# ['あなたも古い音楽が好きなんですか?', '古くても良い曲は良いので、聴いてみる機会があれば聴きますよ。', 'もしあなたのオススメがあれば教えてください。', 'といっても、冬のソナタとか天国の階段とかはまだ見たことがないんです。']
# ['もちろん食べたことがあるから好きです', 'じゃあ質問0学生って言ってたけどなんかサークル入ってる?', 'テニスサークルに入っています。', '入ってます。0人ほどの小さいサークルです。']
# ['疲れが抜けにくいのが気になるね', 'リラックスしてくださいね', '10分リラックスしているよ', 'それじゃ、マッサージをしましょう。']
# ['でもかわいいですよ', 'かわいいというか…どじですね。そういってくれるtefs0さんは、優しいです。', '優しいなんて初めて言われました', 'どっちでもいいや']
# ['優しいなんて初めて言われました', 'どっちでもいいや', '最近雨がよく降りますよね', '天気予報はみますか?']
# ['私が答える番ですね', 'この間がおもしろいですね', '少し遅いですよ', '了解です、気にせずタイピングしてください。']
# ['そうですか?私は昔柴犬を飼っていました。', 'レトリーバーと柴0匹ってすごいですね。。', 'レトリーバーは飼っていません。柴犬を0匹です。', 'レトリーバーと柴0匹ってすごいですね。。']
# ['3線を弾くのが好きです。', 'ギターも弾けるんですか?', '弾けますよ。よくわかりましたね。', '嘘ついている気はないんですけどね']
# ['好きな球団とかありますか?', 'やっぱり地元なんでドラゴンズが好きですね。', '名古屋にお住まいなんですか?', 'いいえ。0人暮らしです。']
# ['そんなことないですよ。これからどこへ行くのですか?', 'いいですね!私はちょっと目が疲れてきました。', '少し休みますか?', '体調を崩したのですか']
# ['柳沢選手って何のスポーツの選手ですか?', 'うんうん、わかりますそういうの。', 'あーそうなんですね。', '机の上が整理されていないと駄目ですね。']
# ['', 'こんにちは。あなたの趣味は何ですか?', 'イラストを描く事です', '描いてません。動画の編集とかはしますが']
# ['イラストを描く事です', '描いてません。動画の編集とかはしますが', '動画の編集ができるのはすごいですね', 'どんな会話してるんでしょうね。']
# ['k-0は少ししかわかりませんが、強い人はかっこいいですね', 'k-0ですか今好きな選手はブアカーオですね。', 'ボクシングはどうですか?', '誰が歌ってる?']
# ['パチンコ屋さんの話でしたか。よく打つんですか?', 'す…凄いですね。iPodに入れてビジネス英語とありますけれど、中々それだけではこの点数は出せないですよ。', '私は英語は全然喋れないですよ。', 'キリル文字っていうんですかね。Nをyと呼んだりして。']
# ['いいえ。家の前で家族で花火を少ししました。', '同じですよ。私も先日まで会社員をしていました。', 'では、今は何を?', '今はグッドだけですよ']
# ['手作りの方が高いですからね。', 'いいですね。何を作ったんですか?', '机を作ったことがあります。', 'チーズケーキくらいです。']
# ['歴史的な道に興味があります', 'あ、そうなんですか?例えばどんな感じか聞いてもいいです?', '古い昔の雰囲気が残っている道など、歩いてみたいですね', 'ロールして歩いてますよ。(因みに昨日も大須で愛犬とうろついてました。']
# ['最近はあまり聴いてないですね', 'う、私勉強不足でした・・・チェックしておきます。', 'チェックしなくてもいいですよ', 'どの番組が正しいのか分からなくなりますよね。']
# ['', 'こんにちは。スポーツは何かしてますか?', 'いや、やっていません', 'んー、運動神経が・・・・']
# ['あなたはスポーツをしているんですか?', 'してないですねー、運動音痴なもんで・・・', 'そうですか', '机の上が整理されていないと駄目ですね。']
# ['私は絵をかくことにはまっています。', 'どんな物を見たのですか?オススメの物があれば教えてください。', '何の御勧めですか?', '毎回目的地は設定してませんが']
# ['何の御勧めですか?', '毎回目的地は設定してませんが', '私は地図を読むのが苦手です。', '暗くまでなりますか!']
# ['私は地図を読むのが苦手です。', '暗くまでなりますか!', '何に暗くなったのですか?', 'あ、スペースマウンテンですか?']
# ['まだ0箇月ほどです。', 'おっと、若いですね。じゃあお酒もまだ駄目なんだ。', 'そうですね。まだお酒は飲めません。', 'お酒は酎ハイ程度しか飲めません。']
# ['そうですか?比較的度数は弱いと聞きますが。', '何か努力は、していますか?何かあると胃にくるタイプですか?', '僕はまだお酒が飲める年齢ではないので、わからないです・', 'お酒は酎ハイ程度しか飲めません。']
# ['こちらも暑いです。好きな冷たい物は?', 'ここは暑いですね。', '東京に近い涼しい所知りませんか?', 'クーラーがきいてるの?']
# ['こってり系ですね', '行ったことないです。ぜひいってみたいです!本郷亭なんかも好きです。', 'そうなんですか', '机の上が整理されていないと駄目ですね。']
# ['几帳面なんですね', '似てる、私と。因みに足の踏み場は確保してます?', 'してないですよ', 'パーマぢゃないっすか?']
# ['私も可愛いと思っていました。ペットを飼っていますか?', '今はかってないです。前は屋台でとった金魚を買ってました。', 'なるほど。金魚も癒されますね。', 'ゆっくり休んでください']
# ['たまにあります。あなたは男性ですか?', '女性ですか?', '私は女性です。', '和布蕪がやたら粘るので納豆かっ!とたまに突っ込みたくなります。']
# ['RPGとか、冒険するのが好きなようです', '私もそうなんです.一緒ですね', '一緒なんですね', 'では、家では何をしているんですか?']
# ['私は家で仕事をしています', '政治家になりたいです.', '政治家はトークスキルが求められますよね', '確かにモラルがないのはいけませんね。']
# ['サークルには入っていません', '吹奏楽です。トランペットやってます。', 'トランペットですか、かっこいいですね', 'どうして、ベースにしたのですか?']
# ['確かに斬新な料理ですね', '下宿する前は家事の手伝いすらろくにしてなかったんですよ。', 'そうなんですか', '机の上が整理されていないと駄目ですね。']
# ['何度もしています', 'あ、それですか!!', 'どうしたんですか', 'やはり、現地で食べる物とはまったく別物ですね。']
# ['ロボット掃除機使うと楽になりますよ。', '小さい時くらいしかないです。', 'そうなんですか?', '机の上が整理されていないと駄目ですね。']
# ['どこに?コンサート?', '地球の裏側とかにもですか?', 'さすが!リオオリンピックだからね', 'そちらこそ!']
# ['昔はよく行ったんだよ', 'いいですね!私もけっこう前ですが、CDをもっていました。', 'CDの話はしてなかったと思うけど…', '本当はもっと色々な事を聞かなきゃいけないんでしょうけど・・・。']
# ['だとすると、お酒は結構飲まれる方ですか?', 'お酒は好きですよ。あまり飲めませんが・・・。', '暑い夏はキンキンに冷えたビールが最高です。あなたはお酒は何がすきですか?', '強くはないけどね。飲む?']
# ['ゆっくりで良いですよ。急にどうしたの?', 'プールいいですね、いいですけど、機会と気合いが足りなくていけません。', '機会は作ればいいんですよ。今度一緒にプールに行きましょう。', 'あ、プールは行かないと駄目ですね。']
# ['犬派ですか', '飼ってみたら猫好きになりました', 'それは嬉しいですね', '果物はどうですか']
# ['そうなんですね。', '机の上が整理されていないと駄目ですね。', '片付けは大事ですよ。', 'おやすみ']
# ['日本人選手、頑張っていますよね。気になる選手とかいますか?', '今回残念ながら出場してないんですけど、浅田選手が好きです。', 'アイススケートの浅野真央さんですか?', 'おはよん。']
# ['とても緊張します。どうして緊張するんだろう?', '私も初めてですので、どうぞお気軽に。', 'ありがとう。気楽にやらせていただきます。', 'あなたの家はどこにありますか?']
# ['犬種は何?', 'まぁ今の時期もう大丈夫ですけどね。', '油断は禁物だよ', 'スキューバとかは?']
# ['油断は禁物だよ', 'スキューバとかは?', '興味ありません', '恥ずかしすぎてできません。']
# ['いえいえ。スノボーはやったことがありますか?', '一回だけやったんですけど、その時転びまくって、お尻が痛くて痛くて!!それ以来やってません。', '最初は皆そんな物ですが、慣れるときっと楽しいですよ。', '大学の研究室でたまにマージャンをやるのですが、運だけだとぼろ負けしてしまいそうなので必死で考えてやってます。']
# ['アルコール関係かな', '即、ブラックリスト登録ですよっ!!笑い', 'そう思う。載りたくないな', 'withha']
# ['そう思う。載りたくないな', 'withha', '最近はまってることは?', '何かありますか?']
# ['洋画も好きでたまに見ますよ', '同じですね', 'おススメの映画はありますか?', 'よく映画を見に行くのですか。']
# ['おススメの映画はありますか?', 'よく映画を見に行くのですか。', 'はい、気になる作品が上映されたら観に行くようにしています', '人類に一人だけ残されたら・・・・子孫も残せない訳だからあまり生きてても意味がないような気がするんですけど。']
# ['クラブは最近いてないです', 'そうです、学校でとか外のクラブとか。', 'お酒は好きですか?', '日本酒を飲みますか?']
# ['お酒は好きですか?', '日本酒を飲みますか?', '日本酒よりワインです', 'なるほどー。私はビール以外なら何でも飲めて食べれます。']
# ['日本酒よりワインです', 'なるほどー。私はビール以外なら何でも飲めて食べれます。', '最近飲んだお酒で、美味しかったのはなんですか?', 'お酒は好きですよ。あまり飲めませんが・・・。']
# ['最近飲んだお酒で、美味しかったのはなんですか?', 'お酒は好きですよ。あまり飲めませんが・・・。', 'お酒は毎日飲みますか?', 'お酒は好きですよ。あまり飲めませんが・・・。']
# ['家飲みと外飲みどちらが多いですか?', '車でってことは、遠くに行くんですよね。', 'お酒を飲む時は車は駄目ですよ', 'お酒は好きですよ。あまり飲めませんが・・・。']
# ['お酒を飲む時は車は駄目ですよ', 'お酒は好きですよ。あまり飲めませんが・・・。', 'どのぐらいが限界ですか?', '一ゃ楽しそう!その場でしか食べられない物って絶対ありますもんね。']
# ['釣りが大好きで、毎週行っています', '去年香嵐渓に紅葉見に行きましたよ!でも平日にいったのにすごい渋滞で・・・。', 'そうなんですね、しばらく紅葉狩りには行っていません', '好きなマスコットキャラクターは何?']
# ['そうなんですね。では好きな飲み物は何ですか?', '私の場合は、炭酸系のドリンクが好きなので、それを飲んでいます。', 'コーラは好きですか?', '酒と味醂を0としたらコーラを0くらいで鶏肉が浸るくらいに入れて。']
# ['はい。ディズニーシーも行きました', 'USJも行く予定ですよ!そうなんですか!年始は名古屋にいるし、年始に行こうかな。', 'ハリーポッターすごく面白いですよ!', 'ゾンビではないですが、']
# ['ちょっとこわいですね', '麒麟の田村じゃないんだから段ボールは食えないよ!って感じです。', 'ホームレス中学生流行りましたね!懐かしいです', 'なんで?']
# ['テニスが一番得意です。あなたはどのスポーツが得意なのですか?', 'そうですね。テニスは高校の部活からずっと今迄継続してやっているので。', '所で、オリンピックの女子卓球、銅メダル取れて良かったですね。', '二人だったら練習とか絶対に休めませんね。']
# ['大学生ではないですよ。', 'はい、そうです。そちらは専門学校へ通ってらっしゃるんですよね?', '違います。', '鴨の嘴というオーストラリアにしかいない動物だよ!']
# ['', 'こんにちは。スポーツは何かしてますか?', '今は何もしていませんが、以前はバレーボールをしていました。', 'そうです。言葉足らずで申し訳ない。']
# ['夢を追いかけて頑張っている人は素敵ですよね。何か夢はありますか?', 'あせらなくても、大丈夫ですよ。私も、最後まで悩んでいましたから…。', 'ありがとうございます。私もよく悩みますが、ポジティブに考えることは大切ですね。', 'ぎゅうぎゅうですよ。空腹で乗車すると酔うのでガッツリ食べるようにしています。']
# ['ありがとうございます。私もよく悩みますが、ポジティブに考えることは大切ですね。', 'ぎゅうぎゅうですよ。空腹で乗車すると酔うのでガッツリ食べるようにしています。', '私も空腹だと酔います。よく電車に乗られるのですか?', 'それは大変そう!私も高校時代だけバス通学をしていましたが、押されて流されて身動きが取れませんでした。']
# ['私も空腹だと酔います。よく電車に乗られるのですか?', 'それは大変そう!私も高校時代だけバス通学をしていましたが、押されて流されて身動きが取れませんでした。', 'バス通学だったのですね。それだけ混んでいたら学校に着いた時にはヘトヘトですね。', '眠たくても席をゆずります。あはは。']
# ['バス通学だったのですね。それだけ混んでいたら学校に着いた時にはヘトヘトですね。', '眠たくても席をゆずります。あはは。', '素晴らしいですね。尊敬します。ずっと立っているのは辛そうです。', 'なぜですか?']
# ['こんにちは。好きな食べ物はチョコレートです。', '最近チョコにはまって困ってます。', 'どんな種類のチョコレートが好きですか?', '0匹とも雑種ですよ。雉虎と黒猫です']
# ['読書です。', 'どんな本を読みますか?', 'SFが好きです。あなたは?', 'SFですか。映画などもみたりします?']
# ['こんにちは。家ではゲームをしていますよ。', 'ほほう、どのようなゲームをされてるんです', 'FPSが多いですね。あなたは家で何をしているのですか?', '主にパソコンのパーツを見て回っていますね。']
# ['映画を見るには小さいですね', '殆どがシネコンですが。', 'そうなんですか', '机の上が整理されていないと駄目ですね。']
# ['見るだけなら可愛いですよね', '結構楽しいですよ。機会があったらやってみてください。', 'そうなんですか', '机の上が整理されていないと駄目ですね。']
# ['', 'こんにちは。好きな動物は何ですか?', 'こんにちは。私はパンダが大好きです。', 'いやいやいや。私好きなんて言ってません。']

# %% [markdown]
# - 検出
#         ['', 'こんにちは。熱中症に気をつけて。', 'はい。ありがとう。あなたも気を付けて。', '熱中症に気をつけないんですか?']
#         ['こんばんは。それは嬉しいです。', '今日の夕食は済みました?', 'カレーライスを食べました。', '夕食は無しか??']
#         ['知りませんでした', '梅雨入りはいいですね', '梅雨明けはいつですか', '梅雨入りは嫌なんですよねえ']
#         ['そうですね。特に柴犬が好きです。', 'ちっこい柴犬やと思います', 'そうですか?私は昔柴犬を飼っていました。', 'レトリーバーと柴0匹ってすごいですね。。']
#         ['DVDの話だったんだね', 'すごいですね!映画館は久しく行っていないです。', '私も映画館には、とんと御無沙汰です', 'よく映画を見に行くのですか。']
#         ['食べてみたいです。', '豆腐も納豆も大好きですね。たくさん食べます。', '私も大好きです。日本人で良かったです。', 'いやいやいや。私好きなんて言ってません。']
#
# - 未検出
#
#         ['行きたいね。なかなか時間が取れないんだけどね。', '服をえらんだりするのはすきですか?', 'センスが良くないから、同じような服ばかり選んでしまうよ。', 'センスはいいですね']
#         ['仲間由紀恵', '仲間由紀恵は怖いですね', '何考えてるか分からない感じある', '仲間由紀恵は美しいですね']
#         ['どのような活性ですか?', '活性は高いです', '活発なのはいいことです。', '活性が全体的に低いです']
#         ['はい。ありがとう。あなたも気を付けて。', '熱中症に気をつけないんですか?', '小まめに水を飲んだりして、気を付けていますよ。', '熱中症に気をつけたいんでしょう?']
#         ['小まめに水を飲んだりして、気を付けていますよ。', '熱中症に気をつけたいんでしょう?', 'そうですね。0度倒れていますから、十分気を付けています。', '熱中症に気をつけなければなりませんでしたっけ']
#         ['対策はしている積もりですよ。', '対策は大丈夫か??', 'はい。水を飲んだり、塩分もとっています。', '対策は必要ないですか']
#         ['なるべく元気でいたいと思っています。', '熱中症が心配されます??', '今日は涼しかったので大丈夫です。', '大丈夫ですか。熱中症が出てますか?']
#         ['愛知ですかぁ。いい所ですね。', 'それから名古屋で就職が決まったことですね。', 'どんな仕事をするんですか?', '専業主婦ですよ。']
#         ['どこの部位のお肉が好きですか?', 'そうだね。肉のが好きかな。', '私は牛タンが好きなんですよ', 'そうなんですか.牛タンを食べたことはありますか.。']
#         ['テニスサークルに入っています。', '入ってます。0人ほどの小さいサークルです。', 'なんのサークルに入ってるのですか?', '今は入っていないです。今は高校時代の友人や、学祭の実行委員をやっていた時の友人とよく遊ぶことが多いです。']
#         ['使ってます。', '小さい時くらいしかないです。', 'タブレットも持ってますよ。', '私も持ってないですねぇ・・・。サンタさんに御願いしようかしら。']
#         ['そうですね', 'では、音楽はどんなのを聴かれていますか?', '最近はあまり音楽を聴かなくなってきました', 'なるほど。では音楽はどんなジャンルをよく聴きますか?']
#         ['あなたも始めてみませんか?', '趣味ですか.因みにあなたの趣味は何ですか?', '音楽鑑賞です', 'なるほど。スポーツが趣味ということですが、何かされていますか?']
#         ['', 'こんにちは。最近気になることとか、はまっていることとかありますか?', '私は絵をかくことにはまっています。', 'どんな物を見たのですか?オススメの物があれば教えてください。']
#         ['やっぱりそうでしたか', '最終回見ましたか?', '見ました', 'いきなりドラマの話ですか!']
#         ['がんばります。今日は暑いですね。', 'いいえ、御弁当を持ってきて院生室で食べました。', 'そうなんですか。私は今から御飯です。', '一緒ですね。']

# %% [markdown]
# - 誤検出
#
#         ['', 'こんにちは!熱中症に気をつけて。', 'こんにちは。暑いから気をつけないといけませんね', '熱中症に気をつけか??']
#         ['水をたくさん飲んでいますよ', '熱中症はいいですね', '良くないですよ', 'いつ']
#         ['', 'こんにちは。海へ行きたいね。', '海はいいですね。泳ぎは得意ですか。', '泳ぎはいいですね']
#         ['ありがとう。クロールが得意なんです。', 'クロールは得意ですね', 'そう、スイミングで習ってるんです。', '朝からスイミングで泳ぎます??']
#         ['こんにちは。調子はどうですか?', '何か普段の生活で気をつけていることはありますか。', '健康には特に気を付けています。', '和食、洋食、中華どれが食べたいですか?']
#         ['センスが良くないから、同じような服ばかり選んでしまうよ。', 'センスはいいですね', '残念だけど、あまり良くないと思うんだ。', '昨日は何を食べましたか?']
#         ['所で今日は、何をしてあそんでいますか。', '掛け声をあげるかもしれない', 'わたしはバーベキューをしました。バーベキューは好きですか。', '大声で上げるかもしれない']
#         ['わたしはバーベキューをしました。バーベキューは好きですか。', '大声で上げるかもしれない', '大声をあげたら、迷惑になりますよ。雨は好きですか。', '女性が大声を上げるのです']
#         ['海に行って何をしたら楽しいですか?', '海は大好きですね', '私も好きです。', 'ありがとう']
#         ['洋食ではどんなメニューが好きですか?', '外食はたまにがいいですね', 'そうですね。', 'うむ']
#         ['今何をしていますか?', '御覧の通りです。', '一緒にお茶でもどうですか', '独身で0人暮らしですね。']
#         ['暇なの?', 'うん', 'じゃあ遊ぼうか', '普段はどんな服を着てますか?']
#         ['何か見るのですか?', '池は寒いです', '夏の時期は気持ちが良いかもしれません。', '池に住むのです']
#         ['気をつかってくれてありがとうございます。', '熱中症に気をつけてたいですか?', 'なるべく元気でいたいと思っています。', '熱中症が心配されます??']
#         ['今からですか?', 'うん', '今日は予定があるので行けません。', '海に行ってないなあ']
#
# ---
#
# - 続きの例
#
#         ['夢を追いかけて頑張っている人は素敵ですよね。何か夢はありますか?', 'あせらなくても、大丈夫ですよ。私も、最後まで悩んでいましたから…。', 'ありがとうございます。私もよく悩みますが、ポジティブに考えることは大切ですね。', 'ぎゅうぎゅうですよ。空腹で乗車すると酔うのでガッツリ食べるようにしています。']
#         ['ありがとうございます。私もよく悩みますが、ポジティブに考えることは大切ですね。', 'ぎゅうぎゅうですよ。空腹で乗車すると酔うのでガッツリ食べるようにしています。', '私も空腹だと酔います。よく電車に乗られるのですか?', 'それは大変そう!私も高校時代だけバス通学をしていましたが、押されて流されて身動きが取れませんでした。']
#         ['私も空腹だと酔います。よく電車に乗られるのですか?', 'それは大変そう!私も高校時代だけバス通学をしていましたが、押されて流されて身動きが取れませんでした。', 'バス通学だったのですね。それだけ混んでいたら学校に着いた時にはヘトヘトですね。', '眠たくても席をゆずります。あはは。']
#         ['バス通学だったのですね。それだけ混んでいたら学校に着いた時にはヘトヘトですね。', '眠たくても席をゆずります。あはは。', '素晴らしいですね。尊敬します。ずっと立っているのは辛そうです。', 'なぜですか?']
#         ['こんにちは。好きな食べ物はチョコレートです。', '最近チョコにはまって困ってます。', 'どんな種類のチョコレートが好きですか?', '0匹とも雑種ですよ。雉虎と黒猫です']
#         ['読書です。', 'どんな本を読みますか?', 'SFが好きです。あなたは?', 'SFですか。映画などもみたりします?']
#         ['こんにちは。家ではゲームをしていますよ。', 'ほほう、どのようなゲームをされてるんです', 'FPSが多いですね。あなたは家で何をしているのですか?', '主にパソコンのパーツを見て回っていますね。']
#         ['映画を見るには小さいですね', '殆どがシネコンですが。', 'そうなんですか', '机の上が整理されていないと駄目ですね。']
#         ['見るだけなら可愛いですよね', '結構楽しいですよ。機会があったらやってみてください。', 'そうなんですか', '机の上が整理されていないと駄目ですね。']
#         ['', 'こんにちは。好きな動物は何ですか?', 'こんにちは。私はパンダが大好きです。', 'いやいやいや。私好きなんて言ってません。']
