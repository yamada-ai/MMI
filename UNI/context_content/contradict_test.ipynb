# %%
import json
import os
import pandas as pd
import numpy as np
from pathlib import Path
import collections
from sklearn.model_selection import train_test_split
from sklearn import metrics

import sys
sys.path.append("../")
from datatools.analyzer import *
from utterance.error_tools import *

from datatools.maneger import DataManager
from datatools.preproc import Preprocessor

# %%
from sentence_transformers import SentenceTransformer
from sentence_transformers import models
bert_path = "../../corpus/pretrained/sbert_snli"
sbert = SentenceTransformer(bert_path)
# Out:
# [677] 2022-01-11 00:37:13,677 Info sentence_transformers.SentenceTransformer :Load pretrained SentenceTransformer: ../../corpus/pretrained/sbert_snli
# [677] 2022-01-11 00:37:14,780 Info sentence_transformers.SentenceTransformer :Use pytorch device: cuda

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.modules import loss
import torch.optim as optim
import torch.nn.utils.rnn as rnn

# %%
def text2vec(text):
    sentences = []
    if isinstance(text, str):
        sentences = [text]
    elif isinstance(text, list):
        sentences = text
    
    return sbert.encode(sentences)

def text2feature(text):
    vector = text2vec(text)
    diff = np.abs( vector[0] - vector[1] )
    return np.concatenate([vector.flatten(), diff])


def vec2feature(vector):
    diff = np.abs( vector[0] - vector[1] )
    return np.concatenate([vector.flatten(), diff])

# %%
class SNLIModel(nn.Module):
    def __init__(self, embedding_dim, tagset_size):
        # 親クラスのコンストラクタ。決まり文句
        super(SNLIModel, self).__init__()    
        self.embedding_dim = embedding_dim
        self.hid1= embedding_dim*2
        self.hid2 = embedding_dim//2
        self.fc1 = nn.Linear(self.embedding_dim, self.hid1)
        self.fc2 = nn.Linear(self.hid1, self.hid2)
        # LSTMの出力を受け取って全結合してsoftmaxに食わせるための１層のネットワーク
        # self.hidden2tag = nn.Linear(self.hid2+self.fb_dim, tagset_size)
        self.hidden2tag = nn.Linear(self.hid2, tagset_size)
    
    def forward(self, x):
        # fb = x[:, :self.fb_dim]
        y = F.relu(self.fc1(x))
        # y = F.relu(self.fc1(x[]))
        y = F.relu(self.fc2(y))
        y = self.hidden2tag( y )
        y = F.log_softmax(y, dim=1)
        return y

# %%
model_path = "../models/context/"
model_name = "sbert_snli_dnn.pickle"
modelM = DataManager(model_path)
model = modelM.load_data(model_name)
# Out:
# success load : ../models/context/sbert_snli_dnn.pickle

# %%
symbol = {"unk_token": "[UNK]", "sep_token": "[SEP]", "pad_token": "[PAD]", "cls_token": "[CLS]", "mask_token": "[MASK]"}

# %%
# path = "../../corpus/eval_labeled/"
path = "../eval_labeled/"

datalist = ['DCM', 'DIT', 'IRS']
convs = read_conv(path, datalist)

# %%
def add_prev_utt(dialogue:list):
    base = ""
    added = []
    for utt in dialogue:
        if base=="":
            added.append(utt)
        else:
            added.append(base+symbol["sep_token"]+utt)
        base = utt
    # 巻き戻す
    added[-1] = dialogue[-1]
    return added

def make_Xy(convs, N=7):
    errors = ["Contradiction", "Self-contradiction"]
    print(errors)
    X = []
    y = []
    for conv in convs:
        dialogue = [""]*N
        for i, ut in enumerate( conv ) :
            # ユーザ発話駆動
            dialogue.append(clean_text( ut.utt) )
            if ut.is_system() and ut.is_exist_error():
                X.append( add_prev_utt( dialogue[-N:] ))
                # X.append(dialogue[-N:])
                if ut.is_error_included(errors) :
                    y.append(1)
                else:
                    y.append(0)
    
    return X, y

# %%
N=6
X_str, y = make_Xy(convs, N=N)
# Out:
# ['Contradiction', 'Self-contradiction']

# %%
X_str
# Out:
# [['',
#   '',
#   '',
#   'こんにちは。気軽に声かけてね。',
#   'こんにちは。気軽に声かけてね。[SEP]こんにちは。はじめまして。',
#   'お、そうですか。えっと、四国は行かれたことありますか?'],
#  ['',
#   'こんにちは。気軽に声かけてね。',
#   'こんにちは。気軽に声かけてね。[SEP]こんにちは。はじめまして。',
#   'こんにちは。はじめまして。[SEP]お、そうですか。えっと、四国は行かれたことありますか?',
#   'お、そうですか。えっと、四国は行かれたことありますか?[SEP]四国は行ったことありません。あなたは行かれたことありますか?',
#   'お遍路の逆回りは迷いやすくて大変な分、御利益が大きいらしいよ。'],
#  ['屋台の食べ物は美味しく感じますよね。食べ物は何が好きですか?',
#   '屋台の食べ物は美味しく感じますよね。食べ物は何が好きですか?[SEP]好きな食べ物は、蕎麦かな。',
#   '好きな食べ物は、蕎麦かな。[SEP]お蕎麦いいですね。麺類は私も好きですよ。',
#   'お蕎麦いいですね。麺類は私も好きですよ。[SEP]兄は無類の麺類好きで、毎日ラーメンを昼食に食べているらしい。',
#   '兄は無類の麺類好きで、毎日ラーメンを昼食に食べているらしい。[SEP]ラーメンもいいですね。お兄さんがいらっしゃるんですか?',
#   'お兄さんに生まれると、頼り甲斐のある性格になるのかな。'],
#  ['',
#   '',
#   '',
#   'こんにちは。ちょうど退屈してたんだ。',
#   'こんにちは。ちょうど退屈してたんだ。[SEP]こんにちは。元気ですか?',
#   '元気ですかは元気です'],
#  ['',
#   'こんにちは。ちょうど退屈してたんだ。',
#   'こんにちは。ちょうど退屈してたんだ。[SEP]こんにちは。元気ですか?',
#   'こんにちは。元気ですか?[SEP]元気ですかは元気です',
#   '元気ですかは元気です[SEP]元気そうでよかった。',
#   '元気ですかは元気ですね'],
#  ['こんにちは。元気ですか?',
#   'こんにちは。元気ですか?[SEP]元気ですかは元気です',
#   '元気ですかは元気です[SEP]元気そうでよかった。',
#   '元気そうでよかった。[SEP]元気ですかは元気ですね',
#   '元気ですかは元気ですね[SEP]今なにしてたの?',
#   'もちろんですってのが元気ですかにいいですね'],
#  ['元気そうでよかった。',
#   '元気そうでよかった。[SEP]元気ですかは元気ですね',
#   '元気ですかは元気ですね[SEP]今なにしてたの?',
#   '今なにしてたの?[SEP]もちろんですってのが元気ですかにいいですね',
#   'もちろんですってのが元気ですかにいいですね[SEP]そうなんだ。どうして?',
#   'もちろんですってのが元気ですかにいいらしいですよ'],
#  ['今なにしてたの?',
#   '今なにしてたの?[SEP]もちろんですってのが元気ですかにいいですね',
#   'もちろんですってのが元気ですかにいいですね[SEP]そうなんだ。どうして?',
#   'そうなんだ。どうして?[SEP]もちろんですってのが元気ですかにいいらしいですよ',
#   'もちろんですってのが元気ですかにいいらしいですよ[SEP]じゃあこれから使うね',
#   '私も好きです'],
#  ['そうなんだ。どうして?',
#   'そうなんだ。どうして?[SEP]もちろんですってのが元気ですかにいいらしいですよ',
#   'もちろんですってのが元気ですかにいいらしいですよ[SEP]じゃあこれから使うね',
#   'じゃあこれから使うね[SEP]私も好きです',
#   '私も好きです[SEP]何が好きなの?',
#   '好きですよ'],
#  ['好きな食べ物は何?',
#   '好きな食べ物は何?[SEP]のりが好きですね',
#   'のりが好きですね[SEP]のり美味しいね。私も好きだよ。',
#   'のり美味しいね。私も好きだよ。[SEP]好きだがいいですね',
#   '好きだがいいですね[SEP]とくに味付きののりがいいね。',
#   '好きだを見ますよねー'],
#  ['のり美味しいね。私も好きだよ。',
#   'のり美味しいね。私も好きだよ。[SEP]好きだがいいですね',
#   '好きだがいいですね[SEP]とくに味付きののりがいいね。',
#   'とくに味付きののりがいいね。[SEP]好きだを見ますよねー',
#   '好きだを見ますよねー[SEP]食べる方がいいよ',
#   '好きだを連発ですよねえ'],
#  ['',
#   '',
#   '',
#   'こんにちは。気軽に声かけてね。',
#   'こんにちは。気軽に声かけてね。[SEP]こんにちは。よろしくね。',
#   'あ、そうですか。そうだ、芸能人に会ったことありますか?'],
#  ['うれしいよね?',
#   'うれしいよね?[SEP]うん',
#   'うん[SEP]ドキドキするしね。',
#   'ドキドキするしね。[SEP]どきどき',
#   'どきどき[SEP]握手してもらったりしますか。',
#   '人間関係を深める為の挨拶としてよく用いられるよね。'],
#  ['ドキドキするしね。',
#   'ドキドキするしね。[SEP]どきどき',
#   'どきどき[SEP]握手してもらったりしますか。',
#   '握手してもらったりしますか。[SEP]人間関係を深める為の挨拶としてよく用いられるよね。',
#   '人間関係を深める為の挨拶としてよく用いられるよね。[SEP]サインはしてもらいますか?',
#   '新しい会社での人間関係が難しくて嫌になっちゃうよ。'],
#  ['握手してもらったりしますか。',
#   '握手してもらったりしますか。[SEP]人間関係を深める為の挨拶としてよく用いられるよね。',
#   '人間関係を深める為の挨拶としてよく用いられるよね。[SEP]サインはしてもらいますか?',
#   'サインはしてもらいますか?[SEP]新しい会社での人間関係が難しくて嫌になっちゃうよ。',
#   '新しい会社での人間関係が難しくて嫌になっちゃうよ。[SEP]写真は撮りますか?',
#   'あそうでしたか。所で、九州に行かれたことありますか?'],
#  ['写真は撮りますか?',
#   '写真は撮りますか?[SEP]あそうでしたか。所で、九州に行かれたことありますか?',
#   'あそうでしたか。所で、九州に行かれたことありますか?[SEP]行ったことあります。',
#   '行ったことあります。[SEP]九州のうまい物巡りをしに旅行に行きたいと常日頃から思ってるんだよ。',
#   '九州のうまい物巡りをしに旅行に行きたいと常日頃から思ってるんだよ。[SEP]御店も沢山ありますよ。',
#   '一番人気の海外旅行は韓国のソウルらしいよ。'],
#  ['',
#   '',
#   '',
#   'こんにちは!熱中症に気をつけて。',
#   'こんにちは!熱中症に気をつけて。[SEP]こんにちは。暑いから気をつけないといけませんね',
#   '熱中症に気をつけか??'],
#  ['',
#   'こんにちは!熱中症に気をつけて。',
#   'こんにちは!熱中症に気をつけて。[SEP]こんにちは。暑いから気をつけないといけませんね',
#   'こんにちは。暑いから気をつけないといけませんね[SEP]熱中症に気をつけか??',
#   '熱中症に気をつけか??[SEP]水をたくさん飲んでいますよ',
#   '熱中症はいいですね'],
#  ['こんにちは。暑いから気をつけないといけませんね',
#   'こんにちは。暑いから気をつけないといけませんね[SEP]熱中症に気をつけか??',
#   '熱中症に気をつけか??[SEP]水をたくさん飲んでいますよ',
#   '水をたくさん飲んでいますよ[SEP]熱中症はいいですね',
#   '熱中症はいいですね[SEP]良くないですよ',
#   'いつ'],
#  ['暑い日はいつでも気をつけてください',
#   '暑い日はいつでも気をつけてください[SEP]話は変わりますけど、アメリカの学校の夏休みは3箇月もあるって知ってました?',
#   '話は変わりますけど、アメリカの学校の夏休みは3箇月もあるって知ってました?[SEP]知りませんでした!長いですね',
#   '知りませんでした!長いですね[SEP]夏休みは欲しいですね',
#   '夏休みは欲しいですね[SEP]どれ位欲しいですか?',
#   '夏休みは楽しいですね'],
#  ['知りませんでした!長いですね',
#   '知りませんでした!長いですね[SEP]夏休みは欲しいですね',
#   '夏休みは欲しいですね[SEP]どれ位欲しいですか?',
#   'どれ位欲しいですか?[SEP]夏休みは楽しいですね',
#   '夏休みは楽しいですね[SEP]ですね。好きです',
#   'えっ'],
#  ['どれ位欲しいですか?',
#   'どれ位欲しいですか?[SEP]夏休みは楽しいですね',
#   '夏休みは楽しいですね[SEP]ですね。好きです',
#   'ですね。好きです[SEP]えっ',
#   'えっ[SEP]あなたも好きですか?',
#   'スポーツは好きですか'],
#  ['',
#   'こんにちは!熱中症に気をつけて。',
#   'こんにちは!熱中症に気をつけて。[SEP]こんにちは。ありがとう、水分とるように気を付けてます。',
#   'こんにちは。ありがとう、水分とるように気を付けてます。[SEP]気をとってるんですね。熱中症に気をつけないんですか?',
#   '気をとってるんですね。熱中症に気をつけないんですか?[SEP]大丈夫です。お仕事がお休みの日は何してるんですか?',
#   '熱中症に気をつけたいのです'],
#  ['こんにちは。ありがとう、水分とるように気を付けてます。',
#   'こんにちは。ありがとう、水分とるように気を付けてます。[SEP]気をとってるんですね。熱中症に気をつけないんですか?',
#   '気をとってるんですね。熱中症に気をつけないんですか?[SEP]大丈夫です。お仕事がお休みの日は何してるんですか?',
#   '大丈夫です。お仕事がお休みの日は何してるんですか?[SEP]熱中症に気をつけたいのです',
#   '熱中症に気をつけたいのです[SEP]水分とって、涼しくしてください。',
#   '熱中症を引き起こします'],
#  ['大丈夫です。お仕事がお休みの日は何してるんですか?',
#   '大丈夫です。お仕事がお休みの日は何してるんですか?[SEP]熱中症に気をつけたいのです',
#   '熱中症に気をつけたいのです[SEP]水分とって、涼しくしてください。',
#   '水分とって、涼しくしてください。[SEP]熱中症を引き起こします',
#   '熱中症を引き起こします[SEP]病院には行きたくないです。',
#   '病院は治療を受けましょう'],
#  ['病院には行きたくないです。',
#   '病院には行きたくないです。[SEP]病院は治療を受けましょう',
#   '病院は治療を受けましょう[SEP]薬は好きじゃありません。',
#   '薬は好きじゃありません。[SEP]病院を終えるんですよねぇ',
#   '病院を終えるんですよねぇ[SEP]車で帰りますよ。',
#   '病院は有名ですね'],
#  ['薬は好きじゃありません。',
#   '薬は好きじゃありません。[SEP]病院を終えるんですよねぇ',
#   '病院を終えるんですよねぇ[SEP]車で帰りますよ。',
#   '車で帰りますよ。[SEP]病院は有名ですね',
#   '病院は有名ですね[SEP]公園は好きですか?',
#   '行くのがいいですね'],
#  ['車で帰りますよ。',
#   '車で帰りますよ。[SEP]病院は有名ですね',
#   '病院は有名ですね[SEP]公園は好きですか?',
#   '公園は好きですか?[SEP]行くのがいいですね',
#   '行くのがいいですね[SEP]帽子を忘れないでくださいね',
#   '帽子がほしいですね'],
#  ['公園は好きですか?',
#   '公園は好きですか?[SEP]行くのがいいですね',
#   '行くのがいいですね[SEP]帽子を忘れないでくださいね',
#   '帽子を忘れないでくださいね[SEP]帽子がほしいですね',
#   '帽子がほしいですね[SEP]麦藁帽子はどうですか?',
#   '帽子は欲しいですね'],
#  ['帽子を忘れないでくださいね',
#   '帽子を忘れないでくださいね[SEP]帽子がほしいですね',
#   '帽子がほしいですね[SEP]麦藁帽子はどうですか?',
#   '麦藁帽子はどうですか?[SEP]帽子は欲しいですね',
#   '帽子は欲しいですね[SEP]ピクニックが好きです。',
#   '帽子は大好きですね'],
#  ['',
#   '',
#   '',
#   'こんにちは。海へ行きたいね。',
#   'こんにちは。海へ行きたいね。[SEP]海はいいですね。泳ぎは得意ですか。',
#   '泳ぎはいいですね'],
#  ['',
#   'こんにちは。海へ行きたいね。',
#   'こんにちは。海へ行きたいね。[SEP]海はいいですね。泳ぎは得意ですか。',
#   '海はいいですね。泳ぎは得意ですか。[SEP]泳ぎはいいですね',
#   '泳ぎはいいですね[SEP]気持ちいいですよね。',
#   '泳ぎが上手ですね'],
#  ['海はいいですね。泳ぎは得意ですか。',
#   '海はいいですね。泳ぎは得意ですか。[SEP]泳ぎはいいですね',
#   '泳ぎはいいですね[SEP]気持ちいいですよね。',
#   '気持ちいいですよね。[SEP]泳ぎが上手ですね',
#   '泳ぎが上手ですね[SEP]ありがとう。クロールが得意なんです。',
#   'クロールは得意ですね'],
#  ['気持ちいいですよね。',
#   '気持ちいいですよね。[SEP]泳ぎが上手ですね',
#   '泳ぎが上手ですね[SEP]ありがとう。クロールが得意なんです。',
#   'ありがとう。クロールが得意なんです。[SEP]クロールは得意ですね',
#   'クロールは得意ですね[SEP]そう、スイミングで習ってるんです。',
#   '朝からスイミングで泳ぎます??'],
#  ['そう、スイミングで習ってるんです。',
#   'そう、スイミングで習ってるんです。[SEP]朝からスイミングで泳ぎます??',
#   '朝からスイミングで泳ぎます??[SEP]泳ぎますよ。目が覚めていいですよ。',
#   '泳ぎますよ。目が覚めていいですよ。[SEP]目は覚めてるんですね。スイミングは楽しいですね',
#   '目は覚めてるんですね。スイミングは楽しいですね[SEP]ですよね。そういえばオリンピックの水泳も楽しみですね。',
#   'スイミングがいいですね'],
#  ['泳ぎますよ。目が覚めていいですよ。',
#   '泳ぎますよ。目が覚めていいですよ。[SEP]目は覚めてるんですね。スイミングは楽しいですね',
#   '目は覚めてるんですね。スイミングは楽しいですね[SEP]ですよね。そういえばオリンピックの水泳も楽しみですね。',
#   'ですよね。そういえばオリンピックの水泳も楽しみですね。[SEP]スイミングがいいですね',
#   'スイミングがいいですね[SEP]金メダルとれるといいですよね。',
#   'スイミングは楽しいですね'],
#  ['金メダルとれるといいですよね。',
#   '金メダルとれるといいですよね。[SEP]スイミングは楽しいですね',
#   'スイミングは楽しいですね[SEP]競泳より楽しんで泳ぐ方がいいかもしれないですね。',
#   '競泳より楽しんで泳ぐ方がいいかもしれないですね。[SEP]気持ちが良いですね',
#   '気持ちが良いですね[SEP]そうそう。川遊びでも水が冷たくて気持ちいいですよね。',
#   'スイミングは気持ちが良いですか'],
#  ['競泳より楽しんで泳ぐ方がいいかもしれないですね。',
#   '競泳より楽しんで泳ぐ方がいいかもしれないですね。[SEP]気持ちが良いですね',
#   '気持ちが良いですね[SEP]そうそう。川遊びでも水が冷たくて気持ちいいですよね。',
#   'そうそう。川遊びでも水が冷たくて気持ちいいですよね。[SEP]スイミングは気持ちが良いですか',
#   'スイミングは気持ちが良いですか[SEP]ええ、ストレス解消になっていいですよ。',
#   'スイミングを続けるかもしれない'],
#  ['',
#   '',
#   '',
#   'こんにちは。声かけてくれるのを待ってたんだ。',
#   'こんにちは。声かけてくれるのを待ってたんだ。[SEP]こんにちは。調子はどうですか?',
#   '何か普段の生活で気をつけていることはありますか。'],
#  ['',
#   'こんにちは。声かけてくれるのを待ってたんだ。',
#   'こんにちは。声かけてくれるのを待ってたんだ。[SEP]こんにちは。調子はどうですか?',
#   'こんにちは。調子はどうですか?[SEP]何か普段の生活で気をつけていることはありますか。',
#   '何か普段の生活で気をつけていることはありますか。[SEP]健康には特に気を付けています。',
#   '和食、洋食、中華どれが食べたいですか?'],
#  ['健康には特に気を付けています。',
#   '健康には特に気を付けています。[SEP]和食、洋食、中華どれが食べたいですか?',
#   '和食、洋食、中華どれが食べたいですか?[SEP]そうですねぇ。和食ですかね。',
#   'そうですねぇ。和食ですかね。[SEP]和食ですか。和食でヘルシーですね',
#   '和食ですか。和食でヘルシーですね[SEP]そうですね。あなたはどれが食べたいですか?',
#   '和食でヘルシーです'],
#  ['そうですね。あなたはどれが食べたいですか?',
#   'そうですね。あなたはどれが食べたいですか?[SEP]和食でヘルシーです',
#   '和食でヘルシーです[SEP]本当、和食はヘルシーで良いですよね。',
#   '本当、和食はヘルシーで良いですよね。[SEP]和食はカロリーが少ないです',
#   '和食はカロリーが少ないです[SEP]そうですよね。あなたは普段からカロリーに気を遣ってたりするんですか?',
#   'カロリーが多いですよねえ'],
#  ['',
#   'こんにちは!声かけてくれるのを待ってたんだ。',
#   'こんにちは!声かけてくれるのを待ってたんだ。[SEP]待たせてすみません。',
#   '待たせてすみません。[SEP]最近気になるニュースは何ですか?',
#   '最近気になるニュースは何ですか?[SEP]北朝鮮問題です。',
#   '北朝鮮問題が落ち着きますか?'],
#  ['待たせてすみません。',
#   '待たせてすみません。[SEP]最近気になるニュースは何ですか?',
#   '最近気になるニュースは何ですか?[SEP]北朝鮮問題です。',
#   '北朝鮮問題です。[SEP]北朝鮮問題が落ち着きますか?',
#   '北朝鮮問題が落ち着きますか?[SEP]時間がかかるでしょうね',
#   'そういえば、よく旅行に行くと言っていましたが、北朝鮮問題が浮上しますか?'],
#  ['時間がかかるでしょうね',
#   '時間がかかるでしょうね[SEP]そういえば、よく旅行に行くと言っていましたが、北朝鮮問題が浮上しますか?',
#   'そういえば、よく旅行に行くと言っていましたが、北朝鮮問題が浮上しますか?[SEP]北朝鮮には行きたくありません。',
#   '北朝鮮には行きたくありません。[SEP]北朝鮮はいいですね',
#   '北朝鮮はいいですね[SEP]あなたは、北朝鮮が好きですか?',
#   '北朝鮮が準備を進めるかもしれない'],
#  ['北朝鮮には行きたくありません。',
#   '北朝鮮には行きたくありません。[SEP]北朝鮮はいいですね',
#   '北朝鮮はいいですね[SEP]あなたは、北朝鮮が好きですか?',
#   'あなたは、北朝鮮が好きですか?[SEP]北朝鮮が準備を進めるかもしれない',
#   '北朝鮮が準備を進めるかもしれない[SEP]他に行きたい国はありますか?',
#   '北朝鮮が発射準備を進めるのです'],
#  ['他に行きたい国はありますか?',
#   '他に行きたい国はありますか?[SEP]北朝鮮が発射準備を進めるのです',
#   '北朝鮮が発射準備を進めるのです[SEP]怖いですね。',
#   '怖いですね。[SEP]怖いんですか??コワクナイヨー',
#   '怖いんですか??コワクナイヨー[SEP]あなたは、強いですね。',
#   '御自分で演奏されたりなさいますか?'],
#  ['怖いですね。',
#   '怖いですね。[SEP]怖いんですか??コワクナイヨー',
#   '怖いんですか??コワクナイヨー[SEP]あなたは、強いですね。',
#   'あなたは、強いですね。[SEP]御自分で演奏されたりなさいますか?',
#   '御自分で演奏されたりなさいますか?[SEP]何をですか?',
#   '退屈させてしまいましたか。うまくコミュニケーション取れるように頑張るので、お付き合いください。話題を変えましょう、最近観た映画は何ですか?'],
#  ['あなたは、強いですね。',
#   'あなたは、強いですね。[SEP]御自分で演奏されたりなさいますか?',
#   '御自分で演奏されたりなさいますか?[SEP]何をですか?',
#   '何をですか?[SEP]退屈させてしまいましたか。うまくコミュニケーション取れるように頑張るので、お付き合いください。話題を変えましょう、最近観た映画は何ですか?',
#   '退屈させてしまいましたか。うまくコミュニケーション取れるように頑張るので、お付き合いください。話題を変えましょう、最近観た映画は何ですか?[SEP]最近は観ていません。',
#   '言葉でコミュニケーションがとれるかもしれない'],
#  ['こんにちは。雨ばっかりで寒そうだけどね。',
#   'こんにちは。雨ばっかりで寒そうだけどね。[SEP]朝から海に行きますか??',
#   '朝から海に行きますか??[SEP]ビーチの場所取りが必要なんだよね。',
#   'ビーチの場所取りが必要なんだよね。[SEP]ビーチに行きたいです??',
#   'ビーチに行きたいです??[SEP]行きたいね。なかなか時間が取れないんだけどね。',
#   '服をえらんだりするのはすきですか?'],
#  ['ビーチの場所取りが必要なんだよね。',
#   'ビーチの場所取りが必要なんだよね。[SEP]ビーチに行きたいです??',
#   'ビーチに行きたいです??[SEP]行きたいね。なかなか時間が取れないんだけどね。',
#   '行きたいね。なかなか時間が取れないんだけどね。[SEP]服をえらんだりするのはすきですか?',
#   '服をえらんだりするのはすきですか?[SEP]センスが良くないから、同じような服ばかり選んでしまうよ。',
#   'センスはいいですね'],
#  ['行きたいね。なかなか時間が取れないんだけどね。',
#   '行きたいね。なかなか時間が取れないんだけどね。[SEP]服をえらんだりするのはすきですか?',
#   '服をえらんだりするのはすきですか?[SEP]センスが良くないから、同じような服ばかり選んでしまうよ。',
#   'センスが良くないから、同じような服ばかり選んでしまうよ。[SEP]センスはいいですね',
#   'センスはいいですね[SEP]残念だけど、あまり良くないと思うんだ。',
#   '昨日は何を食べましたか?'],
#  ['美味しいね。蝦の天麩羅が好きなんだ。',
#   '美味しいね。蝦の天麩羅が好きなんだ。[SEP]天麩羅は食べるのが美味しいですね',
#   '天麩羅は食べるのが美味しいですね[SEP]天汁だけでなく、最近は塩で食べるのも流行っているらしいね?',
#   '天汁だけでなく、最近は塩で食べるのも流行っているらしいね?[SEP]塩は少なめがいいですね',
#   '塩は少なめがいいですね[SEP]健康のことを考えても、味のことを考えてもね。',
#   'そういえば、あなたは美味しい物を食べるのが好きでしたよね?天麩羅は食べるのが好きですね'],
#  ['天汁だけでなく、最近は塩で食べるのも流行っているらしいね?',
#   '天汁だけでなく、最近は塩で食べるのも流行っているらしいね?[SEP]塩は少なめがいいですね',
#   '塩は少なめがいいですね[SEP]健康のことを考えても、味のことを考えてもね。',
#   '健康のことを考えても、味のことを考えてもね。[SEP]そういえば、あなたは美味しい物を食べるのが好きでしたよね?天麩羅は食べるのが好きですね',
#   'そういえば、あなたは美味しい物を食べるのが好きでしたよね?天麩羅は食べるのが好きですね[SEP]食べるのは好きだよ。豚カツもお寿司も美味しいからね。',
#   '好きだは好きですか。お寿司は縁側が好きですね'],
#  ['',
#   '',
#   '',
#   'こんにちは。気軽に声かけてね。',
#   'こんにちは。気軽に声かけてね。[SEP]こんにちはーはじめましてー',
#   'なんと。所で、お花見って行ったことありますか?'],
#  ['',
#   'こんにちは。気軽に声かけてね。',
#   'こんにちは。気軽に声かけてね。[SEP]こんにちはーはじめましてー',
#   'こんにちはーはじめましてー[SEP]なんと。所で、お花見って行ったことありますか?',
#   'なんと。所で、お花見って行ったことありますか?[SEP]ありますあります、楽しいですよねー',
#   'ですか。えっと、何かスポーツをされますか?'],
#  ['こんにちはーはじめましてー',
#   'こんにちはーはじめましてー[SEP]なんと。所で、お花見って行ったことありますか?',
#   'なんと。所で、お花見って行ったことありますか?[SEP]ありますあります、楽しいですよねー',
#   'ありますあります、楽しいですよねー[SEP]ですか。えっと、何かスポーツをされますか?',
#   'ですか。えっと、何かスポーツをされますか?[SEP]ウォーキングをやります',
#   '日本では身体を使った物を指すけど、本来思考力や計算力もスポーツに含まれるよ。'],
#  ['ありますあります、楽しいですよねー',
#   'ありますあります、楽しいですよねー[SEP]ですか。えっと、何かスポーツをされますか?',
#   'ですか。えっと、何かスポーツをされますか?[SEP]ウォーキングをやります',
#   'ウォーキングをやります[SEP]日本では身体を使った物を指すけど、本来思考力や計算力もスポーツに含まれるよ。',
#   '日本では身体を使った物を指すけど、本来思考力や計算力もスポーツに含まれるよ。[SEP]それは知らなかった、物知りなんですね',
#   '日本の国花は桜だけど、法律で決められた物じゃないんだよ。'],
#  ['それは知らなかった、物知りなんですね',
#   'それは知らなかった、物知りなんですね[SEP]日本の国花は桜だけど、法律で決められた物じゃないんだよ。',
#   '日本の国花は桜だけど、法律で決められた物じゃないんだよ。[SEP]桜ってとても綺麗ですよねぇ',
#   '桜ってとても綺麗ですよねぇ[SEP]沖縄の桜前線は、北から南下するんだよ。',
#   '沖縄の桜前線は、北から南下するんだよ。[SEP]沖縄へ行ってみたいなぁ',
#   '沖縄で生まれた有名な武道に「空手」があるよね。'],
#  ['桜ってとても綺麗ですよねぇ',
#   '桜ってとても綺麗ですよねぇ[SEP]沖縄の桜前線は、北から南下するんだよ。',
#   '沖縄の桜前線は、北から南下するんだよ。[SEP]沖縄へ行ってみたいなぁ',
#   '沖縄へ行ってみたいなぁ[SEP]沖縄で生まれた有名な武道に「空手」があるよね。',
#   '沖縄で生まれた有名な武道に「空手」があるよね。[SEP]空手かっこいいですよね',
#   '沖縄県は0個もの島で成り立っているんだよ。'],
#  ['沖縄へ行ってみたいなぁ',
#   '沖縄へ行ってみたいなぁ[SEP]沖縄で生まれた有名な武道に「空手」があるよね。',
#   '沖縄で生まれた有名な武道に「空手」があるよね。[SEP]空手かっこいいですよね',
#   '空手かっこいいですよね[SEP]沖縄県は0個もの島で成り立っているんだよ。',
#   '沖縄県は0個もの島で成り立っているんだよ。[SEP]沢山ありますね、何か美味しい物はありますか?',
#   '長寿1位じゃなくなっちゃったんだよね。'],
#  ['沢山ありますね、何か美味しい物はありますか?',
#   '沢山ありますね、何か美味しい物はありますか?[SEP]長寿1位じゃなくなっちゃったんだよね。',
#   '長寿1位じゃなくなっちゃったんだよね。[SEP]それでも長生きできる人が多いですよね',
#   'それでも長生きできる人が多いですよね[SEP]年をとっても学び続けるのが、長生きの秘訣なんだって。',
#   '年をとっても学び続けるのが、長生きの秘訣なんだって。[SEP]僕もいっぱい学んで長生きがしたいです',
#   '一緒に年を取りたいですよねー'],
#  ['こんにちは',
#   'こんにちは[SEP]こんにちは有りです',
#   'こんにちは有りです[SEP]よろしくお願いします',
#   'よろしくお願いします[SEP]こちらこそ',
#   'こちらこそ[SEP]今日の気分はどうですか',
#   'そうですね、渾名はありますよ。'],
#  ['よろしくお願いします',
#   'よろしくお願いします[SEP]こちらこそ',
#   'こちらこそ[SEP]今日の気分はどうですか',
#   '今日の気分はどうですか[SEP]そうですね、渾名はありますよ。',
#   'そうですね、渾名はありますよ。[SEP]渾名はなんですか',
#   'そうですね、渾名はありますよ。'],
#  ['今日の気分はどうですか',
#   '今日の気分はどうですか[SEP]そうですね、渾名はありますよ。',
#   'そうですね、渾名はありますよ。[SEP]渾名はなんですか',
#   '渾名はなんですか[SEP]そうですね、渾名はありますよ。',
#   'そうですね、渾名はありますよ。[SEP]何と呼べばいいですか',
#   '渾名を持ちます'],
#  ['渾名はなんですか',
#   '渾名はなんですか[SEP]そうですね、渾名はありますよ。',
#   'そうですね、渾名はありますよ。[SEP]何と呼べばいいですか',
#   '何と呼べばいいですか[SEP]渾名を持ちます',
#   '渾名を持ちます[SEP]渾名、教えてください',
#   '職場で同僚を渾名で呼ぶのは、どうかと思うよ。'],
#  ['何と呼べばいいですか',
#   '何と呼べばいいですか[SEP]渾名を持ちます',
#   '渾名を持ちます[SEP]渾名、教えてください',
#   '渾名、教えてください[SEP]職場で同僚を渾名で呼ぶのは、どうかと思うよ。',
#   '職場で同僚を渾名で呼ぶのは、どうかと思うよ。[SEP]そうですね。反省します。',
#   '職場で同僚を渾名で呼ぶのは、どうかと思うよ。'],
#  ['御免なさい',
#   '御免なさい[SEP]え艶冶で',
#   'え艶冶で[SEP]許してくれてありがとうございます',
#   '許してくれてありがとうございます[SEP]渾名がついてるのです',
#   '渾名がついてるのです[SEP]渾名で呼んでいいですか?',
#   '渾名をつけたいのです'],
#  ['',
#   'こんにちは。気軽に声かけてね。',
#   'こんにちは。気軽に声かけてね。[SEP]こんにちは。今日は暑いね。',
#   'こんにちは。今日は暑いね。[SEP]所で、気になるニュースがあるんですが、青森市で東北を代表する夏祭り「青森ねぶた祭」が始まり、大型ねぶた0台が出陣し、ねぶたの前をハネトが飛び跳ね「ラッセラー、ラッセラー」という掛け声とともに中心街を練り歩いたそうですよ。',
#   '所で、気になるニュースがあるんですが、青森市で東北を代表する夏祭り「青森ねぶた祭」が始まり、大型ねぶた0台が出陣し、ねぶたの前をハネトが飛び跳ね「ラッセラー、ラッセラー」という掛け声とともに中心街を練り歩いたそうですよ。[SEP]知っています。見たことありますか。',
#   '掛け声を覚えたことあります'],
#  ['こんにちは。今日は暑いね。',
#   'こんにちは。今日は暑いね。[SEP]所で、気になるニュースがあるんですが、青森市で東北を代表する夏祭り「青森ねぶた祭」が始まり、大型ねぶた0台が出陣し、ねぶたの前をハネトが飛び跳ね「ラッセラー、ラッセラー」という掛け声とともに中心街を練り歩いたそうですよ。',
#   '所で、気になるニュースがあるんですが、青森市で東北を代表する夏祭り「青森ねぶた祭」が始まり、大型ねぶた0台が出陣し、ねぶたの前をハネトが飛び跳ね「ラッセラー、ラッセラー」という掛け声とともに中心街を練り歩いたそうですよ。[SEP]知っています。見たことありますか。',
#   '知っています。見たことありますか。[SEP]掛け声を覚えたことあります',
#   '掛け声を覚えたことあります[SEP]他にどんな祭を知っていますか。',
#   '掛け声をだしたことありますね'],
#  ['知っています。見たことありますか。',
#   '知っています。見たことありますか。[SEP]掛け声を覚えたことあります',
#   '掛け声を覚えたことあります[SEP]他にどんな祭を知っていますか。',
#   '他にどんな祭を知っていますか。[SEP]掛け声をだしたことありますね',
#   '掛け声をだしたことありますね[SEP]掛け声は、いつ出すんですか。',
#   '掛け声が出すのに必要です'],
#  ['他にどんな祭を知っていますか。',
#   '他にどんな祭を知っていますか。[SEP]掛け声をだしたことありますね',
#   '掛け声をだしたことありますね[SEP]掛け声は、いつ出すんですか。',
#   '掛け声は、いつ出すんですか。[SEP]掛け声が出すのに必要です',
#   '掛け声が出すのに必要です[SEP]力が必要ですか。',
#   '掛け声を覚えるかもしれない'],
#  ['掛け声は、いつ出すんですか。',
#   '掛け声は、いつ出すんですか。[SEP]掛け声が出すのに必要です',
#   '掛け声が出すのに必要です[SEP]力が必要ですか。',
#   '力が必要ですか。[SEP]掛け声を覚えるかもしれない',
#   '掛け声を覚えるかもしれない[SEP]所で今日は、何をしてあそんでいますか。',
#   '掛け声をあげるかもしれない'],
#  ['力が必要ですか。',
#   '力が必要ですか。[SEP]掛け声を覚えるかもしれない',
#   '掛け声を覚えるかもしれない[SEP]所で今日は、何をしてあそんでいますか。',
#   '所で今日は、何をしてあそんでいますか。[SEP]掛け声をあげるかもしれない',
#   '掛け声をあげるかもしれない[SEP]わたしはバーベキューをしました。バーベキューは好きですか。',
#   '大声で上げるかもしれない'],
#  ['所で今日は、何をしてあそんでいますか。',
#   '所で今日は、何をしてあそんでいますか。[SEP]掛け声をあげるかもしれない',
#   '掛け声をあげるかもしれない[SEP]わたしはバーベキューをしました。バーベキューは好きですか。',
#   'わたしはバーベキューをしました。バーベキューは好きですか。[SEP]大声で上げるかもしれない',
#   '大声で上げるかもしれない[SEP]大声をあげたら、迷惑になりますよ。雨は好きですか。',
#   '女性が大声を上げるのです'],
#  ['大声をあげたら、迷惑になりますよ。雨は好きですか。',
#   '大声をあげたら、迷惑になりますよ。雨は好きですか。[SEP]女性が大声を上げるのです',
#   '女性が大声を上げるのです[SEP]なるほど。あなたは男性の声で掛け声をあげますか。',
#   'なるほど。あなたは男性の声で掛け声をあげますか。[SEP]掛け声を聞きます',
#   '掛け声を聞きます[SEP]聞く方なんですね。わたしは御菓子が好きですが、あなたは何か好きな物はありますか。',
#   '御菓子は好きですか。掛け声を聞きますよねー'],
#  ['',
#   '',
#   '',
#   'こんにちは。声かけてくれるのを待ってたんだ。',
#   'こんにちは。声かけてくれるのを待ってたんだ。[SEP]こんにちは。最近興味のあることってありますか?',
#   '興味が湧いてないかもです'],
#  ['',
#   'こんにちは。声かけてくれるのを待ってたんだ。',
#   'こんにちは。声かけてくれるのを待ってたんだ。[SEP]こんにちは。最近興味のあることってありますか?',
#   'こんにちは。最近興味のあることってありますか?[SEP]興味が湧いてないかもです',
#   '興味が湧いてないかもです[SEP]そうですかー。映画とか気になるのありません?',
#   '映画が楽しみです'],
#  ['こんにちは。最近興味のあることってありますか?',
#   'こんにちは。最近興味のあることってありますか?[SEP]興味が湧いてないかもです',
#   '興味が湧いてないかもです[SEP]そうですかー。映画とか気になるのありません?',
#   'そうですかー。映画とか気になるのありません?[SEP]映画が楽しみです',
#   '映画が楽しみです[SEP]今いろんな映画やっていますもんね',
#   '映画は大丈夫です'],
#  ['そうですかー。映画とか気になるのありません?',
#   'そうですかー。映画とか気になるのありません?[SEP]映画が楽しみです',
#   '映画が楽しみです[SEP]今いろんな映画やっていますもんね',
#   '今いろんな映画やっていますもんね[SEP]映画は大丈夫です',
#   '映画は大丈夫です[SEP]映画でポップコーン食べるのが好きです。',
#   '映画は元気ですね'],
#  ['今いろんな映画やっていますもんね',
#   '今いろんな映画やっていますもんね[SEP]映画は大丈夫です',
#   '映画は大丈夫です[SEP]映画でポップコーン食べるのが好きです。',
#   '映画でポップコーン食べるのが好きです。[SEP]映画は元気ですね',
#   '映画は元気ですね[SEP]私も元気な映画を見るのは好きですよ',
#   '映画が楽しみですね'],
#  ['私も元気な映画を見るのは好きですよ',
#   '私も元気な映画を見るのは好きですよ[SEP]映画が楽しみですね',
#   '映画が楽しみですね[SEP]楽しみですね。',
#   '楽しみですね。[SEP]映画は楽しみですか。そうですね',
#   '映画は楽しみですか。そうですね[SEP]他にも御祭りや花火も楽しみだよ',
#   '映画が良いですね'],
#  ['楽しみですね。',
#   '楽しみですね。[SEP]映画は楽しみですか。そうですね',
#   '映画は楽しみですか。そうですね[SEP]他にも御祭りや花火も楽しみだよ',
#   '他にも御祭りや花火も楽しみだよ[SEP]映画が良いですね',
#   '映画が良いですね[SEP]ゴジラが気になっているよ',
#   '映画は一人がいいですね'],
#  ['他にも御祭りや花火も楽しみだよ',
#   '他にも御祭りや花火も楽しみだよ[SEP]映画が良いですね',
#   '映画が良いですね[SEP]ゴジラが気になっているよ',
#   'ゴジラが気になっているよ[SEP]映画は一人がいいですね',
#   '映画は一人がいいですね[SEP]一人で見る方が気楽でいいですよね',
#   '映画は音楽がいいですね'],
#  ['ゴジラが気になっているよ',
#   'ゴジラが気になっているよ[SEP]映画は一人がいいですね',
#   '映画は一人がいいですね[SEP]一人で見る方が気楽でいいですよね',
#   '一人で見る方が気楽でいいですよね[SEP]映画は音楽がいいですね',
#   '映画は音楽がいいですね[SEP]音楽好きなんですか?',
#   '映画は映画館がいいですね'],
#  ['ペトリコールはギリシャ語で石のエッセンスを意味するらしいですね。',
#   'ペトリコールはギリシャ語で石のエッセンスを意味するらしいですね。[SEP]ギリシャには、0件も世界遺産があるんだよね。',
#   'ギリシャには、0件も世界遺産があるんだよね。[SEP]そうなんですね。日本の世界遺産の数は幾つあるんでしょう?',
#   'そうなんですね。日本の世界遺産の数は幾つあるんでしょう?[SEP]インターネットで調べた所、1位は、0箇所です。',
#   'インターネットで調べた所、1位は、0箇所です。[SEP]1位はどこの国ですか?',
#   '1位ヶ岳の所在地は山口県長門市・下関市です。'],
#  ['そうなんですね。日本の世界遺産の数は幾つあるんでしょう?',
#   'そうなんですね。日本の世界遺産の数は幾つあるんでしょう?[SEP]インターネットで調べた所、1位は、0箇所です。',
#   'インターネットで調べた所、1位は、0箇所です。[SEP]1位はどこの国ですか?',
#   '1位はどこの国ですか?[SEP]1位ヶ岳の所在地は山口県長門市・下関市です。',
#   '1位ヶ岳の所在地は山口県長門市・下関市です。[SEP]その山は有名な山なんですか?',
#   '1位ヶ岳は山口県の山ですね'],
#  ['',
#   '',
#   '',
#   'こんにちは。気軽に声かけてね。',
#   'こんにちは。気軽に声かけてね。[SEP]久し振りですね、どこかへお出掛けですか。',
#   '女の子が初デートで御洒落してお出掛けって、すごく可愛いく感じるんだ。'],
#  ['',
#   'こんにちは。気軽に声かけてね。',
#   'こんにちは。気軽に声かけてね。[SEP]久し振りですね、どこかへお出掛けですか。',
#   '久し振りですね、どこかへお出掛けですか。[SEP]女の子が初デートで御洒落してお出掛けって、すごく可愛いく感じるんだ。',
#   '女の子が初デートで御洒落してお出掛けって、すごく可愛いく感じるんだ。[SEP]その通りですね。',
#   'どうしたの'],
#  ['その通りですね。',
#   'その通りですね。[SEP]どうしたの',
#   'どうしたの[SEP]デートではないんですけど、御洒落して出かけます。',
#   'デートではないんですけど、御洒落して出かけます。[SEP]今時デートの時に花を持っていく人っているのかな。',
#   '今時デートの時に花を持っていく人っているのかな。[SEP]あまりいないんじゃないですか。でもデートで花はロマンティックかもしれません。',
#   '自分の机の上に花が飾られていると、仕事も勉強も頑張ろうって思うよね。'],
#  ['花には人にいい影響を与えてくれますね。',
#   '花には人にいい影響を与えてくれますね。[SEP]花が奇麗なのは、昆虫や鳥を引きつける為なんだって。',
#   '花が奇麗なのは、昆虫や鳥を引きつける為なんだって。[SEP]花には花の事情があるんですね。',
#   '花には花の事情があるんですね。[SEP]花が枯れそうになっても、ドライフラワーにして香りを楽しむと花も喜ぶと思うよ。',
#   '花が枯れそうになっても、ドライフラワーにして香りを楽しむと花も喜ぶと思うよ。[SEP]ドライフラワーって難しくないですか?',
#   'いいですね'],
#  ['ドライフラワーって難しくないですか?',
#   'ドライフラワーって難しくないですか?[SEP]いいですね',
#   'いいですね[SEP]できたら、ドライフラワーの作り方を教えてほしいです。',
#   'できたら、ドライフラワーの作り方を教えてほしいです。[SEP]ドライフラワーは運気が下がるっていいですよね',
#   'ドライフラワーは運気が下がるっていいですよね[SEP]運気が下がるんですか?初めて聞きました。',
#   'ドライフラワーは手芸ですね'],
#  ['',
#   'こんばんは!海へ行きたいね。',
#   'こんばんは!海へ行きたいね。[SEP]海は気持ちが良いですからね。',
#   '海は気持ちが良いですからね。[SEP]海は楽しいですね',
#   '海は楽しいですね[SEP]海に行って何をしたら楽しいですか?',
#   '海は大好きですね'],
#  ['海は気持ちが良いですからね。',
#   '海は気持ちが良いですからね。[SEP]海は楽しいですね',
#   '海は楽しいですね[SEP]海に行って何をしたら楽しいですか?',
#   '海に行って何をしたら楽しいですか?[SEP]海は大好きですね',
#   '海は大好きですね[SEP]私も好きです。',
#   'ありがとう'],
#  ['海に行って何をしたら楽しいですか?',
#   '海に行って何をしたら楽しいですか?[SEP]海は大好きですね',
#   '海は大好きですね[SEP]私も好きです。',
#   '私も好きです。[SEP]ありがとう',
#   'ありがとう[SEP]海は、ただ眺めてるだけでも良いですよね。',
#   '海は好きですね'],
#  ['どのような海が好きですか?',
#   'どのような海が好きですか?[SEP]気持ちがえいですけどねぇ',
#   '気持ちがえいですけどねぇ[SEP]潮風に吹かれていると気持ちが良いですね。',
#   '潮風に吹かれていると気持ちが良いですね。[SEP]潮風が心地良いですね',
#   '潮風が心地良いですね[SEP]海に行く時は、帽子を忘れないでください。',
#   '潮風は肌に感じます'],
#  ['海に行く時は、帽子を忘れないでください。',
#   '海に行く時は、帽子を忘れないでください。[SEP]潮風は肌に感じます',
#   '潮風は肌に感じます[SEP]肌に感じる潮風と、潮の匂いが大好きです。',
#   '肌に感じる潮風と、潮の匂いが大好きです。[SEP]潮風を感じられるのでしょうかね',
#   '潮風を感じられるのでしょうかね[SEP]潮風を感じて、その侭空を飛べる感じがします。',
#   '肌に感じるんでしょうか'],
#  ['',
#   'こんにちは!ちょうど退屈してたんだ。',
#   'こんにちは!ちょうど退屈してたんだ。[SEP]こんにちは。何をしましょうか。',
#   'こんにちは。何をしましょうか。[SEP]食事は済みましたか?',
#   '食事は済みましたか?[SEP]はい。今日は何を食べましたか?',
#   '食事は家で作るのです'],
#  ['こんにちは。何をしましょうか。',
#   'こんにちは。何をしましょうか。[SEP]食事は済みましたか?',
#   '食事は済みましたか?[SEP]はい。今日は何を食べましたか?',
#   'はい。今日は何を食べましたか?[SEP]食事は家で作るのです',
#   '食事は家で作るのです[SEP]たまには外食もいいですよ',
#   '外食はいんですか??あなた、外食の時も私を連れて行ってよ。'],
#  ['たまには外食もいいですよ',
#   'たまには外食もいいですよ[SEP]外食はいんですか??あなた、外食の時も私を連れて行ってよ。',
#   '外食はいんですか??あなた、外食の時も私を連れて行ってよ。[SEP]いいですよ。今度一緒に行きましょう。',
#   'いいですよ。今度一緒に行きましょう。[SEP]外食は洋食がいいですね',
#   '外食は洋食がいいですね[SEP]洋食ではどんなメニューが好きですか?',
#   '外食はたまにがいいですね'],
#  ['いいですよ。今度一緒に行きましょう。',
#   'いいですよ。今度一緒に行きましょう。[SEP]外食は洋食がいいですね',
#   '外食は洋食がいいですね[SEP]洋食ではどんなメニューが好きですか?',
#   '洋食ではどんなメニューが好きですか?[SEP]外食はたまにがいいですね',
#   '外食はたまにがいいですね[SEP]そうですね。',
#   'うむ'],
#  ['そうですね。',
#   'そうですね。[SEP]うむ',
#   'うむ[SEP]今何をしていますか?',
#   '今何をしていますか?[SEP]御覧の通りです。',
#   '御覧の通りです。[SEP]一緒にお茶でもどうですか',
#   '独身で0人暮らしですね。'],
#  ['',
#   'こんにちはー。ちょうど退屈してたんだ。',
#   'こんにちはー。ちょうど退屈してたんだ。[SEP]暇なの?',
#   '暇なの?[SEP]うん',
#   'うん[SEP]じゃあ遊ぼうか',
#   '普段はどんな服を着てますか?'],
#  ['お金ないよ',
#   'お金ないよ[SEP]同じく',
#   '同じく[SEP]仲間だ',
#   '仲間だ[SEP]ナカーマ',
#   'ナカーマ[SEP]仲間由紀恵',
#   '仲間由紀恵は怖いですね'],
#  ['仲間だ',
#   '仲間だ[SEP]ナカーマ',
#   'ナカーマ[SEP]仲間由紀恵',
#   '仲間由紀恵[SEP]仲間由紀恵は怖いですね',
#   '仲間由紀恵は怖いですね[SEP]何考えてるか分からない感じある',
#   '仲間由紀恵は美しいですね'],
#  ['毎日料理は作ってます。',
#   '毎日料理は作ってます。[SEP]料理を作ってるんですね。料理は奥深いですね',
#   '料理を作ってるんですね。料理は奥深いですね[SEP]そうですね。',
#   'そうですね。[SEP]ねー',
#   'ねー[SEP]同じ料理でも作り方によっていろいろな物になりますね。',
#   'カップラーメンでもインスタントカレーでも、立派な料理だよね。'],
#  ['同じ料理でも作り方によっていろいろな物になりますね。',
#   '同じ料理でも作り方によっていろいろな物になりますね。[SEP]カップラーメンでもインスタントカレーでも、立派な料理だよね。',
#   'カップラーメンでもインスタントカレーでも、立派な料理だよね。[SEP]そうですね。時間がない時はよく使います。',
#   'そうですね。時間がない時はよく使います。[SEP]料理の好きな人は、鍋やフライパンにもすごくこだわりそうだよね。',
#   '料理の好きな人は、鍋やフライパンにもすごくこだわりそうだよね。[SEP]いい物を使うとやりやすいですね。',
#   'カップラーメンでもインスタントカレーでも、立派な料理だよね。'],
#  ['そうですね。時間がない時はよく使います。',
#   'そうですね。時間がない時はよく使います。[SEP]料理の好きな人は、鍋やフライパンにもすごくこだわりそうだよね。',
#   '料理の好きな人は、鍋やフライパンにもすごくこだわりそうだよね。[SEP]いい物を使うとやりやすいですね。',
#   'いい物を使うとやりやすいですね。[SEP]カップラーメンでもインスタントカレーでも、立派な料理だよね。',
#   'カップラーメンでもインスタントカレーでも、立派な料理だよね。[SEP]今のインスタント食品はいろいろ味がよくできていますね。',
#   'カップラーメンでもインスタントカレーでも、立派な料理だよね。'],
#  ['いい物を使うとやりやすいですね。',
#   'いい物を使うとやりやすいですね。[SEP]カップラーメンでもインスタントカレーでも、立派な料理だよね。',
#   'カップラーメンでもインスタントカレーでも、立派な料理だよね。[SEP]今のインスタント食品はいろいろ味がよくできていますね。',
#   '今のインスタント食品はいろいろ味がよくできていますね。[SEP]カップラーメンでもインスタントカレーでも、立派な料理だよね。',
#   'カップラーメンでもインスタントカレーでも、立派な料理だよね。[SEP]やっぱり自分で作った方が美味しい物ができますね。',
#   '料理は美味しいですね'],
#  ['今のインスタント食品はいろいろ味がよくできていますね。',
#   '今のインスタント食品はいろいろ味がよくできていますね。[SEP]カップラーメンでもインスタントカレーでも、立派な料理だよね。',
#   'カップラーメンでもインスタントカレーでも、立派な料理だよね。[SEP]やっぱり自分で作った方が美味しい物ができますね。',
#   'やっぱり自分で作った方が美味しい物ができますね。[SEP]料理は美味しいですね',
#   '料理は美味しいですね[SEP]その時によって美味しくできる時とあんまり美味しくない時といろいろありますね。',
#   '料理の好きな人は、鍋やフライパンにもすごくこだわりそうだよね。'],
#  ['今日はいいお天気ですね',
#   '今日はいいお天気ですね[SEP]お天気の良さはどうですか?',
#   'お天気の良さはどうですか?[SEP]晴れていて気持ちが良いです',
#   '晴れていて気持ちが良いです[SEP]お天気で気持ちがいいですね',
#   'お天気で気持ちがいいですね[SEP]はい。どこかへお出掛けですか?',
#   '女の子が初デートで御洒落してお出掛けって、すごく可愛いく感じるんだ。'],
#  ['晴れていて気持ちが良いです',
#   '晴れていて気持ちが良いです[SEP]お天気で気持ちがいいですね',
#   'お天気で気持ちがいいですね[SEP]はい。どこかへお出掛けですか?',
#   'はい。どこかへお出掛けですか?[SEP]女の子が初デートで御洒落してお出掛けって、すごく可愛いく感じるんだ。',
#   '女の子が初デートで御洒落してお出掛けって、すごく可愛いく感じるんだ。[SEP]そうですね。特に春だと気温もちょうど良くて外出する人が多いですしね。',
#   '世界の年平均気温は右肩上がりで、地球温暖化が進んでいるらしいよ。'],
#  ['そうですね。特に春だと気温もちょうど良くて外出する人が多いですしね。',
#   'そうですね。特に春だと気温もちょうど良くて外出する人が多いですしね。[SEP]世界の年平均気温は右肩上がりで、地球温暖化が進んでいるらしいよ。',
#   '世界の年平均気温は右肩上がりで、地球温暖化が進んでいるらしいよ。[SEP]確かに今年は特に冬でも暖かかったですしね。',
#   '確かに今年は特に冬でも暖かかったですしね。[SEP]海水面の上昇の原因は極の氷の溶解でなく、温暖化で海水が膨張してるからなんだよね。',
#   '海水面の上昇の原因は極の氷の溶解でなく、温暖化で海水が膨張してるからなんだよね。[SEP]そうねんですね。ずっと南極や北極の氷が解けているからだと思っていました。',
#   '世界でどんなに争いが起ころうと南極だけは平和だよね。'],
#  ['確かに今年は特に冬でも暖かかったですしね。',
#   '確かに今年は特に冬でも暖かかったですしね。[SEP]海水面の上昇の原因は極の氷の溶解でなく、温暖化で海水が膨張してるからなんだよね。',
#   '海水面の上昇の原因は極の氷の溶解でなく、温暖化で海水が膨張してるからなんだよね。[SEP]そうねんですね。ずっと南極や北極の氷が解けているからだと思っていました。',
#   'そうねんですね。ずっと南極や北極の氷が解けているからだと思っていました。[SEP]世界でどんなに争いが起ころうと南極だけは平和だよね。',
#   '世界でどんなに争いが起ころうと南極だけは平和だよね。[SEP]非常に寒いですけどね。笑い',
#   '文章の後に格好付きで笑いとか泣きとかつけるのは、時と場合だよね。'],
#  ['非常に寒いですけどね。笑い',
#   '非常に寒いですけどね。笑い[SEP]文章の後に格好付きで笑いとか泣きとかつけるのは、時と場合だよね。',
#   '文章の後に格好付きで笑いとか泣きとかつけるのは、時と場合だよね。[SEP]例えばどんな時ですか?',
#   '例えばどんな時ですか?[SEP]丁寧に心を込めた文章なら、うまくなくて通じると思うんだ。',
#   '丁寧に心を込めた文章なら、うまくなくて通じると思うんだ。[SEP]確かにきちんとした場面でならつけないことの方が多いですね。',
#   'ならを使うのです'],
#  ['', '', '', '今晩はー。気軽に声かけてね。', '今晩はー。気軽に声かけてね。[SEP]分かりました。', 'よろしい'],
#  ['',
#   '今晩はー。気軽に声かけてね。',
#   '今晩はー。気軽に声かけてね。[SEP]分かりました。',
#   '分かりました。[SEP]よろしい',
#   'よろしい[SEP]最近の調子はどうですか?',
#   'そういえば思い出したんですけど、遊園地にある大きな池は、防災も兼ねてるらしいですよ。'],
#  ['最近の調子はどうですか?',
#   '最近の調子はどうですか?[SEP]そういえば思い出したんですけど、遊園地にある大きな池は、防災も兼ねてるらしいですよ。',
#   'そういえば思い出したんですけど、遊園地にある大きな池は、防災も兼ねてるらしいですよ。[SEP]そういえば、聞いたことがあります。防災は大切ですよね。',
#   'そういえば、聞いたことがあります。防災は大切ですよね。[SEP]外で見ようですよ',
#   '外で見ようですよ[SEP]何か見るのですか?',
#   '池は寒いです'],
#  ['そういえば、聞いたことがあります。防災は大切ですよね。',
#   'そういえば、聞いたことがあります。防災は大切ですよね。[SEP]外で見ようですよ',
#   '外で見ようですよ[SEP]何か見るのですか?',
#   '何か見るのですか?[SEP]池は寒いです',
#   '池は寒いです[SEP]夏の時期は気持ちが良いかもしれません。',
#   '池に住むのです'],
#  ['夏の時期は気持ちが良いかもしれません。',
#   '夏の時期は気持ちが良いかもしれません。[SEP]池に住むのです',
#   '池に住むのです[SEP]それは面白そうです。',
#   'それは面白そうです。[SEP]池はいいですね',
#   '池はいいですね[SEP]ボートの使える所もありますね。',
#   '活性が高いですね'],
#  ['それは面白そうです。',
#   'それは面白そうです。[SEP]池はいいですね',
#   '池はいいですね[SEP]ボートの使える所もありますね。',
#   'ボートの使える所もありますね。[SEP]活性が高いですね',
#   '活性が高いですね[SEP]どのような活性ですか?',
#   '活性は高いです'],
#  ['ボートの使える所もありますね。',
#   'ボートの使える所もありますね。[SEP]活性が高いですね',
#   '活性が高いですね[SEP]どのような活性ですか?',
#   'どのような活性ですか?[SEP]活性は高いです',
#   '活性は高いです[SEP]活発なのはいいことです。',
#   '活性が全体的に低いです'],
#  ['どのような活性ですか?',
#   'どのような活性ですか?[SEP]活性は高いです',
#   '活性は高いです[SEP]活発なのはいいことです。',
#   '活発なのはいいことです。[SEP]活性が全体的に低いです',
#   '活性が全体的に低いです[SEP]そういえば、家の近くで御祭りがありました。',
#   '活性は高いですね'],
#  ['',
#   '',
#   '',
#   'こんにちは。熱中症に気をつけて。',
#   'こんにちは。熱中症に気をつけて。[SEP]はい。ありがとう。あなたも気を付けて。',
#   '熱中症に気をつけないんですか?'],
#  ['',
#   'こんにちは。熱中症に気をつけて。',
#   'こんにちは。熱中症に気をつけて。[SEP]はい。ありがとう。あなたも気を付けて。',
#   'はい。ありがとう。あなたも気を付けて。[SEP]熱中症に気をつけないんですか?',
#   '熱中症に気をつけないんですか?[SEP]小まめに水を飲んだりして、気を付けていますよ。',
#   '熱中症に気をつけたいんでしょう?'],
#  ['はい。ありがとう。あなたも気を付けて。',
#   'はい。ありがとう。あなたも気を付けて。[SEP]熱中症に気をつけないんですか?',
#   '熱中症に気をつけないんですか?[SEP]小まめに水を飲んだりして、気を付けていますよ。',
#   '小まめに水を飲んだりして、気を付けていますよ。[SEP]熱中症に気をつけたいんでしょう?',
#   '熱中症に気をつけたいんでしょう?[SEP]そうですね。0度倒れていますから、十分気を付けています。',
#   '熱中症に気をつけなければなりませんでしたっけ'],
#  ['危ないので、気をつけなければいけませんよ。',
#   '危ないので、気をつけなければいけませんよ。[SEP]熱中症は大丈夫ですね',
#   '熱中症は大丈夫ですね[SEP]対策はしている積もりですよ。',
#   '対策はしている積もりですよ。[SEP]対策は大丈夫か??',
#   '対策は大丈夫か??[SEP]はい。水を飲んだり、塩分もとっています。',
#   '対策は必要ないですか'],
#  ['対策はしている積もりですよ。',
#   '対策はしている積もりですよ。[SEP]対策は大丈夫か??',
#   '対策は大丈夫か??[SEP]はい。水を飲んだり、塩分もとっています。',
#   'はい。水を飲んだり、塩分もとっています。[SEP]対策は必要ないですか',
#   '対策は必要ないですか[SEP]この暑さですから、全員必要ですよ',
#   '暑さは暑さですか。対策はいいですね'],
#  ['この暑さですから、全員必要ですよ',
#   'この暑さですから、全員必要ですよ[SEP]暑さは暑さですか。対策はいいですね',
#   '暑さは暑さですか。対策はいいですね[SEP]日頃の心構えが大事だと思います。',
#   '日頃の心構えが大事だと思います。[SEP]運動がいいですね',
#   '運動がいいですね[SEP]日中は辞めた方が良いと思います。',
#   '気分がいいですね'],
#  ['日頃の心構えが大事だと思います。',
#   '日頃の心構えが大事だと思います。[SEP]運動がいいですね',
#   '運動がいいですね[SEP]日中は辞めた方が良いと思います。',
#   '日中は辞めた方が良いと思います。[SEP]気分がいいですね',
#   '気分がいいですね[SEP]運動は気分転換になりますからね。',
#   '運動は気分転換になってるんですね。気分は大丈夫ですね'],
#  ['',
#   'こんにちは!ちょうど退屈してたんだ。',
#   'こんにちは!ちょうど退屈してたんだ。[SEP]こんにちは!じゃあ、一緒に遊ぼうよ',
#   'こんにちは!じゃあ、一緒に遊ぼうよ[SEP]所で、ジャンボジェット機って接着剤で組み立てられてるそうですよ。',
#   '所で、ジャンボジェット機って接着剤で組み立てられてるそうですよ。[SEP]強力なんだろうね',
#   'ジャンボジェット機を飛ばすようです'],
#  ['強力なんだろうね',
#   '強力なんだろうね[SEP]ジャンボジェット機を飛ばすようです',
#   'ジャンボジェット機を飛ばすようです[SEP]すごいね',
#   'すごいね[SEP]でしょ',
#   'でしょ[SEP]所で、夏といえば西瓜だよね',
#   '西瓜が出来てるんでしょうか?'],
#  ['所で、夏といえば西瓜だよね',
#   '所で、夏といえば西瓜だよね[SEP]西瓜が出来てるんでしょうか?',
#   '西瓜が出来てるんでしょうか?[SEP]いやいや',
#   'いやいや[SEP]いやいや笑い',
#   'いやいや笑い[SEP]今日は機嫌がいいね',
#   '機嫌を損ないましょう'],
#  ['今日は機嫌がいいね',
#   '今日は機嫌がいいね[SEP]機嫌を損ないましょう',
#   '機嫌を損ないましょう[SEP]そうはおっしゃらず笑い',
#   'そうはおっしゃらず笑い[SEP]微熱が良いですね',
#   '微熱が良いですね[SEP]微熱?',
#   '微熱は多いです'],
#  ['',
#   '',
#   '',
#   'こんにちは。熱中症に気をつけて。',
#   'こんにちは。熱中症に気をつけて。[SEP]気をつかってくれてありがとうございます。',
#   '熱中症に気をつけてたいですか?'],
#  ['',
#   'こんにちは。熱中症に気をつけて。',
#   'こんにちは。熱中症に気をつけて。[SEP]気をつかってくれてありがとうございます。',
#   '気をつかってくれてありがとうございます。[SEP]熱中症に気をつけてたいですか?',
#   '熱中症に気をつけてたいですか?[SEP]なるべく元気でいたいと思っています。',
#   '熱中症が心配されます??'],
#  ['気をつかってくれてありがとうございます。',
#   '気をつかってくれてありがとうございます。[SEP]熱中症に気をつけてたいですか?',
#   '熱中症に気をつけてたいですか?[SEP]なるべく元気でいたいと思っています。',
#   'なるべく元気でいたいと思っています。[SEP]熱中症が心配されます??',
#   '熱中症が心配されます??[SEP]今日は涼しかったので大丈夫です。',
#   '大丈夫ですか。熱中症が出てますか?'],
#  ['なるべく元気でいたいと思っています。',
#   'なるべく元気でいたいと思っています。[SEP]熱中症が心配されます??',
#   '熱中症が心配されます??[SEP]今日は涼しかったので大丈夫です。',
#   '今日は涼しかったので大丈夫です。[SEP]大丈夫ですか。熱中症が出てますか?',
#   '大丈夫ですか。熱中症が出てますか?[SEP]あなたは体調は大丈夫ですか?',
#   'あなたは、多少体調が悪くても、会社や学校に行くタイプ?'],
#  ['今日は涼しかったので大丈夫です。',
#   '今日は涼しかったので大丈夫です。[SEP]大丈夫ですか。熱中症が出てますか?',
#   '大丈夫ですか。熱中症が出てますか?[SEP]あなたは体調は大丈夫ですか?',
#   'あなたは体調は大丈夫ですか?[SEP]あなたは、多少体調が悪くても、会社や学校に行くタイプ?',
#   'あなたは、多少体調が悪くても、会社や学校に行くタイプ?[SEP]その時によります。',
#   'あなたは、多少体調が悪くても、会社や学校に行くタイプ?'],
#  ['その時によります。',
#   'その時によります。[SEP]あなたは、多少体調が悪くても、会社や学校に行くタイプ?',
#   'あなたは、多少体調が悪くても、会社や学校に行くタイプ?[SEP]大事な時は悩みますね。',
#   '大事な時は悩みますね。[SEP]体調って実は精神状態に左右されることがあるんだよね。',
#   '体調って実は精神状態に左右されることがあるんだよね。[SEP]おおいにありますね。',
#   '左右は良いですね'],
#  ['大事な時は悩みますね。',
#   '大事な時は悩みますね。[SEP]体調って実は精神状態に左右されることがあるんだよね。',
#   '体調って実は精神状態に左右されることがあるんだよね。[SEP]おおいにありますね。',
#   'おおいにありますね。[SEP]左右は良いですね',
#   '左右は良いですね[SEP]最近はお疲れですか?',
#   '顔が左右に動きます'],
#  ['おおいにありますね。',
#   'おおいにありますね。[SEP]左右は良いですね',
#   '左右は良いですね[SEP]最近はお疲れですか?',
#   '最近はお疲れですか?[SEP]顔が左右に動きます',
#   '顔が左右に動きます[SEP]元気なのは良いことです。',
#   '左右に顔を振ります'],
#  ['こんにちは、暑いですからね。',
#   'こんにちは、暑いですからね。[SEP]海に行きませんか??',
#   '海に行きませんか??[SEP]今からですか?',
#   '今からですか?[SEP]うん',
#   'うん[SEP]今日は予定があるので行けません。',
#   '海に行ってないなあ'],
#  ['今からですか?',
#   '今からですか?[SEP]うん',
#   'うん[SEP]今日は予定があるので行けません。',
#   '今日は予定があるので行けません。[SEP]海に行ってないなあ',
#   '海に行ってないなあ[SEP]私も今年はまだ行ってないですね。',
#   '海まで散歩に行くのです'],
#  ['今日は予定があるので行けません。',
#   '今日は予定があるので行けません。[SEP]海に行ってないなあ',
#   '海に行ってないなあ[SEP]私も今年はまだ行ってないですね。',
#   '私も今年はまだ行ってないですね。[SEP]海まで散歩に行くのです',
#   '海まで散歩に行くのです[SEP]海が大好きなんですね。',
#   '海は大好きですか。気持ちがいいですね'],
#  ['私も今年はまだ行ってないですね。',
#   '私も今年はまだ行ってないですね。[SEP]海まで散歩に行くのです',
#   '海まで散歩に行くのです[SEP]海が大好きなんですね。',
#   '海が大好きなんですね。[SEP]海は大好きですか。気持ちがいいですね',
#   '海は大好きですか。気持ちがいいですね[SEP]私も好きですよ。',
#   'ありがとう'],
#  ['海が大好きなんですね。',
#   '海が大好きなんですね。[SEP]海は大好きですか。気持ちがいいですね',
#   '海は大好きですか。気持ちがいいですね[SEP]私も好きですよ。',
#   '私も好きですよ。[SEP]ありがとう',
#   'ありがとう[SEP]それにしても暑いですね。',
#   'ぱたぱた'],
#  ['それにしても暑いですね。',
#   'それにしても暑いですね。[SEP]ぱたぱた',
#   'ぱたぱた[SEP]熱中症に気を付けてくださいね。',
#   '熱中症に気を付けてくださいね。[SEP]ありがとう',
#   'ありがとう[SEP]こまめに水分を取るようにした方がいいみたいですよ。',
#   '水分はいいですね'],
#  ['熱中症に気を付けてくださいね。',
#   '熱中症に気を付けてくださいね。[SEP]ありがとう',
#   'ありがとう[SEP]こまめに水分を取るようにした方がいいみたいですよ。',
#   'こまめに水分を取るようにした方がいいみたいですよ。[SEP]水分はいいですね',
#   '水分はいいですね[SEP]今の時期は汗掻きますからね。',
#   '汗はかっこいいですね'],
#  ['',
#   '',
#   '',
#   'こんにちは。気軽に声かけてね。',
#   'こんにちは。気軽に声かけてね。[SEP]分かりました。用事があれば声かけます。',
#   '大丈夫ですか?'],
#  ['',
#   'こんにちは。気軽に声かけてね。',
#   'こんにちは。気軽に声かけてね。[SEP]分かりました。用事があれば声かけます。',
#   '分かりました。用事があれば声かけます。[SEP]大丈夫ですか?',
#   '大丈夫ですか?[SEP]大丈夫です。心配ありません。',
#   'そうですねー。そうだ、一番印象に残っている誕生日の思い出は何ですか?'],
#  ['分かりました。用事があれば声かけます。',
#   '分かりました。用事があれば声かけます。[SEP]大丈夫ですか?',
#   '大丈夫ですか?[SEP]大丈夫です。心配ありません。',
#   '大丈夫です。心配ありません。[SEP]そうですねー。そうだ、一番印象に残っている誕生日の思い出は何ですか?',
#   'そうですねー。そうだ、一番印象に残っている誕生日の思い出は何ですか?[SEP]ケーキを食べてプレゼントがもらえること',
#   '昔のことをよく感じてしまうことを「思い出補正」っていうんだって。'],
#  ['そうなんですか?知らなかった',
#   'そうなんですか?知らなかった[SEP]そうなの!',
#   'そうなの![SEP]分かりました。',
#   '分かりました。[SEP]ありがとうございます',
#   'ありがとうございます[SEP]こちらこそ、ありがとうございます。',
#   'いえいえよろしくお願いします'],
#  ['こちらこそ、よろしくお願いします。',
#   'こちらこそ、よろしくお願いします。[SEP]なんて呼べばいいですか',
#   'なんて呼べばいいですか[SEP]名字でも渾名でも何でもいいですよ。',
#   '名字でも渾名でも何でもいいですよ。[SEP]職場で同僚を渾名で呼ぶのは、どうかと思うよ。',
#   '職場で同僚を渾名で呼ぶのは、どうかと思うよ。[SEP]それなら名字でお願いします。',
#   'ああ、なるほど。そうだ、趣味を教えて下さい。'],
#  ['',
#   '',
#   '',
#   'こんにちは。気軽に声かけてね。',
#   'こんにちは。気軽に声かけてね。[SEP]こんにちは、今日の天気はどう?',
#   '今は答えられないんです。'],
#  ['',
#   'こんにちは。気軽に声かけてね。',
#   'こんにちは。気軽に声かけてね。[SEP]こんにちは、今日の天気はどう?',
#   'こんにちは、今日の天気はどう?[SEP]今は答えられないんです。',
#   '今は答えられないんです。[SEP]どうして?外が見えない場所にいるとか?',
#   '天気がいいとそれだけで元気が出ちゃうよね。'],
#  ['どうして?外が見えない場所にいるとか?',
#   'どうして?外が見えない場所にいるとか?[SEP]天気がいいとそれだけで元気が出ちゃうよね。',
#   '天気がいいとそれだけで元気が出ちゃうよね。[SEP]そうだね!晴れると気分いいよね。',
#   'そうだね!晴れると気分いいよね。[SEP]朝の気分は、その日一日を左右するよね。',
#   '朝の気分は、その日一日を左右するよね。[SEP]そういえば、朝御飯は食べた?',
#   '牛丼屋さんの朝御飯メニューは、安くてお手軽でおいしいよ。'],
#  ['そうだね!晴れると気分いいよね。',
#   'そうだね!晴れると気分いいよね。[SEP]朝の気分は、その日一日を左右するよね。',
#   '朝の気分は、その日一日を左右するよね。[SEP]そういえば、朝御飯は食べた?',
#   'そういえば、朝御飯は食べた?[SEP]牛丼屋さんの朝御飯メニューは、安くてお手軽でおいしいよ。',
#   '牛丼屋さんの朝御飯メニューは、安くてお手軽でおいしいよ。[SEP]へー、よく行くの?',
#   '天気はいい感じよね'],
#  ['そういえば、朝御飯は食べた?',
#   'そういえば、朝御飯は食べた?[SEP]牛丼屋さんの朝御飯メニューは、安くてお手軽でおいしいよ。',
#   '牛丼屋さんの朝御飯メニューは、安くてお手軽でおいしいよ。[SEP]へー、よく行くの?',
#   'へー、よく行くの?[SEP]天気はいい感じよね',
#   '天気はいい感じよね[SEP]天気予報がはずれるとガッカリする。',
#   '天気予報をする気象予報士の合格率は0%なんだって。'],
#  ['天気予報がはずれるとガッカリする。',
#   '天気予報がはずれるとガッカリする。[SEP]天気予報をする気象予報士の合格率は0%なんだって。',
#   '天気予報をする気象予報士の合格率は0%なんだって。[SEP]0%か。かなり難関だね。',
#   '0%か。かなり難関だね。[SEP]太陽風や地場を予測する「宇宙天気予報」っていうのもあるんだって。',
#   '太陽風や地場を予測する「宇宙天気予報」っていうのもあるんだって。[SEP]初めて聞いたよ!物知りなんだね。',
#   '人類が初めて宇宙でプレーしたスポーツは、月面で行われたゴルフなんだよ。'],
#  ['0%か。かなり難関だね。',
#   '0%か。かなり難関だね。[SEP]太陽風や地場を予測する「宇宙天気予報」っていうのもあるんだって。',
#   '太陽風や地場を予測する「宇宙天気予報」っていうのもあるんだって。[SEP]初めて聞いたよ!物知りなんだね。',
#   '初めて聞いたよ!物知りなんだね。[SEP]人類が初めて宇宙でプレーしたスポーツは、月面で行われたゴルフなんだよ。',
#   '人類が初めて宇宙でプレーしたスポーツは、月面で行われたゴルフなんだよ。[SEP]本当?月でゴルフってなんか不思議。',
#   'パーより0打少ないアルバトロスはホールインワンよりも出る確率が少ないんだって。'],
#  ['初めて聞いたよ!物知りなんだね。',
#   '初めて聞いたよ!物知りなんだね。[SEP]人類が初めて宇宙でプレーしたスポーツは、月面で行われたゴルフなんだよ。',
#   '人類が初めて宇宙でプレーしたスポーツは、月面で行われたゴルフなんだよ。[SEP]本当?月でゴルフってなんか不思議。',
#   '本当?月でゴルフってなんか不思議。[SEP]パーより0打少ないアルバトロスはホールインワンよりも出る確率が少ないんだって。',
#   'パーより0打少ないアルバトロスはホールインワンよりも出る確率が少ないんだって。[SEP]ホールインワンの方が難しそうなのにね。',
#   '一生の内で救急車に乗る確率は0%くらいだそうだ。'],
#  ['', '', '', '今晩はー。ちょうど退屈してたんだ。', '今晩はー。ちょうど退屈してたんだ。[SEP]こんばんは', 'はんばんこ'],
#  ['',
#   '今晩はー。ちょうど退屈してたんだ。',
#   '今晩はー。ちょうど退屈してたんだ。[SEP]こんばんは',
#   'こんばんは[SEP]はんばんこ',
#   'はんばんこ[SEP]どういう意味?',
#   '困らせていますか?コミュニケーション取れるように頑張るので、お付き合いください。お気に入りの音楽って何ですか?'],
#  ['こんばんは',
#   'こんばんは[SEP]はんばんこ',
#   'はんばんこ[SEP]どういう意味?',
#   'どういう意味?[SEP]困らせていますか?コミュニケーション取れるように頑張るので、お付き合いください。お気に入りの音楽って何ですか?',
#   '困らせていますか?コミュニケーション取れるように頑張るので、お付き合いください。お気に入りの音楽って何ですか?[SEP]クラシックがいいですね',
#   '英語でコミュニケーションがとれるらしいです'],
#  ['クラシックがいいですね',
#   'クラシックがいいですね[SEP]英語でコミュニケーションがとれるらしいです',
#   '英語でコミュニケーションがとれるらしいです[SEP]私は英語は苦手です',
#   '私は英語は苦手です[SEP]英語は苦手ですか。コミュニケーションは難しいですね',
#   '英語は苦手ですか。コミュニケーションは難しいですね[SEP]日本語ではできないですか?',
#   'コミュニケーションは得意です'],
#  ['日本語ではできないですか?',
#   '日本語ではできないですか?[SEP]コミュニケーションは得意です',
#   'コミュニケーションは得意です[SEP]よろしくおねがいします',
#   'よろしくおねがいします[SEP]はい',
#   'はい[SEP]何のお話をしますか?',
#   '所で、資格を取るのが趣味だと伺いましたが、コミュニケーションを高めますねぇ'],
#  ['よろしくおねがいします',
#   'よろしくおねがいします[SEP]はい',
#   'はい[SEP]何のお話をしますか?',
#   '何のお話をしますか?[SEP]所で、資格を取るのが趣味だと伺いましたが、コミュニケーションを高めますねぇ',
#   '所で、資格を取るのが趣味だと伺いましたが、コミュニケーションを高めますねぇ[SEP]私は資格はあまり持ってません',
#   '時期から資格を取りますねぇ'],
#  ['何のお話をしますか?',
#   '何のお話をしますか?[SEP]所で、資格を取るのが趣味だと伺いましたが、コミュニケーションを高めますねぇ',
#   '所で、資格を取るのが趣味だと伺いましたが、コミュニケーションを高めますねぇ[SEP]私は資格はあまり持ってません',
#   '私は資格はあまり持ってません[SEP]時期から資格を取りますねぇ',
#   '時期から資格を取りますねぇ[SEP]何か資格を取るんですか?',
#   '資格でもとります'],
#  ['私は資格はあまり持ってません',
#   '私は資格はあまり持ってません[SEP]時期から資格を取りますねぇ',
#   '時期から資格を取りますねぇ[SEP]何か資格を取るんですか?',
#   '何か資格を取るんですか?[SEP]資格でもとります',
#   '資格でもとります[SEP]がんばって下さい。何の資格ですか?',
#   '資格を生かします'],
#  ['', '', '', 'こんにちは!海へ行きたいね。', 'こんにちは!海へ行きたいね。[SEP]おはおは', 'ようよう'],
#  ['',
#   'こんにちは!海へ行きたいね。',
#   'こんにちは!海へ行きたいね。[SEP]おはおは',
#   'おはおは[SEP]ようよう',
#   'ようよう[SEP]好きな漫画は?',
#   '最近じゃあ漫画もスマホで読めるから、すごいよね。'],
#  ['毎日読んでるよ。',
#   '毎日読んでるよ。[SEP]スマホはいいですね',
#   'スマホはいいですね[SEP]電池がすぐなくなっちゃうよね。',
#   '電池がすぐなくなっちゃうよね。[SEP]電池は必要なんですよねー',
#   '電池は必要なんですよねー[SEP]好きな映画は何?',
#   '電池はエネループがいいですね'],
#  ['エネループ好きすぎだろ',
#   'エネループ好きすぎだろ[SEP]エネループは必須ですよねえ',
#   'エネループは必須ですよねえ[SEP]それな',
#   'それな[SEP]ねー',
#   'ねー[SEP]いつまでこの話するの?',
#   '干支は辰年です。'],
#  ['',
#   'こんにちは。気軽に声かけてね。',
#   'こんにちは。気軽に声かけてね。[SEP]こんにちは',
#   'こんにちは[SEP]こんにちは',
#   'こんにちは[SEP]今日は暖かいですね',
#   'そうですか…。所で、卓球は好きですか?'],
#  ['こんにちは',
#   'こんにちは[SEP]こんにちは',
#   'こんにちは[SEP]今日は暖かいですね',
#   '今日は暖かいですね[SEP]そうですか…。所で、卓球は好きですか?',
#   'そうですか…。所で、卓球は好きですか?[SEP]卓球は好きですよ。卓球よくされるんですか?',
#   'あの有名な卓球の選手の掛け声?サー!'],
#  ['卓球は好きですよ。卓球よくされるんですか?',
#   '卓球は好きですよ。卓球よくされるんですか?[SEP]あの有名な卓球の選手の掛け声?サー!',
#   'あの有名な卓球の選手の掛け声?サー![SEP]福原愛ちゃんですね?',
#   '福原愛ちゃんですね?[SEP]あの泣き虫愛ちゃんが結婚したね、素敵な女性になったな。',
#   'あの泣き虫愛ちゃんが結婚したね、素敵な女性になったな。[SEP]ですね、可愛い',
#   '男性よりも精神的に強い女性はたくさんいます。'],
#  ['福原愛ちゃんですね?',
#   '福原愛ちゃんですね?[SEP]あの泣き虫愛ちゃんが結婚したね、素敵な女性になったな。',
#   'あの泣き虫愛ちゃんが結婚したね、素敵な女性になったな。[SEP]ですね、可愛い',
#   'ですね、可愛い[SEP]男性よりも精神的に強い女性はたくさんいます。',
#   '男性よりも精神的に強い女性はたくさんいます。[SEP]女性の方がいろいろ大人ですね?',
#   '大人になったらやっぱり選挙に行かないとね。'],
#  ['女性の方がいろいろ大人ですね?',
#   '女性の方がいろいろ大人ですね?[SEP]大人になったらやっぱり選挙に行かないとね。',
#   '大人になったらやっぱり選挙に行かないとね。[SEP]選挙で候補者選びは大事ですよね?',
#   '選挙で候補者選びは大事ですよね?[SEP]選挙に行くと、政治のニュースも興味深くなるよね。',
#   '選挙に行くと、政治のニュースも興味深くなるよね。[SEP]うん!それはありますね',
#   '選挙はうるさいです'],
#  ['うん!それはありますね',
#   'うん!それはありますね[SEP]選挙はうるさいです',
#   '選挙はうるさいです[SEP]応援演説かな?',
#   '応援演説かな?[SEP]アメリカの大統領って皆演説上手だよね。日本人は向いてないかも。',
#   'アメリカの大統領って皆演説上手だよね。日本人は向いてないかも。[SEP]上手上手。確かにそうかも?',
#   '日本人って本当にラーメンが好きで、いろいろな種類を開発するよね。'],
#  ['',
#   '',
#   '',
#   'こんにちは。熱中症に気をつけて。',
#   'こんにちは。熱中症に気をつけて。[SEP]今日は涼しいから大丈夫でしょう。',
#   '熱中症に気をつけてたいですか?'],
#  ['',
#   'こんにちは。熱中症に気をつけて。',
#   'こんにちは。熱中症に気をつけて。[SEP]今日は涼しいから大丈夫でしょう。',
#   '今日は涼しいから大丈夫でしょう。[SEP]熱中症に気をつけてたいですか?',
#   '熱中症に気をつけてたいですか?[SEP]暑い日には気をつけたいですね。',
#   '熱中症はいいですね'],
#  ['熱中症にはなりたくないです。',
#   '熱中症にはなりたくないです。[SEP]熱中症に気をつけないんですよねー',
#   '熱中症に気をつけないんですよねー[SEP]熱中症に気をつけてますよ。',
#   '熱中症に気をつけてますよ。[SEP]予防が重要ですね',
#   '予防が重要ですね[SEP]水分の補給が大事。',
#   '補給は少ないですね'],
#  ['熱中症に気をつけてますよ。',
#   '熱中症に気をつけてますよ。[SEP]予防が重要ですね',
#   '予防が重要ですね[SEP]水分の補給が大事。',
#   '水分の補給が大事。[SEP]補給は少ないですね',
#   '補給は少ないですね[SEP]しっかり補給しないと。',
#   'コンビニで取りますよねー'],
#  ['しっかり補給しないと。',
#   'しっかり補給しないと。[SEP]コンビニで取りますよねー',
#   'コンビニで取りますよねー[SEP]あちこちに自動販売機もありますしね。',
#   'あちこちに自動販売機もありますしね。[SEP]自動販売機はいいですね',
#   '自動販売機はいいですね[SEP]自動販売機は便利です。',
#   '自動販売機はほしいですね'],
#  ['あちこちに自動販売機もありますしね。',
#   'あちこちに自動販売機もありますしね。[SEP]自動販売機はいいですね',
#   '自動販売機はいいですね[SEP]自動販売機は便利です。',
#   '自動販売機は便利です。[SEP]自動販売機はほしいですね',
#   '自動販売機はほしいですね[SEP]欲しくはないですけどね。',
#   '自動販売機は何気ないですね'],
#  ['自動販売機は便利です。',
#   '自動販売機は便利です。[SEP]自動販売機はほしいですね',
#   '自動販売機はほしいですね[SEP]欲しくはないですけどね。',
#   '欲しくはないですけどね。[SEP]自動販売機は何気ないですね',
#   '自動販売機は何気ないですね[SEP]何気なくそこにある。',
#   '所で、以前から健康に気を遣っていると聞きましたが、予防が大切ですね'],
#  ['',
#   'こんにちは。ちょうど退屈してたんだ。',
#   'こんにちは。ちょうど退屈してたんだ。[SEP]こんにちは、今日も暑いですね。',
#   'こんにちは、今日も暑いですね。[SEP]話は変わりますけど、0月0日は映画の日だって、知ってました?',
#   '話は変わりますけど、0月0日は映画の日だって、知ってました?[SEP]すみません、知りません。',
#   '得意料理はなんですか?'],
#  ['すみません、知りません。',
#   'すみません、知りません。[SEP]得意料理はなんですか?',
#   '得意料理はなんですか?[SEP]ギョーザです。あなたの得意料理はなんですか?',
#   'ギョーザです。あなたの得意料理はなんですか?[SEP]料理は不得手です',
#   '料理は不得手です[SEP]所で好きな映画はなんですか?',
#   '料理は下手です'],
#  ['ギョーザです。あなたの得意料理はなんですか?',
#   'ギョーザです。あなたの得意料理はなんですか?[SEP]料理は不得手です',
#   '料理は不得手です[SEP]所で好きな映画はなんですか?',
#   '所で好きな映画はなんですか?[SEP]料理は下手です',
#   '料理は下手です[SEP]料理は苦手ですが、好きな料理はなんですか?',
#   '料理の好きな人は、鍋やフライパンにもすごくこだわりそうだよね。'],
#  ['所で好きな映画はなんですか?',
#   '所で好きな映画はなんですか?[SEP]料理は下手です',
#   '料理は下手です[SEP]料理は苦手ですが、好きな料理はなんですか?',
#   '料理は苦手ですが、好きな料理はなんですか?[SEP]料理の好きな人は、鍋やフライパンにもすごくこだわりそうだよね。',
#   '料理の好きな人は、鍋やフライパンにもすごくこだわりそうだよね。[SEP]そうですね。良く行く御店はありますか?',
#   '料理は手早いですね'],
#  ['料理は苦手ですが、好きな料理はなんですか?',
#   '料理は苦手ですが、好きな料理はなんですか?[SEP]料理の好きな人は、鍋やフライパンにもすごくこだわりそうだよね。',
#   '料理の好きな人は、鍋やフライパンにもすごくこだわりそうだよね。[SEP]そうですね。良く行く御店はありますか?',
#   'そうですね。良く行く御店はありますか?[SEP]料理は手早いですね',
#   '料理は手早いですね[SEP]話は変わりますけど、旅行には良く行きますか?',
#   '料理が出来上がるのです'],
#  ['そうですね。良く行く御店はありますか?',
#   'そうですね。良く行く御店はありますか?[SEP]料理は手早いですね',
#   '料理は手早いですね[SEP]話は変わりますけど、旅行には良く行きますか?',
#   '話は変わりますけど、旅行には良く行きますか?[SEP]料理が出来上がるのです',
#   '料理が出来上がるのです[SEP]料理はまだですが、テレビですきな番組がありますか?',
#   '朝からテレビをつけるかもしれない'],
#  ['話は変わりますけど、旅行には良く行きますか?',
#   '話は変わりますけど、旅行には良く行きますか?[SEP]料理が出来上がるのです',
#   '料理が出来上がるのです[SEP]料理はまだですが、テレビですきな番組がありますか?',
#   '料理はまだですが、テレビですきな番組がありますか?[SEP]朝からテレビをつけるかもしれない',
#   '朝からテレビをつけるかもしれない[SEP]アニメがすきですか?',
#   'テレビは大切ですね'],
#  ['料理はまだですが、テレビですきな番組がありますか?',
#   '料理はまだですが、テレビですきな番組がありますか?[SEP]朝からテレビをつけるかもしれない',
#   '朝からテレビをつけるかもしれない[SEP]アニメがすきですか?',
#   'アニメがすきですか?[SEP]テレビは大切ですね',
#   'テレビは大切ですね[SEP]私はサスペンスがすきですが、あなたは何を良く見ますか?',
#   '学校や会社から帰ってきて、テレビをつけるとホッとするよね。'],
#  ['',
#   '',
#   '',
#   'こんにちは!夏といえばスイカだね。',
#   'こんにちは!夏といえばスイカだね。[SEP]こんにちは、スイカ好きなんだね',
#   'スイカで有名か??'],
#  ['',
#   'こんにちは!夏といえばスイカだね。',
#   'こんにちは!夏といえばスイカだね。[SEP]こんにちは、スイカ好きなんだね',
#   'こんにちは、スイカ好きなんだね[SEP]スイカで有名か??',
#   'スイカで有名か??[SEP]近くに産地があるよ',
#   'イタリアが好きですね'],
#  ['近くに産地があるよ',
#   '近くに産地があるよ[SEP]イタリアが好きですね',
#   'イタリアが好きですね[SEP]行ったことないよ。イタリア料理は好きだな',
#   '行ったことないよ。イタリア料理は好きだな[SEP]イタリア料理は好きですね',
#   'イタリア料理は好きですね[SEP]大好きだよ',
#   'イタリア料理は大好きですか。もう一回言ってください'],
#  ['大好きだよ',
#   '大好きだよ[SEP]イタリア料理は大好きですか。もう一回言ってください',
#   'イタリア料理は大好きですか。もう一回言ってください[SEP]イタリア料理は大好き',
#   'イタリア料理は大好き[SEP]イタリア料理は大好きですね',
#   'イタリア料理は大好きですね[SEP]うん、好きでよく食べるよ',
#   'イタリア料理で有名ですね'],
#  ['うん、好きでよく食べるよ',
#   'うん、好きでよく食べるよ[SEP]イタリア料理で有名ですね',
#   'イタリア料理で有名ですね[SEP]そんなことはないんじゃないかな?',
#   'そんなことはないんじゃないかな?[SEP]そんなことある',
#   'そんなことある[SEP]そうなんだ。例えばなんて御店??',
#   'イタリア料理は美味しいですね'],
#  ['そうなんだ。例えばなんて御店??',
#   'そうなんだ。例えばなんて御店??[SEP]イタリア料理は美味しいですね',
#   'イタリア料理は美味しいですね[SEP]私はパスタが好きだよ',
#   '私はパスタが好きだよ[SEP]イタリア料理は美味しいですよねー',
#   'イタリア料理は美味しいですよねー[SEP]ピザも好きだな',
#   'イタリア料理は得意ですね'],
#  ['掃除と料理が好きです。',
#   '掃除と料理が好きです。[SEP]料理は楽しいと思いますか?',
#   '料理は楽しいと思いますか?[SEP]たまに失敗することもありますが、料理は楽しいですね。',
#   'たまに失敗することもありますが、料理は楽しいですね。[SEP]カップラーメンでもインスタントカレーでも、立派な料理だよね。',
#   'カップラーメンでもインスタントカレーでも、立派な料理だよね。[SEP]私はカップラーメンもインスタントカレーも大好きです。',
#   '野菜が美味しいですね'],
#  ['たまに失敗することもありますが、料理は楽しいですね。',
#   'たまに失敗することもありますが、料理は楽しいですね。[SEP]カップラーメンでもインスタントカレーでも、立派な料理だよね。',
#   'カップラーメンでもインスタントカレーでも、立派な料理だよね。[SEP]私はカップラーメンもインスタントカレーも大好きです。',
#   '私はカップラーメンもインスタントカレーも大好きです。[SEP]野菜が美味しいですね',
#   '野菜が美味しいですね[SEP]美味しいですよね。野菜はどうやって食べるのが好きですか?',
#   '味が濃いですね'],
#  ['私はカップラーメンもインスタントカレーも大好きです。',
#   '私はカップラーメンもインスタントカレーも大好きです。[SEP]野菜が美味しいですね',
#   '野菜が美味しいですね[SEP]美味しいですよね。野菜はどうやって食べるのが好きですか?',
#   '美味しいですよね。野菜はどうやって食べるのが好きですか?[SEP]味が濃いですね',
#   '味が濃いですね[SEP]濃い味と薄い味どちらが好きですか?',
#   '野菜はたっぷりですね'],
#  ['そうですね。最近は便利な調理器具が増えていますね。',
#   'そうですね。最近は便利な調理器具が増えていますね。[SEP]料理は大切ですね',
#   '料理は大切ですね[SEP]食べることは生きることといいますからね。',
#   '食べることは生きることといいますからね。[SEP]料理の好きな人は、鍋やフライパンにもすごくこだわりそうだよね。',
#   '料理の好きな人は、鍋やフライパンにもすごくこだわりそうだよね。[SEP]私も最近新しいフライパンを買いました。',
#   '料理は手早いですね'],
#  ['',
#   'こんにちは。夏といえばスイカだね。',
#   'こんにちは。夏といえばスイカだね。[SEP]スイカは好きですか?',
#   'スイカは好きですか?[SEP]スイカはうまいですね',
#   'スイカはうまいですね[SEP]はい美味しいですね。',
#   'スイカは食べるのがおいしいですね'],
#  ['スイカは好きですか?',
#   'スイカは好きですか?[SEP]スイカはうまいですね',
#   'スイカはうまいですね[SEP]はい美味しいですね。',
#   'はい美味しいですね。[SEP]スイカは食べるのがおいしいですね',
#   'スイカは食べるのがおいしいですね[SEP]夏といえばスイカ以外に何を思い浮かべますか?',
#   '家で食べます'],
#  ['はい美味しいですね。',
#   'はい美味しいですね。[SEP]スイカは食べるのがおいしいですね',
#   'スイカは食べるのがおいしいですね[SEP]夏といえばスイカ以外に何を思い浮かべますか?',
#   '夏といえばスイカ以外に何を思い浮かべますか?[SEP]家で食べます',
#   '家で食べます[SEP]独り暮らしですか?',
#   '独り暮らしは食生活が偏るのです'],
#  ['夏といえばスイカ以外に何を思い浮かべますか?',
#   '夏といえばスイカ以外に何を思い浮かべますか?[SEP]家で食べます',
#   '家で食べます[SEP]独り暮らしですか?',
#   '独り暮らしですか?[SEP]独り暮らしは食生活が偏るのです',
#   '独り暮らしは食生活が偏るのです[SEP]自炊してますか?',
#   '自炊は安上がりです'],
#  ['独り暮らしですか?',
#   '独り暮らしですか?[SEP]独り暮らしは食生活が偏るのです',
#   '独り暮らしは食生活が偏るのです[SEP]自炊してますか?',
#   '自炊してますか?[SEP]自炊は安上がりです',
#   '自炊は安上がりです[SEP]安上がりですけど面倒ですよね?',
#   '自炊はお金がかからないんですよねぇ'],
#  ['自炊してますか?',
#   '自炊してますか?[SEP]自炊は安上がりです',
#   '自炊は安上がりです[SEP]安上がりですけど面倒ですよね?',
#   '安上がりですけど面倒ですよね?[SEP]自炊はお金がかからないんですよねぇ',
#   '自炊はお金がかからないんですよねぇ[SEP]得意料理は何ですか?',
#   'お金がかかるのです'],
#  ['安上がりですけど面倒ですよね?',
#   '安上がりですけど面倒ですよね?[SEP]自炊はお金がかからないんですよねぇ',
#   '自炊はお金がかからないんですよねぇ[SEP]得意料理は何ですか?',
#   '得意料理は何ですか?[SEP]お金がかかるのです',
#   'お金がかかるのです[SEP]明日の予定は?',
#   'お金は御財布に入れるかもしれない'],
#  ['得意料理は何ですか?',
#   '得意料理は何ですか?[SEP]お金がかかるのです',
#   'お金がかかるのです[SEP]明日の予定は?',
#   '明日の予定は?[SEP]お金は御財布に入れるかもしれない',
#   'お金は御財布に入れるかもしれない[SEP]毎月貯金してますか?',
#   '手を貯金に出しますねぇ'],
#  ['明日の予定は?',
#   '明日の予定は?[SEP]お金は御財布に入れるかもしれない',
#   'お金は御財布に入れるかもしれない[SEP]毎月貯金してますか?',
#   '毎月貯金してますか?[SEP]手を貯金に出しますねぇ',
#   '手を貯金に出しますねぇ[SEP]明日の予定は?',
#   '手を貯金に出します'],
#  ['',
#   'こんばんは。声かけてくれるのを待ってたんだ。',
#   'こんばんは。声かけてくれるのを待ってたんだ。[SEP]こんばんは。それは嬉しいです。',
#   'こんばんは。それは嬉しいです。[SEP]今日の夕食は済みました?',
#   '今日の夕食は済みました?[SEP]カレーライスを食べました。',
#   '夕食は無しか??'],
#  ['こんばんは。それは嬉しいです。',
#   'こんばんは。それは嬉しいです。[SEP]今日の夕食は済みました?',
#   '今日の夕食は済みました?[SEP]カレーライスを食べました。',
#   'カレーライスを食べました。[SEP]夕食は無しか??',
#   '夕食は無しか??[SEP]食べました。',
#   '食べてない'],
#  ['夕食は食べてないのですか?',
#   '夕食は食べてないのですか?[SEP]実家で食べるのです',
#   '実家で食べるのです[SEP]まだなんですね。',
#   'まだなんですね。[SEP]晩御飯を食べるかもしれない',
#   '晩御飯を食べるかもしれない[SEP]何が食べたいですか?',
#   '御飯を食べに行きますよねえ'],
#  ['まだなんですね。',
#   'まだなんですね。[SEP]晩御飯を食べるかもしれない',
#   '晩御飯を食べるかもしれない[SEP]何が食べたいですか?',
#   '何が食べたいですか?[SEP]御飯を食べに行きますよねえ',
#   '御飯を食べに行きますよねえ[SEP]じゃあどんな食べ物が好きですか?',
#   '炊き立てがおいしいですね'],
#  ['じゃあどんな食べ物が好きですか?',
#   'じゃあどんな食べ物が好きですか?[SEP]炊き立てがおいしいですね',
#   '炊き立てがおいしいですね[SEP]御飯は炊き立てが美味しいですね。',
#   '御飯は炊き立てが美味しいですね。[SEP]どんなに落ち込んでいても、おいしい御飯を食べると元気になるよね。',
#   'どんなに落ち込んでいても、おいしい御飯を食べると元気になるよね。[SEP]そうかもしれません。好きな食べ物は御飯ですか?',
#   'どんなに落ち込んでいても、おいしい御飯を食べると元気になるよね。'],
#  ['御飯は炊き立てが美味しいですね。',
#   '御飯は炊き立てが美味しいですね。[SEP]どんなに落ち込んでいても、おいしい御飯を食べると元気になるよね。',
#   'どんなに落ち込んでいても、おいしい御飯を食べると元気になるよね。[SEP]そうかもしれません。好きな食べ物は御飯ですか?',
#   'そうかもしれません。好きな食べ物は御飯ですか?[SEP]どんなに落ち込んでいても、おいしい御飯を食べると元気になるよね。',
#   'どんなに落ち込んでいても、おいしい御飯を食べると元気になるよね。[SEP]御飯がとても好きなようですね。',
#   '食べるのがいいですね'],
#  ['',
#   '',
#   '',
#   'こんにちは!ちょうど退屈してたんだ。',
#   'こんにちは!ちょうど退屈してたんだ。[SEP]今日も暑いですね',
#   '夕食は食べましたか?'],
#  ['',
#   'こんにちは!ちょうど退屈してたんだ。',
#   'こんにちは!ちょうど退屈してたんだ。[SEP]今日も暑いですね',
#   '今日も暑いですね[SEP]夕食は食べましたか?',
#   '夕食は食べましたか?[SEP]昨日の夕食は食べましたよ',
#   '夕食は美味しいですね'],
#  ['ラーメンですか。私も好きですよ。',
#   'ラーメンですか。私も好きですよ。[SEP]豚骨が好きですね',
#   '豚骨が好きですね[SEP]豚骨とは渋い。私は豚骨醤油も好きですよ。',
#   '豚骨とは渋い。私は豚骨醤油も好きですよ。[SEP]醤油は好きですね',
#   '醤油は好きですね[SEP]醤油もいいですよね。味噌や塩はどうですか?',
#   '少なめがいいですね'],
#  ['豚骨とは渋い。私は豚骨醤油も好きですよ。',
#   '豚骨とは渋い。私は豚骨醤油も好きですよ。[SEP]醤油は好きですね',
#   '醤油は好きですね[SEP]醤油もいいですよね。味噌や塩はどうですか?',
#   '醤油もいいですよね。味噌や塩はどうですか?[SEP]少なめがいいですね',
#   '少なめがいいですね[SEP]ほほ、小食なんですね。たくさん食べると太りますもんね。',
#   '最近は頬にピアスをする人もいるみたいだけど、信じられないよね。'],
#  ['ほほ、小食なんですね。たくさん食べると太りますもんね。',
#   'ほほ、小食なんですね。たくさん食べると太りますもんね。[SEP]最近は頬にピアスをする人もいるみたいだけど、信じられないよね。',
#   '最近は頬にピアスをする人もいるみたいだけど、信じられないよね。[SEP]頬にピアスですか?蛇にピアスって小説があったような…。',
#   '頬にピアスですか?蛇にピアスって小説があったような…。[SEP]最近は、耳だけじゃなくて、お臍や鼻につけている人もいるんだよね。',
#   '最近は、耳だけじゃなくて、お臍や鼻につけている人もいるんだよね。[SEP]そうそう。それはいますね。やってみたいですか?',
#   '耳朶の大きい福耳の人はお金が貯まるっていうから、うらやましいよね。'],
#  ['頬にピアスですか?蛇にピアスって小説があったような…。',
#   '頬にピアスですか?蛇にピアスって小説があったような…。[SEP]最近は、耳だけじゃなくて、お臍や鼻につけている人もいるんだよね。',
#   '最近は、耳だけじゃなくて、お臍や鼻につけている人もいるんだよね。[SEP]そうそう。それはいますね。やってみたいですか?',
#   'そうそう。それはいますね。やってみたいですか?[SEP]耳朶の大きい福耳の人はお金が貯まるっていうから、うらやましいよね。',
#   '耳朶の大きい福耳の人はお金が貯まるっていうから、うらやましいよね。[SEP]松井秀喜さんは大きいよね。ネイマールは小さいんだよ。',
#   'お金は大きとか'],
#  ['',
#   '',
#   '',
#   'こんにちは。気軽に声かけてね。',
#   'こんにちは。気軽に声かけてね。[SEP]こんにちは。冷えますね。',
#   'おや、それは!じゃあ、最近気になるニュースなどはありますか?'],
#  ['',
#   'こんにちは。気軽に声かけてね。',
#   'こんにちは。気軽に声かけてね。[SEP]こんにちは。冷えますね。',
#   'こんにちは。冷えますね。[SEP]おや、それは!じゃあ、最近気になるニュースなどはありますか?',
#   'おや、それは!じゃあ、最近気になるニュースなどはありますか?[SEP]大阪なおみさんが気になります。',
#   '大阪と聞いてイメージする「食い倒れ人形」が何なのか知らない人が多いよね。'],
#  ['福井県では、蕎麦と、饂飩を一体にしたうそばがあるそうですよ。',
#   '福井県では、蕎麦と、饂飩を一体にしたうそばがあるそうですよ。[SEP]蕎麦かな。',
#   '蕎麦かな。[SEP]そうですか。何か趣味はありますか?',
#   'そうですか。何か趣味はありますか?[SEP]趣味はゲームかな。',
#   '趣味はゲームかな。[SEP]どうんなゲームが好きですか?',
#   'どうだと思いますか??'],
#  ['そうですか。何か趣味はありますか?',
#   'そうですか。何か趣味はありますか?[SEP]趣味はゲームかな。',
#   '趣味はゲームかな。[SEP]どうんなゲームが好きですか?',
#   'どうんなゲームが好きですか?[SEP]どうだと思いますか??',
#   'どうだと思いますか??[SEP]パズルゲームが好きそうですが違いますか?',
#   '寝られなくなるから夜はやめた方がいいよ。'],
#  ['どうんなゲームが好きですか?',
#   'どうんなゲームが好きですか?[SEP]どうだと思いますか??',
#   'どうだと思いますか??[SEP]パズルゲームが好きそうですが違いますか?',
#   'パズルゲームが好きそうですが違いますか?[SEP]寝られなくなるから夜はやめた方がいいよ。',
#   '寝られなくなるから夜はやめた方がいいよ。[SEP]確かに、寝る前にゲームをするとなかなか寝られないですよね。',
#   '世界で最初に作られたコンピューターゲームは、チェスのゲームなんだよ。'],
#  ['スイカ大好きなんです。',
#   'スイカ大好きなんです。[SEP]スイカは実が大きいですね',
#   'スイカは実が大きいですね[SEP]そうですね。重いですしね。',
#   'そうですね。重いですしね。[SEP]スイカは大好きですね',
#   'スイカは大好きですね[SEP]甘くて美味しいですよね。',
#   'スイカは面白いですね'],
#  ['そうですね。重いですしね。',
#   'そうですね。重いですしね。[SEP]スイカは大好きですね',
#   'スイカは大好きですね[SEP]甘くて美味しいですよね。',
#   '甘くて美味しいですよね。[SEP]スイカは面白いですね',
#   'スイカは面白いですね[SEP]見た目のしましまがユニークですね。',
#   '見た目は真面目ですね'],
#  ['甘くて美味しいですよね。',
#   '甘くて美味しいですよね。[SEP]スイカは面白いですね',
#   'スイカは面白いですね[SEP]見た目のしましまがユニークですね。',
#   '見た目のしましまがユニークですね。[SEP]見た目は真面目ですね',
#   '見た目は真面目ですね[SEP]私の見た目ですか?よく言われます。',
#   '見た目は清楚ですね'],
#  ['私の見た目ですか?よく言われます。',
#   '私の見た目ですか?よく言われます。[SEP]見た目は清楚ですね',
#   '見た目は清楚ですね[SEP]ありがとうございます。嬉しいです。',
#   'ありがとうございます。嬉しいです。[SEP]見た目はチャラいですか',
#   '見た目はチャラいですか[SEP]そうでもないですよ。中身が大事ですよね。',
#   '見た目はかっこいいですね'],
#  ['ありがとうございます。嬉しいです。',
#   'ありがとうございます。嬉しいです。[SEP]見た目はチャラいですか',
#   '見た目はチャラいですか[SEP]そうでもないですよ。中身が大事ですよね。',
#   'そうでもないですよ。中身が大事ですよね。[SEP]見た目はかっこいいですね',
#   '見た目はかっこいいですね[SEP]見た目には自信がありません。',
#   '見た目はクールですね'],
#  ['見た目には自信がありません。',
#   '見た目には自信がありません。[SEP]見た目はクールですね',
#   '見た目はクールですね[SEP]涼しい感じでしょうか。',
#   '涼しい感じでしょうか。[SEP]見た目はかっこいいらしいですよ',
#   '見た目はかっこいいらしいですよ[SEP]またまた。',
#   'たまたま'],
#  ['',
#   '',
#   '',
#   'こんにちは!声かけてくれるのを待ってたんだ。',
#   'こんにちは!声かけてくれるのを待ってたんだ。[SEP]私もかけようか迷っていた所です',
#   '体は丈夫ですか?'],
#  ['',
#   'こんにちは!声かけてくれるのを待ってたんだ。',
#   'こんにちは!声かけてくれるのを待ってたんだ。[SEP]私もかけようか迷っていた所です',
#   '私もかけようか迷っていた所です[SEP]体は丈夫ですか?',
#   '体は丈夫ですか?[SEP]少し痛いですね',
#   '今日のお昼は何を食べました?'],
#  ['お好み焼きと御飯は一緒に食べませんよ',
#   'お好み焼きと御飯は一緒に食べませんよ[SEP]お好み焼きは家で食べてるのですか?',
#   'お好み焼きは家で食べてるのですか?[SEP]家で食べましたよ',
#   '家で食べましたよ[SEP]体調の方はいかがでしょう',
#   '体調の方はいかがでしょう[SEP]あまり良くないですね',
#   '好きな人はいますか?'],
#  ['家で食べましたよ',
#   '家で食べましたよ[SEP]体調の方はいかがでしょう',
#   '体調の方はいかがでしょう[SEP]あまり良くないですね',
#   'あまり良くないですね[SEP]好きな人はいますか?',
#   '好きな人はいますか?[SEP]嫁と子供が好きです',
#   '愛妻弁当ってお嫁さんの象徴だよね。'],
#  ['あまり良くないですね',
#   'あまり良くないですね[SEP]好きな人はいますか?',
#   '好きな人はいますか?[SEP]嫁と子供が好きです',
#   '嫁と子供が好きです[SEP]愛妻弁当ってお嫁さんの象徴だよね。',
#   '愛妻弁当ってお嫁さんの象徴だよね。[SEP]で毎日だと飽きますよ',
#   '映画はよく見るんですか?'],
#  ['で毎日だと飽きますよ',
#   'で毎日だと飽きますよ[SEP]映画はよく見るんですか?',
#   '映画はよく見るんですか?[SEP]最近は見ないですね',
#   '最近は見ないですね[SEP]映画は一緒に見るんですか?',
#   '映画は一緒に見るんですか?[SEP]一人で見るのが好きです',
#   '映画は見やすいですね'],
#  ['',
#   '',
#   '',
#   'こんにちはー。気軽に声かけてね。',
#   'こんにちはー。気軽に声かけてね。[SEP]今日は暑いですね。',
#   'どんなジャンルの本を読みますか?'],
#  ['',
#   'こんにちはー。気軽に声かけてね。',
#   'こんにちはー。気軽に声かけてね。[SEP]今日は暑いですね。',
#   '今日は暑いですね。[SEP]どんなジャンルの本を読みますか?',
#   'どんなジャンルの本を読みますか?[SEP]SF小説が好きです。',
#   'SF小説で有名ですね'],
#  ['今日は暑いですね。',
#   '今日は暑いですね。[SEP]どんなジャンルの本を読みますか?',
#   'どんなジャンルの本を読みますか?[SEP]SF小説が好きです。',
#   'SF小説が好きです。[SEP]SF小説で有名ですね',
# ...
#   '0年間は短いようで長いので忘れていることも多くて、リプトン・ウインターティーパンチを見ると、今年の日本の状況がよく分かります。[SEP]紅茶はリプトンに限りますよ。',
#   '紅茶はリプトンに限りますよ。[SEP]「日本に住んでいれば安全だ。」と自信を持って言える国になってほしいです。',
#   '「日本に住んでいれば安全だ。」と自信を持って言える国になってほしいです。[SEP]そうですね。0年後の東京オリンピックが楽しみです。',
#   '日本では今や洋食や中華料理などもかなり普及している中で、和食が改めて見直される機会にもなって、私はとても良い事だと思います。'],
#  ['',
#   'こんにちは。好きな食べ物は何ですか?',
#   'こんにちは。好きな食べ物は何ですか?[SEP]こんにちは。私は苺が好きです。あなたは?',
#   'こんにちは。私は苺が好きです。あなたは?[SEP]私は林檎が好きです',
#   '私は林檎が好きです[SEP]林檎美味しいですよね。好きな色は何ですか?',
#   '美味しいですね'],
#  ['こんにちは。私は苺が好きです。あなたは?',
#   'こんにちは。私は苺が好きです。あなたは?[SEP]私は林檎が好きです',
#   '私は林檎が好きです[SEP]林檎美味しいですよね。好きな色は何ですか?',
#   '林檎美味しいですよね。好きな色は何ですか?[SEP]美味しいですね',
#   '美味しいですね[SEP]どんな人が好きですか?',
#   'そうです、顔にもすぐ出る方なので厄介です。'],
#  ['林檎美味しいですよね。好きな色は何ですか?',
#   '林檎美味しいですよね。好きな色は何ですか?[SEP]美味しいですね',
#   '美味しいですね[SEP]どんな人が好きですか?',
#   'どんな人が好きですか?[SEP]そうです、顔にもすぐ出る方なので厄介です。',
#   'そうです、顔にもすぐ出る方なので厄介です。[SEP]あなたはどんな性格ですか?',
#   '最近だと旅行にはまりだしたので、旅代で消えてしまいますね。'],
#  ['どんな人が好きですか?',
#   'どんな人が好きですか?[SEP]そうです、顔にもすぐ出る方なので厄介です。',
#   'そうです、顔にもすぐ出る方なので厄介です。[SEP]あなたはどんな性格ですか?',
#   'あなたはどんな性格ですか?[SEP]最近だと旅行にはまりだしたので、旅代で消えてしまいますね。',
#   '最近だと旅行にはまりだしたので、旅代で消えてしまいますね。[SEP]私も旅行にはまっています。最近どこに行きましたか?',
#   '行くというより、最近、帰国しました。'],
#  ['どこの出身ですか?',
#   'どこの出身ですか?[SEP]愛知の知多ですよ。知多半島にあります。',
#   '愛知の知多ですよ。知多半島にあります。[SEP]愛知ですかぁ。いい所ですね。',
#   '愛知ですかぁ。いい所ですね。[SEP]それから名古屋で就職が決まったことですね。',
#   'それから名古屋で就職が決まったことですね。[SEP]どんな仕事をするんですか?',
#   '専業主婦ですよ。'],
#  ['どんな仕事をするんですか?',
#   'どんな仕事をするんですか?[SEP]専業主婦ですよ。',
#   '専業主婦ですよ。[SEP]専業主婦とは羨ましい。旦那さん稼いでいるんですね。',
#   '専業主婦とは羨ましい。旦那さん稼いでいるんですね。[SEP]うらやましいのかなぁ?でも、いつでも昼寝ができていいですね。',
#   'うらやましいのかなぁ?でも、いつでも昼寝ができていいですね。[SEP]子供はいないんですか?',
#   '例えば何かありますか?'],
#  ['',
#   'こんにちは。あなたはいつも家では何をしてますか?',
#   'こんにちは。あなたはいつも家では何をしてますか?[SEP]家ではテレビ観たりしてます',
#   '家ではテレビ観たりしてます[SEP]テレビはあまり見ない方なので、家に帰ったらまず音楽をつけます。',
#   'テレビはあまり見ない方なので、家に帰ったらまず音楽をつけます。[SEP]音楽鑑賞もいいですね',
#   'なるほど。スポーツが趣味ということですが、何かされていますか?'],
#  ['音楽鑑賞もいいですね',
#   '音楽鑑賞もいいですね[SEP]なるほど。スポーツが趣味ということですが、何かされていますか?',
#   'なるほど。スポーツが趣味ということですが、何かされていますか?[SEP]毎晩ジョギングしています',
#   '毎晩ジョギングしています[SEP]スポーツが好きなんですね。',
#   'スポーツが好きなんですね。[SEP]汗を掻くと気持ちいいですからね',
#   'もちろんスポーツクラブだけじゃなくて'],
#  ['毎晩ジョギングしています',
#   '毎晩ジョギングしています[SEP]スポーツが好きなんですね。',
#   'スポーツが好きなんですね。[SEP]汗を掻くと気持ちいいですからね',
#   '汗を掻くと気持ちいいですからね[SEP]もちろんスポーツクラブだけじゃなくて',
#   'もちろんスポーツクラブだけじゃなくて[SEP]ジムに通えたらいいのですが結構お金かかりますからね',
#   '親さんですか。お金はかかりますよね、俺はバイトでぎりぎり何とかなるかなって感じです。'],
#  ['どんなアルバイトをしているのですか?',
#   'どんなアルバイトをしているのですか?[SEP]学部の時はずっと家の近くのコンビニでアルバイトしてました。',
#   '学部の時はずっと家の近くのコンビニでアルバイトしてました。[SEP]コンビニのアルバイトは楽でいいですよね',
#   'コンビニのアルバイトは楽でいいですよね[SEP]楽だけど、情緒がないでしょ?',
#   '楽だけど、情緒がないでしょ?[SEP]単純作業の繰り返しですからね',
#   '駄目な繰り返しですよ'],
#  ['コンビニのアルバイトは楽でいいですよね',
#   'コンビニのアルバイトは楽でいいですよね[SEP]楽だけど、情緒がないでしょ?',
#   '楽だけど、情緒がないでしょ?[SEP]単純作業の繰り返しですからね',
#   '単純作業の繰り返しですからね[SEP]駄目な繰り返しですよ',
#   '駄目な繰り返しですよ[SEP]私は深夜のコンビニでアルバイトしていましたが御客さんが来ないので暇でしたよ',
#   '言えてます!寒いからきついですねぇ。'],
#  ['単純作業の繰り返しですからね',
#   '単純作業の繰り返しですからね[SEP]駄目な繰り返しですよ',
#   '駄目な繰り返しですよ[SEP]私は深夜のコンビニでアルバイトしていましたが御客さんが来ないので暇でしたよ',
#   '私は深夜のコンビニでアルバイトしていましたが御客さんが来ないので暇でしたよ[SEP]言えてます!寒いからきついですねぇ。',
#   '言えてます!寒いからきついですねぇ。[SEP]確かに冬にジュースの陳列をするのは寒くてきつかったですね',
#   'なんていうか、海外にある御洒落なランチも食べれるカフェいいですよね。'],
#  ['',
#   '',
#   '',
#   'こんにちは。好きな食べ物は何ですか?',
#   'こんにちは。好きな食べ物は何ですか?[SEP]こんにちは。そうですねー、カレーですかねー。',
#   'そうですね、でも意外と少なくて、香り付けに生姜をたくさん使います。'],
#  ['こんにちは。そうですねー、カレーですかねー。',
#   'こんにちは。そうですねー、カレーですかねー。[SEP]そうですね、でも意外と少なくて、香り付けに生姜をたくさん使います。',
#   'そうですね、でも意外と少なくて、香り付けに生姜をたくさん使います。[SEP]生姜を使われるんですか。自分はスパイスよりも甘さを重視するので、蜂蜜を使います。',
#   '生姜を使われるんですか。自分はスパイスよりも甘さを重視するので、蜂蜜を使います。[SEP]そうなんですね。本場のカレー程香辛料の種類は少ないと聞きますがどうなんでしょう。',
#   'そうなんですね。本場のカレー程香辛料の種類は少ないと聞きますがどうなんでしょう。[SEP]それはよく聞きますね。インド料理店で聞いてみたことがあるのですが、本場では数十種のスパイスを使うみたいですよ。',
#   'もともとソースとかスープをカレーと言うからシンプルだよね。'],
#  ['生姜を使われるんですか。自分はスパイスよりも甘さを重視するので、蜂蜜を使います。',
#   '生姜を使われるんですか。自分はスパイスよりも甘さを重視するので、蜂蜜を使います。[SEP]そうなんですね。本場のカレー程香辛料の種類は少ないと聞きますがどうなんでしょう。',
#   'そうなんですね。本場のカレー程香辛料の種類は少ないと聞きますがどうなんでしょう。[SEP]それはよく聞きますね。インド料理店で聞いてみたことがあるのですが、本場では数十種のスパイスを使うみたいですよ。',
#   'それはよく聞きますね。インド料理店で聞いてみたことがあるのですが、本場では数十種のスパイスを使うみたいですよ。[SEP]もともとソースとかスープをカレーと言うからシンプルだよね。',
#   'もともとソースとかスープをカレーと言うからシンプルだよね。[SEP]ですね。カレーは飲み物というねたも、そこから来てるんですかね?',
#   '四国に渡るのに橋の通行料金が高かったような・・。'],
#  ['それはよく聞きますね。インド料理店で聞いてみたことがあるのですが、本場では数十種のスパイスを使うみたいですよ。',
#   'それはよく聞きますね。インド料理店で聞いてみたことがあるのですが、本場では数十種のスパイスを使うみたいですよ。[SEP]もともとソースとかスープをカレーと言うからシンプルだよね。',
#   'もともとソースとかスープをカレーと言うからシンプルだよね。[SEP]ですね。カレーは飲み物というねたも、そこから来てるんですかね?',
#   'ですね。カレーは飲み物というねたも、そこから来てるんですかね?[SEP]四国に渡るのに橋の通行料金が高かったような・・。',
#   '四国に渡るのに橋の通行料金が高かったような・・。[SEP]そうなんですか。それはいいことを聞きました。四国にいく予定があるので、お金を多く持っていきます。',
#   'いいねバイク。四国は今だ行った事ありません。'],
#  ['ですね。カレーは飲み物というねたも、そこから来てるんですかね?',
#   'ですね。カレーは飲み物というねたも、そこから来てるんですかね?[SEP]四国に渡るのに橋の通行料金が高かったような・・。',
#   '四国に渡るのに橋の通行料金が高かったような・・。[SEP]そうなんですか。それはいいことを聞きました。四国にいく予定があるので、お金を多く持っていきます。',
#   'そうなんですか。それはいいことを聞きました。四国にいく予定があるので、お金を多く持っていきます。[SEP]いいねバイク。四国は今だ行った事ありません。',
#   'いいねバイク。四国は今だ行った事ありません。[SEP]バイクいいですよねー。微風を感じる速度で走るのが大好きです。',
#   '本当この年でって感じですよ。私もお酒は好きだけど、ビールはあんまり飲めないです。'],
#  ['そうなんですか。それはいいことを聞きました。四国にいく予定があるので、お金を多く持っていきます。',
#   'そうなんですか。それはいいことを聞きました。四国にいく予定があるので、お金を多く持っていきます。[SEP]いいねバイク。四国は今だ行った事ありません。',
#   'いいねバイク。四国は今だ行った事ありません。[SEP]バイクいいですよねー。微風を感じる速度で走るのが大好きです。',
#   'バイクいいですよねー。微風を感じる速度で走るのが大好きです。[SEP]本当この年でって感じですよ。私もお酒は好きだけど、ビールはあんまり飲めないです。',
#   '本当この年でって感じですよ。私もお酒は好きだけど、ビールはあんまり飲めないです。[SEP]年なんて気にしなくていいじゃないですか。ビールはちょっと独特ですものね。',
#   '間違えました、年齢が下がってくるでした。'],
#  ['バイクいいですよねー。微風を感じる速度で走るのが大好きです。',
#   'バイクいいですよねー。微風を感じる速度で走るのが大好きです。[SEP]本当この年でって感じですよ。私もお酒は好きだけど、ビールはあんまり飲めないです。',
#   '本当この年でって感じですよ。私もお酒は好きだけど、ビールはあんまり飲めないです。[SEP]年なんて気にしなくていいじゃないですか。ビールはちょっと独特ですものね。',
#   '年なんて気にしなくていいじゃないですか。ビールはちょっと独特ですものね。[SEP]間違えました、年齢が下がってくるでした。',
#   '間違えました、年齢が下がってくるでした。[SEP]若々しいなるということですね。とてもいいことだと思いますよ。',
#   'うん、今の時期はセミがいっぱいいます'],
#  ['年なんて気にしなくていいじゃないですか。ビールはちょっと独特ですものね。',
#   '年なんて気にしなくていいじゃないですか。ビールはちょっと独特ですものね。[SEP]間違えました、年齢が下がってくるでした。',
#   '間違えました、年齢が下がってくるでした。[SEP]若々しいなるということですね。とてもいいことだと思いますよ。',
#   '若々しいなるということですね。とてもいいことだと思いますよ。[SEP]うん、今の時期はセミがいっぱいいます',
#   'うん、今の時期はセミがいっぱいいます[SEP]夏ですもんね。蝉の声がとても風情を感じさせます。',
#   '雨が止んでよかったですね。'],
#  ['若々しいなるということですね。とてもいいことだと思いますよ。',
#   '若々しいなるということですね。とてもいいことだと思いますよ。[SEP]うん、今の時期はセミがいっぱいいます',
#   'うん、今の時期はセミがいっぱいいます[SEP]夏ですもんね。蝉の声がとても風情を感じさせます。',
#   '夏ですもんね。蝉の声がとても風情を感じさせます。[SEP]雨が止んでよかったですね。',
#   '雨が止んでよかったですね。[SEP]ですね。昨日は大雨で散々でしたよ。',
#   'ですね。でも私は寒いのが嫌いで・・・。'],
#  ['こんにちは。犬が好きです。',
#   'こんにちは。犬が好きです。[SEP]犬はかわいいですよ。',
#   '犬はかわいいですよ。[SEP]猫もかわいいです。',
#   '猫もかわいいです。[SEP]そうなんですか?',
#   'そうなんですか?[SEP]はい。飼ったことはないんですけどね。',
#   'ミニチュアダックスとってもかわいいですよね。'],
#  ['猫もかわいいです。',
#   '猫もかわいいです。[SEP]そうなんですか?',
#   'そうなんですか?[SEP]はい。飼ったことはないんですけどね。',
#   'はい。飼ったことはないんですけどね。[SEP]ミニチュアダックスとってもかわいいですよね。',
#   'ミニチュアダックスとってもかわいいですよね。[SEP]足が短い所がいいですよね。',
#   '何の勉強を?'],
#  ['はい。飼ったことはないんですけどね。',
#   'はい。飼ったことはないんですけどね。[SEP]ミニチュアダックスとってもかわいいですよね。',
#   'ミニチュアダックスとってもかわいいですよね。[SEP]足が短い所がいいですよね。',
#   '足が短い所がいいですよね。[SEP]何の勉強を?',
#   '何の勉強を?[SEP]今は絵の勉強をしています。',
#   'デスノートの絵を書いている方の今の漫画はどうです?。'],
#  ['足が短い所がいいですよね。',
#   '足が短い所がいいですよね。[SEP]何の勉強を?',
#   '何の勉強を?[SEP]今は絵の勉強をしています。',
#   '今は絵の勉強をしています。[SEP]デスノートの絵を書いている方の今の漫画はどうです?。',
#   'デスノートの絵を書いている方の今の漫画はどうです?。[SEP]デスノートの作者さんの漫画、読んだことないんです。',
#   'デスノートの絵を書いている方の今の漫画はどうです?。'],
#  ['今は絵の勉強をしています。',
#   '今は絵の勉強をしています。[SEP]デスノートの絵を書いている方の今の漫画はどうです?。',
#   'デスノートの絵を書いている方の今の漫画はどうです?。[SEP]デスノートの作者さんの漫画、読んだことないんです。',
#   'デスノートの作者さんの漫画、読んだことないんです。[SEP]デスノートの絵を書いている方の今の漫画はどうです?。',
#   'デスノートの絵を書いている方の今の漫画はどうです?。[SEP]他に誰か好きな作者さんはいますか?',
#   '柳沢選手が親戚と同じ名前で親近感があります。'],
#  ['デスノートの作者さんの漫画、読んだことないんです。',
#   'デスノートの作者さんの漫画、読んだことないんです。[SEP]デスノートの絵を書いている方の今の漫画はどうです?。',
#   'デスノートの絵を書いている方の今の漫画はどうです?。[SEP]他に誰か好きな作者さんはいますか?',
#   '他に誰か好きな作者さんはいますか?[SEP]柳沢選手が親戚と同じ名前で親近感があります。',
#   '柳沢選手が親戚と同じ名前で親近感があります。[SEP]そうなんですね。スポーツは好きですか?',
#   '保育園の先生なんですね。音楽とかも必須なんですよね?スポーツというか、スノーボードとかですけどね。'],
#  ['他に誰か好きな作者さんはいますか?',
#   '他に誰か好きな作者さんはいますか?[SEP]柳沢選手が親戚と同じ名前で親近感があります。',
#   '柳沢選手が親戚と同じ名前で親近感があります。[SEP]そうなんですね。スポーツは好きですか?',
#   'そうなんですね。スポーツは好きですか?[SEP]保育園の先生なんですね。音楽とかも必須なんですよね?スポーツというか、スノーボードとかですけどね。',
#   '保育園の先生なんですね。音楽とかも必須なんですよね?スポーツというか、スノーボードとかですけどね。[SEP]スノーボードできるんですか!すごいです。',
#   '天気がよく、暖かい日は、0km位走ることもありますね。'],
#  ['そうなんですね。スポーツは好きですか?',
#   'そうなんですね。スポーツは好きですか?[SEP]保育園の先生なんですね。音楽とかも必須なんですよね?スポーツというか、スノーボードとかですけどね。',
#   '保育園の先生なんですね。音楽とかも必須なんですよね?スポーツというか、スノーボードとかですけどね。[SEP]スノーボードできるんですか!すごいです。',
#   'スノーボードできるんですか!すごいです。[SEP]天気がよく、暖かい日は、0km位走ることもありますね。',
#   '天気がよく、暖かい日は、0km位走ることもありますね。[SEP]一人で走るんですか?',
#   'そうですね!一人でドライブする時は自分の好きな曲を流しながら走っています。'],
#  ['古いレコードを買うことです',
#   '古いレコードを買うことです[SEP]ああ、なんか懐かしい感じがします。',
#   'ああ、なんか懐かしい感じがします。[SEP]あなたも古い音楽が好きなんですか?',
#   'あなたも古い音楽が好きなんですか?[SEP]古くても良い曲は良いので、聴いてみる機会があれば聴きますよ。',
#   '古くても良い曲は良いので、聴いてみる機会があれば聴きますよ。[SEP]もしあなたのオススメがあれば教えてください。',
#   'といっても、冬のソナタとか天国の階段とかはまだ見たことがないんです。'],
#  ['もしあなたのオススメがあれば教えてください。',
#   'もしあなたのオススメがあれば教えてください。[SEP]といっても、冬のソナタとか天国の階段とかはまだ見たことがないんです。',
#   'といっても、冬のソナタとか天国の階段とかはまだ見たことがないんです。[SEP]所であなたの好きな食べ物はなんですか?',
#   '所であなたの好きな食べ物はなんですか?[SEP]焼き肉です.',
#   '焼き肉です.[SEP]どこの部位のお肉が好きですか?',
#   'そうだね。肉のが好きかな。'],
#  ['所であなたの好きな食べ物はなんですか?',
#   '所であなたの好きな食べ物はなんですか?[SEP]焼き肉です.',
#   '焼き肉です.[SEP]どこの部位のお肉が好きですか?',
#   'どこの部位のお肉が好きですか?[SEP]そうだね。肉のが好きかな。',
#   'そうだね。肉のが好きかな。[SEP]私は牛タンが好きなんですよ',
#   'そうなんですか.牛タンを食べたことはありますか.。'],
#  ['どこの部位のお肉が好きですか?',
#   'どこの部位のお肉が好きですか?[SEP]そうだね。肉のが好きかな。',
#   'そうだね。肉のが好きかな。[SEP]私は牛タンが好きなんですよ',
#   '私は牛タンが好きなんですよ[SEP]そうなんですか.牛タンを食べたことはありますか.。',
#   'そうなんですか.牛タンを食べたことはありますか.。[SEP]もちろん食べたことがあるから好きです',
#   'じゃあ質問0学生って言ってたけどなんかサークル入ってる?'],
#  ['私は牛タンが好きなんですよ',
#   '私は牛タンが好きなんですよ[SEP]そうなんですか.牛タンを食べたことはありますか.。',
#   'そうなんですか.牛タンを食べたことはありますか.。[SEP]もちろん食べたことがあるから好きです',
#   'もちろん食べたことがあるから好きです[SEP]じゃあ質問0学生って言ってたけどなんかサークル入ってる?',
#   'じゃあ質問0学生って言ってたけどなんかサークル入ってる?[SEP]テニスサークルに入っています。',
#   '入ってます。0人ほどの小さいサークルです。'],
#  ['もちろん食べたことがあるから好きです',
#   'もちろん食べたことがあるから好きです[SEP]じゃあ質問0学生って言ってたけどなんかサークル入ってる?',
#   'じゃあ質問0学生って言ってたけどなんかサークル入ってる?[SEP]テニスサークルに入っています。',
#   'テニスサークルに入っています。[SEP]入ってます。0人ほどの小さいサークルです。',
#   '入ってます。0人ほどの小さいサークルです。[SEP]なんのサークルに入ってるのですか?',
#   '今は入っていないです。今は高校時代の友人や、学祭の実行委員をやっていた時の友人とよく遊ぶことが多いです。'],
#  ['テニスサークルに入っています。',
#   'テニスサークルに入っています。[SEP]入ってます。0人ほどの小さいサークルです。',
#   '入ってます。0人ほどの小さいサークルです。[SEP]なんのサークルに入ってるのですか?',
#   'なんのサークルに入ってるのですか?[SEP]今は入っていないです。今は高校時代の友人や、学祭の実行委員をやっていた時の友人とよく遊ぶことが多いです。',
#   '今は入っていないです。今は高校時代の友人や、学祭の実行委員をやっていた時の友人とよく遊ぶことが多いです。[SEP]ユジンとはどこで遊ぶのですか?',
#   '地球の裏側とかにもですか?'],
#  ['',
#   '',
#   '',
#   'こんにちは。あなたはいつも家では何をしてますか?',
#   'こんにちは。あなたはいつも家では何をしてますか?[SEP]絵を描いてるよ',
#   'どこででも描けるんですかね。私はよく家で絵を描きます。'],
#  ['',
#   'こんにちは。あなたはいつも家では何をしてますか?',
#   'こんにちは。あなたはいつも家では何をしてますか?[SEP]絵を描いてるよ',
#   '絵を描いてるよ[SEP]どこででも描けるんですかね。私はよく家で絵を描きます。',
#   'どこででも描けるんですかね。私はよく家で絵を描きます。[SEP]楽しいですよね',
#   '後0ラウンドがんばりましょう!'],
#  ['絵を描いてるよ',
#   '絵を描いてるよ[SEP]どこででも描けるんですかね。私はよく家で絵を描きます。',
#   'どこででも描けるんですかね。私はよく家で絵を描きます。[SEP]楽しいですよね',
#   '楽しいですよね[SEP]後0ラウンドがんばりましょう!',
#   '後0ラウンドがんばりましょう![SEP]頑張ります!外で運動するのも楽しいですよ',
#   'そうですねーソフトバンクのゼロ円が、本当にゼロ円なら言う事無いんですけど実際は高いみたいですしね。'],
#  ['安いんですかね?',
#   '安いんですかね?[SEP]人と犬で0円位とかってのが殆どかな。',
#   '人と犬で0円位とかってのが殆どかな。[SEP]ソフトバンクといえば白い犬ですもんね',
#   'ソフトバンクといえば白い犬ですもんね[SEP]是非やってみます。',
#   '是非やってみます。[SEP]野球はやりますか?',
#   '野球とサッカーですか、どういったポジションでプレーをしていたのですか?'],
#  ['釣りにはまっています。',
#   '釣りにはまっています。[SEP]とっても楽しんでいますね。',
#   'とっても楽しんでいますね。[SEP]そうですね。すきな食べ物はなんですか?',
#   'そうですね。すきな食べ物はなんですか?[SEP]焼き肉です.',
#   '焼き肉です.[SEP]焼き肉はいいですよね。焼き肉になにを付けて食べます?',
#   '家で食べると部屋が汚れるので、主に焼き肉屋で食べますね。'],
#  ['そうですね。すきな食べ物はなんですか?',
#   'そうですね。すきな食べ物はなんですか?[SEP]焼き肉です.',
#   '焼き肉です.[SEP]焼き肉はいいですよね。焼き肉になにを付けて食べます?',
#   '焼き肉はいいですよね。焼き肉になにを付けて食べます?[SEP]家で食べると部屋が汚れるので、主に焼き肉屋で食べますね。',
#   '家で食べると部屋が汚れるので、主に焼き肉屋で食べますね。[SEP]私もそうですね。今度一緒に行きませんか?',
#   '本当偶然ですね。残念ながらおしまいみたいですね。'],
#  ['焼き肉はいいですよね。焼き肉になにを付けて食べます?',
#   '焼き肉はいいですよね。焼き肉になにを付けて食べます?[SEP]家で食べると部屋が汚れるので、主に焼き肉屋で食べますね。',
#   '家で食べると部屋が汚れるので、主に焼き肉屋で食べますね。[SEP]私もそうですね。今度一緒に行きませんか?',
#   '私もそうですね。今度一緒に行きませんか?[SEP]本当偶然ですね。残念ながらおしまいみたいですね。',
#   '本当偶然ですね。残念ながらおしまいみたいですね。[SEP]それは残念ですね。結婚はされているんですか?',
#   'したくないな'],
#  ['テニスいいですね。私はしたことが無いのでぜひ教えて欲しいです。',
#   'テニスいいですね。私はしたことが無いのでぜひ教えて欲しいです。[SEP]でも最近暑くてしんどいです',
#   'でも最近暑くてしんどいです[SEP]この時期は辛いですよね。本はなんのジャンルが好きですか',
#   'この時期は辛いですよね。本はなんのジャンルが好きですか[SEP]ビジネスマンの情報活用術、スケジュール管理、とか。',
#   'ビジネスマンの情報活用術、スケジュール管理、とか。[SEP]難しいのが好きなんですね。今度内容を教えてください。',
#   'かわいい服なのでよろしいかと・・'],
#  ['',
#   '',
#   '',
#   'こんにちは。最近気になることとか、はまっていることとかありますか?',
#   'こんにちは。最近気になることとか、はまっていることとかありますか?[SEP]疲れが抜けにくいのが気になるね',
#   'リラックスしてくださいね'],
#  ['',
#   'こんにちは。最近気になることとか、はまっていることとかありますか?',
#   'こんにちは。最近気になることとか、はまっていることとかありますか?[SEP]疲れが抜けにくいのが気になるね',
#   '疲れが抜けにくいのが気になるね[SEP]リラックスしてくださいね',
#   'リラックスしてくださいね[SEP]10分リラックスしているよ',
#   'それじゃ、マッサージをしましょう。'],
#  ['疲れが抜けにくいのが気になるね',
#   '疲れが抜けにくいのが気になるね[SEP]リラックスしてくださいね',
#   'リラックスしてくださいね[SEP]10分リラックスしているよ',
#   '10分リラックスしているよ[SEP]それじゃ、マッサージをしましょう。',
#   'それじゃ、マッサージをしましょう。[SEP]肩がこっていてね',
#   '私も体力系のお仕事よりは入力や事務系のお仕事の方が好きかな。'],
#  ['10分リラックスしているよ',
#   '10分リラックスしているよ[SEP]それじゃ、マッサージをしましょう。',
#   'それじゃ、マッサージをしましょう。[SEP]肩がこっていてね',
#   '肩がこっていてね[SEP]私も体力系のお仕事よりは入力や事務系のお仕事の方が好きかな。',
#   '私も体力系のお仕事よりは入力や事務系のお仕事の方が好きかな。[SEP]事務仕事もそれはそれで大変だけどね',
#   'お金貯めるのは俺も苦手です貿易事務とかなんか響きがかっこいいですね!英語とかいるんですか?'],
#  ['事務仕事もそれはそれで大変だけどね',
#   '事務仕事もそれはそれで大変だけどね[SEP]お金貯めるのは俺も苦手です貿易事務とかなんか響きがかっこいいですね!英語とかいるんですか?',
#   'お金貯めるのは俺も苦手です貿易事務とかなんか響きがかっこいいですね!英語とかいるんですか?[SEP]よく知らないけど必要だと思う',
#   'よく知らないけど必要だと思う[SEP]見てますよー!',
#   '見てますよー![SEP]何を見ているの',
#   '週末に読む積もりです。'],
#  ['何を見ているの',
#   '何を見ているの[SEP]週末に読む積もりです。',
#   '週末に読む積もりです。[SEP]何を読むの',
#   '何を読むの[SEP]最近まったく読んでないですが、浦沢直樹とか手塚治虫関係、闇のパープルアイ描いてる人、花より男子を読んでました。',
#   '最近まったく読んでないですが、浦沢直樹とか手塚治虫関係、闇のパープルアイ描いてる人、花より男子を読んでました。[SEP]漫画は読む物じゃなくて見る物だと思う',
#   '面白い漫画ですよ。吹奏楽部にいた頃を思い出す漫画です。'],
#  ['漫画は読む物じゃなくて見る物だと思う',
#   '漫画は読む物じゃなくて見る物だと思う[SEP]面白い漫画ですよ。吹奏楽部にいた頃を思い出す漫画です。',
#   '面白い漫画ですよ。吹奏楽部にいた頃を思い出す漫画です。[SEP]何のパートを担当していたの',
#   '何のパートを担当していたの[SEP]バイオリンです。',
#   'バイオリンです。[SEP]得意な曲はある?',
#   'そうそう。その曲しかないですね。'],
#  ['',
#   '',
#   '',
#   'こんにちは。よくチャットはやられるんですか?',
#   'こんにちは。よくチャットはやられるんですか?[SEP]よくします。',
#   'いいですね。何か好きな食べ物とかってありますか?'],
#  ['',
#   'こんにちは。よくチャットはやられるんですか?',
#   'こんにちは。よくチャットはやられるんですか?[SEP]よくします。',
#   'よくします。[SEP]いいですね。何か好きな食べ物とかってありますか?',
#   'いいですね。何か好きな食べ物とかってありますか?[SEP]この時期だとスイカが好きです。',
#   'そうですね。特に小さい子とかに好きな子が多いと思います。'],
#  ['夏はやっぱりスイカですね。',
#   '夏はやっぱりスイカですね。[SEP]そうですね、スイカは美味しいです。',
#   'そうですね、スイカは美味しいです。[SEP]はい。',
#   'はい。[SEP]木の素材とか、大量生産してるとか、手作りとか・・そういうので全然値段が変わってきますからね。',
#   '木の素材とか、大量生産してるとか、手作りとか・・そういうので全然値段が変わってきますからね。[SEP]一般的にはネットに入っていますね。',
#   'スマホを使っていますか?'],
#  ['一般的にはネットに入っていますね。',
#   '一般的にはネットに入っていますね。[SEP]スマホを使っていますか?',
#   'スマホを使っていますか?[SEP]使ってます。',
#   '使ってます。[SEP]小さい時くらいしかないです。',
#   '小さい時くらいしかないです。[SEP]タブレットも持ってますよ。',
#   '私も持ってないですねぇ・・・。サンタさんに御願いしようかしら。'],
#  ['使ってます。',
#   '使ってます。[SEP]小さい時くらいしかないです。',
#   '小さい時くらいしかないです。[SEP]タブレットも持ってますよ。',
#   'タブレットも持ってますよ。[SEP]私も持ってないですねぇ・・・。サンタさんに御願いしようかしら。',
#   '私も持ってないですねぇ・・・。サンタさんに御願いしようかしら。[SEP]タブレットはとても便利です。',
#   'てことは、PCから入れるんですよね?'],
#  ['タブレットも持ってますよ。',
#   'タブレットも持ってますよ。[SEP]私も持ってないですねぇ・・・。サンタさんに御願いしようかしら。',
#   '私も持ってないですねぇ・・・。サンタさんに御願いしようかしら。[SEP]タブレットはとても便利です。',
#   'タブレットはとても便利です。[SEP]てことは、PCから入れるんですよね?',
#   'てことは、PCから入れるんですよね?[SEP]いえ、タブレットは単独で動作します。',
#   '深海を操作するの?'],
#  ['タブレットはとても便利です。',
#   'タブレットはとても便利です。[SEP]てことは、PCから入れるんですよね?',
#   'てことは、PCから入れるんですよね?[SEP]いえ、タブレットは単独で動作します。',
#   'いえ、タブレットは単独で動作します。[SEP]深海を操作するの?',
#   '深海を操作するの?[SEP]タッチして操作します。',
#   'マニピュレーターとか操作難しそうだよね。'],
#  ['',
#   '',
#   '',
#   'こんにちは。好きな動物は何ですか?',
#   'こんにちは。好きな動物は何ですか?[SEP]パンダが好きです',
#   'そうですか!私は苦手です。。。冬服は重いし高い。'],
#  ['',
#   'こんにちは。好きな動物は何ですか?',
#   'こんにちは。好きな動物は何ですか?[SEP]パンダが好きです',
#   'パンダが好きです[SEP]そうですか!私は苦手です。。。冬服は重いし高い。',
#   'そうですか!私は苦手です。。。冬服は重いし高い。[SEP]でもかわいいですよ',
#   'かわいいというか…どじですね。そういってくれるtefs0さんは、優しいです。'],
#  ['パンダが好きです',
#   'パンダが好きです[SEP]そうですか!私は苦手です。。。冬服は重いし高い。',
#   'そうですか!私は苦手です。。。冬服は重いし高い。[SEP]でもかわいいですよ',
#   'でもかわいいですよ[SEP]かわいいというか…どじですね。そういってくれるtefs0さんは、優しいです。',
#   'かわいいというか…どじですね。そういってくれるtefs0さんは、優しいです。[SEP]優しいなんて初めて言われました',
#   'どっちでもいいや'],
#  ['でもかわいいですよ',
#   'でもかわいいですよ[SEP]かわいいというか…どじですね。そういってくれるtefs0さんは、優しいです。',
#   'かわいいというか…どじですね。そういってくれるtefs0さんは、優しいです。[SEP]優しいなんて初めて言われました',
#   '優しいなんて初めて言われました[SEP]どっちでもいいや',
#   'どっちでもいいや[SEP]最近雨がよく降りますよね',
#   '天気予報はみますか?'],
#  ['いちよう毎日見ます',
#   'いちよう毎日見ます[SEP]あ、にでした。',
#   'あ、にでした。[SEP]暑いですね',
#   '暑いですね[SEP]ここは暑いですね。',
#   'ここは暑いですね。[SEP]この暑さはいつまで続くのでしょう?',
#   '楽しいが一番です。'],
#  ['暑いですね',
#   '暑いですね[SEP]ここは暑いですね。',
#   'ここは暑いですね。[SEP]この暑さはいつまで続くのでしょう?',
#   'この暑さはいつまで続くのでしょう?[SEP]楽しいが一番です。',
#   '楽しいが一番です。[SEP]笑っていられるのが一番ですよね',
#   'それは良かった!!次は質問する側なので、見習って頑張りますね。'],
#  ['この暑さはいつまで続くのでしょう?',
#   'この暑さはいつまで続くのでしょう?[SEP]楽しいが一番です。',
#   '楽しいが一番です。[SEP]笑っていられるのが一番ですよね',
#   '笑っていられるのが一番ですよね[SEP]それは良かった!!次は質問する側なので、見習って頑張りますね。',
#   'それは良かった!!次は質問する側なので、見習って頑張りますね。[SEP]私が答える番ですね',
#   'この間がおもしろいですね'],
#  ...]

# %%
X_str_all = sum(X_str, [])

# %%
len( X_str_all )
# Out:
# 8316

# %%
X_all = text2vec(X_str_all)
# Out:
# Batches:   0%|          | 0/260 [00:00<?, ?it/s]

# %%
X_vec =  X_all.reshape(len(X_str), N, -1)

# %%
X_vec.shape
# Out:
# (1386, 6, 768)

# %%
# 推定の時間だ
y_pred = []
for X in tqdm( X_vec):
    hypo = X[-1]
    is_contradict = False
    features = []
    for prev in X[:-1]:
        feature = vec2feature( np.array([prev, hypo]) )
        features.append(feature)
    features = np.array(features)
    with torch.no_grad():
        features = torch.from_numpy(features).cuda()
        y_pred_ = np.array(model(features).cpu()).argmax(axis=1)
    if 2 in y_pred_:
        y_pred.append(1)
    else:
        y_pred.append(0)
# Out:
# 100%|██████████| 1386/1386 [00:02<00:00, 687.57it/s]

# %%
score(y, y_pred)
# Out:
# confusion matrix =
#  [[1208  156]
#  [  17    5]]
# accuracy =  0.8751803751803752
# precision =  0.031055900621118012
# recall =  0.22727272727272727
# f1 score =  0.054644808743169404

# %% [markdown]
# - N=7 eval
#
#         confusion matrix =
#         [[1166  198]
#         [  16    6]]
#         accuracy =  0.8455988455988456
#         precision =  0.029411764705882353
#         recall =  0.2727272727272727
#         f1 score =  0.05309734513274336
#
#     - 6件だけの検出
#     - 結構ミスが多いので，もっとNを減らして効果を見る
#
# - N=6 eval
#
#         confusion matrix =
#         [[1173  191]
#         [  16    6]]
#         accuracy =  0.8506493506493507
#         precision =  0.030456852791878174
#         recall =  0.2727272727272727
#         f1 score =  0.05479452054794521
#
#     - おそらく最もここが精度が高い，が...
#
# - N=4 eval
#
#         confusion matrix =
#         [[1208  156]
#         [  17    5]]
#         accuracy =  0.8751803751803752
#         precision =  0.031055900621118012
#         recall =  0.22727272727272727
#         f1 score =  0.054644808743169404
#
# ## 発話加算スタイル
# - ### 各前提に，直前の発話を加算
# - N=6 added
#
#         confusion matrix =
#         [[1256  108]
#         [  18    4]]
#         accuracy =  0.9090909090909091
#         precision =  0.03571428571428571
#         recall =  0.18181818181818182
#         f1 score =  0.05970149253731343
#
#    - 結構誤検出が減る
#
# - N=4 added
#
#         confusion matrix =
#         [[1283   81]
#         [  18    4]]
#         accuracy =  0.9285714285714286
#         precision =  0.047058823529411764
#         recall =  0.18181818181818182
#         f1 score =  0.07476635514018691
#
#     - 減ったけどなぁ
#
# - N=3 added
#
#     confusion matrix =
#     [[1311   53]
#     [  21    1]]
#     accuracy =  0.9466089466089466
#     precision =  0.018518518518518517
#     recall =  0.045454545454545456
#     f1 score =  0.02631578947368421
#
#     - N=3, N=4で大きな違いはありそう
#     - しかし，未検出の18を拾いたい

# %%
# 検出出来ているものはなんだ
i = 0
for i, x in enumerate(X_str):
    if y[i]==1 and y_pred[i]==0:
        print(x)
# Out:
# ['ビーチの場所取りが必要なんだよね。', 'ビーチの場所取りが必要なんだよね。[SEP]ビーチに行きたいです??', 'ビーチに行きたいです??[SEP]行きたいね。なかなか時間が取れないんだけどね。', '行きたいね。なかなか時間が取れないんだけどね。[SEP]服をえらんだりするのはすきですか?', '服をえらんだりするのはすきですか?[SEP]センスが良くないから、同じような服ばかり選んでしまうよ。', 'センスはいいですね']
# ['仲間だ', '仲間だ[SEP]ナカーマ', 'ナカーマ[SEP]仲間由紀恵', '仲間由紀恵[SEP]仲間由紀恵は怖いですね', '仲間由紀恵は怖いですね[SEP]何考えてるか分からない感じある', '仲間由紀恵は美しいですね']
# ['ボートの使える所もありますね。', 'ボートの使える所もありますね。[SEP]活性が高いですね', '活性が高いですね[SEP]どのような活性ですか?', 'どのような活性ですか?[SEP]活性は高いです', '活性は高いです[SEP]活発なのはいいことです。', '活性が全体的に低いです']
# ['', '', '', 'こんにちは。熱中症に気をつけて。', 'こんにちは。熱中症に気をつけて。[SEP]はい。ありがとう。あなたも気を付けて。', '熱中症に気をつけないんですか?']
# ['', 'こんにちは。熱中症に気をつけて。', 'こんにちは。熱中症に気をつけて。[SEP]はい。ありがとう。あなたも気を付けて。', 'はい。ありがとう。あなたも気を付けて。[SEP]熱中症に気をつけないんですか?', '熱中症に気をつけないんですか?[SEP]小まめに水を飲んだりして、気を付けていますよ。', '熱中症に気をつけたいんでしょう?']
# ['はい。ありがとう。あなたも気を付けて。', 'はい。ありがとう。あなたも気を付けて。[SEP]熱中症に気をつけないんですか?', '熱中症に気をつけないんですか?[SEP]小まめに水を飲んだりして、気を付けていますよ。', '小まめに水を飲んだりして、気を付けていますよ。[SEP]熱中症に気をつけたいんでしょう?', '熱中症に気をつけたいんでしょう?[SEP]そうですね。0度倒れていますから、十分気を付けています。', '熱中症に気をつけなければなりませんでしたっけ']
# ['危ないので、気をつけなければいけませんよ。', '危ないので、気をつけなければいけませんよ。[SEP]熱中症は大丈夫ですね', '熱中症は大丈夫ですね[SEP]対策はしている積もりですよ。', '対策はしている積もりですよ。[SEP]対策は大丈夫か??', '対策は大丈夫か??[SEP]はい。水を飲んだり、塩分もとっています。', '対策は必要ないですか']
# ['気をつかってくれてありがとうございます。', '気をつかってくれてありがとうございます。[SEP]熱中症に気をつけてたいですか?', '熱中症に気をつけてたいですか?[SEP]なるべく元気でいたいと思っています。', 'なるべく元気でいたいと思っています。[SEP]熱中症が心配されます??', '熱中症が心配されます??[SEP]今日は涼しかったので大丈夫です。', '大丈夫ですか。熱中症が出てますか?']
# ['傘を持って行った方がいいですか', '傘を持って行った方がいいですか[SEP]0月0日は梅雨入りになることが多いから、「傘の日」なんだって。', '0月0日は梅雨入りになることが多いから、「傘の日」なんだって。[SEP]知りませんでした', '知りませんでした[SEP]梅雨入りはいいですね', '梅雨入りはいいですね[SEP]梅雨明けはいつですか', '梅雨入りは嫌なんですよねえ']
# ['どこの出身ですか?', 'どこの出身ですか?[SEP]愛知の知多ですよ。知多半島にあります。', '愛知の知多ですよ。知多半島にあります。[SEP]愛知ですかぁ。いい所ですね。', '愛知ですかぁ。いい所ですね。[SEP]それから名古屋で就職が決まったことですね。', 'それから名古屋で就職が決まったことですね。[SEP]どんな仕事をするんですか?', '専業主婦ですよ。']
# ['もちろん食べたことがあるから好きです', 'もちろん食べたことがあるから好きです[SEP]じゃあ質問0学生って言ってたけどなんかサークル入ってる?', 'じゃあ質問0学生って言ってたけどなんかサークル入ってる?[SEP]テニスサークルに入っています。', 'テニスサークルに入っています。[SEP]入ってます。0人ほどの小さいサークルです。', '入ってます。0人ほどの小さいサークルです。[SEP]なんのサークルに入ってるのですか?', '今は入っていないです。今は高校時代の友人や、学祭の実行委員をやっていた時の友人とよく遊ぶことが多いです。']
# ['一般的にはネットに入っていますね。', '一般的にはネットに入っていますね。[SEP]スマホを使っていますか?', 'スマホを使っていますか?[SEP]使ってます。', '使ってます。[SEP]小さい時くらいしかないです。', '小さい時くらいしかないです。[SEP]タブレットも持ってますよ。', '私も持ってないですねぇ・・・。サンタさんに御願いしようかしら。']
# ['歩くのは楽しいですよね', '歩くのは楽しいですよね[SEP]まだ外にいけるだけ幸せですよね', 'まだ外にいけるだけ幸せですよね[SEP]そうですね', 'そうですね[SEP]では、音楽はどんなのを聴かれていますか?', 'では、音楽はどんなのを聴かれていますか?[SEP]最近はあまり音楽を聴かなくなってきました', 'なるほど。では音楽はどんなジャンルをよく聴きますか?']
# ['hearthstoneというゲームが気になっています', 'hearthstoneというゲームが気になっています[SEP]ゲームですか.いいですね・', 'ゲームですか.いいですね・[SEP]あなたも始めてみませんか?', 'あなたも始めてみませんか?[SEP]趣味ですか.因みにあなたの趣味は何ですか?', '趣味ですか.因みにあなたの趣味は何ですか?[SEP]音楽鑑賞です', 'なるほど。スポーツが趣味ということですが、何かされていますか?']
# ['', '', '', 'こんにちは。最近気になることとか、はまっていることとかありますか?', 'こんにちは。最近気になることとか、はまっていることとかありますか?[SEP]私は絵をかくことにはまっています。', 'どんな物を見たのですか?オススメの物があれば教えてください。']
# ['新鮮でしたか?', '新鮮でしたか?[SEP]1年目って言っても、学部時代に0年過ごしてるから、あんまり新鮮味はないかも。', '1年目って言っても、学部時代に0年過ごしてるから、あんまり新鮮味はないかも。[SEP]やっぱりそうでしたか', 'やっぱりそうでしたか[SEP]最終回見ましたか?', '最終回見ましたか?[SEP]見ました', 'いきなりドラマの話ですか!']
# ['楽しいですね!', '楽しいですね![SEP]後0ラウンドがんばりましょう!', '後0ラウンドがんばりましょう![SEP]がんばります。今日は暑いですね。', 'がんばります。今日は暑いですね。[SEP]いいえ、御弁当を持ってきて院生室で食べました。', 'いいえ、御弁当を持ってきて院生室で食べました。[SEP]そうなんですか。私は今から御飯です。', '一緒ですね。']
