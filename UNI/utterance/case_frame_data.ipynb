# %%
import json
import os
import pandas as pd
import numpy as np
from pathlib import Path
import collections
from sklearn.model_selection import train_test_split
from sklearn import metrics

import sys
sys.path.append("../")
from datatools.analyzer import *
from utterance.error_tools import *

from datatools.maneger import DataManager
from datatools.preproc import Preprocessor

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.modules import loss
import torch.optim as optim

# %%
class CaseModel(nn.Module):
    def __init__(self, embedding_dim, tagset_size):
        # 親クラスのコンストラクタ。決まり文句
        super(CaseModel, self).__init__()    
        self.embedding_dim = embedding_dim
        self.hid1= embedding_dim*2
        self.hid2 = embedding_dim//2
        self.fc1 = nn.Linear(self.embedding_dim, self.hid1)
        self.fc2 = nn.Linear(self.hid1, self.hid2)
        self.hidden2tag = nn.Linear(self.hid2, tagset_size)
    
    def forward(self, x):
        y = F.relu(self.fc1(x))
        y = F.relu(self.fc2(y))
        y = self.hidden2tag( y )
        y = F.log_softmax(y, dim=1)
        return y

# %%
border=0.8

# %%
dict_path = "../models/utterance/"
dict_name = "group_border={0}_2.pickle".format(border)
dictM = DataManager(dict_path)
group_dict = dictM.load_data(dict_name)
# Out:
# success load : ../models/utterance/group_border=0.8_2.pickle

# %%
def search_word(word):
    word = clean_text(word)
    found_list = []
    for group_key in group_dict.keys():
        if word in group_dict[group_key]:
            found_list.append(group_key)
    return found_list

# %%
from gensim.models import KeyedVectors
w2v_path = "../../corpus/w2v/"
# fasttext
# https://qiita.com/Hironsan/items/513b9f93752ecee9e670
# w2v_name =  "dep-ja-300dim"
w2v_name =  "model.vec"
w2v_model = KeyedVectors.load_word2vec_format(w2v_path+w2v_name)
# Out:
# [2152] 2022-01-06 00:48:23,715 Info gensim.models.keyedvectors :loading projection weights from ../../corpus/w2v/model.vec
# [2152] 2022-01-06 00:49:26,580 Info gensim.utils :KeyedVectors lifecycle event {'msg': 'loaded (351122, 300) matrix of type float32 from ../../corpus/w2v/model.vec', 'binary': False, 'encoding': 'utf8', 'datetime': '2022-01-06T00:49:26.579736', 'gensim': '4.0.1', 'python': '3.6.9 (default, Jan 26 2021, 15:33:00) \n[GCC 8.4.0]', 'platform': 'Linux-5.4.72-microsoft-standard-WSL2-x86_64-with-Ubuntu-18.04-bionic', 'event': 'load_word2vec_format'}

# %%
group2index = dict(zip( group_dict.keys(), range(len(group_dict.keys())) ))
index2group = dict(zip(range(len(group_dict.keys())), group_dict.keys() ))

# %%
model_path = "../models/utterance/"
model_name = "case_frame_{0}_2.pickle".format(border)
modelM = DataManager(model_path)
cmodel = modelM.load_data(model_name)
# Out:
# success load : ../models/utterance/case_frame_0.8_2.pickle

# %%
def classify_word(word):
    word = clean_text(word)
    if word not in w2v_model:
        return ""
    with torch.no_grad():
        vector = torch.tensor([w2v_model[word]]).cuda()
        pred = np.array(cmodel(vector).cpu()).argmax()
    
    return index2group[pred]

# %%
word = "オリンピック"

# %%
search_word(word)
# Out:
# []

# %%
classify_word(word)
# Out:
# '<イベント>'

# %%
group_filename = "../../corpus/case_frame/easy_case_frame.csv"

# %%
def register_triple(case_frane:dict, V, C, Noun):
    # 動詞の確認
    if V not in case_frame:
        case_frame[V] = dict()

    # 格の確認
    if C not in case_frame[V]:
        case_frame[V][C] = set()
    
    # 名詞の登録
    case_frame[V][C].add(Noun)

# %%
import csv
case_frame = dict()
unique_nouns = dict()

with open(group_filename, mode="r") as f:
    reader = csv.reader(f)
    for row in reader:
        V = row[0]
        C = row[1]
        for i in range(2, len(row), 2):
            if "Unnamed" in row[i] or "" == row[i]:
                continue
            Noun = row[i]
            register_triple(case_frame, V, C, row[i])

            # 有効 などの登録
            if Noun not in group_dict.keys():
                if Noun not in unique_nouns:
                    unique_nouns[Noun] = set()
                unique_nouns[Noun].add(V)

# %%
case_frame_name = "case_frame.pickle"
unique_name = "unique_nouns.pickle"
group_name = "group.pickle"
data_path = "../X_y_data/utterance/"

# %%
dataM = DataManager(data_path)
dataM.save_data(unique_name, unique_nouns)
dataM.save_data(case_frame_name, case_frame)
# dataM.save_data(group_name, group_dict)
# Out:
# success save : ../X_y_data/utterance/unique_nouns.pickle
# success save : ../X_y_data/utterance/case_frame.pickle

# %%
def is_declinable(token):
    pos = token.tag_.split("-")
    try:
        if pos[0] == "動詞" or pos[0] == "形容詞" or pos[2] == "サ変可能":
            # print(token.lemma_)
            return True
        else:
            False
    except:
        return False


# case_set = set( "が　を　に　で は".split() )

def extract_RDF_triple(text):
    text = clean_text(text)
    doc = nlp(text)
    triple_list = []
    for i, token in enumerate( doc ):
        # if token.pos_ in ["VERB", "ADJ"]:
        if token.pos_=="VERB":
        # if is_declinable(token):
            phrase = ""
            for c in token.children:
                if c.dep_ in ["nsubj", "obj"]:
                    noun = c.lemma_
                    for c2 in c.children:
                        # if c2.dep_ == "case" and c2.orth_ in case_set:
                        if c2.dep_ == "case":
                            case = c2.orth_
                            if case == "は":
                                case = "が"
                            triple_list.append( (token.lemma_, case, noun) )
    return triple_list

# %%
t = "インターネットは排出量が多い"
t = "固有抽出表現は、文から日付や地名等の固有表現を抽出する処理です。"
# t = "マドリッドの原宿、表参道エリアを中心に人気専門店が続々登場するなど、今年一躍話題になったポップコーンですが、日本穀物検定協会が金曜ロードSHOW!とコラボレーションしたきょうは会社休みます。を12月に発売するそうです。"
triples = extract_RDF_triple(t)
triples
# Out:
# [('抽出', 'を', '表現')]

# %%
def search_triple(V, C, N):
    if N in case_frame[V][C]:
        return True
    else:
        return False

# %%
# True : 用法は問題ない
# False : 問題あり
def judge_triple(triple):
    V = triple[0]
    C = triple[1]
    noun = triple[2]

    # Vが登録されていないならパスしておくかな(一旦)
    if V not in case_frame:
        # print("not registered V :", V)
        return True
    
    # C が登録されていないなら，アウト
    if C not in case_frame[V]:
        # print("not registered V, C :", V, C)
        return False
    
    # 名詞はユニークで，且つ動詞とペアになるか？
    if noun in unique_nouns :
        # print("unique noun", noun)
        if noun in case_frame[V][C]:
            # 存在するなら良かったね
            if search_triple(V, C, noun):
                return True
    
    # 名詞がどこかのグループに属する
    group_ = search_word(noun)
    if len(group_) > 0:
        # 1つでも引っかかればOK
        for group in group_:
            if search_triple(V, C, group):
                return True
        return False
    # グループを推定
    else:
        group = classify_word(noun) 
        return search_triple(V, C, group)

# %%
for triple in triples:
    print(triple)
    print(judge_triple(triple))
    print("----")

# %%
path = "../eval_labeled/"
datalist = ['DCM', 'DIT', 'IRS']
convs = read_conv(path, datalist)

# %%
error = "Semantic error"
sys_utt = []
y = []
for conv in convs:
    for ut in conv:
        if ut.is_system() and ut.is_exist_error():
            sys_utt.append(ut.utt)
            if ut.is_error_included(error):
                y.append(1)
            else:
                y.append(0)

# %%
y_pred = []
for utt in tqdm(sys_utt):
    is_valid = True

    triples = extract_RDF_triple(utt)
    for triple in triples:
        if not judge_triple(triple):
            is_valid = False
            break
    if is_valid:
        y_pred.append(0)
    else:
        y_pred.append(1)
# Out:
# 100%|██████████| 1386/1386 [00:22<00:00, 62.18it/s]

# %%
score(y, y_pred)
# Out:
# confusion matrix =
#  [[847 531]
#  [  6   2]]
# accuracy =  0.6125541125541125
# precision =  0.00375234521575985
# recall =  0.25
# f1 score =  0.0073937153419593345

# %% [markdown]
# - 複文への分類がキツイ可能性を考えた
# - 複文への分類が生きている場合
#
#
#         confusion matrix =
#         [[888 490]
#         [  6   2]]
#         accuracy =  0.6421356421356421
#         precision =  0.0040650406504065045
#         recall =  0.25
#         f1 score =  0.008
#
# - 複文への分類はあきらめた
#
#         confusion matrix =
#         [[921 457]
#         [  6   2]]
#         accuracy =  0.665945165945166
#         precision =  0.004357298474945534
#         recall =  0.25
#         f1 score =  0.008565310492505354

# %%
w = "人たち"
print( search_word(w) ) 
print(classify_word(w))
# Out:
# ['<ヒト>']
# <ヒト>

# %%
for t, p, utt in zip(y, y_pred, sys_utt):
    if t==0 and p==1:
        print(utt)
        print(extract_RDF_triple(utt))
        print("--------")
# Out:
# お、そうですか。　えっと、四国は行かれたことありますか？
# [('ある', 'が', '四国')]
# --------
# お兄さんに生まれると、頼りがいのある性格になるのかな。
# [('生まれる', 'に', 'お兄さん'), ('なる', 'に', '性格')]
# --------
# あ　そうでしたか。　ところで、九州に行かれたことありますか？
# [('行く', 'に', '九州'), ('ある', 'で', '所')]
# --------
# 熱中症に気をつけか？？
# [('つける', 'に', '熱中症'), ('つける', 'を', '気')]
# --------
# 熱中症に気をつけたいのです
# [('つける', 'に', '熱中症'), ('つける', 'を', '気')]
# --------
# 朝からスイミングで泳ぎます？？
# [('泳ぐ', 'で', 'スイミング')]
# --------
# スイミングを続けるかもしれない
# [('続ける', 'を', 'スイミング')]
# --------
# 何か普段の生活で気をつけていることはありますか。
# [('つける', 'で', '生活'), ('つける', 'を', '気'), ('ある', 'が', 'こと')]
# --------
# 和食、洋食、中華どれが食べたいですか？
# [('食べる', 'が', 'どれ')]
# --------
# 退屈させてしまいましたか。うまくコミュニケーション取れるように頑張るので、お付き合いください。話題を変えましょう、最近観た映画は何ですか？
# [('変える', 'を', '話題')]
# --------
# 昨日は何を食べましたか？
# [('食べる', 'が', '昨日'), ('食べる', 'を', '何')]
# --------
# なんと。　ところで、お花見って行ったことありますか？
# [('ある', 'で', '所')]
# --------
# 日本では身体を使ったものを指すけど、本来思考力や計算力もスポーツに含まれるよ。
# [('使う', 'を', '身体'), ('指す', 'で', '日本'), ('指す', 'が', '日本'), ('指す', 'を', '物'), ('含む', 'に', 'スポーツ')]
# --------
# 日本の国花は桜だけど、法律で決められたものじゃないんだよ。
# [('決める', 'で', '法律')]
# --------
# 沖縄で生まれた有名な武道に「空手」があるよね。
# [('生まれる', 'で', '沖縄'), ('ある', 'に', '武道'), ('ある', 'が', '空手')]
# --------
# 職場で同僚をあだ名で呼ぶのは、どうかと思うよ。
# [('呼ぶ', 'で', '職場'), ('呼ぶ', 'を', '同僚'), ('呼ぶ', 'で', '渾名')]
# --------
# 職場で同僚をあだ名で呼ぶのは、どうかと思うよ。
# [('呼ぶ', 'で', '職場'), ('呼ぶ', 'を', '同僚'), ('呼ぶ', 'で', '渾名')]
# --------
# かけ声が出すのに必要です
# [('出す', 'が', '掛け声')]
# --------
# 肌に感じるんでしょうか
# [('感じる', 'に', '肌')]
# --------
# 食事は家で作るのです
# [('作る', 'が', '食事'), ('作る', 'で', '家')]
# --------
# 外食はいんですか？？あなた、外食のときも私を連れて行ってよ。
# [('いる', 'が', '外食'), ('連れる', 'を', '私')]
# --------
# 普段はどんな服を着てますか？
# [('着る', 'が', '普段'), ('着る', 'を', '服')]
# --------
# 世界の年平均気温は右肩上がりで、地球温暖化が進んでいるらしいよ。
# [('進む', 'が', '温暖化')]
# --------
# 熱中症に気をつけないんですか？
# [('つける', 'に', '熱中症'), ('つける', 'を', '気')]
# --------
# 熱中症に気をつけたいんでしょう？
# [('つける', 'に', '熱中症'), ('つける', 'を', '気')]
# --------
# 熱中症に気をつけなければなりませんでしたっけ
# [('つける', 'に', '熱中症'), ('つける', 'を', '気')]
# --------
# 運動は気分転換になってるんですね。気分は大丈夫ですね
# [('なる', 'が', '運動'), ('なる', 'に', '気分転換')]
# --------
# 西瓜が出来てるんでしょうか？
# [('出来る', 'が', '西瓜')]
# --------
# 熱中症に気をつけてたいですか？
# [('つける', 'に', '熱中症'), ('つける', 'を', '気')]
# --------
# 顔が左右に動きます
# [('動く', 'が', '顔'), ('動く', 'に', '左右')]
# --------
# 左右に顔を振ります
# [('振る', 'に', '左右'), ('振る', 'を', '顔')]
# --------
# 昔のことをよく感じてしまうことを「思い出補正」っていうんだって。
# [('感ずる', 'を', 'こと'), ('いう', 'を', 'こと')]
# --------
# ああ、なるほど。　そうだ、趣味を教えて下さい。
# [('教える', 'を', '趣味')]
# --------
# 今は答えられないんです。
# [('答える', 'が', '今')]
# --------
# 天気がいいとそれだけで元気が出ちゃうよね。
# [('出る', 'で', 'それ'), ('出る', 'が', '元気')]
# --------
# 一生の内で救急車に乗る確率は4％くらいだそうだ。
# [('乗る', 'で', '内'), ('乗る', 'に', '救急車')]
# --------
# 資格でもとります
# [('とる', 'で', '資格')]
# --------
# 大人になったらやっぱり選挙に行かないとね。
# [('なる', 'に', '大人'), ('行く', 'に', '選挙')]
# --------
# 日本人って本当にラーメンが好きで、いろいろな種類を開発するよね。
# [('開発', 'を', '種類')]
# --------
# 熱中症に気をつけてたいですか？
# [('つける', 'に', '熱中症'), ('つける', 'を', '気')]
# --------
# コンビニで取りますよねー
# [('取る', 'で', 'コンビニ')]
# --------
# 自炊はお金がかからないんですよねぇ
# [('かかる', 'が', '自炊'), ('かかる', 'が', 'お金')]
# --------
# お金はお財布に入れるかもしれない
# [('入れる', 'が', 'お金'), ('入れる', 'に', '財布')]
# --------
# 手を貯金に出します
# [('出す', 'を', '手'), ('出す', 'に', '貯金')]
# --------
# 最近は頬にピアスをする人もいるみたいだけど、信じられないよね。
# [('する', 'に', '頬'), ('する', 'を', 'ピアス'), ('いる', 'が', '最近')]
# --------
# 寝られなくなるから夜はやめたほうがいいよ。
# [('やめる', 'が', '夜')]
# --------
# 世界で最初に作られたコンピューターゲームは、チェスのゲームなんだよ。
# [('作る', 'で', '世界'), ('作る', 'に', '最初')]
# --------
# 今日のお昼は何を食べました？
# [('食べる', 'が', '昼'), ('食べる', 'を', '何')]
# --------
# 映画はよく見るんですか？
# [('見る', 'が', '映画')]
# --------
# 映画は見やすいですね
# [('見る', 'が', '映画')]
# --------
# 健康美を目指しますねぇ
# [('目指す', 'を', '健康美')]
# --------
# 朝ごはんは一人で食べるのです
# [('食べる', 'が', '朝御飯'), ('食べる', 'で', '一人')]
# --------
# どんな趣味をお持ちですか？
# [('持つ', 'を', '趣味')]
# --------
# 趣味はお金がかかりますか
# [('かかる', 'が', '趣味'), ('かかる', 'が', 'お金')]
# --------
# 朝から天気が変わりますよねー
# [('変わる', 'が', '天気')]
# --------
# ６月１１日は梅雨入りになることが多いから、「傘の日」なんだって。
# [('なる', 'が', '日'), ('なる', 'に', '梅雨入り')]
# --------
# 熱中症に気をつけないんですか？
# [('つける', 'に', '熱中症'), ('つける', 'を', '気')]
# --------
# 塩分は気にしません？？
# [('する', 'が', '塩分'), ('する', 'に', '気')]
# --------
# 塩分に気をつけないんですか？
# [('つける', 'に', '塩分'), ('つける', 'を', '気')]
# --------
# ネタは鮮度が落ちてたことあります
# [('落ちる', 'が', '鮮度'), ('ある', 'が', 'ねた')]
# --------
# 楽しみが続くっていいですよね
# [('続く', 'が', '楽しみ')]
# --------
# どちらに行ってるんですね。コメディは好きですね
# [('行く', 'に', 'どちら')]
# --------
# 熱中症に気をつけか？？
# [('つける', 'に', '熱中症'), ('つける', 'を', '気')]
# --------
# 麦茶を用意するんですね。予防を怠ります
# [('用意', 'を', '麦茶'), ('怠る', 'を', '予防')]
# --------
# 寝不足のときは、頭のてっぺんを軽く押すといいんだって。
# [('押す', 'が', '時'), ('押す', 'を', '天辺')]
# --------
# 寝不足のときは、頭のてっぺんを軽く押すといいんだって。
# [('押す', 'が', '時'), ('押す', 'を', '天辺')]
# --------
# idに行きます
# [('行く', 'に', 'ID')]
# --------
# iDに行きます
# [('行く', 'に', 'ID')]
# --------
# idを使います
# [('使う', 'を', 'ID')]
# --------
# ドコモでiPhone4が使えます
# [('使える', 'で', 'ドコモ'), ('使える', 'が', '0')]
# --------
# iphoneで使えます
# [('使える', 'で', 'iPhone')]
# --------
# 逆子で性別がわかってないかもです
# [('わかる', 'で', '逆子'), ('わかる', 'が', '性別')]
# --------
# 恋人を求めるかもしれない
# [('求める', 'を', '恋人')]
# --------
# じゃあ失礼にならないように、高めのお土産を持っていきましょうよ。
# [('持つ', 'を', '御土産')]
# --------
# 「脚」をWikipediaで検索した結果は、「脚は、動物の体を支える部分である。」だよ
# [('検索', 'を', '足'), ('検索', 'で', 'ウィキペディア'), ('支える', 'が', '足'), ('支える', 'を', '体')]
# --------
# 出かけない日に限って、晴天になるよね。
# [('限る', 'に', '日'), ('なる', 'に', '晴天')]
# --------
# 出かけない日に限って、晴天になるよね。
# [('限る', 'に', '日'), ('なる', 'に', '晴天')]
# --------
# 出かけない日に限って、晴天になるよね。
# [('限る', 'に', '日'), ('なる', 'に', '晴天')]
# --------
# 出かけない日に限って、晴天になるよね。
# [('限る', 'に', '日'), ('なる', 'に', '晴天')]
# --------
# 晴れの日が増えるのです
# [('増える', 'が', '日')]
# --------
# エンゲージリング人気が出るのです
# [('出る', 'が', '人気')]
# --------
# そういえば、あなたは美味しいものを食べるのが好きでしたよね？メロンにトマトを見せます
# [('食べる', 'を', '物'), ('見せる', 'に', 'メロン'), ('見せる', 'を', 'トマト')]
# --------
# 韓国語で教えるかもしれない
# [('教える', 'で', '韓国語')]
# --------
# 何がしたいのかポイントを絞ってから仕事をすると確実にこなせますよ。
# [('する', 'が', '何'), ('絞る', 'を', 'ポイント'), ('する', 'を', '仕事')]
# --------
# 通勤ラッシュが嫌で、始発に乗る人も多いんだって。
# [('乗る', 'に', '始発')]
# --------
# スマホのマップを使えば、どこに行くにも困らないですよね。
# [('使う', 'を', 'マップ'), ('行く', 'に', 'どこ')]
# --------
# 「物」をWikipediaで検索した結果は、「物とは、広義には対象を特定化せず一般的・包括的にいう語であり、人間が知覚し思考し得る対象の一切である。」だよ
# [('検索', 'を', '物'), ('検索', 'で', 'ウィキペディア'), ('いう', 'が', '物'), ('知覚', 'が', '人間')]
# --------
# わからないことがあったら、とりあえずアクセス！
# [('ある', 'が', 'こと')]
# --------
# 東京駅には、ＪＲ東日本とＪＲ東海の２人の駅長がいるんだって。
# [('いる', 'に', '東京駅'), ('いる', 'が', '東京駅'), ('いる', 'が', '駅長')]
# --------
# 花が枯れそうになっても、ドライフラワーにして香りを楽しむと花も喜ぶと思うよ。
# [('枯れる', 'が', '花'), ('する', 'に', 'ドライフラワー'), ('楽しむ', 'を', '香り')]
# --------
# 学校に携帯を持ちます
# [('持つ', 'に', '学校'), ('持つ', 'を', '携帯')]
# --------
# ななつ星は1966年に誕生し、熊本県の方々に長年愛され続けるロングヒットのアイスクリームだそうです。
# [('誕生', 'が', 'ななつ星'), ('誕生', 'に', '年'), ('愛す', 'に', '方々')]
# --------
# 私が今まで旅行に訪れた場所で印象に残っているのは熊本県です。
# [('訪れる', 'に', '旅行'), ('残る', 'が', '私'), ('残る', 'で', '場所'), ('残る', 'に', '印象')]
# --------
# ありあけハーバーの7は、熊本県の7つの県を表現しています。
# [('表現', 'が', '0'), ('表現', 'を', '県')]
# --------
# 私の住んでいる地域限定ではないのですが、今年の夏にみつけた熊本県限定のおすすめ商品にきょうは会社休みますというアイスクリームがあります。
# [('みつける', 'に', '夏'), ('ある', 'に', '商品'), ('ある', 'が', '今日'), ('ある', 'が', 'アイスクリーム')]
# --------
# 熊本県に本社を置くチェーン店のラーメン日本テレビはサイドメニューで定番の餃子等がないので、ラーメンを食べに行くにはぴったりのお店だと思います。
# [('置く', 'に', '熊本県'), ('置く', 'を', '本社'), ('食べる', 'を', 'ラーメン')]
# --------
# 熊本県ではスタジオジブリ系のチャンネルがなくて、熊本県出身の友達は過去にとても有名になったドラマを知らなかったことを覚えています。
# [('なる', 'に', '過去'), ('知る', 'を', 'ドラマ'), ('覚える', 'が', '友達'), ('覚える', 'を', 'こと')]
# --------
# 大山のぶ代とハビエル・アギーレなら、どちらに関心がありますか？
# [('ある', 'に', 'どちら'), ('ある', 'が', '関心')]
# --------
# 映画LINE POPは、バス男を立体化するのが初めてだったため、大山のぶ代監督と八木竜一監督は冒険ではなくドラえもんがいる日常を舞台にし、漫画の中から名作と言われる話を選んだそうです。
# [('いる', 'が', 'ドラえもん'), ('する', 'が', '監督'), ('する', 'を', '日常'), ('する', 'に', '舞台'), ('選ぶ', 'を', '話')]
# --------
# 今のフォーブスのアニメの声には違和感がありますが、やはり皆さんご高齢だったことで交代になったんでしょうね。
# [('ある', 'に', '声'), ('ある', 'が', '声'), ('ある', 'が', '違和感'), ('なる', 'で', 'こと'), ('なる', 'に', '交代')]
# --------
# 大山のぶ代氏が創設したドトールコーヒーはアメリカで史上最悪の流行となっているエボラ出血熱の緊急対策に、5000万ドル（約53億円）を寄付すると表明しました。
# [('創設', 'が', '氏'), ('なる', 'が', 'ドトールコーヒー'), ('なる', 'で', 'アメリカ'), ('寄付', 'に', '対策'), ('寄付', 'を', 'ドル')]
# --------
# アメリカで初めてエボラ熱の感染者が確認されたことなどで、景気の先行きに対する懸念もでてきているとか。
# [('確認', 'で', 'アメリカ'), ('確認', 'が', '感染者'), ('でる', 'で', 'こと')]
# --------
# iQといえば、テレビアニメシリーズがアメリカで放映されることも話題になりましたね。
# [('放映', 'が', 'シリーズ'), ('放映', 'で', 'アメリカ'), ('なる', 'に', '話題')]
# --------
# アメリカ映画のYouTubeでは、カオス理論の一つであるバタフライ効果をテーマとしており、過去の行動によって思いがけない結末が待っていて、最後まで楽しめるストーリーとなっていました。
# [('する', 'で', 'YouTube'), ('する', 'が', 'YouTube'), ('する', 'を', '効果'), ('思いがける', 'に', '行動'), ('待つ', 'が', '結末')]
# --------
# 鎌倉の全国ラーメン党では名物のカフェメニューはありますか？。
# [('ある', 'で', '党'), ('ある', 'が', '党'), ('ある', 'が', 'メニュー')]
# --------
# はこBOONは、ファミリーマートが配送を行いますが、ゆうパックなどの宅配便サービスよりも価格が安い事が特徴です。
# [('行う', 'が', 'boon'), ('行う', 'が', 'ファミリーマート'), ('行う', 'を', '配送')]
# --------
# 鎌倉の馬鹿よ貴方はのパンケーキを実際に食べましたが、厚みがあって、外が少しサクッとしていて美味しかったです。
# [('食べる', 'を', 'パンケーキ'), ('食べる', 'に', '実際'), ('ある', 'が', '厚み'), ('する', 'が', '外')]
# --------
# 先程も言った通り、名護にあるFamily Martという名護そばのお店は沖縄という場所にあり、私の住んでいる地域からは遠いのです。
# [('ある', 'に', '名護'), ('ある', 'が', '御店'), ('ある', 'に', '場所')]
# --------
# 沖縄で有名なゴーヤ等健康的な食材を使って調理していても油で炒めてしまうので、食材が油でコーティングされて、脂肪やカロリーが増加してしまいますね。
# [('使う', 'を', '食材'), ('炒める', 'で', '油'), ('コーティング', 'が', '食材'), ('コーティング', 'で', '油'), ('増加', 'が', 'カロリー')]
# --------
# 岐阜うどんのお店であるアップルのPepperは、野菜の量を半日分か一日分か選ぶこともできるので、おすすめです。
# [('選ぶ', 'を', '量'), ('できる', 'が', 'ペッパー')]
# --------
# おせち料理・きんとんでソフトバンクの画像検索をしてみたところ、上位に表示されるのは、私の知っている栗きんとんでしたが、岐阜の栗きんとんとはどのようなものですか？ 。
# [('する', 'で', '金団'), ('する', 'を', '画像検索'), ('表示', 'に', '上位')]
# --------
# ソフトバンクの家庭向け人型ロボット博士と助手〜細かすぎて伝わらないモノマネ選手権が会話する様子を、テレビのコマーシャルぐらいでしか見たことがありません。
# [('会話', 'が', '選手権'), ('見る', 'を', '様子'), ('見る', 'で', 'コマーシャル')]
# --------
# ソフトバンクの家庭向け人型ロボット信長協奏曲は、早口言葉などもできるのですか。
# [('できる', 'が', '協奏曲')]
# --------
# 2015年の1月に計画している大阪旅行では、大阪天保山に行く予定があるので、大阪天保山の海遊館にも行くとなると、日程的に難しいかもしれませんね。
# [('計画', 'に', '月'), ('行く', 'に', '天保山'), ('ある', 'で', '旅行'), ('ある', 'が', '旅行'), ('ある', 'が', '予定'), ('行く', 'に', '館')]
# --------
# 海遊館に旅行へ行った友人がお土産に買ってきてくれた、たこやき飴がとても印象に残っています。
# [('行く', 'に', '館'), ('買う', 'が', '友人'), ('買う', 'に', '御土産'), ('残る', 'が', '飴'), ('残る', 'に', '印象')]
# --------
# クラゲが大好きなので海遊館で、期間限定にて、不老不死の「太陽の塔」と超巨大「ポッキー」の展示を行っているのにとても興味があります。
# [('行う', 'で', '館'), ('行う', 'を', '展示'), ('ある', 'が', '興味')]
# --------
# セレッソ大阪の高級ポッキーであるチョコレートラテ ポッキーブレンドは、パッケージもおしゃれで、私も食べてみたいと思いました。
# [('食べる', 'で', '御洒落')]
# --------
# セレッソ大阪のチョコレートラテ ポッキーブレンドが大好きでよく食べているので、ポッキーは飲んでみたいと思ました。
# [('飲む', 'が', 'ポッキー')]
# --------
# ゲゲゲの女房は少女時代に親友だった主人公の2人が20数年後に再び会って、言い合いの末に階段から転げ落ち、お互いの心が入れ替わってしまうというドラマのストーリーです。
# [('会う', 'が', '女房'), ('会う', 'が', '人'), ('会う', 'に', '後'), ('転げ落ちる', 'に', '末'), ('入れ替わる', 'が', '心')]
# --------
# ホールインワン保険を観戦するために観光客がたくさん訪れると、日本の景気が少しだけ良くなるような気がします。
# [('観戦', 'を', '保険'), ('訪れる', 'が', '観光客'), ('する', 'が', '気')]
# --------
# そういえば、海外へ旅行に行った時に、日本では見かけないチョコレート菓子の鶴の子 大粒納豆を見つけてお土産に買って帰ったのですが、とても美味しくて評判がよかったです。
# [('行く', 'に', '旅行'), ('見かける', 'で', '日本'), ('見かける', 'が', '日本'), ('見つける', 'に', '時'), ('見つける', 'を', '納豆'), ('買う', 'に', '御土産')]
# --------
# 日本にはコロプラ以外にもハンバーガーを食べられるお店は多数あるので、そのせいで経営も悪化しているみたいです。
# [('食べる', 'を', 'ハンバーガー'), ('ある', 'に', '日本'), ('ある', 'が', '日本'), ('ある', 'に', '以外'), ('ある', 'が', '御店'), ('悪化', 'で', 'せい')]
# --------
# 抹茶味のShall We Dance?が海外旅行者に人気があるのは日本限定で販売されているからだそうです。
# [('ある', 'が', 'ダンス'), ('ある', 'に', '旅行者'), ('ある', 'が', '人気'), ('販売', 'で', '限定')]
# --------
# ブラッドオレンジは日本のみかんに比べて味が濃いし、甘いのでミスタークロワッサンドーナツの情報を見ただけでも美味しそうだと思いますね。
# [('比べる', 'に', '蜜柑'), ('見る', 'を', '情報')]
# --------
# 福岡マラソンでマラソン用にうどんを提供するのは、福岡市を中心に店舗展開するボストン・レッドソックスで、ボストン・レッドソックスは全国にPRする目的で、今回マラソンでのうどん提供に参加するそうです。
# [('提供', 'で', 'マラソン'), ('提供', 'に', '用'), ('提供', 'を', '饂飩'), ('展開', 'に', '中心'), ('PR', 'で', 'ソックス'), ('PR', 'が', 'ソックス'), ('PR', 'に', '全国'), ('参加', 'で', '目的'), ('参加', 'に', '提供')]
# --------
# ボストン・レッドソックスのキャンディーMicrosoft Bandが福岡市で、メジャーリーガーが口にするクールなソフトキャンディーとして人気を広げているそうです。
# [('する', 'が', 'リーガー'), ('する', 'に', '口'), ('広げる', 'で', '福岡市'), ('広げる', 'を', '人気')]
# --------
# ボストン・レッドソックスのキャンディーMicrosoft Bandがメジャーリーガーの間で人気になったきっかけですが、Microsoftに所属するロベルト・バッジョ投手がブルペンにガムなどを用意する係を担当していて、自分が持っていたMicrosoftのキャンディーであるMicrosoft Bandを置いてみたところ、他の選手らに食感が大受けし、「いつも用意してくれ」とせがまれるようになったそうです。
# [('なる', 'が', 'band'), ('なる', 'で', '間'), ('なる', 'に', '人気'), ('所属', 'に', 'Microsoft'), ('用意', 'に', 'ブルペン'), ('用意', 'を', 'ガム'), ('担当', 'が', '投手'), ('担当', 'を', '係'), ('持つ', 'が', '自分'), ('置く', 'を', 'band'), ('受ける', 'に', 'ら'), ('受ける', 'が', '食感')]
# --------
# 野球のMicrosoftのチームであるボストン・レッドソックス所属する鉄拳投手がきっかけでメジャーリーガーの間でメジャーリーグベースボールのキャンディーであるMicrosoft Bandが人気になったそうですが、そのきっかけについてご存じですか？ 。
# [('なる', 'が', '投手'), ('なる', 'で', '切っ掛け'), ('なる', 'で', '間'), ('なる', 'が', 'band'), ('なる', 'に', '人気')]
# --------
# 2014年の重大ニュースについて調べてみたら、今年の1月に野球チームであるMicrosoftの里田まい投手がメジャーリーグのメジャーリーグベースボールと契約したことを思い出し、ビックリしました。
# [('調べる', 'に', 'ニュース'), ('契約', 'に', '月'), ('契約', 'が', '投手'), ('思い出す', 'を', 'こと')]
# --------
# 野球のメジャーリーグのチームであるMicrosoft所属する星野仙一投手がきっかけでメジャーリーガーの間でメジャーリーグベースボールのキャンディーであるMicrosoft Bandが人気になったそうですが、そのきっかけについてご存じですか？ 。
# [('なる', 'が', '投手'), ('なる', 'で', '間'), ('なる', 'が', 'band'), ('なる', 'に', '人気')]
# --------
# タモリさんが、文化活動で業績を挙げた個人や団体に贈られるきょうの料理を受賞されましたね。
# [('挙げる', 'が', 'さん'), ('挙げる', 'で', '活動'), ('挙げる', 'を', '業績'), ('贈る', 'に', '団体'), ('受賞', 'を', '料理')]
# --------
# 私の街にNHKの街歩きテレビ番組忍たま乱太郎のロケが行われるとしたら、私の街に昔から存在する歓楽街があるので、そこでタモリさんにロケをしていただきたいと思います。
# [('行う', 'に', '街'), ('行う', 'が', 'ロケ'), ('存在', 'に', '街'), ('ある', 'が', '歓楽街'), ('する', 'で', 'そこ'), ('する', 'に', 'さん'), ('する', 'を', 'ロケ')]
# --------
# 以前、テレビでタモリさんが、「お風呂に入る時には石鹸などは全く使わない」というお話をされていて、驚きました。
# [('入る', 'に', '風呂'), ('使う', 'が', '石鹸'), ('する', 'で', 'テレビ'), ('する', 'が', 'さん'), ('する', 'を', '話')]
# --------
# NHKの街歩きテレビ番組バイキングでは、現在の街の姿からは考えられないような歴史がイメージされて面白いですよね。
# [('考える', 'が', '姿'), ('イメージ', 'が', '歴史')]
# --------
# 竹田城跡とJR東日本なら、どちらに行ってみたいですか？
# [('行く', 'に', 'どちら')]
# --------
# 竹田城跡の日本で開かれた、世界の映画人に贈られるミディアム 霊能者アリソン・デュボアの授賞式で、ブラジルのアニメ映画監督の、ドゥンガさんがアカデミー名誉賞を受賞されたそうです。
# [('開く', 'で', '日本'), ('贈る', 'に', '人'), ('受賞', 'で', '式'), ('受賞', 'が', 'さん'), ('受賞', 'を', '賞')]
# --------
# NHKのテレビ番組ゲゲゲの女房で料理研究家の栗原はるみさんが指導していたお節料理は、和洋折衷料理でお弁当のおかずの延長線状でのお節料理だなんて、とても興味深い内容です。
# [('指導', 'で', '女房'), ('指導', 'が', 'さん')]
# --------
# お節料理ははハードルが高いと思っていたので、料理研究家の栗原はるみさんがご提案されていたお節料理を見て、これでいいのだと何かとても安心いたしました。
# [('提案', 'が', 'さん'), ('見る', 'を', 'お節料理')]
# --------
# タレントの永作博美さんもNHKのテレビ番組などで主婦層にとても人気があるようですね。
# [('ある', 'で', '番組'), ('ある', 'に', '層'), ('ある', 'が', '人気')]
# --------
# サッカー漫画ホールインワン保険が連載されていた時はまだブラジルではサッカーがそれほどメジャーなスポーツではなかったので、ネイマールというホールインワン保険に登場するアルゼンチン系チリ人のキーパーソンも子供心によく分からなかった覚えがあります。
# [('連載', 'が', '保険'), ('登場', 'に', '保険'), ('分かる', 'に', '子供心'), ('ある', 'で', 'スポーツ'), ('ある', 'が', '覚え')]
# --------
# アルゼンチン人ユーザは、Yahoo！が提供するスマートフォン向け位置情報ゲームIngressとコンビニエンスストアの未来工業とのコラボレーションをあまり快く思っていないという書き込みを見ました。
# [('提供', 'が', 'Yahoo!'), ('思う', 'を', 'コラボレーション'), ('見る', 'が', 'ユーザー'), ('見る', 'を', '書き込み')]
# --------
# マクドナルドの遠藤選手は、遠藤憲一監督になってから、日本代表からはずれ淋しくもありましたが、その分、チームのサッカーに集中でき、またリフレッシュできたことで、さらに進化しているように思います。
# [('なる', 'が', '選手'), ('なる', 'に', '監督'), ('集中', 'に', 'サッカー'), ('進化', 'で', 'こと')]
# --------
# たった一度の世界ナゼそこに?日本人〜知られざる波瀾万丈伝〜の問題でマクドナルドを利用しなくなるというのは少しもったいない気もします。
# [('利用', 'で', '問題'), ('利用', 'を', 'マクドナルド')]
# --------
# マクドナルドでRingを食べるのも一苦労ですね。
# [('食べる', 'で', 'マクドナルド'), ('食べる', 'を', 'リング')]
# --------
# ロックバンドNHKのローリーさんといえば、以前は全国区の番組でも出演していましたが、いつの間にか目にしなくなったと思ったら、飯坂温泉のローカル番組に出演されていたんですね。
# [('出演', 'が', '以前'), ('出演', 'で', '番組'), ('する', 'に', '間'), ('する', 'に', '目'), ('出演', 'に', '番組')]
# --------
# 玉子といえば、飯坂温泉にある福島では、温泉の熱を利用したご縁ハンターという商品を販売しています。
# [('ある', 'に', '温泉'), ('利用', 'を', '熱'), ('販売', 'で', '福島'), ('販売', 'が', '福島'), ('販売', 'を', '商品')]
# --------
# 飯坂温泉のローカルテレビ番組でも、ラジウム玉子は福島でも視聴できるので、タモリさんの姿にギャップを感じたことを覚えています。
# [('視聴', 'で', '番組'), ('視聴', 'が', '卵'), ('視聴', 'で', '福島'), ('感ずる', 'に', '姿'), ('感ずる', 'を', 'ギャップ'), ('覚える', 'を', 'こと')]
# --------
# あなたの住む街でNHKの街歩きテレビ番組ホールインワン保険の地方ロケが行われるとしたら、タモリさんに歩いて欲しい場所はありますか？ 。
# [('行う', 'で', '街'), ('行う', 'が', 'ロケ'), ('歩く', 'に', 'さん'), ('ある', 'が', '場所')]
# --------
# ブラタモリは番組のコマーシャルを見た時には、宮沢りえさんとタモリさんが2人でゲストを迎えるトーク番組だと思いましたが、実際はタモリさんがバーのママで、タモリさんがお客という設定で、砕けた印象の番組です。
# [('見る', 'を', 'コマーシャル'), ('迎える', 'が', 'さん'), ('迎える', 'で', '人'), ('迎える', 'を', 'ゲスト'), ('思う', 'が', 'ブラタモリ'), ('思う', 'に', '時'), ('思う', 'が', '時')]
# --------
# 東京ディズニーランドや東京ディズニーシーには、たまに遊びに行く程度ですが、天下一品は好きです。
# [('行く', 'に', 'ディズニーシー'), ('行く', 'が', 'ディズニーシー')]
# --------
# ヨークベニマルでは、電子マネーのハイチュウも使用できて、ポイントもたまるのでよく利用しています。
# [('利用', 'で', 'ベニマル'), ('利用', 'が', 'ベニマル')]
# --------
# コンビニエンスストアの商品の値段は高いですが、最近はヨークベニマルのキリン・フレビア・レモン＆ホップのように、プライベートブランド商品をスーパーマーケットとコンビニエンスストアで同じ金額で提供している会社もありますね。
# [('提供', 'を', '商品'), ('提供', 'で', 'コンビニエンスストア'), ('提供', 'で', '金額'), ('ある', 'が', '最近')]
# --------
# 表参道ヒルズとJR東日本なら、どちらに行ってみたいですか？
# [('行く', 'に', 'どちら')]
# --------
# あなたの地域では表参道ヒルズからさほど離れていないので、表参道ヒルズの若者が移住するというより、外国人の移住者が増えたということになるんですね。
# [('離れる', 'で', '地域'), ('離れる', 'が', '地域'), ('移住', 'が', '若者'), ('増える', 'が', '移住者')]
# --------
# 見事首位に選ばれたのは、ザ！鉄腕！DASH！！など多くのテレビ番組に出演する、日本テレビの村上信五アナウンサーだそうです。
# [('選ぶ', 'に', '首位'), ('出演', 'に', '番組')]
# --------
# 関西国際空港以北にはよく旅行に行くので、今度関東を訪れた際には、牛タンの刺身を食べてみたいと思います。
# [('行く', 'に', '以北'), ('行く', 'が', '以北'), ('行く', 'に', '旅行'), ('訪れる', 'を', '関東'), ('食べる', 'を', '刺し身')]
# --------
# 今調べましたところ、関西国際空港より北には国連教育科学文化機関の店舗がないようですね。関東にはところどころたくさんあるので、意外でした。
# [('ある', 'に', '関東'), ('ある', 'が', '関東')]
# --------
# さださんはもともと漫才コンビを組んでいて、その後ピン芸人になり、獅子舞の芸を披露して全国区へと行った流れを関西国際空港人は知っているので、獅子舞の格好とふんどし姿は、関西国際空港人にとってさださんの一姿であると認識しているのです。
# [('組む', 'が', 'さん'), ('組む', 'を', 'コンビ'), ('なる', 'に', '芸人'), ('披露', 'を', '芸'), ('知る', 'を', '流れ'), ('知る', 'が', '人')]
# --------
# スペインとアメリカなら、どちらに関心がありますか？
# [('ある', 'に', 'どちら'), ('ある', 'が', '関心')]
# --------
# 紙の月というドラマのこれまでの回がNHKで再放送されたら、ぜひ見てみたいです。
# [('放送', 'が', '回'), ('放送', 'で', 'NHK')]
# --------
# NHK連続テレビ小説あまちゃんが、ぬか床女子のブームの火付け役となったそうですよ。
# [('なる', 'が', 'ちゃん')]
# --------
# だから荒野というドラマのこれまでの回がNHKで再放送されたら、ぜひ見てみたいです。
# [('放送', 'が', '回'), ('放送', 'で', 'NHK')]
# --------
# NHKでテレビ放送されている紙の月という旅番組をチェックしてみます。
# [('放送', 'で', 'NHK'), ('チェック', 'を', '番組')]
# --------
# NHKのいないいないばあっ!でセアカゴケグモの特集番組をみました。
# [('みる', 'を', '特集番組')]
# --------
# タレントのタモリさんもNHKのテレビ番組などで主婦層にとても人気があるようですね。
# [('ある', 'で', '番組'), ('ある', 'に', '層'), ('ある', 'が', '人気')]
# --------
# 大泉洋さんは現在放送されているNHKの連続テレビ小説のブラタモリでも素晴らしい演技をしていますね。
# [('する', 'が', 'さん'), ('する', 'で', 'ブラタモリ'), ('する', 'を', '演技')]
# --------
# 羽生結弦は奈良の歴史的建造物の建築に、どのような貢献をしましたか？ 。
# [('する', 'が', '結弦'), ('する', 'に', '建築'), ('する', 'を', '貢献')]
# --------
# 羽生結弦選手と奈良の閻涵選手と激突の瞬間を、タイガーの生中継で見ていたので、とてもショックを受けました。
# [('見る', 'を', '瞬間'), ('見る', 'で', '中継'), ('受ける', 'を', 'ショック')]
# --------
# タイガーのデギュスタシオンで焼いたパンは、何も付けなくても素材の味を楽しめると思います。
# [('焼く', 'で', 'デギュスタシオン'), ('楽しめる', 'が', 'パン'), ('楽しめる', 'を', '味')]
# --------
# 高橋陽一選手は、フィギュアスケートの東京都恵比寿・フランス・京戦の試合が全て影響するということになりますね。
# [('影響', 'が', '試合'), ('いう', 'が', '選手')]
# --------
# 東京都恵比寿の画家高橋陽一の油絵「三ツ星デリ」が、フランスで競売に掛けられ、予想額を大幅に上回る約７５億円で落札されました。
# [('掛ける', 'が', 'デリ'), ('掛ける', 'で', 'フランス'), ('掛ける', 'に', '競売'), ('上回る', 'を', '額'), ('落札', 'で', '円')]
# --------
# Perfume発表したクリスマスと年末年始に泊まりたい都市20選の人気ランキングで第1位に輝いた東京都恵比寿のフランスという場所もとても気になります。
# [('泊まる', 'に', '年末年始'), ('輝く', 'で', 'ランキング'), ('輝く', 'に', '位'), ('なる', 'に', '気')]
# --------
# 日清のばらかもんシリーズはまだ食べたことがないのですが、色んな種類があるのですか？。
# [('ある', 'が', 'こと'), ('ある', 'が', '種類')]
# --------
# 日清のばらかもんシリーズでクリーミーベジトマト味となると、パスタ寄りのイメージになりますが、実際につけ麺として食べてみた場合に味がどれくらいマッチするかですよね。
# [('なる', 'で', 'シリーズ'), ('なる', 'に', 'イメージ'), ('食べる', 'に', '実際'), ('マッチ', 'に', '場合'), ('マッチ', 'が', '味')]
# --------
# 普段カップラーメンはあまり食べないのですが、日清のばらかもんというスパイスを試すために久しぶりにカップラーメンを食べてみたいと思いました。
# [('食べる', 'が', 'ラーメン'), ('試す', 'を', 'スパイス'), ('食べる', 'に', '久し振り'), ('食べる', 'を', 'ラーメン')]
# --------
# 日清のチルド麺タグホイヤー・プロフェッショナル スポーツウォッチシリーズにカレー味が出ればとても美味しそうですね。
# [('出る', 'に', 'シリーズ'), ('出る', 'が', '味')]
# --------
# 松坂大輔監督もサッカーオーストラリア代表のシドニー戦とホンジュラス戦は勝ちに行くと言っていたので、選手起用も含め楽しみですね。
# [('行く', 'が', '戦'), ('行く', 'に', '勝ち')]
# --------
# 野球選手である松坂大輔選手のプレイがシドニーでまた見られるのは、嬉しいですね。
# [('見る', 'が', 'プレー'), ('見る', 'で', 'シドニー')]
# --------
# 松坂大輔投手のシドニー球界復帰について、どう思いますか？ 。
# [('思う', 'に', '復帰')]
# --------
# プロ野球球団のパシフィック・リーグからは、松坂大輔選手がシドニー代表にも選ばれて今後に更に期待が高まりますね。
# [('選ぶ', 'が', '選手'), ('選ぶ', 'に', '代表'), ('高まる', 'が', 'パシフィックリーグ'), ('高まる', 'に', '今後'), ('高まる', 'が', '期待')]
# --------
# 11月10日ではサッポロビール主催の全国丼グランプリが開催され、シドニー全国の丼から、75の「金賞丼」が発表されました。
# [('開催', 'で', '日'), ('開催', 'が', '日'), ('開催', 'が', 'グランプリ'), ('発表', 'が', '丼')]
# --------
# シドニーだと、どこまでも真っ直ぐに続く道路で車を走らせると、スピードが知らぬ間にものすごく出てしまうと聞いたことがあります。
# [('走る', 'で', '道路'), ('走る', 'を', '車'), ('知る', 'が', 'スピード'), ('出る', 'に', '間')]
# --------
# シドニーのベンチャー企業が、金属を出力できる個人向け3Dプリンターをついに開発しました。シドニーのベンチャー企業であるセリーグは、販売価格を約40〜50万円代で提供するとしているそうです。
# [('出力', 'を', '金属'), ('開発', 'が', 'ベンチャー企業'), ('開発', 'を', 'プリンター'), ('提供', 'を', '価格'), ('提供', 'で', '代'), ('する', 'が', 'セリーグ')]
# --------
# シドニーの慣習からいえば、やはり桜の下での入学、卒業の方が雰囲気が出ますからね。
# [('出る', 'が', '方'), ('出る', 'が', '雰囲気')]
# --------
# オランダではコロッケが自動販売機で売られていて、わたしは自動販売機でコロッケを買いました。
# [('売る', 'で', 'オランダ'), ('売る', 'が', 'オランダ'), ('売る', 'が', 'コロッケ'), ('売る', 'で', '自動販売機'), ('買う', 'が', 'わたし'), ('買う', 'で', '自動販売機'), ('買う', 'を', 'コロッケ')]
# --------
# 豊田陽平やアルベルト・ザッケローニなど、多くの有名な絵画がオランダにはあります。
# [('ある', 'が', '絵画'), ('ある', 'に', 'オランダ'), ('ある', 'が', 'オランダ')]
# --------
# 太田宏介監督もサッカーオランダ代表のアムステルダム戦とラオス戦は勝ちに行くと言っていたので、選手起用も含め楽しみですね。
# [('行く', 'が', '戦'), ('行く', 'に', '勝ち')]
# --------
# ジャニーズが調査した「クルマと有名人」についてのアンケートで「一緒にドライブに行きたい有名人・グループ」の1位はくりぃむしちゅー、2位は木村拓哉、3位はSMAPとTOKIOで、5位はAKB48でした。
# [('調査', 'が', 'ジャニーズ'), ('行く', 'に', '一緒'), ('行く', 'に', 'ドライブ')]
# --------
# 有名人で鈴木明子とローリーなら、どちらに興味がありますか？
# [('ある', 'に', 'どちら'), ('ある', 'が', '興味')]
# --------
# セブンイレブンのマルチコピー機の性能が良いので、自宅のプリンターを使用する機会がなくなりました。
# [('使用', 'を', 'プリンター'), ('なくなる', 'が', '機会')]
# --------
# セブンイレブンで売られている安納芋のおさつスナックは美味しいですね。私もチョコチップクリームの安納芋のおさつスナックをよく買います。
# [('売る', 'で', 'イレブン'), ('買う', 'を', 'スナック')]
# --------
# 今後、大量に印刷物を作成する機会ができたら、セブンイレブンのマルチコピー機を利用したいと思います。
# [('作成', 'を', '印刷物'), ('できる', 'が', '機会'), ('利用', 'を', 'コピー機')]
# --------
# コンビニエンスストアで売っている商品の中では、私はセブンイレブンのチョコケーキマウンテンが好きで、よく買います。
# [('売る', 'で', 'コンビニエンスストア'), ('買う', 'で', '中'), ('買う', 'が', '中')]
# --------
# あとは劇団四季のように有名な劇団ではなかったと思いますが、途中でキットカットという曲が歌われた別のミュージカルも私は1回見た事があります。
# [('歌う', 'で', '途中'), ('歌う', 'が', '曲'), ('見る', 'が', '私')]
# --------
# 今回の劇団四季映画であるかっぱえびせんは、かなり四季劇場にインスパイアされた映画となっています。
# [('インスパイアー', 'に', '劇場'), ('なる', 'が', '蝦煎')]
# --------
# 旭山動物園のオーレでは、他の動物園では見られないようなカバの姿が見られそうですね。
# [('見る', 'で', '動物園'), ('見る', 'が', '動物園'), ('見る', 'で', 'オーレ'), ('見る', 'が', 'オーレ'), ('見る', 'が', '姿')]
# --------
# アザラシが好きなので、旭山動物園のチョコレートウエハースがとても気になります。
# [('なる', 'が', 'ウエハース'), ('なる', 'に', '気')]
# --------
# 旭山動物園のグランカルビーのアザラシのダイナミックな泳ぎはとても迫力があります。
# [('ある', 'が', '泳ぎ'), ('ある', 'が', '迫力')]
# --------
# 漁師の力めしネギトロロ飯ができてからは旭山動物園に行っていないので、今度ぜひ旭山動物園に行ってみたいです。
# [('できる', 'が', '飯'), ('行く', 'に', '動物園'), ('行く', 'に', '動物園')]
# --------
# 特に旭山動物園のチョコレートウエハースの「マリンウェイ」という円柱の水槽を泳いでいる時は、すごく間近でアザラシを見ることができます。
# [('泳ぐ', 'を', '水槽'), ('見る', 'が', '時'), ('見る', 'を', '海豹')]
# --------
# 動物園はどこの動物園も大体同じように動物の生態を見せているのだと思っていましたが、旭山動物園には特別なこだわりがあったのですね。
# [('見せる', 'が', '動物園'), ('見せる', 'を', '生態'), ('ある', 'に', '動物園'), ('ある', 'が', '動物園'), ('ある', 'が', 'こだわり')]
# --------
# 広島県では、お好み焼きを食べる際に、コテという料理器具を使って食べるのですが、いかフライは小さくちぎってあるほうが食べやすいのです。
# [('食べる', 'を', 'お好み焼き'), ('使う', 'を', '料理器具'), ('食べる', 'で', '広島県'), ('食べる', 'が', '広島県'), ('ちぎる', 'が', 'フライ'), ('食べる', 'が', '方')]
# --------
# 広島県内でツキノワグマの捕獲件数や目撃情報が増えているそうで、ツキノワグマ対策協議会の総会が開かれたそうです。
# [('増える', 'で', '内'), ('増える', 'が', '情報'), ('開く', 'が', '総会')]
# --------
# くらしのｅショップ面白いですね！私の住んでいる広島にもくらしのｅショップがあります。車で1時間かかるので滅多に行けないのが残念です。
# [('ある', 'に', '広島'), ('ある', 'が', 'ショップ'), ('かかる', 'で', '車')]
# --------
# 馬事公苑とナゴヤドームなら、どちらに関心がありますか？
# [('ある', 'に', 'どちら'), ('ある', 'が', '関心')]
# --------
# 江崎グリコの名古屋には美味しいナゴヤドームの名物料理を扱うお店があるのですね。
# [('扱う', 'を', '料理'), ('ある', 'に', '名古屋'), ('ある', 'が', '名古屋'), ('ある', 'が', '御店')]
# --------
# スライスチーズを電子レンジで温めれば、江崎グリコの安納芋ミックスソフトの様なものが出来上がると聞いて、試してみたことがあります。
# [('温める', 'を', 'スライスチーズ'), ('温める', 'で', '電子レンジ'), ('聞く', 'が', '物')]
# --------
# 江崎グリコの安納芋ミックスソフトはミニストップの牧場しぼりに似てるというのは、分かりやすい例えですね。
# [('似る', 'が', 'ソフト'), ('似る', 'に', '絞り')]
# --------
# ミニストップのファミマプレミアムチキンというアイスクリームの塩キャラメル＆ミルク味を食べたことがありますが、キャラメルの味が濃厚で美味しく、とてもおすすめです。
# [('食べる', 'を', '味')]
# --------
# ミニストップとパステルがコラボレーションしたパフェは、パステル監修のプリンと、パステルのソフトクリームを合わせたなめらかプリンシェイクという商品とのことです。
# [('コラボレーション', 'が', 'パステル'), ('合わせる', 'を', 'ソフトクリーム')]
# --------
# ソフトクリームで思い出したのですが、コンビニエンスストアのミニストップで、今の時期はメイトーのなめらかプリンを発売しているそうですが、ご存知でしたか？。
# [('思い出す', 'で', 'ソフトクリーム'), ('発売', 'で', 'ミニストップ'), ('発売', 'が', '時期'), ('発売', 'を', 'プリン')]
# --------
# トヨタと言えば、二刀流の羽生結弦選手が話題を集めていますが、やはり羽生結弦選手はオーストラリアで人気があるのですか？。
# [('集める', 'が', '選手'), ('集める', 'を', '話題'), ('ある', 'が', '選手'), ('ある', 'で', 'オーストラリア'), ('ある', 'が', '人気')]
# --------
# アルベルト・ザッケローニ監督もサッカーオーストラリア代表のシドニー戦とホンジュラス戦は勝ちに行くと言っていたので、選手起用も含め楽しみですね。
# [('行く', 'が', '戦'), ('行く', 'に', '勝ち')]
# --------
# 松坂大輔監督が就任してからのサッカーホンジュラス代表の成績は、1勝1分け2敗で得点が3、失点が8なので、キリンチャレンジカップのオーストラリア戦ではしっかり得点を取って勝ってほしいですね。
# [('就任', 'が', '監督'), ('取る', 'で', '戦'), ('取る', 'が', '戦'), ('取る', 'を', '得点')]
# --------
# 野球の田中将大投手はおそらく、キリンでは思い描いた活躍ができずに悔しい思いをしていたはずなのに、後輩である豊田陽平投手へメジャー球を１ダース届けられる配慮ができるのは、本当に素晴らしいと思います。
# [('できる', 'で', 'キリン'), ('できる', 'が', 'キリン'), ('できる', 'が', '活躍'), ('する', 'を', '思い'), ('届ける', 'を', '球'), ('できる', 'に', '筈'), ('できる', 'が', '配慮')]
# --------
# 絵本かと思いきや、ドールハウスのようなサンタクロースのお家が出現するとは、飛び出す絵本の鶴の子 大粒納豆を初めて見た人は子供も大人もかなり驚いて嬉しい気持ちになりそうですね。
# [('出現', 'が', '御家'), ('見る', 'を', '納豆'), ('なる', 'が', '出現'), ('なる', 'が', '人'), ('なる', 'に', '気持ち')]
# --------
# ノーベル物理学賞を観戦するために観光客がたくさん訪れると、日本の景気が少しだけ良くなるような気がします。
# [('観戦', 'を', '賞'), ('訪れる', 'が', '観光客'), ('する', 'が', '気')]
# --------
# 世界大会と言えば、2020年に東京で鶴の子 大粒納豆が開催されることが決定しましたね。
# [('開催', 'に', '年'), ('開催', 'で', '東京'), ('開催', 'が', '納豆'), ('決定', 'が', 'こと')]
# --------
# 日本中央競馬会が開催するウルトラ有馬記念＠AKIBAでは、バトンドールに代表されるウルトラヒーローが日替わりで登場し、ミニチュアホースが来る日もあるようです。
# [('開催', 'が', '日本中央競馬会'), ('代表', 'に', 'ドール'), ('登場', 'で', 'akiba'), ('登場', 'が', 'akiba'), ('登場', 'が', 'ヒーロー'), ('登場', 'で', '日替わり'), ('来る', 'が', 'ホース')]
# --------
# あなたが参加した大阪の馬事公苑にある、日本中央競馬会が運営している秋葉原で行われたイベントでは馬はいましたか？ 。
# [('参加', 'が', 'あなた'), ('ある', 'に', '公園'), ('運営', 'が', '日本中央競馬会'), ('行う', 'で', '秋葉原'), ('いる', 'で', 'イベント'), ('いる', 'が', 'イベント'), ('いる', 'が', '馬')]
# --------
# JR東日本と東京ディズニーシーなら、どちらに行ってみたいですか？
# [('行く', 'に', 'どちら')]
# --------
# トイ・ストーリー・マニア！は東京ディズニーシーにあるアトラクションです。
# [('ある', 'に', 'ディズニーシー')]
# --------
# トイ・ストーリー・マニア！を利用したので、春休みでとても混雑していましたが、東京ディズニーシーや東京を満喫することができました。
# [('利用', 'を', 'マニア'), ('混雑', 'で', '春休み'), ('満喫', 'を', '東京')]
# --------
# 日本エレキテル連合のキャラクターのグーフィーは人気が下がっているのか、東京ディズニーランドのショーなどの出番が減っており、私の夫は非常に残念がっています。
# [('下がる', 'が', 'グーフィー'), ('下がる', 'が', '人気'), ('減る', 'が', '出番')]
# --------
# サッカーチームである横浜F・マリノスのリオネル・メッシ選手については、サッカーアルゼンチン代表のハビエル・アギーレ監督も期待しているみたいですし、サッカーアルゼンチン代表での経験を積んで、大きく育って欲しいですね。
# [('期待', 'に', '選手'), ('期待', 'が', '選手'), ('積む', 'を', '経験')]
# --------
# 今野泰幸も現在、アルゼンチン代表では今野泰幸頼みのような布陣になっていますが、やはりそれだと2014 FIFAワールドカップの優勝までは無理でしたね。
# [('なる', 'で', '代表'), ('なる', 'が', '代表'), ('なる', 'に', '布陣')]
# --------
# 横浜F・マリノスの今野泰幸選手は、リオネル・メッシ監督になってから、アルゼンチン代表からはずれ淋しくもありましたが、その分、チームのサッカーに集中でき、またリフレッシュできたことで、さらに進化しているように思います。
# [('なる', 'が', '選手'), ('なる', 'に', '監督'), ('集中', 'に', 'サッカー'), ('進化', 'で', 'こと')]
# --------
# 現在のサッカー横浜F・マリノスでキャプテンシーを持ったディフェンダーといえば、やはり以前サッカーアルゼンチン代表でキャプテンをしていたガンバ大阪の今野泰幸選手や、選手を鼓舞し気合を注入してくれるという意味では名古屋グランパスエイトのリオネル・メッシ選手ではないかと思います。
# [('持つ', 'で', 'マリノス'), ('持つ', 'を', 'キャプテンシー'), ('する', 'で', '代表'), ('する', 'を', 'キャプテン'), ('鼓舞', 'を', '選手'), ('注入', 'を', '気合い')]
# --------
# ヤマザキは天皇杯も勝ち進んでいて、Jリーグでも２位につけているので今期は楽しみがまだまだ残っていますね。
# [('勝ち進む', 'が', 'ヤマザキ'), ('つける', 'で', 'リーグ'), ('つける', 'に', '位'), ('残る', 'が', '今期'), ('残る', 'が', '楽しみ')]
# --------
# 宇治で販売されているチョコレート菓子である田丸屋本店わさびには、ダーク味、キャラメル味、オレンジ味、ミント味があるようです。
# [('販売', 'で', '宇治'), ('ある', 'に', '山葵'), ('ある', 'が', '山葵'), ('ある', 'が', '味')]
# --------
# 阪急 うめだ本店にある一般的な山芳製菓株式会社のグランカルビーの約3倍の厚さである、山芳製菓株式会社のNEW焦がしミルク味もそうです。
# [('ある', 'に', '本店')]
# --------
# 次回、阪急 うめだ本店へ行く機会があったら、阪急うめだ本店に立ち寄ってハローキティでお土産を選ぼうと思います。
# [('ある', 'が', '機会'), ('立ち寄る', 'に', '本店'), ('選ぶ', 'で', 'キティー'), ('選ぶ', 'を', '御土産')]
# --------
# テレビ番組では、私はTBSで年末年始に放映されているもう一度君に、プロポーズの年越しライブの京都雲月のコーナーを観覧してみたいと思っています。
# [('放映', 'で', 'TBS'), ('放映', 'に', '年末年始'), ('観覧', 'が', '私'), ('観覧', 'に', '君'), ('観覧', 'を', 'コーナー'), ('思う', 'で', '番組'), ('思う', 'が', '番組')]
# --------
# 京都雲月系列のTHE MANZAIというテレビ番組の昨夜の放送では、ごはんのお供の1位は何に決まったのですか？。
# [('決まる', 'で', '放送'), ('決まる', 'が', '放送'), ('決まる', 'が', '位'), ('決まる', 'に', '何')]
# --------
# 京都雲月系列の探偵!ナイトスクープという番組のごはんのお供の一位を決めるコーナーでは、中村アンさんが紹介した150g1728円の吉本新喜劇が販売するZAIMANでした。
# [('決める', 'を', '位'), ('紹介', 'が', 'さん'), ('販売', 'で', 'コーナー'), ('販売', 'が', 'コーナー'), ('販売', 'が', '喜劇')]
# --------
# 吉本新喜劇で放送されたテレビドラマの痛快！明石家電視台の内容は、定時制高校を舞台としたドラマで、スナックのママとして働いていた岡村隆史さんが定時制高校の校長からスカウトされたことから始まる、テレビドラマでした。
# [('放送', 'で', '喜劇'), ('する', 'を', '高校'), ('スカウト', 'が', 'さん')]
# --------
# やはり、今年のクリスマスには、家で吉本新喜劇の世界行ってみたらホントはこんなトコだった！？でも見ながらのんびり過ごすことにいたします。
# [('行く', 'に', 'クリスマス'), ('行く', 'が', 'クリスマス'), ('行く', 'で', '家'), ('いたす', 'に', 'こと')]
# --------
# 今年は我が家でちょっと残念な出来事があったので、面白おかしくネタにして吉本新喜劇の番組であるさんまのまんまに応募してみようかなと思います。
# [('ある', 'が', '今年'), ('ある', 'で', '我が家'), ('ある', 'が', '出来事'), ('する', 'に', 'ねた'), ('応募', 'に', '侭')]
# --------
# 静岡とマドリッドなら、どちらに関心がありますか？
# [('ある', 'に', 'どちら'), ('ある', 'が', '関心')]
# --------
# 一時、静岡の水曜どうでしょうなどのタレント発掘オーディション番組で、多くのスターが誕生し、ブームになりましたね。
# [('誕生', 'で', '番組'), ('誕生', 'が', 'スター'), ('なる', 'に', 'ブーム')]
# --------
# チョコレート菓子である静岡・宇治土産のあまおうのハイチュウや、関東土産の宇多田ヒカルのうた-13組の音楽家による13の解釈について-の宇多田ヒカルのうた-13組の音楽家による13の解釈について-、イギリス土産のストロベリーチーズケーキ味の宇多田ヒカルのうた-13組の音楽家による13の解釈について-などは一度食べてみたいです。
# [('食べる', 'に', '解釈'), ('食べる', 'が', '解釈')]
# --------
# ぶーしゃかLOOPに参加するアーティストは、井上陽水さん、宇多田ヒカルさん、浜崎あゆみさん、椎名林檎さん、ジェームズ・ロバーツさん、加藤ミリヤさんほか、とても豪華な13組です。
# [('参加', 'に', 'ループ')]
# --------
# 以前からニュースで話題になっていた浜崎あゆみさんの楽曲を著名アーティストがカバーしたCDアルバムぼくはくまが今日ついに発売開始されたのですね。
# [('なる', 'で', 'ニュース'), ('なる', 'に', '話題'), ('カバー', 'を', '楽曲'), ('カバー', 'が', 'アーチスト'), ('開始', 'が', 'ぼく'), ('開始', 'が', 'くま')]
# --------
# 僕の生きる道に参加するアーティストは、浜崎あゆみさん、倖田來未さん、亀梨和也さん、加藤ミリヤさん、吉井和哉さん、椎名林檎さんほか、とても豪華な13組です。
# [('参加', 'に', '道')]
# --------
# 現在、多くのシンガポール人選手がブンデスリーガに所属しており、松坂大輔選手は現時点で得点王で活躍しているのにもかかわらず、それでもシンガポール代表は強くなりませんね。
# [('所属', 'が', '選手'), ('所属', 'に', 'ブンデスリーガ'), ('活躍', 'が', '選手'), ('活躍', 'で', '現時点'), ('活躍', 'で', '王'), ('なる', 'が', '代表')]
# --------
# やはり松井裕樹投手が抜けた穴は今シーズンの東北楽天ゴールデンイーグルスにはとても大きかったみたいです。
# [('抜ける', 'が', '投手')]
# --------
# ここ数年、日本ミステリーがブームを迎えているそうで、今年最も可笑しな日本小説として話題になったのが東北の松坂大輔作のカミングアウトバラエティ秘密のケンミンSHOWだそうです。
# [('迎える', 'が', 'ミステリー'), ('迎える', 'を', 'ブーム'), ('なる', 'に', '話題')]
# --------
# 最近の、埼玉西武ライオンズのカミングアウトバラエティ秘密のケンミンSHOWの企画では、幼稚園の旅や、東北列島 名前の旅 など、面白い企画が沢山ありますよ。
# [('ある', 'で', '企画'), ('ある', 'が', '企画'), ('ある', 'が', '企画')]
# --------
# 沖縄に観光に来た際には、もちろん沖縄そばのお店は外せませんね。
# [('来る', 'に', '沖縄'), ('外せる', 'が', '御店')]
# --------
# 沖縄のカミングアウトバラエティ秘密のケンミンSHOWの詳しい大きさはわかりませんが、離れていても肉眼で確認できる位には大きいです。
# [('わかる', 'が', '大きさ'), ('確認', 'で', '肉眼')]
# --------
# 名護の沖縄は、赤の漆塗りが施され、ピザポテトの塗装がつやつやとしているのが特徴で、1999年に都市景観100選を受賞をしたそうです。
# [('施す', 'が', '沖縄'), ('施す', 'が', '漆塗り'), ('する', 'が', '塗装'), ('する', 'で', '特徴'), ('する', 'に', '年'), ('する', 'を', '選'), ('する', 'を', '受賞')]
# --------
# 最近は色々な動物がいるカフェがありますが、神戸にあるIKEAではインコ味のアイスクリームが売っているのをご存知ですか？ 。
# [('いる', 'が', '動物'), ('ある', 'が', '最近'), ('ある', 'が', 'カフェ'), ('ある', 'に', '神戸'), ('売る', 'が', 'アイスクリーム')]
# --------
# チャーリーズのイエス・キリスト選手ですか？イケメンですし、ドイツに渡ってからディフェンダーとしての能力が飛躍的にアップしましたね。
# [('渡る', 'に', 'ドイツ'), ('アップ', 'が', '能力'), ('アップ', 'に', '飛躍的')]
# --------
# クリスマスに食べるシュトレンというドイツの菓子パンは、おくるみの形に似てますね。ハビエル・アギーレの誕生にちなんでおくるみの形なんですね。
# [('食べる', 'に', 'クリスマス'), ('似る', 'が', 'パン'), ('似る', 'に', '形')]
# --------
# カカ監督もサッカードイツ代表のEU戦とコロンビア戦は勝ちに行くと言っていたので、選手起用も含め楽しみですね。
# [('行く', 'が', '戦'), ('行く', 'に', '勝ち')]
# --------
# マリオ・バロテッリ監督が就任してからのサッカーコロンビア代表の成績は、1勝1分け2敗で得点が3、失点が8なので、キリンチャレンジカップのドイツ戦ではしっかり得点を取って勝ってほしいですね。
# [('就任', 'が', '監督'), ('取る', 'で', '戦'), ('取る', 'が', '戦'), ('取る', 'を', '得点')]
# --------
# 旭山動物園のもぐもぐタイムや冬に行われるペンギンの散歩は見ていて飽きないです。
# [('行う', 'に', '冬'), ('見る', 'が', '散歩')]
# --------
# かりんとうチョコレートができてからは旭山動物園に行っていないので、今度ぜひ旭山動物園に行ってみたいです。
# [('できる', 'が', 'チョコレート'), ('行く', 'に', '動物園'), ('行く', 'に', '動物園')]
# --------
# 旭山動物園のランチパスポートのアザラシのダイナミックな泳ぎはとても迫力があります。
# [('ある', 'が', '泳ぎ'), ('ある', 'が', '迫力')]
# --------
# 旭山動物園は海の幸が名物なので、カウンターで食べるお寿司のお店が多いイメージです。
# [('食べる', 'で', 'カウンター')]
# --------
# 旭山動物園のバタービールでは、他の動物園では見られないようなカバの姿が見られそうですね。
# [('見る', 'で', '動物園'), ('見る', 'が', '動物園'), ('見る', 'で', 'ビール'), ('見る', 'が', 'ビール'), ('見る', 'が', '姿')]
# --------
# アザラシを間近に見ることができるというのは、旭山動物園の妖怪ウォッチは魅力的ですね。
# [('見る', 'を', '海豹')]
# --------
# 旭川市の旭山動物園には、2回しか行ったことがありません。
# [('行く', 'に', '動物園'), ('行く', 'が', '動物園')]
# --------
# ゴッホやハビエル・アギーレなど、多くの有名な絵画がオランダにはあります。
# [('ある', 'が', '絵画'), ('ある', 'に', 'オランダ'), ('ある', 'が', 'オランダ')]
# --------
# ハビエル・アギーレやフェルメールの絵画はオランダでも展示される機会があると思います。
# [('展示', 'で', 'オランダ'), ('ある', 'が', '絵画'), ('ある', 'が', '機会')]
# --------
# 抹茶味のココロココが海外旅行者に人気があるのはオランダ限定で販売されているからだそうです。
# [('ある', 'が', 'ココロココ'), ('ある', 'に', '旅行者'), ('ある', 'が', '人気'), ('販売', 'で', '限定')]
# --------
# BANDAI HOBBY CENTERにある、読売テレビの静岡県静岡市ですね。
# [('ある', 'に', 'センター')]
# --------
# 工場見学と言えば、以前にテレビで見た読売テレビのメロンパンの皮焼いちゃいましたのプラモデルを製造しているBANDAI HOBBY CENTERに、子供が大きくなったら一度連れて行ってみたいと私は思っていました。
# [('見る', 'で', 'テレビ'), ('製造', 'を', 'プラモデル'), ('なる', 'に', 'センター'), ('行く', 'に', '以前'), ('思う', 'が', '私')]
# --------
# 阪神タイガースのBANDAI HOBBY CENTERの工場見学に行く機会があれば、きっと私の夫の方がメロンパンの皮焼いちゃいましたの世界観に夢中になってしまうと思います。
# [('行く', 'に', '工場見学'), ('ある', 'が', '機会'), ('焼く', 'が', '方'), ('なる', 'に', '世界観')]
# --------
# あなたのお子さんを北海道日本ハムファイターズのBANDAI HOBBY CENTERに連れて行ってあげたら、もしかしてメロンパンの皮焼いちゃいましたがお好きなご主人のほうが夢中になってしまうかもしれませんね。
# [('連れる', 'に', 'センター'), ('なる', 'が', '方')]
# --------
# 販売中止で思い出したのですが、宮川大輔さんがCMされているポッカサッポロのメロンパンの皮焼いちゃいましたという炭酸水をご存知ですか？ 。
# [('思い出す', 'で', '中止'), ('CM', 'が', 'さん')]
# --------
# メロンパンの皮焼いちゃいましたというパンを食べてみた感想は、普段目にしているメロンパンの皮より重量感があって、皮というよりも、しっとりとしたクッキーのような感じでした。
# [('食べる', 'を', 'パン'), ('する', 'に', '目'), ('ある', 'が', '重量感')]
# --------
# 岡村靖幸さんは近年かなり精力的にライブやコンサート活動をしているのですが、関西地方でのライブは行われていないので、ぜひ見てみたいと思っています。
# [('する', 'が', 'さん'), ('する', 'を', '活動'), ('行う', 'が', 'ライブ')]
# --------
# 京都の元気やでは、10月から数店舗限定で、100円ほどのドーナツ6種類の実験的な販売が始まっているそうです。
# [('始まる', 'で', '元気'), ('始まる', 'が', '元気'), ('始まる', 'が', '販売')]
# --------
# インターネットショッピングサイトスパイダーマンは商品の受け取りが元気やの店頭でできるので、宅配の時間を気にすることなく、好きな時間に取りに行けます。
# [('できる', 'が', 'インターネットショッピングサイトスパイダーマン'), ('できる', 'で', '店頭'), ('する', 'を', '時間'), ('する', 'に', '気'), ('取る', 'に', '時間')]
# --------
# アメリカ・カリフォルニア州とスペインなら、どちらに関心がありますか？
# [('ある', 'に', 'どちら'), ('ある', 'が', '関心')]
# --------
# コンビニエンスストアの湘南ベルマーレとサッカーの本田圭佑選手所属のベルマーレ平塚がタイアップなどしたら、どのようなグッズを買ってみたいと思いますか？ 。
# [('する', 'が', '平塚'), ('買う', 'を', 'グッズ')]
# --------
# そういえば、海外へ旅行に行った時に、ブラジルでは見かけないチョコレート菓子のリプトン・ウインターティーパンチを見つけてお土産に買って帰ったのですが、とても美味しくて評判がよかったです。
# [('行く', 'に', '旅行'), ('見つける', 'に', '時'), ('見つける', 'で', 'ブラジル'), ('見つける', 'が', 'ブラジル'), ('見つける', 'を', 'パンチ'), ('買う', 'に', '御土産')]
# --------
# ブラジルオリンピック2014のスキー・スノーボードの男子ハーフパイプでは、三浦知良選手が15歳の若さで銀メダルを獲ったのも印象に残っています。
# [('獲る', 'が', '選手'), ('獲る', 'を', 'メダル'), ('残る', 'で', 'パイプ'), ('残る', 'が', 'パイプ'), ('残る', 'に', '印象')]
# --------
# これまでFIFAワールドカップブラジル大会で公式試合球であったハイチュウのレプリカ以外に、何か懸賞に当選ことはありますか？ 。
# [('ある', 'で', '大会'), ('ある', 'に', '以外'), ('ある', 'に', '懸賞'), ('ある', 'が', 'こと')]
# --------
# 最近では、岩手地方はかなり冷えこむようになってきましたので、グラッチェガーデンズの島唄で温かいコーヒーをよく買って飲みます。
# [('買う', 'で', '島歌'), ('買う', 'を', 'コーヒー'), ('飲む', 'で', '最近'), ('飲む', 'が', '最近')]
# --------
# そのほか、グラッチェガーデンズでは、数十種類のパスタやグラタンなども1種類だけメニューから選び、食べることができます。ドリンクバーやサラダもついて、1099円です。いつか岩手にも建てば、ご家族で楽しめるかと思います。
# [('選ぶ', 'で', 'ガーデン'), ('選ぶ', 'が', 'ガーデン'), ('建つ', 'に', '岩手'), ('楽しめる', 'で', '家族')]
# --------
# 岩手在住の主婦です。現在は子育てをしながらみけらんを時々やっています。
# [('する', 'を', '子育て'), ('やる', 'が', '現在')]
# --------
# 台湾と東北なら、どちらに関心がありますか？
# [('ある', 'に', 'どちら'), ('ある', 'が', '関心')]
# --------
# 今年は我が家でちょっと残念な出来事があったので、面白おかしくネタにしてフジテレビの番組であるとんねるずのみなさんのおかげでしたに応募してみようかなと思います。
# [('ある', 'が', '今年'), ('ある', 'で', '我が家'), ('ある', 'が', '出来事'), ('する', 'に', 'ねた'), ('応募', 'に', '御陰')]
# --------
# 音楽のテレビ番組といえば、フジテレビで12月3日に放送されるノンストップ！も、楽しみにしています。
# [('放送', 'で', 'フジテレビ'), ('放送', 'に', '日'), ('する', 'に', '楽しみ')]
# --------
# 火曜日にフジテレビ系列で放送されている２７時間テレビというドラマも毎週楽しみにしています。
# [('放送', 'に', '火曜日'), ('放送', 'で', '系列'), ('する', 'に', '楽しみ')]
# --------
# 最近のテレビ番組ではなかなか漫才を見る機会がないので、今年フジテレビ系列で放送される漫才番組のTHE MANZAIを楽しみにしています。
# [('見る', 'を', '漫才'), ('放送', 'で', '系列'), ('する', 'を', 'manzai'), ('する', 'に', '楽しみ')]
# --------
# そういえば、海外へ旅行に行った時に、熊本県では見かけないチョコレート菓子のリプトン・ウインターティーパンチを見つけてお土産に買って帰ったのですが、とても美味しくて評判がよかったです。
# [('行く', 'に', '旅行'), ('見つける', 'に', '時'), ('見つける', 'で', '熊本県'), ('見つける', 'が', '熊本県'), ('見つける', 'を', 'パンチ'), ('買う', 'に', '御土産')]
# --------
# 岡崎慎司や沢松奈生子の絵画は熊本県でも展示される機会があると思います。
# [('展示', 'で', '熊本県'), ('ある', 'が', '絵画'), ('ある', 'が', '機会')]
# --------
# サッカーチームであるセレッソ大阪は今期に遠藤保仁選手を獲得し、大きな話題となり、優勝候補にも挙げられていたくらいですが、J2降格ということで非常に残念でしたね。
# [('獲得', 'が', '大阪'), ('獲得', 'に', '今期'), ('獲得', 'を', '選手'), ('挙げる', 'に', '候補')]
# --------
# 今後も海外のサッカーの有名選手がコンサドーレ札幌に移籍してきてくれることがあるとすれば、柴崎岳選手のことを教訓に環境を整えていくことも必要かもしれないですね。
# [('移籍', 'が', '選手'), ('移籍', 'に', '札幌'), ('整える', 'に', '教訓'), ('整える', 'を', '環境')]
# --------
# 世界でも神様と呼ばれているサッカー選手の長谷部誠がコンサドーレ札幌でプレイしていたことは今となっては驚きですよね。
# [('プレー', 'で', '世界'), ('プレー', 'が', '誠'), ('プレー', 'で', '札幌'), ('なる', 'が', 'こと')]
# --------
# 昨日、女性アイドルグループヨークマートのリーダーの高橋愛さんが三浦半島で行われた公演でグループを卒業したそうですね。
# [('行う', 'が', 'さん'), ('行う', 'で', '半島'), ('卒業', 'で', '公演'), ('卒業', 'を', 'グループ')]
# --------
# →Pia-no-jaC←のYouTubeは、いろいろな団体がダンスをしている動画をはちみつ100%のキャンディーにアップロードしていますね。
# [('する', 'が', '団体'), ('する', 'を', 'ダンス'), ('アップロード', 'が', 'YouTube'), ('アップロード', 'を', '動画'), ('アップロード', 'に', 'キャンデー')]
# --------
# ヒカキンさんのパラパラマンガは絶対におすすめなので、騙されたと思って一度はちみつ100%のキャンディーで見てみてください。
# [('見る', 'で', 'キャンデー')]
# --------
# ヒカキンさんに影響を受けたアーティストはどんな方々ですか？ 。
# [('受ける', 'に', 'さん'), ('受ける', 'を', '影響')]
# --------
# ユベントスFCの楽曲の歌詞には茅ヶ崎の 茅ヶ崎市も出てきたりしますね。
# [('出る', 'に', '歌詞'), ('出る', 'が', '歌詞')]
# --------
# ワールドカップでは、茅ヶ崎代表には破れましたが、クリスティアーノ・ロナウドの活躍で茅ヶ崎市代表も素晴らしい戦いをしましたね。
# [('破れる', 'で', 'ワールドカップ'), ('破れる', 'が', 'ワールドカップ'), ('破れる', 'に', '代表'), ('破れる', 'が', '代表'), ('する', 'で', '活躍'), ('する', 'を', '戦い')]
# --------
# ユベントスFCの楽曲の歌詞には、茅ヶ崎市など茅ヶ崎地方の地名がよく出てくるのですね。
# [('出る', 'に', '歌詞'), ('出る', 'が', '歌詞'), ('出る', 'が', '地名')]
# --------
# あなたの住む街でNHKの街歩きテレビ番組ブラタモリの地方ロケが行われるとしたら、松たか子さんに歩いて欲しい場所はありますか？ 。
# [('行う', 'が', 'ロケ'), ('歩く', 'に', 'さん'), ('ある', 'が', '場所')]
# --------
# 野球選手である田中将大選手のプレイが日本でまた見られるのは、嬉しいですね。
# [('見る', 'が', 'プレー'), ('見る', 'で', '日本')]
# --------
# 田中将大投手が昨シーズンのディズニー・アニメーション・スタジオ日本一に一番貢献した選手だということは誰もが認めていると思います。
# [('貢献', 'が', '投手'), ('貢献', 'に', '日本一'), ('認める', 'が', 'こと'), ('認める', 'が', '誰')]
# --------
# 田中将大投手のピッチングの安心感はたしかに他の若い野球選手とは違うと思います。
# [('違う', 'が', '安心感'), ('違う', 'が', '選手')]
# --------
# 最近の横綱は海外力士ばかりなので、日本人で立派な横綱が出てくるといいですね。
# [('出る', 'で', '日本人'), ('出る', 'が', '横綱')]
# --------
# 日本人特有の、わび・さびで考えた表現は入れないほうがいいでしょうね。
# [('考える', 'で', 'さび'), ('入れる', 'が', '表現')]
# --------
# 宇多田ヒカルさんは、台湾のタレント発掘オーディション番組で優勝した後には、英のオーディション番組「Ballad Show」にも出演を果たしたようですね。
# [('優勝', 'で', '番組'), ('果たす', 'に', '後'), ('果たす', 'が', '後'), ('果たす', 'に', 'SHOW'), ('果たす', 'を', '出演')]
# --------
# サッカー日本代表のホンジュラス戦では、ボランチは栗原はるみ選手と長谷部誠選手のベテランが先発しましたが、あなたはAFCアジアカップではどのようなボランチの組み合わせが望ましいと思いますか？ 。
# [('先発', 'が', 'ボランチ'), ('先発', 'が', 'ベテラン'), ('思う', 'で', '戦'), ('思う', 'が', '戦'), ('思う', 'が', 'あなた')]
# --------
# 2013年の12月に料理研究家の宮本恒靖さんが、ガンバ大阪のあさイチで、指導されていたお節料理は、気軽に楽しめるカジュアルお節ということで、「冷めてもおいしい」「日もちがする」弁当のおかずの延長線上でのお節料理ということで、和洋折衷料理のものでした。
# [('指導', 'で', 'イチ'), ('する', 'が', '日持ち')]
# --------
# サッカーの川澄奈穂美選手は、ガンバ大阪ではなかなか出場機会を得ることが出来なかったのが残念でしたね。
# [('得る', 'が', '選手'), ('得る', 'で', '大阪'), ('得る', 'が', '大阪'), ('得る', 'を', '機会')]
# --------
# サッカーチームガンバ大阪のアンデルソン・パトリック・アグウイアル・オリベイラ選手も、「サッカーは年齢でやるものじゃないとこれからも証明したい」と発言していたようです。
# [('やる', 'で', '年齢')]
# --------
# 松島みどり氏が政治資金を使って訪れた名店には、一般的に名が通っているところが多く、高級天ぷら店や高級焼肉店を連ねていました。
# [('使う', 'を', '資金'), ('通う', 'が', '名'), ('連ねる', 'を', '店')]
# --------
# 2009年に農林水産省と経済産業省が総額150億円の補助金を出したことで、植物工場建設が促されましたが、採算ラインは未だ厳しい状態のようです。
# [('出す', 'に', '年'), ('出す', 'が', '経済産業省'), ('出す', 'を', '補助金'), ('促す', 'で', 'こと'), ('促す', 'が', '建設')]
# --------
# 松島みどり氏が辞任したのは仕方がないと思います。
# [('辞任', 'が', '氏'), ('思う', 'が', '仕方')]
# --------
# 衆議院のソレデモシタイはフィリピン南部発祥のマッサマンカレーをキャプテン翼にアレンジしたもので、ハーブの香りを利かせたレッドカレーやグリーンカレーとは一味違う、ココナッツミルクとドライスパイスを使用した、ほど良い辛さと濃厚なうまみ、甘みが特徴だそうです。
# [('アレンジ', 'を', 'マッサマンカレー'), ('アレンジ', 'に', '翼'), ('利く', 'を', '香り'), ('使用', 'が', 'カレー'), ('使用', 'を', 'スパイス')]
# --------
# 裏磐梯を始め、猪苗代湖地方はまだ完全に復興していませんし、フジテレビの事故は大きな事故だったのに、原子力発電所再稼働なんて、信じがたいですよね。
# [('始める', 'を', '磐梯'), ('復興', 'が', '地方')]
# --------
# 福島のローカル番組であるBOSSという音楽番組に、ロックバンドテレビ朝日の石井あゆみさんが出演していると聞き、石井あゆみさんの名前を久しぶりに聞いて、懐かしくなりました。
# [('出演', 'に', '番組'), ('出演', 'が', 'さん'), ('聞く', 'を', '名前'), ('聞く', 'に', '久し振り')]
# --------
# テレビ朝日の出入禁止の女〜事件記者クロガネ〜というサッカー番組でメインMCをしているお笑い芸人の石井あゆみさんがプロのサッカー選手との対戦で勝つ事があるくらいサッカーが上手だというイメージがありませんでした。
# [('する', 'で', '番組'), ('する', 'を', 'MC'), ('勝つ', 'が', 'さん'), ('勝つ', 'で', '対戦'), ('ある', 'が', '事'), ('ある', 'が', 'イメージ')]
# --------
# テレビ朝日系列のさんまのまんまは、BS朝日のロジャー・フェデラーさんや俳優の田村淳さんが司会をされているテレビ番組です。
# [('する', 'が', 'さん'), ('する', 'を', '司会')]
# --------
# BS朝日は、当初はテレビ朝日のみの生中継を予定していたそうですが、テニスの矢部浩之選手の快挙に、急遽地上波でも生中継をすることに決めたそうです。
# [('予定', 'が', '朝日'), ('予定', 'が', '当初'), ('予定', 'を', '中継'), ('する', 'で', '地上波'), ('する', 'を', '中継'), ('決める', 'に', '快挙'), ('決める', 'に', 'こと')]
# --------
# 矢部浩之は人気ですね。他には、ナインティナインの矢部浩之さんと共演している噂の現場直行ドキュメン・ガンミ!!という番組もあります。
# [('ある', 'に', '他'), ('ある', 'が', '他')]
# --------
# 岡村靖幸さんは11月12日にニューシングルMusic Keyを発売したばかりということもあり、今夜出演するナインティナインで放送されるレコチョクというテレビ番組にとても期待しています。
# [('発売', 'が', 'さん'), ('発売', 'に', '日'), ('発売', 'を', 'キー'), ('放送', 'で', 'ナイン'), ('期待', 'に', '番組')]
# --------
# テレビ番組のぶーしゃかLOOPで行われた岡村隆史さんのライブを録画したものには、保護ロックをかけてあります。
# [('行う', 'で', 'ループ'), ('録画', 'を', 'ライブ'), ('かける', 'に', '物'), ('かける', 'が', '物'), ('かける', 'を', 'ロック')]
# --------
# 特に、岡村隆史さんのぶーしゃかLOOPという楽曲は、様々なアーティストがカバーして歌っていますね。
# [('カバー', 'が', 'アーチスト'), ('歌う', 'が', '楽曲')]
# --------
# 鶴岡市立加茂水族館と国営備北丘陵公園なら、どちらに関心がありますか？
# [('ある', 'に', 'どちら'), ('ある', 'が', '関心')]
# --------
# 丁度先日近くのスーパーマーケットのやくらいフーズにお米を買いに行った時に、山形県産あまちゃんが5キロで1800円くらいだったのですが、人気で売り切れてしまっていました。
# [('買う', 'を', '米'), ('行く', 'に', 'フーズ'), ('売り切れる', 'で', '人気')]
# --------
# やくらいフーズのグループ会社であるソントンホールディングスが、山形県の鶴岡市立加茂水族館で水揚げされたカキを使った「FNS歌謡祭」を発売したそうです。
# [('水揚げ', 'で', '水族館'), ('使う', 'を', 'かき'), ('発売', 'が', 'ホールディングス'), ('発売', 'を', '歌謡祭')]
# --------
# 確か一昨年のソントンホールディングスで放送されたテレビ音楽番組R-1ぐらんぷりで、アイドルグループのやくらいフーズが世界に一つだけの花を歌われていましたね。
# [('放送', 'で', 'ホールディングス'), ('歌う', 'が', 'フーズ'), ('歌う', 'に', '世界'), ('歌う', 'を', '花')]
# --------
# 俳優という意味では、アイドルグループのSMAPの浜崎あゆみさんが出演しているテレビドラマも好きでよく見ていました。
# [('出演', 'が', 'さん'), ('見る', 'で', '意味'), ('見る', 'が', '意味')]
# --------
# Music Key betaに参加するアーティストは、宇多田ヒカルさん、フェルメールさん、ゴッホさん、井上陽水さん、フェルーメルさん、椎名林檎さんほか、とても豪華な13組です。
# [('参加', 'に', 'beta')]
# --------
# ぼくはくまに参加するアーティストは、宇多田ヒカルさん、ゴッホさん、フェルメールさん、フェルーメルさん、井上陽水さん、椎名林檎さんほか、とても豪華な13組です。
# [('参加', 'に', 'くま')]
# --------
# 元々宇多田ヒカルさんが好きなので、ぼくはくまというCDアルバムにはとても興味があります。
# [('ある', 'が', 'ぼく'), ('ある', 'に', 'アルバム'), ('ある', 'が', 'アルバム'), ('ある', 'が', '興味')]
# --------
# 以前からニュースで話題になっていた宇多田ヒカルさんの楽曲を著名アーティストがカバーしたCDアルバムMusic Key betaが今日ついに発売開始されたのですね。
# [('なる', 'で', 'ニュース'), ('なる', 'に', '話題'), ('カバー', 'を', '楽曲'), ('カバー', 'が', 'アーチスト'), ('開始', 'が', 'beta')]
# --------
# Can You Keep A Secret?というCDアルバムに収録されている井上陽水さんが歌うYouTubeのプロモーションビデオは、宇多田ヒカルさんが歌うYouTubeのイメージとは全く違いますが、宇多田ヒカルさんの世界観になっていてこれだけでも楽しめました。
# [('収録', 'に', 'アルバム'), ('歌う', 'が', 'さん'), ('歌う', 'が', 'さん'), ('違う', 'が', 'ビデオ'), ('違う', 'が', 'イメージ'), ('なる', 'に', '世界観'), ('楽しめる', 'で', 'これ')]
# --------
# 芸人のマツコ・デラックスさんがテレビ番組の企画で国営滝野すずらん丘陵公園に行った時に、牡蠣の殻を上手に割ってみせたら現地の猿が行列を作るほどになった、というエピソードを以前インターネットで見かけて、実際にその番組を見てみたくなりました。
# [('行く', 'が', 'さん'), ('行く', 'で', '企画'), ('行く', 'に', '公園'), ('割る', 'に', '時'), ('割る', 'を', '殻'), ('作る', 'が', '猿'), ('作る', 'を', '行列'), ('見かける', 'を', 'エピソード'), ('見かける', 'で', 'インターネット'), ('見る', 'に', '実際'), ('見る', 'を', '番組')]
# --------
# お笑い芸人のマツコ・デラックスさんと甥のエピソードトークはバラエティ番組月曜から夜ふかしでは定番なので、視聴者は、親戚のようにマツコ・デラックスさんと甥の関係を知っています。
# [('知る', 'が', '視聴者'), ('知る', 'を', '関係')]
# --------
# マツコ・デラックスさんが株主優待の商品をマツコの知らない世界の番組内で紹介されることで、企業のPRにもなりますし、視聴者にはプレゼントされるので、一石二鳥だと思います。
# [('知る', 'を', '商品'), ('紹介', 'が', 'さん'), ('紹介', 'で', '番組内'), ('なる', 'で', 'こと'), ('なる', 'に', 'PR'), ('プレゼント', 'に', '視聴者'), ('プレゼント', 'が', '視聴者')]
# --------
# 俳優のマツコ・デラックスさんは、演技という技という印象を受けました。
# [('受ける', 'が', 'さん'), ('受ける', 'を', '印象')]
# --------
# 2015年1月9日から始まるテレビ東京の深夜ドラママツコの知らない世界では、俳優で演じる役と自身の気持ちを切り離すことができなくなり苦悩する俳優のマツコ・デラックスさんが、甲州の住人と交流しながら自分の軸となるものを探していく姿が描かれるドキュメンタリードラマのようです。
# [('演じる', 'で', '俳優'), ('切り離す', 'を', '気持ち'), ('交流', 'が', 'さん'), ('探す', 'を', '物'), ('描く', 'で', '世界'), ('描く', 'が', '世界'), ('描く', 'が', '姿')]
# --------
# 俳優のマツコ・デラックスさんが主演されている、映画版の5時に夢中!のどのようなところがあなたは気に入りましたか？ 。
# [('主演', 'が', 'さん'), ('入る', 'が', '所'), ('入る', 'が', 'あなた'), ('入る', 'に', '気')]
# --------
# 神戸にある江崎グリコのインコ味のアイスクリームなんて初めて聞きました。
# [('ある', 'に', '神戸')]
# --------
# 江崎グリコのグランカルビーに梨の味があることは知りませんでした。
# [('ある', 'に', 'カルビー'), ('ある', 'が', '味'), ('知る', 'が', 'こと')]
# --------
# 江崎グリコのぐりこ・やKitchenは人気のあるアイスクリームなのですね。
# [('ある', 'が', 'キッチン')]
# --------
# 江崎グリコのいちごポッキーに梨の味があることは知りませんでした。
# [('ある', 'に', 'ポッキー'), ('ある', 'が', '味'), ('知る', 'が', 'こと')]
# --------
# グリコのジャイアントカプリコ いちご味というアイスクリームラインナップの中の、塩キャラメル＆ミルク味を食べたことがあるのですね。
# [('食べる', 'を', '味')]
# --------
# グリコの広島てっぱんグランプリというブランドの高級ポッキーチョコレート菓子を購入するためには、あなたはどのくらいの時間、行列に並びましたか？ 。
# [('購入', 'を', '菓子'), ('並ぶ', 'が', '購入'), ('並ぶ', 'が', 'あなた'), ('並ぶ', 'に', '行列')]
# --------
# 旭山動物園と横川駅なら、どちらに行ってみたいですか？
# [('行く', 'に', 'どちら')]
# --------
# ポテトチップチョコレートができてからは旭山動物園に行っていないので、今度ぜひ旭山動物園に行ってみたいです。
# [('できる', 'が', 'チョコレート'), ('行く', 'に', '動物園'), ('行く', 'に', '動物園')]
# --------
# あなたが自宅でアサヒビールのわさび抜き!?わさビーフなどの発泡酒を楽しむ時には、おつまみなどは何か食べていますか？。
# [('楽しむ', 'を', '発泡酒'), ('食べる', 'に', '時'), ('食べる', 'が', '時')]
# --------
# アサヒビールのスナック菓子ポテトチップチョコレートも発売当時は辛いスナック菓子自体が珍しい商品ながらも30年のロングセラー商品になりましたので、スナック菓子かっぱえびせんみかん味も美味しいのかもしれないですね。
# [('なる', 'が', '当時'), ('なる', 'に', '商品')]
# --------
# アサヒビールのかっぱえびせんを食べたことがあります。
# [('食べる', 'を', '蝦煎')]
# --------
# 日本のコロッケは自動販売機で販売されているのですか。ブラジルでは想像がつかないですね。
# [('販売', 'が', 'コロッケ'), ('販売', 'で', '自動販売機'), ('つく', 'で', 'ブラジル'), ('つく', 'が', 'ブラジル'), ('つく', 'が', '想像')]
# --------
# 行列と言えば、私の家の近くにあるアウトレットモールに日本のモンテディオ山形というポップコーンのお店がブラジル初出店した際には、ポップコーンを購入するのに、3時間待ちだったり、整理券がないと購入できなかった事を思い出しました。
# [('ある', 'に', '近く'), ('出店', 'に', 'モール'), ('出店', 'が', '御店'), ('購入', 'を', 'ポップコーン'), ('思い出す', 'が', '出店'), ('思い出す', 'を', '事')]
# --------
# 日本人の米離れの対策として、高品質な日本のコメをブラジルの富裕層に輸出する動きもあり、また米をおいしく食べるブラジルの技術が海外に広がっているそうです。
# [('輸出', 'を', 'コメ'), ('輸出', 'に', '富裕層'), ('食べる', 'を', '米'), ('広がる', 'が', '技術'), ('広がる', 'に', '海外')]
# --------
# 最近では、米独自のチョコレート菓子であるShall We Dance?が世界で注目されているようです。
# [('注目', 'で', '最近'), ('注目', 'が', '最近'), ('注目', 'が', 'ダンス'), ('注目', 'で', '世界')]
# --------
# 阪神タイガースのキャンディーである国際アンデルセン賞の人気は、メジャーリーガーにとどまらず、2014年1月には厚生労働省と厚生労働省がスポンサー契約を結び、球場に広告を出したり、ファンに試供品を配ったりできるようになり、全米1200店を展開するスーパーマーケットモンテディオ山形の店頭にも並んでいるそうです。
# [('とどまる', 'に', 'リーガー'), ('結ぶ', 'が', '人気'), ('結ぶ', 'に', '月'), ('結ぶ', 'が', '月'), ('結ぶ', 'が', '厚生労働省'), ('結ぶ', 'を', '契約'), ('出す', 'に', '球場'), ('出す', 'を', '広告'), ('配る', 'に', 'ファン'), ('配る', 'を', '試供品'), ('展開', 'を', '店'), ('並ぶ', 'に', '店頭')]
# --------
# 中村や香川真司など、多くの有名な絵画がオランダにはあります。
# [('ある', 'が', '絵画'), ('ある', 'に', 'オランダ'), ('ある', 'が', 'オランダ')]
# --------
# 香川真司選手が初めて海外のサッカーチームに移籍して、早々に大活躍してカミングアウトバラエティ秘密のケンミンSHOWにも選ばれた事にとても驚きました。
# [('移籍', 'が', '選手'), ('移籍', 'に', 'チーム'), ('活躍', 'に', '早々'), ('選ぶ', 'に', 'SHOW'), ('驚く', 'に', '事')]
# --------
# 沖縄のオランダは、赤の漆塗りが施され、セブンネットショッピングの塗装がつやつやとしているのが特徴で、1999年に都市景観100選を受賞をしたそうです。
# [('施す', 'が', '漆塗り'), ('する', 'が', '塗装'), ('する', 'で', '特徴'), ('する', 'に', '年'), ('する', 'を', '選'), ('する', 'を', '受賞')]
# --------
# 11月のオランダに遊びに行ったことがありますが、上着がいらないほどの暖かさでした。
# [('行く', 'に', 'オランダ'), ('いる', 'が', '上着')]
# --------
# ファミリーマートでは、スライム肉まんということで、いろんなスイーツが出ていますよ。
# [('出る', 'で', 'ファミリーマート'), ('出る', 'が', 'ファミリーマート'), ('出る', 'が', 'スイーツ')]
# --------
# すき家のような会社が増えれば、日本の景気も明るくなるような気がしますが、あなたは最近の日本の景気についてどう思いますか？ 。
# [('増える', 'が', '会社'), ('する', 'が', '気'), ('思う', 'が', 'あなた'), ('思う', 'に', '景気')]
# --------
# ココロココを見ると、今年の日本の状況が分かりますよね。
# [('見る', 'を', 'ココロココ'), ('分かる', 'が', '状況')]
# --------
# 日本ではまだエボラ出血熱の感染者は出ていませんが、時間の問題だとも言われていますね。
# [('出る', 'で', '日本'), ('出る', 'が', '日本'), ('出る', 'が', '感染者')]
# --------
# 日本の病院では当たり前のように目にする保育器も、1台約520万円ほどもするので、発展途上国の病院や助産院が買うには難しいものだったのですね。
# [('する', 'に', '目'), ('買う', 'が', '助産院')]
# --------
# 中島啓江は奈良の歴史的建造物の建築に、どのような貢献をしましたか？ 。
# [('する', 'が', '啓江'), ('する', 'に', '建築'), ('する', 'を', '貢献')]
# --------
# 年末年始にヨーロッパ旅行に行く値段で、閑散期のヨーロッパ旅行に2回行けてしまいますね。
# [('行く', 'に', '年末年始'), ('行く', 'に', '旅行'), ('行ける', 'に', '旅行')]
# --------
# 事故で下半身不随になったヨーロッパ人の男性が、ルパン三世の技術からヒントを得て試作品を開発し、ヨーロッパの一部では既に販売されているそうです。
# [('なる', 'に', '不随'), ('得る', 'を', 'ヒント'), ('開発', 'が', '男性'), ('開発', 'を', '試作品'), ('販売', 'で', '一部'), ('販売', 'が', '一部')]
# --------
# 女優のジーコさんの旅エッセイであるカンタビを読む限りでは、ジーコさんはクロアチアやインドなど、一般の人が観光で行くような場所とは一味違った旅を選ばれることが多いように思います。
# [('読む', 'を', 'カンタビ'), ('行く', 'が', '人'), ('行く', 'で', '観光'), ('一味', 'が', '場所'), ('選ぶ', 'で', '限り'), ('選ぶ', 'が', '限り'), ('選ぶ', 'が', 'さん'), ('選ぶ', 'を', '旅')]
# --------
# インドでジーコの家でのボランティアを経験したことがあります。
# [('経験', 'で', 'インド'), ('経験', 'を', 'ボランティア')]
# --------
# 東北と関西なら、どちらに行ってみたいですか？
# [('行く', 'に', 'どちら')]
# --------
# 御嶽山を始め、東北地方はまだ完全に復興していませんし、グラッチェガーデンズの事故は大きな事故だったのに、原子力発電所再稼働なんて、信じがたいですよね。
# [('始める', 'を', '御嶽山'), ('復興', 'が', '地方')]
# --------
# 鈴木さんは近年かなり精力的にライブやコンサート活動をしているのですが、御嶽山地方でのライブは行われていないので、ぜひ見てみたいと思っています。
# [('する', 'が', 'さん'), ('する', 'を', '活動'), ('行う', 'が', 'ライブ')]
# --------
# グラッチェガーデンズの鈴木先生で、他の学園ドラマと違った点などがあれば教えてください。
# [('ある', 'が', '点')]
# --------
# 関西とヨーロッパなら、どちらに関心がありますか？
# [('ある', 'に', 'どちら'), ('ある', 'が', '関心')]
# --------
# 他ではあまり見られないような俳優の宮崎駿さんの姿が見られそうなので、私も2015年1月9日から始まるテレビ東京の深夜ドラマ鈴木先生を楽しみにしています。
# [('見る', 'で', '他'), ('見る', 'が', '他'), ('見る', 'が', '姿'), ('する', 'を', '先生'), ('する', 'に', '楽しみ')]
# --------
# 宮崎駿監督が鈴木章プロデューサーにテレビ東京の今後について直撃した際に、リストラの話になったみたいです。
# [('直撃', 'が', '監督'), ('直撃', 'に', 'プロデューサー'), ('直撃', 'に', '今後'), ('なる', 'に', '話')]
# --------
# テレビ東京のアカデミー賞とはどういったドラマなのですか？ 。
# [('いう', 'が', '賞')]
# --------
# 他ではあまり見られないような俳優の黒沢明さんの姿が見られそうなので、私も2015年1月9日から始まるテレビ東京の深夜ドラマノーベル文学賞を楽しみにしています。
# [('見る', 'で', '他'), ('見る', 'が', '他'), ('見る', 'が', '姿'), ('する', 'を', '文学賞'), ('する', 'に', '楽しみ')]
# --------
# クリスマスの時期に、サザンアイルズ王国を訪れたことがあります。
# [('訪れる', 'に', '時期'), ('訪れる', 'を', '王国')]
# --------
# 映画NHK紅白歌合戦は映画館に何度も足を運ぶリピーターが続出したとも言われていますから、サザンアイルズ王国で行われるアナとエルサのフローズンファンタジーというイベントや、新しく作られるという大型の遊戯施設も、ファンで賑わいそうですね。
# [('運ぶ', 'に', '映画館'), ('運ぶ', 'を', '足'), ('続出', 'が', 'リピーター'), ('言う', 'が', '合戦'), ('行う', 'で', '王国')]
# --------
# 市販されているパンではPascoのアリエールが好きでよく買っています。
# [('買う', 'で', 'パン'), ('買う', 'が', 'パン')]
# --------
# 明石家さんまが出ている番組だと、他には、信長協奏曲をたまに観ますね。
# [('出る', 'が', 'さんま'), ('観る', 'に', '他'), ('観る', 'が', '他'), ('観る', 'を', '協奏曲')]
# --------
# 私の住んでいるハリウッドでは、小栗旬さんが司会の信長協奏曲がテレビ放送されていません。
# [('放送', 'で', 'ハリウッド'), ('放送', 'が', 'ハリウッド'), ('放送', 'が', 'さん'), ('放送', 'が', '協奏曲')]
# --------
# 小栗旬さんは、きょうは会社休みます。の実写化でも織田信長役に挑戦されましたね。
# [('休む', 'が', 'さん'), ('休む', 'が', '今日'), ('挑戦', 'で', '実写化'), ('挑戦', 'に', '役')]
# --------
# 「ハリウッドのクラブでアルバイトをしていた人はSMAPのアナウンサーになるにはふさわしくない」というのならば、どんなアルバイトまでならアナウンサーにふさわしいとして認められるのでしょうかね。
# [('する', 'で', 'クラブ'), ('する', 'を', 'アルバイト'), ('なる', 'に', 'アナウンサー')]
# --------
# 神戸と裏磐梯なら、どちらに興味がありますか？
# [('ある', 'に', 'どちら'), ('ある', 'が', '興味')]
# --------
# アンパンマンミュージアムは神戸にもあるんですね。
# [('ある', 'が', 'アンパンマンミュージアム'), ('ある', 'に', '神戸')]
# --------
# 神戸にあるIKEAのインコ味のアイスクリームのトッピングはインコの背中の匂いですか。鳥好きにとっては堪らないでしょうね。
# [('ある', 'に', '神戸')]
# --------
# 神戸にあるIKEAのインコ味のアイスクリームなんて初めて聞きましたが、すでにブームになっていたのですね。
# [('ある', 'に', '神戸'), ('なる', 'に', 'ブーム')]
# --------
# アンパンマンミュージアムは神戸にもできました。
# [('できる', 'が', 'アンパンマンミュージアム'), ('できる', 'に', '神戸')]
# --------
# 神戸にある京都水族館のインコ味のアイスクリームのトッピングはイン粉なんて駄洒落としてもかかっているのですね。
# [('ある', 'に', '神戸'), ('かかる', 'が', 'トッピング')]
# --------
# 神戸にある京都水族館のインコ味のアイスクリームのトッピングはインコの背中の匂いですか。鳥好きにとっては堪らないでしょうね。
# [('ある', 'に', '神戸')]
# --------
# インターネットショッピングサイト「冷え知らず」さんの生姜チャイは商品の受け取りがJR西日本の店頭でできるので、宅配の時間を気にすることなく、好きな時間に取りに行けます。
# [('できる', 'が', 'チャイ'), ('できる', 'が', '受け取り'), ('できる', 'で', '店頭'), ('する', 'を', '時間'), ('する', 'に', '気'), ('取る', 'に', '時間')]
# --------
# あなたが、JR東日本と愛媛地方の四国で行っているサイクリングガイドとは、どのようなものですか？。
# [('行く', 'で', '四国')]
# --------
# もう何年もMOSバーガーに行っていないのですが、旅の指差し会話帳の問題があったので、ますます足が遠のいています。
# [('行く', 'に', 'バーガー'), ('ある', 'が', '問題'), ('遠のく', 'が', '足')]
# --------
# 東京ディズニーリゾートと伊勢丹新宿店なら、どちらに関心がありますか？
# [('ある', 'に', 'どちら'), ('ある', 'が', '関心')]
# --------
# ピエール瀧さんのアナとエルサのフローズンファンタジースペシャルルームという曲は、カラオケでもロングヒットとなっていて、株式会社エクシングが発表した2014年のカラオケランキングで4位にランクインされているようです。
# [('なる', 'が', '曲'), ('なる', 'で', 'カラオケ'), ('発表', 'が', 'エクシング'), ('ランクイン', 'で', 'ランキング'), ('ランクイン', 'に', '位')]
# --------
# もともとアイドルグループのAKB48については詳しくありませんが、その中でも大島優子さんの様に知っているメンバーがどんどん卒業していくので、さらに知らないアイドルグループと化しています。
# [('ある', 'に', '0'), ('ある', 'が', '0'), ('卒業', 'で', '中'), ('卒業', 'が', 'メンバー')]
# --------
# 特に資格を取得したことがないので、AKB48の国分太一がアイドルをしながら資格を取得するのはすごいと思いました。
# [('取得', 'を', '資格'), ('する', 'を', 'アイドル'), ('取得', 'が', '太一'), ('取得', 'を', '資格')]
# --------
# 岡崎慎司選手がルームウェアで、清武弘嗣選手の部屋でくつろぐ画像は見たことがありますね。
# [('くつろぐ', 'で', '部屋'), ('見る', 'が', '選手'), ('見る', 'で', 'ウェア'), ('見る', 'が', '画像')]
# --------
# 「日本に住んでいれば安全だ。」と自信を持って言える国になってほしいです。
# [('住む', 'に', '日本'), ('持つ', 'を', '自信'), ('なる', 'に', '国')]
# --------
# 日本では今や洋食や中華料理などもかなり普及している中で、和食が改めて見直される機会にもなって、私はとても良い事だと思います。
# [('普及', 'で', '日本'), ('普及', 'が', '日本'), ('見直す', 'が', '和食'), ('なる', 'で', '中'), ('なる', 'に', '機会')]
# --------
# そうです、顔にもすぐ出る方なのでやっかいです。
# [('出る', 'に', '顔')]
# --------
# 最近だと旅行にはまりだしたので、旅代で消えてしまいますね。
# [('はまる', 'に', '旅行'), ('消える', 'で', '代')]
# --------
# 親さんですか〜。お金はかかりますよね、俺はバイトでぎりぎり何とかなるかな〜って感じです。
# [('かかる', 'が', 'お金'), ('なる', 'が', '俺'), ('なる', 'で', 'バイト')]
# --------
# そうですね、でも意外と少なくて、香り付けにショウガをたくさん使います。
# [('使う', 'に', '香り付け'), ('使う', 'を', '生姜')]
# --------
# もともとソースとかスープをカレーと言うからシンプルだよね。
# [('言う', 'を', 'スープ')]
# --------
# うん、今の時期はセミがいっぱいいます
# [('いる', 'が', '時期'), ('いる', 'が', 'セミ')]
# --------
# 柳沢選手が親戚と同じ名前で親近感があります。
# [('ある', 'が', '選手'), ('ある', 'で', '名前'), ('ある', 'が', '親近感')]
# --------
# 天気がよく、暖かい日は、６０ｋｍ位走ることもありますね。
# [('走る', 'が', '日')]
# --------
# そうですね！一人でドライブする時は自分の好きな曲を流しながら走っています。
# [('ドライブ', 'で', '一人'), ('流す', 'を', '曲'), ('走る', 'が', '時')]
# --------
# そうなんですか．　牛タンを食べたことはありますか．。
# [('食べる', 'を', '牛タン'), ('食べる', 'が', 'こと')]
# --------
# 今は入っていないです。いまは高校時代の友人や、学祭の実行委員をやっていたときの友人とよく遊ぶことが多いです。
# [('入る', 'が', '今'), ('やる', 'を', '委員')]
# --------
# どこででも描けるんですかね。私はよく家で絵を描きます。
# [('描ける', 'で', 'どこ'), ('描く', 'が', '私'), ('描く', 'で', '家'), ('描く', 'を', '絵')]
# --------
# 野球とサッカーですか、どういったポジションでプレーをしていたのですか？
# [('する', 'で', 'ポジション'), ('する', 'を', 'プレー')]
# --------
# 週末に読むつもりです。
# [('読む', 'に', '週末')]
# --------
# 面白いマンガですよ。吹奏楽部にいた頃を思い出すマンガです。
# [('いる', 'に', '部'), ('思い出す', 'を', '頃')]
# --------
# スマホを使っていますか？
# [('使う', 'を', 'スマホ')]
# --------
# てことは、PCから入れるんですよね？
# [('入れる', 'が', 'こと')]
# --------
# 天気予報はみますか？
# [('みる', 'が', '天気予報')]
# --------
# 誤解を受けたという話よりも、いいたいのは
# [('受ける', 'を', '誤解')]
# --------
# 今はデジカメでもPCカメラ機能付きであれば使えるから、兼用のを買うという手もありますね。
# [('使える', 'で', 'デジカメ'), ('買う', 'を', '兼用'), ('ある', 'が', '今')]
# --------
# 柳沢選手が親戚と同じ名前で親近感があります。
# [('ある', 'が', '選手'), ('ある', 'で', '名前'), ('ある', 'が', '親近感')]
# --------
# 机の上が整理されていないとだめですね。
# [('整理', 'が', '上')]
# --------
# 描いてません。動画の編集とかはしますが
# [('する', 'が', '編集')]
# --------
# それもかなりあると思います。僕が吸い始めた頃にはかなり禁煙化が進んでいたので気を遣いながら吸いますが、何にも問題にならないまま吸ってたら煙のことまでは考えないで吸ってたかもしれないですね。
# [('吸う', 'が', '僕'), ('進む', 'に', '頃'), ('進む', 'が', '頃'), ('進む', 'が', '化'), ('遣う', 'を', '気'), ('なる', 'に', '問題'), ('考える', 'が', 'こと')]
# --------
# 言いたいことがよくわからないです
# [('わかる', 'が', 'こと')]
# --------
# 今年の夏はどこか行きましたか
# [('行く', 'が', '夏')]
# --------
# す…凄いですね。ipodに入れてビジネス英語とありますけれど、中々それだけではこの点数は出せないですよ。
# [('入れる', 'に', 'iPod'), ('出せる', 'で', 'それ'), ('出せる', 'が', 'それ'), ('出せる', 'が', '点数')]
# --------
# キリル文字っていうんですかね。ＮをＹと呼んだりして。
# [('呼ぶ', 'を', 'N')]
# --------
# 白夜行も面白いですよ！東野圭吾さんの他の本とは多少傾向が違うようですが。
# [('違う', 'が', '本'), ('違う', 'が', '傾向')]
# --------
# 他にはどんな曲を弾くの？
# [('弾く', 'に', '他'), ('弾く', 'が', '他'), ('弾く', 'を', '曲')]
# --------
# この夏は花火大会や海にお出かけになられましたか。
# [('なる', 'が', '夏'), ('なる', 'に', '海'), ('なる', 'に', 'お出掛け')]
# --------
# 同じですよ。私も先日まで会社員をしていました。
# [('する', 'を', '会社員')]
# --------
# さっきのドライブの話に戻りますけど
# [('戻る', 'に', '話')]
# --------
# いいですね〜。何を作ったんですか？
# [('作る', 'を', '何')]
# --------
# ええ、私も初めて見たときは驚きましたが、一度食べてからはやみつきになりました。
# [('驚く', 'が', '時')]
# --------
# 何を食べに行きますか
# [('食べる', 'を', '何')]
# --------
# まったく。。前に友達に教えてもらって、メッセンジャーをしたくらいでしょうか。
# [('教える', 'に', '前'), ('教える', 'に', '友達'), ('する', 'を', 'メッセンジャー')]
# --------
# なにを食べましょうね。
# [('食べる', 'を', 'なに')]
# --------
# 舞台ですか？今年見にいく予定の舞台は、映画にもなった「あずみ」と藤原竜也と市村政規出演の「ライフインザシアター」っていうやつです。
# [('なる', 'に', '映画')]
# --------
# 机の上が整理されていないとだめですね。
# [('整理', 'が', '上')]
# --------
# では、あなたはいつも家では何をしてますか？
# [('する', 'が', 'あなた'), ('する', 'で', '家'), ('する', 'が', '家'), ('する', 'を', '何')]
# --------
# てことは、PCから入れるんですよね？
# [('入れる', 'が', 'こと')]
# --------
# お気に入りの一枚を撮ると、言葉とか自然に浮かんできますよね。
# [('撮る', 'を', '枚')]
# --------
# 最後に、マンガでプロになろうと思ってます？
# [('なる', 'に', 'プロ'), ('思う', 'に', '最後'), ('思う', 'で', '漫画')]
# --------
# お気に入りの一枚を撮ると、言葉とか自然に浮かんできますよね。
# [('撮る', 'を', '枚')]
# --------
# でもどんな服を着ていくとかは事前に言いましたよ。
# [('着る', 'を', '服'), ('言う', 'に', '事前')]
# --------
# このときは結構特殊で、知り合いじゃないけど実際お互いに見たことはあるという関係だったんです。
# [('見る', 'に', '互い')]
# --------
# ドライブ以外にも、ビリヤードに行かれるそうですが。
# [('行く', 'に', '以外'), ('行く', 'に', 'ビリヤード')]
# --------
# 今までどこに旅行しましたか？
# [('旅行', 'に', 'どこ')]
# --------
# 中学高校の頃、雨になると傘さし運転してると補導員みたいな人に注意されて学校に通報されちゃうって言う事があったので、学校指定のカッパを装備して学校までの道のり約11Kmを走ってたんですよね…　これがもう蒸し暑くて仕様が無かったですね。
# [('なる', 'に', '雨'), ('注意', 'に', '人'), ('通報', 'に', '学校'), ('ある', 'が', '事'), ('装備', 'を', 'かっぱ'), ('走る', 'を', 'km')]
# --------
# はい。話は変わりますが、高校の履修漏れがなくてよかったですね。
# [('変わる', 'が', '話')]
# --------
# へぇ〜。髪型とか表情とか洋服とか角度が場面ごとに同じように描くのは難しくないんですか？
# [('描く', 'が', '角度'), ('描く', 'に', 'ごと')]
# --------
# おかげで気づいたら漫画の本だけでもすでに部屋に１０００冊以上（２０００行ってるかな？）になってしまっています。
# [('気づく', 'で', '御陰'), ('なる', 'に', '部屋'), ('なる', 'に', '以上')]
# --------
# クーラーがきいてるの？
# [('きく', 'が', 'クーラー')]
# --------
# 週末に読むつもりです。
# [('読む', 'に', '週末')]
# --------
# 机の上が整理されていないとだめですね。
# [('整理', 'が', '上')]
# --------
# 似てる、私と。ちなみに足の踏み場は確保してます？
# [('確保', 'が', '踏み場')]
# --------
# 話す余裕がなくなるくらい忙しい時もあるんですか？
# [('なくなる', 'が', '余裕')]
# --------
# 友達同士で忘年会とかしたりします？
# [('する', 'で', '同士')]
# --------
# では、家では何をしているんですか？
# [('する', 'で', '家'), ('する', 'が', '家'), ('する', 'を', '何')]
# --------
# どうして、ベースにしたのですか？
# [('する', 'に', 'ベース')]
# --------
# う〜ん、パスタの上にハンバーグがのっててその上にシチューをかけるという斬新なものでした。
# [('のる', 'に', '上'), ('のる', 'が', 'ハンバーグ'), ('かける', 'に', '上'), ('かける', 'を', 'シチュー')]
# --------
# 下宿する前は家事の手伝いすらろくにしてなかったんですよ。
# [('する', 'が', '前')]
# --------
# 机の上が整理されていないとだめですね。
# [('整理', 'が', '上')]
# --------
# 私は、目覚ましは携帯を利用していますね。
# [('利用', 'が', '私'), ('利用', 'が', '目覚まし'), ('利用', 'を', '携帯')]
# --------
# 一年目って言っても、学部時代に４年過ごしてるから、あんまり新鮮味はないかも。
# [('過ごす', 'に', '時代')]
# --------
# つい最近初めて携帯で買い物しましたよ。
# [('買い物', 'で', '携帯')]
# --------
# 机の上が整理されていないとだめですね。
# [('整理', 'が', '上')]
# --------
# 美味しいかき氷とお好み焼きがあって幸せでした。
# [('ある', 'が', 'お好み焼き')]
# --------
# ホントはもっと色々な事を聞かなきゃいけないんでしょうけど・・・。
# [('聞く', 'が', '本当'), ('聞く', 'を', '事')]
# --------
# そのモードのなれば意外と早かったり、テーマがあれば言葉も出てきやすいですけど、。
# [('ある', 'が', 'テーマ')]
# --------
# 今年の夏はどこか行きましたか
# [('行く', 'が', '夏')]
# --------
# 飼ってみたら猫好きになりました
# [('なる', 'に', '猫好き')]
# --------
# とはいっても、ペペロンチーノは辛い部類に入るんですが・・・。
# [('入る', 'が', 'ペペロンチーノ'), ('入る', 'に', '部類')]
# --------
# からあげ、私も大須に行くたびに食べているような気がします。
# [('行く', 'に', '大須'), ('食べる', 'に', '度'), ('する', 'が', '気')]
# --------
# 今回のもかなりよかったんですよね〜、でも前回、えっとどこでしたっけ、時代絵巻みたいな開会式のアトラクションがあったのは。
# [('ある', 'が', 'アトラクション')]
# --------
# いいえ、お弁当を持ってきて院生室で食べました。
# [('持つ', 'を', '弁当'), ('食べる', 'で', '室')]
# --------
# 机の上が整理されていないとだめですね。
# [('整理', 'が', '上')]
# --------
# ありがとうございます、オリンピックは予選くらいしか見られませんね。
# [('見る', 'が', 'オリンピック')]
# --------
# 日本人選手などはニュースでもやりますしね。
# [('やる', 'が', '選手'), ('やる', 'で', 'ニュース')]
# --------
# あなたの家はどこにありますか？
# [('ある', 'が', '家'), ('ある', 'に', 'どこ')]
# --------
# でもあんなんがあったと思うとちょっと気持ち悪いです。
# [('ある', 'が', 'あんなん')]
# --------
# 曖昧な情報ですみません。
# [('すむ', 'で', '情報')]
# --------
# 大学の研究室でたまに麻雀をやるのですが、運だけだとぼろ負けしてしまいそうなので必死で考えてやってます。
# [('やる', 'で', '研究室'), ('やる', 'を', 'マージャン')]
# --------
# 頭はどうか分かりませんが、自己組織化というのは、物質でも生き物でも社会でも、自律的にパターンを形成する現象のことです。
# [('分かる', 'が', '頭'), ('形成', 'に', '自律的'), ('形成', 'を', 'パターン')]
# --------
# ずっと洋書を読んで研究されてきたならばその分野できっとご活躍されることでしょう。
# [('読む', 'を', '洋書'), ('活躍', 'で', '分野')]
# --------
# てことは、PCから入れるんですよね？
# [('入れる', 'が', 'こと')]
# --------
# 人類に一人だけ残されたら・・・・子孫も残せないわけだからあまり生きてても意味がないような気がするんですけど。
# [('残す', 'に', '人類'), ('する', 'が', '気')]
# --------
# そうですね、人とわいわいやるのも嫌いではないのですが、私はどちらかというと一人で何かに集中することのほうが好きなので、漫画もその一つです。
# [('集中', 'に', '何')]
# --------
# 車でってことは、遠くに行くんですよね。
# [('行く', 'が', 'こと'), ('行く', 'に', '遠く')]
# --------
# 去年香嵐渓に紅葉見に行きましたよ！でも平日にいったのにすごい渋滞で・・・。
# [('行く', 'に', '渓'), ('いく', 'に', '平日')]
# --------
# 宇宙に行きたいです。あと流れ星に乗りたい。
# [('行く', 'に', '宇宙'), ('乗る', 'に', '流れ星')]
# --------
# そういうことになるんですかね？　自分としては、やっぱりまだまだ自覚が足りないような気がしています。
# [('足りる', 'が', '自覚'), ('する', 'が', '自分'), ('する', 'が', '気')]
# --------
# へ〜、お店に買いに行く必要がないですね。
# [('買う', 'に', '御店')]
# --------
# ＵＳＪも行く予定ですよ！そうなんですか！年始は名古屋にいるし、年始に行こうかな。
# [('いる', 'が', '年始'), ('いる', 'に', '名古屋'), ('行く', 'に', '年始')]
# --------
# 昔捨てられなかった雑誌が２００冊ほどあり一気に廃品回収に出したら腰を痛めました。
# [('ある', 'が', '雑誌'), ('出す', 'に', '一気'), ('出す', 'に', '回収'), ('痛める', 'を', '腰')]
# --------
# では、スポーツは何かしてますか？
# [('する', 'が', 'スポーツ')]
# --------
# 最近はテニスをするということですが、テニスが一番得意なんですか？
# [('する', 'が', '最近'), ('する', 'を', 'テニス')]
# --------
# ちょうどウクライナに行ったときに、周辺国をまわったので結構いきましたよ。
# [('行く', 'に', 'ウクライナ'), ('まわる', 'に', '時'), ('まわる', 'を', '周辺国')]
# --------
# はい、そうです。そちらは専門学校へ通ってらっしゃるんですよね？
# [('通う', 'が', 'そちら')]
# --------
# でも、＋−で同じ星の人とは大さっかいの時期が違うだけで性格（？）上は変わらないそうです。
# [('違う', 'が', '時期'), ('変わる', 'が', '上')]
# --------
# 最近は株式について勉強しています。
# [('勉強', 'が', '最近'), ('勉強', 'に', '株式')]
# --------
# ２０歳に見えます
# [('見える', 'に', '歳')]
# --------
# はい。私の通っているスポーツクラブは、以前は小さなお風呂とシャワー室があったのですが、。
# [('ある', 'が', 'クラブ'), ('ある', 'が', '以前'), ('ある', 'が', 'シャワー室')]
# --------
# 夢がある人、追いかけてる人、すうサンみたいにかなう人…かっこいいと思います！！!
# [('ある', 'が', '夢')]
# --------
# それは大変そう！私も高校時代だけバス通学をしていましたが、押されて流されて身動きが取れませんでした。
# [('する', 'を', '通学'), ('取れる', 'が', '身動き')]
# --------
# アイアムレジェンドを見てきましたよ。
# [('見る', 'を', 'アイアムレジェンド')]
# --------
# 海外のサイトを利用したりしますか？
# [('利用', 'を', 'サイト')]
# --------
# すみません。嘘でした。ゼミに外国人いました。
# [('いる', 'に', 'ゼミ')]
# --------
# 誰かと一緒にみます。観てくれるかな・・
# [('みる', 'に', '一緒')]
# --------
# ドラマはあまり見ないんですが、さんまのやつ見ました。
# [('見る', 'が', 'ドラマ')]
# --------
# お肉関係が美味しいお店で、確かちょっと前にテレビにも出ていたはずなんですが、名前が思い出せない、というか覚えていた記憶がないです。
# [('出る', 'に', '前'), ('出る', 'に', 'テレビ'), ('思い出せる', 'が', '名前')]
# --------
# 夢がある人、追いかけてる人、すうサンみたいにかなう人…かっこいいと思います！！!
# [('ある', 'が', '夢')]
# --------
# どうして、ベースにしたのですか？
# [('する', 'に', 'ベース')]
# --------
# それが、広く浅くありすぎて、よく聞かれて困るんですよ。
# [('聞く', 'が', 'それ')]
# --------
# でもきっと写真屋さんで育たれたのなら”良い写真”というのがわかっているから、普通の人が撮ろうとする写真とは構図とか違うんじゃないですか？
# [('育つ', 'で', 'さん'), ('する', 'が', '人'), ('違う', 'が', '写真')]
# --------
# ってデジカメはもとから小さいのでは？空を見れてる時って心に余裕ができたときなんですよね。
# [('見れる', 'を', '空'), ('できる', 'に', '心'), ('できる', 'が', '余裕')]
# --------
# いいですよねー。ただ、今期間限定で出ている、沖縄ラーメンは個人的にはイマイチでした…；。
# [('出る', 'で', '限定')]
# --------
# まったく。。前に友達に教えてもらって、メッセンジャーをしたくらいでしょうか。
# [('教える', 'に', '前'), ('教える', 'に', '友達'), ('する', 'を', 'メッセンジャー')]
# --------
# 子供の習い事の送迎に親がついて行かないといてないのですよ。
# [('つく', 'が', '親'), ('行く', 'に', '送迎')]
# --------
# 俺も今は行ってないよ。けど、春休み昼間とか暇なんで行きたい気分っすね!
# [('行く', 'が', '今')]
# --------
# 趣味に映画鑑賞とありましたが、最近何か観ましたか？
# [('ある', 'に', '趣味')]
# --------
# 机の上が整理されていないとだめですね。
# [('整理', 'が', '上')]
# --------
# 似てる、私と。ちなみに足の踏み場は確保してます？
# [('確保', 'が', '踏み場')]
# --------
# 机の上が整理されていないとだめですね。
# [('整理', 'が', '上')]
# --------
# 似てる、私と。ちなみに足の踏み場は確保してます？
# [('確保', 'が', '踏み場')]
# --------
# いいですね〜。何を作ったんですか？
# [('作る', 'を', '何')]
# --------
# １０年前に行方不明になった飛行機が突然現れて、乗っていた人たちにとっては、１０年経っていなくて・・・つまり、１０年後に来てしまったんです。
# [('なる', 'に', '前'), ('なる', 'に', '行方不明'), ('現れる', 'が', '飛行機'), ('経つ', 'に', 'たち'), ('経つ', 'が', 'たち'), ('来る', 'に', '後')]
# --------

# %%
t = "人たち"
from spacy import displacy
displacy.render(nlp(t), style='dep', jupyter=True, options={'compact':True, 'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ja" id="c1c5215c54414811a896f158104e76be-0" class="displacy" width="230" height="182.0" direction="ltr" style="max-width: none; height: 182.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="92.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">人</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="92.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">たち</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c1c5215c54414811a896f158104e76be-0-0" stroke-width="2px" d="M62,47.0 62,32.0 140.0,32.0 140.0,47.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c1c5215c54414811a896f158104e76be-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,49.0 L58,41.0 66,41.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
def compound_noun(token):
    base = token.lemma_
    for child in token.children:
        if child.dep_ == "compound":
            return child.lemma_ + base
